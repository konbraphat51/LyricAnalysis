# %% [markdown]
# # Lyrics Analysis

# %%
lyrics_directory = "Lyrics_Data/"
tracks_csv = "tracks_group.csv"
stopwords_file = "stopwords.txt"

# %%
target_group = "itzy"
kpop_group = set(['kpop', 'itzy', 'seventeen', 'bts', 'twice'])
global_group = set(['global', 'billboard'])

target_and_kpop = kpop_group.union(set([target_group]))
target_and_global = global_group.union(set([target_group]))

# %% [markdown]
# ## Import data

# %%
import pandas as pd

# %%
df = pd.read_csv(tracks_csv)

df.head(3)
# Out:
#                       track_name                track_id grouping
# 0  Ice Cream (with Selena Gomez)  2J4P46vCFm1rPkNkp9pZWX     kpop
# 1                       Dynamite  0v1x6rN6JHRapa03JElljE     kpop
# 2                    THE BADDEST  2V4Fx72svQRxrFvNT1eq5f     kpop

# %%
df.shape
# Out:
# (4618, 3)

# %%
df["grouping"].unique()
# Out:
# array(['kpop', 'itzy', 'seventeen', 'bts', 'twice', 'global', 'billboard'],
#       dtype=object)

# %%
def get_lyrics(track_id):
    try:
        lyrics = ""
        with open(lyrics_directory + track_id + ".txt", "r") as f:
            lyrics = f.read()
            
        return lyrics            
    except:
        return None
    
df["lyrics"] = df["track_id"].apply(get_lyrics)

df.shape
# Out:
# (4618, 4)

# %%
# stop words
# https://www.kaggle.com/datasets/rowhitswami/stopwords/
stopwords = set()
with open(stopwords_file, "r") as f:
    stopwords = set(f.read().split("\n"))
    
stopwords
# Out:
# {',',
#  '>',
#  '?',
#  'Just',
#  'Yes',
#  'a',
#  'abaft',
#  'abafter',
#  'abaftest',
#  'about',
#  'abouter',
#  'aboutest',
#  'above',
#  'abover',
#  'abovest',
#  'accordingly',
#  'aer',
#  'aest',
#  'afore',
#  'after',
#  'afterer',
#  'afterest',
#  'afterward',
#  'afterwards',
#  'again',
#  'against',
#  'aid',
#  'ain',
#  'albeit',
#  'all',
#  'aller',
#  'allest',
#  'alls',
#  'allyou',
#  'almost',
#  'along',
#  'alongside',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amid',
#  'amidst',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'andor',
#  'anear',
#  'anent',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anywhere',
#  'apart',
#  'aparter',
#  'apartest',
#  'appear',
#  'appeared',
#  'appearing',
#  'appears',
#  'appropriate',
#  'appropriated',
#  'appropriater',
#  'appropriates',
#  'appropriatest',
#  'appropriating',
#  'are',
#  'ares',
#  'around',
#  'as',
#  'ases',
#  'aside',
#  'asides',
#  'aslant',
#  'astraddle',
#  'astraddler',
#  'astraddlest',
#  'astride',
#  'astrider',
#  'astridest',
#  'at',
#  'athwart',
#  'atop',
#  'atween',
#  'aught',
#  'aughts',
#  'available',
#  'availabler',
#  'availablest',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'becominger',
#  'becomingest',
#  'becomings',
#  'been',
#  'before',
#  'beforehand',
#  'beforehander',
#  'beforehandest',
#  'behind',
#  'behinds',
#  'below',
#  'beneath',
#  'beside',
#  'besides',
#  'better',
#  'bettered',
#  'bettering',
#  'betters',
#  'between',
#  'betwixt',
#  'beyond',
#  'bist',
#  'both',
#  'but',
#  'buts',
#  'by',
#  'by-and-by',
#  'byandby',
#  'c',
#  'can',
#  'cannot',
#  'canst',
#  'cant',
#  'canted',
#  'cantest',
#  'canting',
#  'cants',
#  'cer',
#  'certain',
#  'certainer',
#  'certainest',
#  'cest',
#  'chez',
#  'circa',
#  'co',
#  'come',
#  'come-on',
#  'come-ons',
#  'comeon',
#  'comeons',
#  'concerning',
#  'concerninger',
#  'concerningest',
#  'consequently',
#  'considering',
#  'could',
#  'couldst',
#  'cum',
#  'd',
#  'da',
#  'day',
#  'dday',
#  'ddays',
#  'describe',
#  'described',
#  'describes',
#  'describing',
#  'despite',
#  'despited',
#  'despites',
#  'despiting',
#  'did',
#  'different',
#  'differenter',
#  'differentest',
#  'do',
#  'doe',
#  'does',
#  'doing',
#  'doings',
#  'don',
#  "don't",
#  'done',
#  'doner',
#  'dones',
#  'donest',
#  'dos',
#  'dost',
#  'doth',
#  'downs',
#  'downward',
#  'downwarder',
#  'downwardest',
#  'downwards',
#  'du',
#  'during',
#  'e',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'ere',
#  'et',
#  'etc',
#  'even',
#  'evened',
#  'evenest',
#  'evens',
#  'evenser',
#  'evensest',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'except',
#  'excepted',
#  'excepting',
#  'excepts',
#  'exes',
#  'f',
#  'fact',
#  'facts',
#  'failing',
#  'failings',
#  'few',
#  'fewer',
#  'fewest',
#  'figupon',
#  'figuponed',
#  'figuponing',
#  'figupons',
#  'five',
#  'followthrough',
#  'for',
#  'forby',
#  'forbye',
#  'fore',
#  'forer',
#  'fores',
#  'forever',
#  'former',
#  'formerer',
#  'formerest',
#  'formerly',
#  'formers',
#  'fornenst',
#  'forwhy',
#  'four',
#  'fourscore',
#  'frae',
#  'from',
#  'fs',
#  'further',
#  'furthered',
#  'furtherer',
#  'furtherest',
#  'furthering',
#  'furthermore',
#  'furthers',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'go',
#  'going',
#  'gone',
#  'good',
#  'got',
#  'gotta',
#  'gotten',
#  'h',
#  'had',
#  'hadst',
#  'hae',
#  'hardly',
#  'has',
#  'hast',
#  'hath',
#  'have',
#  'haves',
#  'having',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereafters',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hey',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hitherer',
#  'hitherest',
#  'hoo',
#  'hoos',
#  'how',
#  'how-do-you-do',
#  'howbeit',
#  'howdoyoudo',
#  'however',
#  'hr',
#  'huh',
#  'humph',
#  'i',
#  "i'll",
#  "i'm",
#  'idem',
#  'idemer',
#  'idemest',
#  'ie',
#  'if',
#  'ifs',
#  'immediate',
#  'immediately',
#  'immediater',
#  'immediatest',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'indicating',
#  'info',
#  'information',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'inwarder',
#  'inwardest',
#  'inwards',
#  'is',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'know',
#  'l',
#  'la',
#  'latter',
#  'latterer',
#  'latterest',
#  'latterly',
#  'latters',
#  'layabout',
#  'layabouts',
#  'less',
#  'lest',
#  'like',
#  'll',
#  'look',
#  'lot',
#  'lots',
#  'lotted',
#  'lotting',
#  'm',
#  'main',
#  'make',
#  'many',
#  'mauger',
#  'maugre',
#  'mayest',
#  'me',
#  'meanwhile',
#  'meanwhiles',
#  'midst',
#  'midsts',
#  'might',
#  'mights',
#  'mm',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'mucher',
#  'muchest',
#  'must',
#  'musth',
#  'musths',
#  'musts',
#  'my',
#  'myself',
#  'n',
#  'na',
#  'natheless',
#  'nathless',
#  'neath',
#  'neaths',
#  'necessarier',
#  'necessariest',
#  'necessary',
#  'neither',
#  'nethe',
#  'nethermost',
#  'never',
#  'nevertheless',
#  'nigh',
#  'nigher',
#  'nighest',
#  'nine',
#  'no',
#  'no-one',
#  'nobodies',
#  'nobody',
#  'noes',
#  'none',
#  'noone',
#  'nor',
#  'nos',
#  'not',
#  'nothing',
#  'nothings',
#  'notwithstanding',
#  'now',
#  'nowhere',
#  'nowheres',
#  'o',
#  'of',
#  'off',
#  'offest',
#  'offs',
#  'often',
#  'oftener',
#  'oftenest',
#  'oh',
#  'on',
#  'one',
#  'oneself',
#  'onest',
#  'ons',
#  'onto',
#  'or',
#  'orer',
#  'orest',
#  'other',
#  'others',
#  'otherwise',
#  'otherwiser',
#  'otherwisest',
#  'ought',
#  'oughts',
#  'our',
#  'ours',
#  'ourself',
#  'ourselves',
#  'out',
#  'outed',
#  'outest',
#  'outs',
#  'outside',
#  'outwith',
#  'over',
#  'overall',
#  'overaller',
#  'overallest',
#  'overalls',
#  'overs',
#  'own',
#  'owned',
#  'owning',
#  'owns',
#  'owt',
#  'p',
#  'particular',
#  'particularer',
#  'particularest',
#  'particularly',
#  'particulars',
#  'per',
#  'perhaps',
#  'plaintiff',
#  'please',
#  'pleased',
#  'pleases',
#  'plenties',
#  'plenty',
#  'pro',
#  'probably',
#  'provide',
#  'provided',
#  'provides',
#  'providing',
#  'q',
#  'qua',
#  'que',
#  'quite',
#  'r',
#  'rath',
#  'rathe',
#  'rather',
#  'rathest',
#  're',
#  'really',
#  'regarding',
#  'relate',
#  'related',
#  'relatively',
#  'res',
#  'respecting',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'saider',
#  'saidest',
#  'same',
#  'samer',
#  'sames',
#  'samest',
#  'sans',
#  'sanserif',
#  'sanserifs',
#  'sanses',
#  'saved',
#  'sayid',
#  'sayyid',
#  'see',
#  'seem',
#  'seemed',
#  'seeminger',
#  'seemingest',
#  'seemings',
#  'seems',
#  'send',
#  'sent',
#  'senza',
#  'serious',
#  'seriouser',
#  'seriousest',
#  'seven',
#  'several',
#  'severaler',
#  'severalest',
#  'shall',
#  'shalled',
#  'shalling',
#  'shalls',
#  'she',
#  'should',
#  'shoulded',
#  'shoulding',
#  'shoulds',
#  'since',
#  'sine',
#  'sines',
#  'sith',
#  'six',
#  'so',
#  'sobeit',
#  'soer',
#  'soest',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimer',
#  'sometimes',
#  'sometimest',
#  'somewhat',
#  'somewhere',
#  'stop',
#  'stopped',
#  'such',
#  'summat',
#  'sup',
#  'supped',
#  'supping',
#  'sups',
#  'syn',
#  'syne',
#  't',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'thee',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'thener',
#  'thenest',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'therer',
#  'therest',
#  'thereupon',
#  'these',
#  'they',
#  'thine',
#  'thing',
#  'things',
#  'this',
#  'thises',
#  'thorough',
#  'thorougher',
#  'thoroughest',
#  'thoroughly',
#  'those',
#  'thou',
#  'though',
#  'thous',
#  'thouses',
#  'three',
#  'thro',
#  'through',
#  'througher',
#  'throughest',
#  'throughout',
#  'thru',
#  'thruer',
#  'thruest',
#  'thus',
#  'thy',
#  'thyself',
#  'till',
#  'tilled',
#  'tilling',
#  'tills',
#  'time',
#  'to',
#  'together',
#  'too',
#  'toward',
#  'towarder',
#  'towardest',
#  'towards',
#  'two',
#  'u',
#  'umpteen',
#  'under',
#  'underneath',
#  'unless',
#  'unlike',
#  'unliker',
#  'unlikest',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'uponed',
#  'uponing',
#  'upons',
#  'upped',
#  'upping',
#  'ups',
#  'us',
#  'use',
#  'used',
#  'usedest',
#  'username',
#  'usually',
#  'v',
#  'various',
#  'variouser',
#  'variousest',
#  'verier',
#  'veriest',
#  'versus',
#  'very',
#  'via',
#  'vis-a-vis',
#  'vis-a-viser',
#  'vis-a-visest',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'was',
#  'wast',
#  'we',
#  'were',
#  'wert',
#  'what',
#  'whatever',
#  'whateverer',
#  'whateverest',
#  'whatsoever',
#  'whatsoeverer',
#  'whatsoeverest',
#  'wheen',
#  'when',
#  'whenas',
#  'whence',
#  'whencesoever',
#  'whenever',
#  'whensoever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherefrom',
#  'wherein',
#  'whereinto',
#  'whereof',
#  'whereon',
#  'wheresoever',
#  'whereto',
#  'whereupon',
#  'wherever',
#  'wherewith',
#  'wherewithal',
#  'whether',
#  'which',
#  'whichever',
#  'whichsoever',
#  'while',
#  'whiles',
#  'whilst',
#  'whither',
#  'whithersoever',
#  'who',
#  'whoever',
#  'whomever',
#  'whose',
#  'whoso',
#  'whosoever',
#  'why',
#  'will',
#  'with',
#  'withal',
#  'within',
#  'without',
#  'would',
#  'woulded',
#  'woulding',
#  'woulds',
#  'x',
#  'y',
#  'ye',
#  'yeah',
#  'yet',
#  'yon',
#  'yond',
#  'yonder',
#  'you',
#  "you're",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zillion',
#  'ð',
#  '♪',
#  '♫'}

# %% [markdown]
# ## Analyze

# %%
def is_stopword(word):
    word = word.lower()
    
    if len(word) <= 1:
        return True
    
    # in the list
    if word in stopwords:
        return True
    
    # is Korean
    if ord("가") <= ord(word[0]) <= ord("힣"):
        return True
    
    return False

# %% [markdown]
# ### Characteristic Keyword
# Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #### Among global

# %%
df_looking = df[df["grouping"].isin(target_and_global)].reset_index(drop=True)

# %%
vectorizer = TfidfVectorizer(stop_words=list(stopwords), max_features=1000, min_df=10)

x = vectorizer.fit_transform(df_looking["lyrics"].fillna("")).toarray()

df_tfidf = pd.DataFrame(x, columns=vectorizer.get_feature_names_out()).T
# Out:
# c:\Users\Hiyoko\.conda\envs\data\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['vis', 'viser', 'visest', 'yes'] not in stop_words.
#   warnings.warn(

# %%
threshold = 0.001
counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    tfidf_series = df_tfidf[cnt]
    
    keywords = tfidf_series[tfidf_series > threshold].index.tolist()
    for keyword in keywords:
        counter[keyword] = counter.get(keyword, 0) + 1
        summer[keyword] = summer.get(keyword, 0) + float(tfidf_series[keyword])

# %%
def sort_dictionary(dictionary):
    return [(k, dictionary[k]) for k in sorted(dictionary, key=dictionary.get, reverse=True)]

# %%
tfidf_counter_global = sort_dictionary(counter)
tfidf_counter_global
# Out:
# [('sorry', 23),
#  ('love', 22),
#  ('mind', 22),
#  ('yes', 21),
#  ('let', 20),
#  ('say', 19),
#  ('tell', 14),
#  ('feel', 14),
#  ('baby', 13),
#  ('down', 13),
#  ('heart', 13),
#  ('keep', 13),
#  ('take', 12),
#  ('care', 12),
#  ('back', 12),
#  ('bad', 11),
#  ('eyes', 11),
#  ('matter', 11),
#  ('crazy', 11),
#  ('think', 11),
#  ('show', 10),
#  ('control', 10),
#  ('need', 10),
#  ('room', 10),
#  ('ah', 10),
#  ('am', 9),
#  ('turn', 9),
#  ('put', 9),
#  ('little', 9),
#  ('forget', 9),
#  ('way', 9),
#  ('home', 9),
#  ('only', 8),
#  ('hear', 8),
#  ('coming', 8),
#  ('girl', 8),
#  ('game', 8),
#  ('doesn', 7),
#  ('face', 7),
#  ('honey', 7),
#  ('ready', 7),
#  ('break', 7),
#  ('dance', 7),
#  ('worry', 7),
#  ('okay', 7),
#  ('stay', 7),
#  ('follow', 7),
#  ('play', 7),
#  ('head', 7),
#  ('high', 7),
#  ('hit', 7),
#  ('light', 7),
#  ('world', 7),
#  ('cuz', 6),
#  ('give', 6),
#  ('child', 6),
#  ('fight', 6),
#  ('kill', 6),
#  ('feeling', 6),
#  ('uh', 6),
#  ('boy', 6),
#  ('didn', 6),
#  ('start', 6),
#  ('still', 6),
#  ('top', 6),
#  ('new', 6),
#  ('free', 6),
#  ('end', 6),
#  ('lost', 6),
#  ('life', 6),
#  ('city', 6),
#  ('fly', 6),
#  ('words', 6),
#  ('won', 6),
#  ('trust', 6),
#  ('bring', 6),
#  ('call', 5),
#  ('leave', 5),
#  ('well', 5),
#  ('woo', 5),
#  ('cool', 5),
#  ('best', 5),
#  ('read', 5),
#  ('run', 5),
#  ('told', 5),
#  ('hard', 5),
#  ('shut', 5),
#  ('sweet', 5),
#  ('ve', 5),
#  ('people', 5),
#  ('talking', 5),
#  ('sing', 5),
#  ('tomorrow', 5),
#  ('open', 5),
#  ('wow', 5),
#  ('stronger', 5),
#  ('listen', 5),
#  ('wait', 5),
#  ('step', 5),
#  ('tonight', 5),
#  ('night', 5),
#  ('side', 5),
#  ('fire', 5),
#  ('burn', 5),
#  ('business', 4),
#  ('imma', 4),
#  ('man', 4),
#  ('live', 4),
#  ('weird', 4),
#  ('days', 4),
#  ('dreaming', 4),
#  ('sick', 4),
#  ('sleep', 4),
#  ('wake', 4),
#  ('choice', 4),
#  ('cry', 4),
#  ('made', 4),
#  ('miss', 4),
#  ('mean', 4),
#  ('style', 4),
#  ('pop', 4),
#  ('warm', 4),
#  ('hold', 4),
#  ('hot', 4),
#  ('rock', 4),
#  ('wish', 4),
#  ('blow', 4),
#  ('faster', 4),
#  ('lose', 4),
#  ('focus', 4),
#  ('hands', 4),
#  ('mine', 4),
#  ('problem', 4),
#  ('alone', 4),
#  ('clear', 4),
#  ('choose', 4),
#  ('faith', 4),
#  ('ride', 4),
#  ('type', 4),
#  ('doubt', 4),
#  ('burns', 4),
#  ('away', 4),
#  ('beat', 3),
#  ('big', 3),
#  ('hate', 3),
#  ('touch', 3),
#  ('finally', 3),
#  ('guess', 3),
#  ('loves', 3),
#  ('fine', 3),
#  ('late', 3),
#  ('taking', 3),
#  ('anymore', 3),
#  ('babe', 3),
#  ('next', 3),
#  ('phone', 3),
#  ('sit', 3),
#  ('20', 3),
#  ('dream', 3),
#  ('list', 3),
#  ('ooh', 3),
#  ('move', 3),
#  ('em', 3),
#  ('fault', 3),
#  ('leaving', 3),
#  ('party', 3),
#  ('afraid', 3),
#  ('doctor', 3),
#  ('living', 3),
#  ('lying', 3),
#  ('mess', 3),
#  ('problems', 3),
#  ('trying', 3),
#  ('story', 3),
#  ('excuse', 3),
#  ('fall', 3),
#  ('friends', 3),
#  ('gonna', 3),
#  ('mirror', 3),
#  ('red', 3),
#  ('thinking', 3),
#  ('voice', 3),
#  ('funny', 3),
#  ('pass', 3),
#  ('body', 3),
#  ('fresh', 3),
#  ('queen', 3),
#  ('ask', 3),
#  ('wrong', 3),
#  ('guy', 3),
#  ('loud', 3),
#  ('real', 3),
#  ('strong', 3),
#  ('waiting', 3),
#  ('feet', 3),
#  ('walking', 3),
#  ('flow', 3),
#  ('shake', 3),
#  ('being', 3),
#  ('change', 3),
#  ('finish', 3),
#  ('old', 3),
#  ('dreams', 3),
#  ('thank', 3),
#  ('hope', 3),
#  ('last', 3),
#  ('fighting', 3),
#  ('true', 3),
#  ('boom', 3),
#  ('straight', 3),
#  ('track', 3),
#  ('fear', 3),
#  ('tie', 3),
#  ('lonely', 3),
#  ('lord', 3),
#  ('shows', 3),
#  ('beauty', 3),
#  ('eat', 3),
#  ('future', 3),
#  ('believe', 3),
#  ('act', 2),
#  ('couple', 2),
#  ('drop', 2),
#  ('likes', 2),
#  ('shy', 2),
#  ('born', 2),
#  ('yellow', 2),
#  ('ayy', 2),
#  ('youth', 2),
#  ('fool', 2),
#  ('pretty', 2),
#  ('calls', 2),
#  ('learn', 2),
#  ('hi', 2),
#  ('inside', 2),
#  ('may', 2),
#  ('name', 2),
#  ('chi', 2),
#  ('fill', 2),
#  ('weight', 2),
#  ('bed', 2),
#  ('blame', 2),
#  ('boys', 2),
#  ('calling', 2),
#  ('guys', 2),
#  ('kid', 2),
#  ('lies', 2),
#  ('mom', 2),
#  ('raise', 2),
#  ('tried', 2),
#  ('wonder', 2),
#  ('crowd', 2),
#  ('diamond', 2),
#  ('second', 2),
#  ('sun', 2),
#  ('wants', 2),
#  ('road', 2),
#  ('hello', 2),
#  ('piece', 2),
#  ('god', 2),
#  ('chance', 2),
#  ('24', 2),
#  ('hours', 2),
#  ('mama', 2),
#  ('false', 2),
#  ('girls', 2),
#  ('slow', 2),
#  ('close', 2),
#  ('long', 2),
#  ('find', 2),
#  ('pride', 2),
#  ('boss', 2),
#  ('check', 2),
#  ('ta', 2),
#  ('cause', 2),
#  ('haters', 2),
#  ('lower', 2),
#  ('caught', 2),
#  ('full', 2),
#  ('gave', 2),
#  ('today', 2),
#  ('limit', 2),
#  ('beautiful', 2),
#  ('happen', 2),
#  ('morning', 2),
#  ('moves', 2),
#  ('rain', 2),
#  ('went', 2),
#  ('bang', 2),
#  ('noise', 2),
#  ('view', 2),
#  ('blowing', 2),
#  ('calm', 2),
#  ('damn', 2),
#  ('heat', 2),
#  ('speed', 2),
#  ('lights', 2),
#  ('mistake', 2),
#  ('yesterday', 2),
#  ('win', 2),
#  ('trouble', 2),
#  ('nights', 2),
#  ('flower', 2),
#  ('line', 2),
#  ('box', 1),
#  ('wood', 1),
#  ('job', 1),
#  ('atmosphere', 1),
#  ('driving', 1),
#  ('message', 1),
#  ('ring', 1),
#  ('understand', 1),
#  ('celebrate', 1),
#  ('die', 1),
#  ('dry', 1),
#  ('number', 1),
#  ('twenty', 1),
#  ('stupid', 1),
#  ('feelings', 1),
#  ('felt', 1),
#  ('friend', 1),
#  ('help', 1),
#  ('hollywood', 1),
#  ('mother', 1),
#  ('places', 1),
#  ('reason', 1),
#  ('whoa', 1),
#  ('screaming', 1),
#  ('summer', 1),
#  ('bust', 1),
#  ('continue', 1),
#  ('killed', 1),
#  ('oooh', 1),
#  ('pa', 1),
#  ('bounce', 1),
#  ('eh', 1),
#  ('diamonds', 1),
#  ('special', 1),
#  ('try', 1),
#  ('double', 1),
#  ('hop', 1),
#  ('yo', 1),
#  ('continues', 1),
#  ('great', 1),
#  ('heard', 1),
#  ('hide', 1),
#  ('sea', 1),
#  ('wave', 1),
#  ('worried', 1),
#  ('bye', 1),
#  ('part', 1),
#  ('wanted', 1),
#  ('waste', 1),
#  ('word', 1),
#  ('beats', 1),
#  ('breathe', 1),
#  ('freedom', 1),
#  ('guide', 1),
#  ('mistakes', 1),
#  ('perfect', 1),
#  ('pretend', 1),
#  ('slip', 1),
#  ('space', 1),
#  ('thinks', 1),
#  ('bling', 1),
#  ('che', 1),
#  ('ho', 1),
#  ('il', 1),
#  ('lo', 1),
#  ('non', 1),
#  ('arm', 1),
#  ('blue', 1),
#  ('dare', 1),
#  ('fun', 1),
#  ('grow', 1),
#  ('kind', 1),
#  ('looking', 1),
#  ('rude', 1),
#  ('sky', 1),
#  ('young', 1),
#  ('higher', 1),
#  ('working', 1),
#  ('racks', 1),
#  ('rest', 1),
#  ('shoot', 1),
#  ('tired', 1),
#  ('dead', 1),
#  ('ends', 1),
#  ('first', 1),
#  ('makes', 1),
#  ('playing', 1),
#  ('rules', 1),
#  ('slowly', 1),
#  ('standing', 1),
#  ('teeth', 1),
#  ('goodbye', 1),
#  ('nah', 1),
#  ('wild', 1),
#  ('broken', 1),
#  ('closed', 1),
#  ('edge', 1),
#  ('gon', 1),
#  ('heaven', 1),
#  ('hell', 1),
#  ('losing', 1),
#  ('near', 1),
#  ('pure', 1),
#  ('push', 1),
#  ('sign', 1),
#  ('thoughts', 1),
#  ('watching', 1),
#  ('land', 1),
#  ('murder', 1),
#  ('shot', 1),
#  ('shout', 1),
#  ('stage', 1),
#  ('throw', 1),
#  ('woah', 1),
#  ('breaking', 1),
#  ('fast', 1),
#  ('monster', 1),
#  ('pedal', 1),
#  ('round', 1),
#  ('star', 1),
#  ('ladies', 1),
#  ('roll', 1),
#  ('talk', 1),
#  ('tight', 1),
#  ('deal', 1),
#  ('door', 1),
#  ('goes', 1),
#  ('holding', 1),
#  ('making', 1),
#  ('pump', 1),
#  ('running', 1),
#  ('saying', 1),
#  ('shoes', 1),
#  ('sweat', 1),
#  ('cut', 1),
#  ('finished', 1),
#  ('pain', 1),
#  ('wasted', 1),
#  ('bet', 1),
#  ('deny', 1),
#  ('nice', 1),
#  ('ay', 1),
#  ('cake', 1),
#  ('ice', 1),
#  ('knows', 1),
#  ('laugh', 1),
#  ('cards', 1),
#  ('hanging', 1),
#  ('liar', 1),
#  ('lover', 1),
#  ('pictures', 1),
#  ('sad', 1),
#  ('single', 1),
#  ('strange', 1),
#  ('sure', 1),
#  ('account', 1),
#  ('falls', 1),
#  ('price', 1),
#  ('return', 1),
#  ('dum', 1),
#  ('front', 1),
#  ('ha', 1),
#  ('hand', 1),
#  ('magic', 1),
#  ('search', 1),
#  ('smile', 1),
#  ('weak', 1),
#  ('white', 1),
#  ('wrote', 1),
#  ('comes', 1),
#  ('easy', 1),
#  ('facebook', 1),
#  ('share', 1),
#  ('sugar', 1),
#  ('welcome', 1),
#  ('bass', 1),
#  ('dancing', 1),
#  ('games', 1),
#  ('harder', 1),
#  ('heartbeat', 1),
#  ('song', 1),
#  ('songs', 1),
#  ('sounds', 1),
#  ('buy', 1)]

# %%
tfidf_summer_global = sort_dictionary(summer)
tfidf_summer_global
# Out:
# [('love', 3.2111590137486092),
#  ('sorry', 3.1624247485449186),
#  ('trust', 2.3862535651729093),
#  ('hot', 2.352824882534737),
#  ('woo', 2.1142086197441174),
#  ('mind', 2.1046574503957345),
#  ('put', 2.020884450575801),
#  ('flower', 1.980310452818118),
#  ('em', 1.9626333700933452),
#  ('shy', 1.9226858042564654),
#  ('ready', 1.9188426805354042),
#  ('worry', 1.837092103431801),
#  ('yes', 1.8106564463544794),
#  ('business', 1.8082325752768063),
#  ('fall', 1.8011038824731416),
#  ('heart', 1.7928345825331622),
#  ('care', 1.7165829596424889),
#  ('chi', 1.7042387770576761),
#  ('keep', 1.6902832699626618),
#  ('taking', 1.608198525916642),
#  ('matter', 1.5818529324911066),
#  ('home', 1.5356698179913768),
#  ('finally', 1.5236500520493004),
#  ('crazy', 1.510161642126581),
#  ('think', 1.505804405173682),
#  ('tomorrow', 1.4769442397116785),
#  ('ah', 1.4542463159967527),
#  ('words', 1.4389624091552111),
#  ('control', 1.411335330255775),
#  ('hit', 1.366162842085624),
#  ('break', 1.3357711651378272),
#  ('stronger', 1.2855896443304236),
#  ('top', 1.2635157870819123),
#  ('world', 1.2559301833619023),
#  ('voice', 1.211041390208556),
#  ('hear', 1.2067161399548407),
#  ('tell', 1.1973126751256733),
#  ('boy', 1.186531713565186),
#  ('bad', 1.173972455801339),
#  ('room', 1.1569968705570575),
#  ('kill', 1.1470133962264524),
#  ('am', 1.1465192516371947),
#  ('down', 1.117975012611655),
#  ('need', 1.111221285319223),
#  ('fly', 1.1043940578562157),
#  ('doubt', 1.1021830704432967),
#  ('okay', 1.0954901163988282),
#  ('say', 1.0922868577053229),
#  ('end', 1.0876644180635182),
#  ('dance', 1.0663784022963694),
#  ('little', 1.0535281096472728),
#  ('choose', 1.0445080832300784),
#  ('let', 1.034080723601818),
#  ('cake', 0.9999873916485129),
#  ('wow', 0.9957933421588775),
#  ('summer', 0.9946593325489034),
#  ('show', 0.9829212824309034),
#  ('24', 0.980367341544059),
#  ('won', 0.9798582432622278),
#  ('baby', 0.9750070648757019),
#  ('dreaming', 0.971617412258972),
#  ('ring', 0.9684818824540147),
#  ('face', 0.9517154387027932),
#  ('cuz', 0.9427142776839862),
#  ('babe', 0.941732615078053),
#  ('uh', 0.9287419595974981),
#  ('twenty', 0.9060338631824257),
#  ('call', 0.9054581661715877),
#  ('new', 0.8707727796539871),
#  ('weird', 0.8592176932572665),
#  ('20', 0.8589434234606392),
#  ('take', 0.8531106025422488),
#  ('warm', 0.8404432072401238),
#  ('listen', 0.8397720944389334),
#  ('sick', 0.8327547442221926),
#  ('noise', 0.827386895267944),
#  ('eyes', 0.8168115587864503),
#  ('ride', 0.8020439445288368),
#  ('doesn', 0.7948931519697479),
#  ('hold', 0.7873198189537838),
#  ('thank', 0.7785520225786049),
#  ('feel', 0.7777948489533735),
#  ('back', 0.7775154421177803),
#  ('non', 0.7758029764232184),
#  ('bounce', 0.765464478761731),
#  ('talking', 0.7553987975152484),
#  ('faster', 0.7468275278330234),
#  ('girl', 0.7462077400175179),
#  ('only', 0.7375034215094279),
#  ('leave', 0.7340449559575436),
#  ('waiting', 0.732734135737825),
#  ('guess', 0.7262207943409194),
#  ('boss', 0.7257873634898626),
#  ('hard', 0.7129631273085824),
#  ('side', 0.7125419926782596),
#  ('hours', 0.7100182715985924),
#  ('nah', 0.6988177827710095),
#  ('loves', 0.6985529349363339),
#  ('high', 0.6967570271855023),
#  ('turn', 0.6936087695590052),
#  ('shut', 0.6931469807691809),
#  ('pa', 0.6930561256249017),
#  ('people', 0.6876641533970511),
#  ('head', 0.6842976142098016),
#  ('game', 0.6837508542083842),
#  ('coming', 0.6736938652697799),
#  ('problems', 0.6698118831157704),
#  ('hate', 0.6658144582961281),
#  ('wish', 0.6579924241443995),
#  ('faith', 0.6566751577856083),
#  ('weight', 0.6481303168490715),
#  ('change', 0.641793046894294),
#  ('honey', 0.6382284466060556),
#  ('likes', 0.6360296518235155),
#  ('style', 0.6353455747658706),
#  ('cool', 0.6322497368900224),
#  ('sugar', 0.6285249251777649),
#  ('rock', 0.6229260421826905),
#  ('mine', 0.6202665537838902),
#  ('limit', 0.6134572990547933),
#  ('stay', 0.6114856395459495),
#  ('child', 0.6109435160465441),
#  ('dum', 0.6108627729054358),
#  ('believe', 0.6056324796016066),
#  ('forget', 0.5940602030754633),
#  ('follow', 0.5895640154740832),
#  ('imma', 0.5860155808317292),
#  ('city', 0.582614124031874),
#  ('being', 0.5819697241156631),
#  ('step', 0.5773833150614102),
#  ('loud', 0.5723714001648768),
#  ('alone', 0.5663000744849744),
#  ('queen', 0.5625254342265983),
#  ('type', 0.5608487471343087),
#  ('bang', 0.5578367513981453),
#  ('lose', 0.5540578060338702),
#  ('read', 0.553860520520828),
#  ('touch', 0.5516776693597417),
#  ('choice', 0.5496002445368423),
#  ('blow', 0.539256254170515),
#  ('fresh', 0.536043395915789),
#  ('give', 0.5303520914047062),
#  ('problem', 0.5233392799028225),
#  ('win', 0.519452080483177),
#  ('list', 0.5152917027819379),
#  ('lost', 0.5014683026869434),
#  ('days', 0.4989898151905676),
#  ('tight', 0.49780722133222316),
#  ('feeling', 0.4973576116504097),
#  ('wait', 0.4914329127137529),
#  ('light', 0.4886252358749691),
#  ('fight', 0.4790242820947302),
#  ('sleep', 0.4743519192102683),
#  ('guys', 0.4735907744217795),
#  ('sweet', 0.46916784291582936),
#  ('fear', 0.4654757882318924),
#  ('diamond', 0.4624177943889887),
#  ('night', 0.45948988794768375),
#  ('crowd', 0.4550673960127065),
#  ('eh', 0.45120082985742455),
#  ('way', 0.4298624892236334),
#  ('tie', 0.4265389709179535),
#  ('free', 0.4255000326045038),
#  ('pretty', 0.42254487566476717),
#  ('clear', 0.42172686100489265),
#  ('boys', 0.4176722455738084),
#  ('second', 0.41159078297020535),
#  ('ice', 0.4089179797111849),
#  ('sing', 0.40596535165463865),
#  ('pride', 0.4001207610399654),
#  ('account', 0.3931156642399529),
#  ('shows', 0.3911713540106063),
#  ('che', 0.3894864042907355),
#  ('dream', 0.3855349881603143),
#  ('bet', 0.38267219445394246),
#  ('gonna', 0.3804399827592195),
#  ('funny', 0.37803148142339627),
#  ('il', 0.37615942425716864),
#  ('start', 0.37385235220611657),
#  ('live', 0.37271795927377704),
#  ('mean', 0.3713030936264641),
#  ('fast', 0.3698229598454493),
#  ('help', 0.36928330793716213),
#  ('guy', 0.36592603956549835),
#  ('true', 0.36391831239359906),
#  ('happen', 0.3589801049252679),
#  ('late', 0.35488407111981557),
#  ('body', 0.34728177746387995),
#  ('well', 0.3430471829242851),
#  ('morning', 0.3414441593209161),
#  ('sun', 0.33983880771039654),
#  ('strong', 0.3390293932672626),
#  ('play', 0.3381152919088946),
#  ('miss', 0.3374577374212243),
#  ('trying', 0.3344738960757019),
#  ('wants', 0.3314179426386883),
#  ('find', 0.33044780994532097),
#  ('track', 0.3288625545888818),
#  ('boom', 0.32711730925689114),
#  ('games', 0.3261777728944414),
#  ('check', 0.3250004073685576),
#  ('wave', 0.3247950069258941),
#  ('mess', 0.32183527273190804),
#  ('pretend', 0.3200714126365183),
#  ('fool', 0.31893204086629),
#  ('mistake', 0.31857008191412994),
#  ('hope', 0.31615179410074223),
#  ('raise', 0.3148444767121148),
#  ('pop', 0.31136316374187645),
#  ('yesterday', 0.3106367446864081),
#  ('feet', 0.3100799169024656),
#  ('girls', 0.30715218281754936),
#  ('living', 0.3047207126110433),
#  ('dare', 0.304600206377422),
#  ('job', 0.30164959789824297),
#  ('learn', 0.301082148546379),
#  ('easy', 0.29891509810840766),
#  ('move', 0.29846871462047264),
#  ('fighting', 0.2965022789201645),
#  ('next', 0.2952028811720074),
#  ('rain', 0.29207287571414375),
#  ('ooh', 0.2895513092106142),
#  ('god', 0.28866108458011436),
#  ('welcome', 0.2885519200424522),
#  ('real', 0.28729399761096),
#  ('pedal', 0.2872501863328465),
#  ('cry', 0.2849196544298124),
#  ('perfect', 0.28411530008424524),
#  ('trouble', 0.2825196193694128),
#  ('ve', 0.28118303283168605),
#  ('view', 0.27673522077835866),
#  ('calls', 0.2736914969367933),
#  ('life', 0.2733358672213425),
#  ('big', 0.27248712870384373),
#  ('oooh', 0.26851939085717763),
#  ('losing', 0.268236913106061),
#  ('excuse', 0.26746095272998494),
#  ('beat', 0.2657974763374415),
#  ('walking', 0.2601238839330844),
#  ('racks', 0.25892646364282734),
#  ('still', 0.257613455811369),
#  ('story', 0.25739284982384447),
#  ('lord', 0.25688492847712047),
#  ('mirror', 0.2568546048535871),
#  ('didn', 0.2553118980490638),
#  ('stupid', 0.2550831187498126),
#  ('kid', 0.25504978074553813),
#  ('man', 0.25219926969012574),
#  ('hands', 0.2518815214149225),
#  ('away', 0.25162346925673673),
#  ('ladies', 0.25159274239812024),
#  ('bring', 0.24987142111430038),
#  ('rules', 0.2494716564963497),
#  ('bye', 0.24896453060990106),
#  ('afraid', 0.24818730633153624),
#  ('mama', 0.2466724206089524),
#  ('breaking', 0.24547852223240826),
#  ('beauty', 0.24410766663034072),
#  ('monster', 0.2401757677162495),
#  ('act', 0.23751594169932938),
#  ('heard', 0.23735979584580047),
#  ('moves', 0.23596701598773523),
#  ('false', 0.23458627660924433),
#  ('ayy', 0.23402991979560692),
#  ('fill', 0.2318273631201877),
#  ('lover', 0.22980427151781221),
#  ('went', 0.22900151325070306),
#  ('lights', 0.22737569775052321),
#  ('best', 0.22691975294779118),
#  ('pass', 0.22547939840263267),
#  ('round', 0.2245595582658137),
#  ('yellow', 0.2243962455816193),
#  ('focus', 0.21978801981611157),
#  ('bass', 0.21834336841337046),
#  ('haters', 0.21797992064846733),
#  ('fine', 0.21578208418453254),
#  ('name', 0.2125796941186278),
#  ('rest', 0.21130661939352793),
#  ('dreams', 0.21127346149503232),
#  ('ta', 0.21031509567404869),
#  ('shoot', 0.20810547176427643),
#  ('open', 0.20722314748855902),
#  ('double', 0.206175627318368),
#  ('star', 0.20367095399880086),
#  ('lower', 0.2032583908084893),
#  ('finish', 0.2022060495908835),
#  ('bust', 0.20112569863868193),
#  ('wild', 0.20075890411570305),
#  ('tired', 0.19887199514206508),
#  ('cut', 0.19696322403042035),
#  ('last', 0.19690426337453631),
#  ('born', 0.1947492367183668),
#  ('anymore', 0.19276214460123933),
#  ('throw', 0.1881262923556305),
#  ('front', 0.18670188079200054),
#  ('close', 0.18543114874997993),
#  ('roll', 0.18314310802635056),
#  ('red', 0.17978735520222905),
#  ('caught', 0.17925343777379205),
#  ('hello', 0.1770973225189968),
#  ('hi', 0.17665878433045396),
#  ('cause', 0.17607659807623513),
#  ('killed', 0.17480749575237844),
#  ('flow', 0.1725140491253951),
#  ('great', 0.17185378229639753),
#  ('couple', 0.17138882149817988),
#  ('tonight', 0.16804440024656836),
#  ('may', 0.16780392578708103),
#  ('talk', 0.16426088635060285),
#  ('slow', 0.16194978039719185),
#  ('old', 0.16044513996023213),
#  ('beautiful', 0.16025509846983083),
#  ('chance', 0.1600196257184024),
#  ('piece', 0.15989807597947595),
#  ('sit', 0.15946459778062635),
#  ('heartbeat', 0.1593481890588659),
#  ('today', 0.15654503026729158),
#  ('run', 0.15599634137311436),
#  ('inside', 0.1554482573515723),
#  ('lying', 0.15470108057830087),
#  ('thinking', 0.15393087972444272),
#  ('deny', 0.15288849468556473),
#  ('long', 0.15260312806461007),
#  ('laugh', 0.14747025445005918),
#  ('full', 0.1463945922650707),
#  ('murder', 0.14583175030769766),
#  ('continue', 0.14409185305111985),
#  ('shout', 0.14400687862113315),
#  ('wonder', 0.14358666177760163),
#  ('freedom', 0.1407224004114309),
#  ('told', 0.1397017414960915),
#  ('gave', 0.13959818538265772),
#  ('liar', 0.13859445921172425),
#  ('falls', 0.13714708661619437),
#  ('dancing', 0.1370416612036041),
#  ('ask', 0.13535888496134008),
#  ('wrong', 0.13408103866229926),
#  ('wasted', 0.1332533719689252),
#  ('fault', 0.1328679927007888),
#  ('finished', 0.13209840128420844),
#  ('stage', 0.13061192020794882),
#  ('lonely', 0.1282822357382116),
#  ('pictures', 0.12528706860252342),
#  ('mom', 0.12519502032168903),
#  ('nice', 0.12407775600273083),
#  ('cards', 0.12364645175446336),
#  ('line', 0.12307888759243946),
#  ('burn', 0.12302471539649514),
#  ('hanging', 0.1226123969927101),
#  ('guide', 0.12234960826864412),
#  ('fire', 0.12159610850672974),
#  ('strange', 0.12114103005823466),
#  ('land', 0.11974149750707977),
#  ('worried', 0.11821069649341792),
#  ('made', 0.11788674516231093),
#  ('doctor', 0.11774415253917976),
#  ('slip', 0.11768016054548025),
#  ('mistakes', 0.11631289238025812),
#  ('ends', 0.11587607309886641),
#  ('knows', 0.1149981270680529),
#  ('teeth', 0.11467855410734977),
#  ('thinks', 0.1130202978716255),
#  ('leaving', 0.11220734970940384),
#  ('continues', 0.11164975787077637),
#  ('single', 0.11087345470129656),
#  ('woah', 0.11066704155971173),
#  ('beats', 0.11048130929665377),
#  ('higher', 0.11025234104335621),
#  ('wake', 0.10955703364967492),
#  ('sad', 0.10852294894366785),
#  ('making', 0.10827802723037905),
#  ('rude', 0.10798681785584721),
#  ('shake', 0.10779495753989433),
#  ('slowly', 0.10767216168916512),
#  ('bling', 0.1074741212163339),
#  ('sea', 0.10724187999843973),
#  ('pure', 0.10670475436291105),
#  ('hop', 0.10631071157847286),
#  ('shot', 0.10629100803078917),
#  ('goodbye', 0.10566705069211214),
#  ('future', 0.10323722820180936),
#  ('facebook', 0.10179929064364),
#  ('space', 0.10149800407453337),
#  ('saying', 0.10077267271730607),
#  ('playing', 0.09869136154111062),
#  ('standing', 0.09869136154111062),
#  ('breathe', 0.09865918721490949),
#  ('arm', 0.09852225639329798),
#  ('party', 0.09756832031752619),
#  ('working', 0.0965086263472107),
#  ('sure', 0.09615300412383232),
#  ('dead', 0.09557387063823844),
#  ('edge', 0.09532373877736526),
#  ('youth', 0.09406863294365811),
#  ('pain', 0.09236563468105898),
#  ('hide', 0.0922666503631082),
#  ('thoughts', 0.09087470831179996),
#  ('road', 0.0908230661004755),
#  ('watching', 0.09057286539651412),
#  ('closed', 0.08998351652316808),
#  ('eat', 0.08973639046962588),
#  ('yo', 0.08902234863023181),
#  ('sign', 0.08858714939918906),
#  ('ho', 0.08727433713211541),
#  ('hollywood', 0.08628159403639907),
#  ('push', 0.08386232925809765),
#  ('grow', 0.08329263523686069),
#  ('sweat', 0.08328807644927752),
#  ('gon', 0.08324692714499188),
#  ('calling', 0.0823688548322426),
#  ('weak', 0.08183705469440622),
#  ('heaven', 0.07943040275604009),
#  ('search', 0.07901272424404687),
#  ('whoa', 0.0788421302281369),
#  ('magic', 0.07872793100246002),
#  ('nights', 0.07834618728422134),
#  ('near', 0.07831469780388178),
#  ('ha', 0.07711919472598774),
#  ('blue', 0.07711675207684403),
#  ('blame', 0.07664984050348733),
#  ('lies', 0.07645690678788344),
#  ('makes', 0.07641371430143022),
#  ('wrote', 0.07637233465765869),
#  ('kind', 0.07612267624968225),
#  ('friends', 0.07598627493446307),
#  ('first', 0.07537920637711694),
#  ('hell', 0.0745475210654761),
#  ('places', 0.07421804179717686),
#  ('fun', 0.07415673816662752),
#  ('price', 0.07415322774556192),
#  ('feelings', 0.073196492255076),
#  ('sky', 0.07128288350490102),
#  ('comes', 0.071047342990001),
#  ('share', 0.07073686519426979),
#  ('broken', 0.07048124499071211),
#  ('felt', 0.06801259413285601),
#  ('reason', 0.06625956348563851),
#  ('tried', 0.06625933054702995),
#  ('return', 0.0655002941135407),
#  ('special', 0.0653474065479153),
#  ('smile', 0.06470357403583311),
#  ('running', 0.0638965939245448),
#  ('young', 0.0632110610325658),
#  ('bed', 0.0631989509433497),
#  ('white', 0.062333680451448735),
#  ('buy', 0.061693886069556815),
#  ('mother', 0.06117256087302665),
#  ('goes', 0.059800514740129235),
#  ('looking', 0.0593682305872071),
#  ('friend', 0.058614016832095814),
#  ('harder', 0.05801358381764079),
#  ('drop', 0.05685595146766153),
#  ('hand', 0.054340007991776317),
#  ('diamonds', 0.05377617097047959),
#  ('straight', 0.05167308940738424),
#  ('sounds', 0.05148416121466487),
#  ('lo', 0.050866289270362894),
#  ('songs', 0.05083248431769819),
#  ('burns', 0.0486625320253256),
#  ('wood', 0.046167336865298364),
#  ('pump', 0.046037460759418045),
#  ('try', 0.04518068538987945),
#  ('driving', 0.044618581447681833),
#  ('blowing', 0.04461140195365451),
#  ('die', 0.0416748620570442),
#  ('holding', 0.04096201588442246),
#  ('box', 0.04082350698315154),
#  ('deal', 0.040800213954664745),
#  ('shoes', 0.03833759263326154),
#  ('screaming', 0.036985727278471374),
#  ('song', 0.036724597718940016),
#  ('dry', 0.029165617889184852),
#  ('door', 0.02900729844830041),
#  ('waste', 0.02767963090114483),
#  ('part', 0.02681201855640554),
#  ('celebrate', 0.026555664701048937),
#  ('word', 0.026259231876599804),
#  ('number', 0.02598723213376084),
#  ('phone', 0.025253743447782154),
#  ('atmosphere', 0.024453213932958767),
#  ('message', 0.023842291713058232),
#  ('wanted', 0.02383934951364709),
#  ('damn', 0.02211957844020932),
#  ('calm', 0.020928848612128417),
#  ('understand', 0.01627494691554301),
#  ('speed', 0.010464424306064209),
#  ('heat', 0.010155003950359658),
#  ('ay', 0.0011372170869838375)]

# %% [markdown]
# #### Among KPOP

# %%
df_looking = df[df["grouping"].isin(target_and_kpop)].reset_index(drop=True)

# %%
vectorizer = TfidfVectorizer(stop_words=list(stopwords), max_features=1000, min_df=10)

x = vectorizer.fit_transform(df_looking["lyrics"].fillna("")).toarray()

df_tfidf = pd.DataFrame(x, columns=vectorizer.get_feature_names_out()).T
# Out:
# c:\Users\Hiyoko\.conda\envs\data\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['vis', 'viser', 'visest', 'yes'] not in stop_words.
#   warnings.warn(

# %%
threshold = 0.001
counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    tfidf_series = df_tfidf[cnt]
    
    keywords = tfidf_series[tfidf_series > threshold].index.tolist()
    for keyword in keywords:
        counter[keyword] = counter.get(keyword, 0) + 1
        summer[keyword] = summer.get(keyword, 0) + float(tfidf_series[keyword])

# %%
tfidf_counter_kpop = sort_dictionary(counter)
tfidf_counter_kpop
# Out:
# [('sorry', 23),
#  ('love', 22),
#  ('mind', 22),
#  ('yes', 21),
#  ('let', 20),
#  ('say', 19),
#  ('tell', 14),
#  ('feel', 14),
#  ('baby', 13),
#  ('down', 13),
#  ('heart', 13),
#  ('keep', 13),
#  ('take', 12),
#  ('care', 12),
#  ('back', 12),
#  ('bad', 11),
#  ('eyes', 11),
#  ('matter', 11),
#  ('crazy', 11),
#  ('think', 11),
#  ('show', 10),
#  ('control', 10),
#  ('need', 10),
#  ('room', 10),
#  ('ah', 10),
#  ('am', 9),
#  ('turn', 9),
#  ('put', 9),
#  ('little', 9),
#  ('forget', 9),
#  ('way', 9),
#  ('home', 9),
#  ('only', 8),
#  ('hear', 8),
#  ('coming', 8),
#  ('girl', 8),
#  ('game', 8),
#  ('doesn', 7),
#  ('face', 7),
#  ('honey', 7),
#  ('ready', 7),
#  ('한국', 7),
#  ('break', 7),
#  ('dance', 7),
#  ('worry', 7),
#  ('okay', 7),
#  ('stay', 7),
#  ('follow', 7),
#  ('play', 7),
#  ('head', 7),
#  ('high', 7),
#  ('informazioni', 7),
#  ('hit', 7),
#  ('light', 7),
#  ('world', 7),
#  ('cuz', 6),
#  ('give', 6),
#  ('territory', 6),
#  ('child', 6),
#  ('fight', 6),
#  ('kill', 6),
#  ('feeling', 6),
#  ('uh', 6),
#  ('boy', 6),
#  ('didn', 6),
#  ('start', 6),
#  ('still', 6),
#  ('top', 6),
#  ('new', 6),
#  ('free', 6),
#  ('end', 6),
#  ('lost', 6),
#  ('life', 6),
#  ('city', 6),
#  ('fly', 6),
#  ('words', 6),
#  ('won', 6),
#  ('trust', 6),
#  ('bring', 6),
#  ('call', 5),
#  ('leave', 5),
#  ('well', 5),
#  ('woo', 5),
#  ('cool', 5),
#  ('best', 5),
#  ('read', 5),
#  ('run', 5),
#  ('told', 5),
#  ('hard', 5),
#  ('shut', 5),
#  ('sweet', 5),
#  ('ve', 5),
#  ('people', 5),
#  ('talking', 5),
#  ('sing', 5),
#  ('tomorrow', 5),
#  ('open', 5),
#  ('wow', 5),
#  ('stronger', 5),
#  ('blah', 5),
#  ('listen', 5),
#  ('wait', 5),
#  ('step', 5),
#  ('tonight', 5),
#  ('night', 5),
#  ('side', 5),
#  ('united', 5),
#  ('fire', 5),
#  ('burn', 5),
#  ('business', 4),
#  ('imma', 4),
#  ('agriculture', 4),
#  ('hurry', 4),
#  ('man', 4),
#  ('live', 4),
#  ('di', 4),
#  ('weird', 4),
#  ('한국어', 4),
#  ('days', 4),
#  ('dreaming', 4),
#  ('sick', 4),
#  ('sleep', 4),
#  ('wake', 4),
#  ('choice', 4),
#  ('cry', 4),
#  ('made', 4),
#  ('miss', 4),
#  ('mean', 4),
#  ('style', 4),
#  ('pop', 4),
#  ('warm', 4),
#  ('hold', 4),
#  ('hot', 4),
#  ('rock', 4),
#  ('wish', 4),
#  ('blow', 4),
#  ('faster', 4),
#  ('lose', 4),
#  ('focus', 4),
#  ('hands', 4),
#  ('pow', 4),
#  ('mine', 4),
#  ('problem', 4),
#  ('alone', 4),
#  ('clear', 4),
#  ('choose', 4),
#  ('faith', 4),
#  ('news', 4),
#  ('ride', 4),
#  ('type', 4),
#  ('doubt', 4),
#  ('burns', 4),
#  ('away', 4),
#  ('beat', 3),
#  ('big', 3),
#  ('hate', 3),
#  ('touch', 3),
#  ('finally', 3),
#  ('guess', 3),
#  ('loves', 3),
#  ('fine', 3),
#  ('late', 3),
#  ('을和', 3),
#  ('anymore', 3),
#  ('babe', 3),
#  ('next', 3),
#  ('phone', 3),
#  ('sit', 3),
#  ('dream', 3),
#  ('list', 3),
#  ('ooh', 3),
#  ('move', 3),
#  ('em', 3),
#  ('fault', 3),
#  ('leaving', 3),
#  ('party', 3),
#  ('afraid', 3),
#  ('living', 3),
#  ('lying', 3),
#  ('problems', 3),
#  ('trying', 3),
#  ('data', 3),
#  ('story', 3),
#  ('excuse', 3),
#  ('fall', 3),
#  ('friends', 3),
#  ('gonna', 3),
#  ('mirror', 3),
#  ('red', 3),
#  ('thinking', 3),
#  ('voice', 3),
#  ('funny', 3),
#  ('pass', 3),
#  ('body', 3),
#  ('fresh', 3),
#  ('queen', 3),
#  ('contact', 3),
#  ('ask', 3),
#  ('um', 3),
#  ('그래', 3),
#  ('wrong', 3),
#  ('guy', 3),
#  ('loud', 3),
#  ('real', 3),
#  ('rousing', 3),
#  ('strong', 3),
#  ('waiting', 3),
#  ('지和지', 3),
#  ('colombo', 3),
#  ('feet', 3),
#  ('walking', 3),
#  ('flow', 3),
#  ('shake', 3),
#  ('being', 3),
#  ('change', 3),
#  ('finish', 3),
#  ('old', 3),
#  ('ma', 3),
#  ('dreams', 3),
#  ('hidden', 3),
#  ('thank', 3),
#  ('hope', 3),
#  ('last', 3),
#  ('fighting', 3),
#  ('true', 3),
#  ('question', 3),
#  ('boom', 3),
#  ('straight', 3),
#  ('track', 3),
#  ('fear', 3),
#  ('kingdom', 3),
#  ('tie', 3),
#  ('lonely', 3),
#  ('lord', 3),
#  ('beauty', 3),
#  ('eat', 3),
#  ('future', 3),
#  ('believe', 3),
#  ('act', 2),
#  ('couple', 2),
#  ('drop', 2),
#  ('likes', 2),
#  ('shy', 2),
#  ('movie', 2),
#  ('born', 2),
#  ('dangerous', 2),
#  ('organization', 2),
#  ('yellow', 2),
#  ('cherry', 2),
#  ('administration', 2),
#  ('ayy', 2),
#  ('level', 2),
#  ('youth', 2),
#  ('fool', 2),
#  ('pretty', 2),
#  ('questions', 2),
#  ('un', 2),
#  ('和지', 2),
#  ('하和', 2),
#  ('calls', 2),
#  ('learn', 2),
#  ('prepare', 2),
#  ('hi', 2),
#  ('inside', 2),
#  ('may', 2),
#  ('name', 2),
#  ('fill', 2),
#  ('weight', 2),
#  ('bed', 2),
#  ('boys', 2),
#  ('calling', 2),
#  ('date', 2),
#  ('guys', 2),
#  ('kid', 2),
#  ('mom', 2),
#  ('raise', 2),
#  ('tried', 2),
#  ('wonder', 2),
#  ('laughter', 2),
#  ('terms', 2),
#  ('crowd', 2),
#  ('diamond', 2),
#  ('gauze', 2),
#  ('second', 2),
#  ('sun', 2),
#  ('wants', 2),
#  ('road', 2),
#  ('ora', 2),
#  ('bam', 2),
#  ('drum', 2),
#  ('hello', 2),
#  ('piece', 2),
#  ('god', 2),
#  ('chance', 2),
#  ('24', 2),
#  ('hours', 2),
#  ('criminal', 2),
#  ('false', 2),
#  ('girls', 2),
#  ('slow', 2),
#  ('close', 2),
#  ('hesitate', 2),
#  ('long', 2),
#  ('find', 2),
#  ('던子', 2),
#  ('boss', 2),
#  ('final', 2),
#  ('check', 2),
#  ('ta', 2),
#  ('cause', 2),
#  ('haters', 2),
#  ('board', 2),
#  ('caught', 2),
#  ('copyright', 2),
#  ('forgot', 2),
#  ('full', 2),
#  ('gave', 2),
#  ('izen', 2),
#  ('password', 2),
#  ('price_varies', 2),
#  ('reserved', 2),
#  ('rights', 2),
#  ('sharing', 2),
#  ('today', 2),
#  ('limit', 2),
#  ('beautiful', 2),
#  ('morning', 2),
#  ('flame', 2),
#  ('rain', 2),
#  ('went', 2),
#  ('bang', 2),
#  ('noise', 2),
#  ('view', 2),
#  ('blowing', 2),
#  ('calm', 2),
#  ('damn', 2),
#  ('dynamite', 2),
#  ('heat', 2),
#  ('passion', 2),
#  ('speed', 2),
#  ('temperature', 2),
#  ('zione', 2),
#  ('lights', 2),
#  ('mistake', 2),
#  ('yesterday', 2),
#  ('race', 2),
#  ('win', 2),
#  ('너와', 2),
#  ('trouble', 2),
#  ('nights', 2),
#  ('flower', 2),
#  ('zoom', 2),
#  ('cute', 2),
#  ('line', 2),
#  ('impossible', 2),
#  ('job', 1),
#  ('니和까', 1),
#  ('acrylate', 1),
#  ('atmosphere', 1),
#  ('message', 1),
#  ('ping', 1),
#  ('ring', 1),
#  ('understand', 1),
#  ('celebrate', 1),
#  ('die', 1),
#  ('dry', 1),
#  ('number', 1),
#  ('stanza', 1),
#  ('stupid', 1),
#  ('whoo', 1),
#  ('generating', 1),
#  ('feelings', 1),
#  ('friend', 1),
#  ('help', 1),
#  ('medicine', 1),
#  ('mother', 1),
#  ('reason', 1),
#  ('rose', 1),
#  ('whoa', 1),
#  ('summer', 1),
#  ('comment', 1),
#  ('persons', 1),
#  ('flash', 1),
#  ('traduzione', 1),
#  ('continue', 1),
#  ('force', 1),
#  ('video', 1),
#  ('orientation', 1),
#  ('attempted', 1),
#  ('bounce', 1),
#  ('eh', 1),
#  ('hiding', 1),
#  ('amazing', 1),
#  ('diamonds', 1),
#  ('special', 1),
#  ('하和하', 1),
#  ('drama', 1),
#  ('invalid', 1),
#  ('skip', 1),
#  ('try', 1),
#  ('double', 1),
#  ('rate', 1),
#  ('yo', 1),
#  ('和만', 1),
#  ('able', 1),
#  ('continues', 1),
#  ('great', 1),
#  ('heard', 1),
#  ('hide', 1),
#  ('island', 1),
#  ('sea', 1),
#  ('wave', 1),
#  ('worried', 1),
#  ('bye', 1),
#  ('던和', 1),
#  ('dive', 1),
#  ('dreamed', 1),
#  ('part', 1),
#  ('signs', 1),
#  ('wanted', 1),
#  ('waste', 1),
#  ('word', 1),
#  ('beats', 1),
#  ('breathe', 1),
#  ('perfect', 1),
#  ('space', 1),
#  ('teach', 1),
#  ('bling', 1),
#  ('che', 1),
#  ('english', 1),
#  ('fate', 1),
#  ('ho', 1),
#  ('il', 1),
#  ('non', 1),
#  ('su', 1),
#  ('blue', 1),
#  ('busy', 1),
#  ('fun', 1),
#  ('grow', 1),
#  ('kind', 1),
#  ('looking', 1),
#  ('sky', 1),
#  ('young', 1),
#  ('higher', 1),
#  ('satisfied', 1),
#  ('stops', 1),
#  ('working', 1),
#  ('모두', 1),
#  ('important', 1),
#  ('rest', 1),
#  ('shoot', 1),
#  ('tired', 1),
#  ('dead', 1),
#  ('film', 1),
#  ('first', 1),
#  ('makes', 1),
#  ('playing', 1),
#  ('rules', 1),
#  ('slowly', 1),
#  ('standing', 1),
#  ('goodbye', 1),
#  ('nah', 1),
#  ('wild', 1),
#  ('broken', 1),
#  ('closed', 1),
#  ('edge', 1),
#  ('fan', 1),
#  ('gon', 1),
#  ('heaven', 1),
#  ('hell', 1),
#  ('losing', 1),
#  ('near', 1),
#  ('push', 1),
#  ('roller', 1),
#  ('rush', 1),
#  ('sign', 1),
#  ('smooth', 1),
#  ('thoughts', 1),
#  ('trapped', 1),
#  ('watching', 1),
#  ('activities', 1),
#  ('bomb', 1),
#  ('food', 1),
#  ('land', 1),
#  ('shot', 1),
#  ('stage', 1),
#  ('throw', 1),
#  ('woah', 1),
#  ('fast', 1),
#  ('monster', 1),
#  ('round', 1),
#  ('star', 1),
#  ('te', 1),
#  ('ladies', 1),
#  ('roll', 1),
#  ('talk', 1),
#  ('tight', 1),
#  ('attitude', 1),
#  ('door', 1),
#  ('goes', 1),
#  ('making', 1),
#  ('running', 1),
#  ('saying', 1),
#  ('shoes', 1),
#  ('sweat', 1),
#  ('athletic', 1),
#  ('cut', 1),
#  ('finished', 1),
#  ('nurse', 1),
#  ('pain', 1),
#  ('bet', 1),
#  ('nice', 1),
#  ('cake', 1),
#  ('maybe', 1),
#  ('cream', 1),
#  ('daily', 1),
#  ('ice', 1),
#  ('knows', 1),
#  ('laugh', 1),
#  ('pantyhose', 1),
#  ('test', 1),
#  ('fireworks', 1),
#  ('lover', 1),
#  ('natural', 1),
#  ('negative', 1),
#  ('sad', 1),
#  ('single', 1),
#  ('subscribe', 1),
#  ('sure', 1),
#  ('price', 1),
#  ('return', 1),
#  ('trophy', 1),
#  ('appearance', 1),
#  ('destiny', 1),
#  ('front', 1),
#  ('ha', 1),
#  ('hand', 1),
#  ('hero', 1),
#  ('history', 1),
#  ('magic', 1),
#  ('page', 1),
#  ('smile', 1),
#  ('tea', 1),
#  ('white', 1),
#  ('zero', 1),
#  ('comes', 1),
#  ('easy', 1),
#  ('facebook', 1),
#  ('share', 1),
#  ('sugar', 1),
#  ('welcome', 1),
#  ('bass', 1),
#  ('dancing', 1),
#  ('enjoy', 1),
#  ('games', 1),
#  ('heartbeat', 1),
#  ('song', 1),
#  ('sounds', 1),
#  ('programme', 1),
#  ('buy', 1)]

# %%
tfidf_summer_kpop = sort_dictionary(summer)
tfidf_summer_kpop
# Out:
# [('love', 3.7295123013654305),
#  ('put', 2.4826616351462447),
#  ('trust', 2.4324877675268377),
#  ('hot', 2.3126303347836705),
#  ('keep', 2.0253074558606508),
#  ('woo', 1.9559731310647535),
#  ('flower', 1.9553951154721705),
#  ('crazy', 1.9351914543271769),
#  ('fall', 1.896361950718139),
#  ('worry', 1.889137009235887),
#  ('mind', 1.8725577824369803),
#  ('shy', 1.8625770823631649),
#  ('business', 1.858239331562063),
#  ('blah', 1.7916503324920754),
#  ('한국', 1.7395776915919268),
#  ('yes', 1.6725149283019323),
#  ('em', 1.6580317150045465),
#  ('control', 1.6275816088166775),
#  ('sorry', 1.6181170837152725),
#  ('think', 1.6029053675806249),
#  ('hit', 1.5946636358702568),
#  ('heart', 1.4564988011678022),
#  ('down', 1.4448309833777575),
#  ('ah', 1.4297295710406557),
#  ('ready', 1.4238208197606785),
#  ('say', 1.3873513044732313),
#  ('matter', 1.3653434369426067),
#  ('bad', 1.348649525140968),
#  ('only', 1.3440981678289643),
#  ('home', 1.3414986661490813),
#  ('break', 1.3410441116279574),
#  ('tell', 1.3296895882414261),
#  ('care', 1.3191897875671474),
#  ('show', 1.2957768432622427),
#  ('words', 1.2923647092609394),
#  ('um', 1.2867436915999138),
#  ('need', 1.2799791065085246),
#  ('tomorrow', 1.2776029371981186),
#  ('stronger', 1.270546782590531),
#  ('finally', 1.2689015758108784),
#  ('am', 1.2519640209541776),
#  ('hear', 1.2265383074979495),
#  ('kill', 1.1845886270574875),
#  ('won', 1.1843643814272413),
#  ('take', 1.1036974349476052),
#  ('doubt', 1.1029731711258055),
#  ('let', 1.079601848721568),
#  ('boy', 1.0776840662984295),
#  ('voice', 1.0669334586837427),
#  ('world', 1.0627816374694268),
#  ('choose', 1.0515775689492888),
#  ('little', 1.0511921210062545),
#  ('call', 1.0274333036594734),
#  ('di', 1.0216560814453302),
#  ('okay', 1.0216547540562402),
#  ('fly', 1.0126219789089466),
#  ('cake', 0.9999844327884532),
#  ('ring', 0.9727662450369481),
#  ('summer', 0.9717606520336209),
#  ('dreaming', 0.9699516877633086),
#  ('territory', 0.9656278860265353),
#  ('top', 0.9397712338197587),
#  ('feel', 0.9378168790919961),
#  ('informazioni', 0.9309306718511181),
#  ('face', 0.9296321744225291),
#  ('weight', 0.9289319523486004),
#  ('dance', 0.9117562242359215),
#  ('ride', 0.899818715839306),
#  ('end', 0.8956280319583926),
#  ('doesn', 0.879043590262287),
#  ('living', 0.8746749389219919),
#  ('hard', 0.8618245153822194),
#  ('uh', 0.8598957265258262),
#  ('listen', 0.850177623583095),
#  ('하和', 0.8481632367972597),
#  ('hold', 0.8309889446884715),
#  ('back', 0.8273616959570916),
#  ('baby', 0.8263732458248579),
#  ('room', 0.8188663577236889),
#  ('wish', 0.8153228747238528),
#  ('head', 0.8110099023194601),
#  ('24', 0.8083885271230834),
#  ('girl', 0.8041673473566462),
#  ('noise', 0.8004591356965048),
#  ('bounce', 0.7839147805184147),
#  ('talking', 0.7809527485108454),
#  ('coming', 0.7760101244773138),
#  ('turn', 0.7727778999940186),
#  ('agriculture', 0.7669989007292236),
#  ('wow', 0.7614257702779755),
#  ('new', 0.7564050986615285),
#  ('faster', 0.7508963785118286),
#  ('cuz', 0.7404601403320266),
#  ('cherry', 0.7313674456210993),
#  ('hours', 0.7216172257404677),
#  ('people', 0.7150319046987716),
#  ('warm', 0.7147557595268353),
#  ('waiting', 0.7128438402599807),
#  ('boss', 0.7088681039844057),
#  ('side', 0.7030078223386521),
#  ('nah', 0.6985729110317622),
#  ('high', 0.6931772065501904),
#  ('sick', 0.6931271578947129),
#  ('hurry', 0.6895122044301523),
#  ('orientation', 0.6887744161548873),
#  ('guess', 0.6880484367175779),
#  ('change', 0.6752047801596667),
#  ('city', 0.6720099113867795),
#  ('game', 0.6661920602195248),
#  ('faith', 0.6645337009046776),
#  ('leave', 0.6611485718381948),
#  ('loves', 0.6582468752040607),
#  ('problems', 0.656736429740139),
#  ('weird', 0.6467674024641468),
#  ('non', 0.643230931145541),
#  ('believe', 0.6394797562923993),
#  ('hate', 0.6337816423401608),
#  ('stay', 0.6307736474012828),
#  ('list', 0.626490570257925),
#  ('style', 0.6223898796801847),
#  ('babe', 0.6199447560943144),
#  ('loud', 0.619338975798996),
#  ('being', 0.61664686871474),
#  ('fight', 0.6151708153512823),
#  ('honey', 0.609015193373812),
#  ('rousing', 0.6063701346044671),
#  ('pow', 0.5883224418297636),
#  ('blow', 0.579694584485548),
#  ('eyes', 0.5775908245984758),
#  ('너와', 0.5749352414412133),
#  ('queen', 0.5716019478412504),
#  ('sugar', 0.5715313209980051),
#  ('alone', 0.5611442325317755),
#  ('likes', 0.5543189390699925),
#  ('lost', 0.5536363901172716),
#  ('thank', 0.553452353494958),
#  ('rock', 0.5531759345723285),
#  ('forget', 0.5437891591107168),
#  ('child', 0.5325500086638967),
#  ('movie', 0.530826633040403),
#  ('type', 0.5212487765220324),
#  ('mine', 0.5147335817794386),
#  ('feeling', 0.5125952816495991),
#  ('shut', 0.50271880069984),
#  ('choice', 0.5015072308690525),
#  ('step', 0.5014438581764329),
#  ('guy', 0.49845037574601825),
#  ('free', 0.4919696116986404),
#  ('well', 0.4899576082010363),
#  ('night', 0.48656122019534304),
#  ('way', 0.4856563847224115),
#  ('ooh', 0.4841222916286297),
#  ('touch', 0.48347781484661145),
#  ('imma', 0.48289512119789657),
#  ('crowd', 0.48256680354283693),
#  ('tie', 0.48207945622899845),
#  ('dangerous', 0.47411170971824956),
#  ('problem', 0.47192427670865056),
#  ('fresh', 0.4693628396134677),
#  ('days', 0.4657818577528339),
#  ('gauze', 0.4655154866670485),
#  ('give', 0.4651151129771765),
#  ('limit', 0.46502054843491963),
#  ('fear', 0.46279867173303824),
#  ('和지', 0.46178264912878814),
#  ('boys', 0.4602955309828057),
#  ('un', 0.4558292311998918),
#  ('guys', 0.45116648577109436),
#  ('test', 0.44676793680205656),
#  ('lose', 0.43957909831451153),
#  ('light', 0.4391778937867983),
#  ('ma', 0.4380557930518089),
#  ('한국어', 0.4378415796376014),
#  ('follow', 0.436733089263377),
#  ('sweet', 0.4342787548252755),
#  ('bang', 0.4314665727117204),
#  ('diamond', 0.42886644946438784),
#  ('second', 0.42886644946438784),
#  ('afraid', 0.42673344184830775),
#  ('mean', 0.42286753284537887),
#  ('win', 0.4226601223798717),
#  ('administration', 0.4196861905114002),
#  ('sleep', 0.41958420340036034),
#  ('play', 0.416274732356362),
#  ('sing', 0.4146264311562815),
#  ('walking', 0.4134488116785684),
#  ('gonna', 0.4127404647902942),
#  ('을和', 0.4116061683830745),
#  ('eh', 0.4081894722587663),
#  ('bet', 0.4079042581071949),
#  ('trying', 0.4067667180659522),
#  ('read', 0.40424645941022613),
#  ('stops', 0.40366315682305753),
#  ('tight', 0.39846847647472666),
#  ('clear', 0.3968912073535604),
#  ('united', 0.39532282193412466),
#  ('live', 0.3949792381255032),
#  ('wants', 0.3944820127442152),
#  ('help', 0.3921575912581412),
#  ('wait', 0.39055249020276595),
#  ('hope', 0.3679116857093264),
#  ('그래', 0.3631553240337906),
#  ('prepare', 0.3605457957125967),
#  ('check', 0.35289179570790136),
#  ('cool', 0.3527075891764351),
#  ('true', 0.3508887121889942),
#  ('strong', 0.34795866884726545),
#  ('late', 0.3478721983722545),
#  ('bam', 0.3476961380959017),
#  ('che', 0.34736256069300275),
#  ('body', 0.3434178110428005),
#  ('cute', 0.3357106543130374),
#  ('find', 0.3339982164342926),
#  ('fighting', 0.3334468663690182),
#  ('activities', 0.33319484103815267),
#  ('big', 0.3329522490911667),
#  ('fill', 0.3318156814050176),
#  ('raise', 0.33068336612193394),
#  ('ayy', 0.33043123327573),
#  ('data', 0.3290796911007853),
#  ('whoo', 0.32844519356755997),
#  ('impossible', 0.3247674489582893),
#  ('ve', 0.32423928816511216),
#  ('man', 0.32351721567274627),
#  ('cream', 0.32296272135026877),
#  ('sun', 0.32276892225577486),
#  ('morning', 0.3194245560424368),
#  ('race', 0.31640814978121456),
#  ('games', 0.3160730511005213),
#  ('destiny', 0.31585550825903147),
#  ('life', 0.31351715497759114),
#  ('girls', 0.3133775537431194),
#  ('excuse', 0.31270798285639057),
#  ('mistake', 0.3122513111274008),
#  ('yesterday', 0.3122513111274008),
#  ('heard', 0.31033424354538264),
#  ('wave', 0.30784496000807254),
#  ('rush', 0.3075267396646124),
#  ('colombo', 0.3047524430570244),
#  ('start', 0.30240119163530627),
#  ('fool', 0.3023327501832379),
#  ('daily', 0.302261297720662),
#  ('miss', 0.3015234759959493),
#  ('nurse', 0.30012694244328336),
#  ('track', 0.2985871460348582),
#  ('away', 0.29513078340672894),
#  ('지和지', 0.2941847806875405),
#  ('모두', 0.29356943929738566),
#  ('real', 0.29122260174213443),
#  ('니和까', 0.2877602654121314),
#  ('athletic', 0.28775239199401265),
#  ('lord', 0.286332357894438),
#  ('beat', 0.28624775773204236),
#  ('pretty', 0.2851125655342243),
#  ('su', 0.282459042016726),
#  ('final', 0.2820581829769593),
#  ('beauty', 0.2809295375403482),
#  ('fast', 0.2797318051363188),
#  ('bring', 0.2778075847115299),
#  ('god', 0.27751006758393826),
#  ('still', 0.27654196372066514),
#  ('boom', 0.2765043295831563),
#  ('ice', 0.2758694424911216),
#  ('losing', 0.2747169364009924),
#  ('perfect', 0.2736309879936244),
#  ('welcome', 0.26747128105292084),
#  ('didn', 0.2668562034752684),
#  ('easy', 0.26344931294362134),
#  ('job', 0.2630817720279637),
#  ('rain', 0.2629629505424165),
#  ('cause', 0.2622727051713929),
#  ('yellow', 0.2611622455320155),
#  ('drum', 0.2602827753912392),
#  ('story', 0.2600587279196278),
#  ('funny', 0.2590497661486104),
#  ('il', 0.2580795658123187),
#  ('lights', 0.25748753573007377),
#  ('learn', 0.25738963648042434),
#  ('next', 0.25550677964218993),
#  ('cry', 0.2548817856656579),
#  ('hero', 0.25309443761000916),
#  ('went', 0.2520929874312801),
#  ('pop', 0.25019677856285705),
#  ('kid', 0.24801252459145046),
#  ('feet', 0.24687475441383266),
#  ('pass', 0.2443550389675171),
#  ('和만', 0.24105075639468349),
#  ('born', 0.24060150131067676),
#  ('fine', 0.23681785657773152),
#  ('date', 0.23528426118205317),
#  ('rules', 0.2342997579304591),
#  ('laughter', 0.23052878218875883),
#  ('last', 0.22938695754323918),
#  ('lover', 0.2292731720464863),
#  ('bass', 0.2285163513009742),
#  ('flame', 0.22645567802755495),
#  ('bomb', 0.22453115718068012),
#  ('video', 0.22367838890666297),
#  ('trouble', 0.22258220082220329),
#  ('dream', 0.22146659555927545),
#  ('move', 0.22112797769105563),
#  ('calls', 0.22046140328671415),
#  ('mirror', 0.22009641969006177),
#  ('question', 0.2196227167446106),
#  ('piece', 0.21942548412366167),
#  ('best', 0.21911840599207655),
#  ('roller', 0.2135390741350518),
#  ('finish', 0.21307260033733053),
#  ('name', 0.21061792152471173),
#  ('questions', 0.20903082597397987),
#  ('tonight', 0.20842428050240389),
#  ('criminal', 0.20748359326978166),
#  ('haters', 0.20721575105326207),
#  ('ladies', 0.20685042039832072),
#  ('die', 0.20532394118992628),
#  ('couple', 0.20509629400415347),
#  ('hidden', 0.20247810901499763),
#  ('hands', 0.20244706671445378),
#  ('focus', 0.20209456305552048),
#  ('cut', 0.20008462829552223),
#  ('wild', 0.19973371610306795),
#  ('front', 0.19878548305363158),
#  ('throw', 0.19352706833942757),
#  ('organization', 0.19046140394095173),
#  ('pantyhose', 0.19025634212173867),
#  ('open', 0.18898274474402785),
#  ('bye', 0.1874069146068755),
#  ('roll', 0.18607580115362107),
#  ('view', 0.1859387321167075),
#  ('old', 0.18475536546611954),
#  ('hello', 0.18439168734760264),
#  ('ask', 0.1843510906651394),
#  ('told', 0.184241700462503),
#  ('dreams', 0.18376004534331375),
#  ('contact', 0.18196096952848506),
#  ('act', 0.18065510043651356),
#  ('chance', 0.18037768890713107),
#  ('heartbeat', 0.17851070902514635),
#  ('may', 0.17707129067563104),
#  ('inside', 0.17649846457224946),
#  ('lying', 0.1759119932007345),
#  ('red', 0.17589582103064805),
#  ('youth', 0.17426445553008013),
#  ('te', 0.17299916000292087),
#  ('thinking', 0.17295737812362322),
#  ('sit', 0.17247455370967518),
#  ('news', 0.1723888852037724),
#  ('monster', 0.17050837127985696),
#  ('false', 0.17031262452398843),
#  ('long', 0.1698645663644277),
#  ('anymore', 0.16975506557864148),
#  ('close', 0.16904602317898432),
#  ('terms', 0.16896118357117454),
#  ('great', 0.16822257978574348),
#  ('talk', 0.16780043046415322),
#  ('board', 0.16724274356498775),
#  ('caught', 0.16724274356498775),
#  ('continue', 0.1636062867911501),
#  ('level', 0.16288945063497876),
#  ('flow', 0.1622764775742307),
#  ('round', 0.16053773966516222),
#  ('slow', 0.15973221383236835),
#  ('ora', 0.15963060928743095),
#  ('copyright', 0.15955386614886224),
#  ('gave', 0.15955386614886224),
#  ('ta', 0.15881215275509133),
#  ('dancing', 0.1567235092556231),
#  ('acrylate', 0.15613127151632727),
#  ('trophy', 0.15608318351356293),
#  ('sharing', 0.15574167005552714),
#  ('double', 0.1555087817855751),
#  ('beautiful', 0.15469712429436888),
#  ('made', 0.15219012629980355),
#  ('comment', 0.1519659596710938),
#  ('하和하', 0.1516853372596012),
#  ('kingdom', 0.14988439047646618),
#  ('wrong', 0.14688769553263134),
#  ('lonely', 0.14676008079532485),
#  ('izen', 0.1465719833196277),
#  ('rights', 0.1465719833196277),
#  ('run', 0.1461454741414213),
#  ('reserved', 0.14570752849442525),
#  ('stupid', 0.14460431530191595),
#  ('wonder', 0.14399737474836233),
#  ('forgot', 0.14027040735515417),
#  ('hesitate', 0.1401955649364684),
#  ('important', 0.14005275021197514),
#  ('rest', 0.13896649844471057),
#  ('password', 0.1388831059035022),
#  ('burn', 0.13886636279455386),
#  ('hi', 0.13884109780319964),
#  ('shoot', 0.13595088183549706),
#  ('celebrate', 0.13194008822680142),
#  ('line', 0.1314581515252755),
#  ('dry', 0.1301670680214449),
#  ('mom', 0.12804311264956325),
#  ('tired', 0.1271336430220517),
#  ('natural', 0.12590880723518344),
#  ('negative', 0.12432094861814323),
#  ('teach', 0.12252774620151329),
#  ('dead', 0.12245373904538727),
#  ('fireworks', 0.1214598667903418),
#  ('traduzione', 0.12055869606667227),
#  ('full', 0.12031827473342316),
#  ('fire', 0.11992073370535829),
#  ('wake', 0.11979678095934085),
#  ('land', 0.11968614096002905),
#  ('programme', 0.11832978652904311),
#  ('number', 0.1175289702917774),
#  ('던子', 0.1168078045405331),
#  ('beats', 0.11660991753830265),
#  ('star', 0.11656147217100163),
#  ('shot', 0.11637774243797758),
#  ('slowly', 0.11600881842802895),
#  ('single', 0.11563333718973692),
#  ('fault', 0.11554682000695446),
#  ('force', 0.11501857066295354),
#  ('playing', 0.11492630017253976),
#  ('standing', 0.11389660917623394),
#  ('food', 0.1135437224224855),
#  ('road', 0.1134450476947573),
#  ('continues', 0.11312350226772747),
#  ('today', 0.1123824601903837),
#  ('island', 0.11052011482391402),
#  ('worried', 0.10933815022277604),
#  ('able', 0.10716964575214301),
#  ('trapped', 0.1067695370675259),
#  ('space', 0.10662267000508238),
#  ('shake', 0.10624975358111874),
#  ('price_varies', 0.10567227244000885),
#  ('attitude', 0.10532590695814757),
#  ('making', 0.10532590695814757),
#  ('fan', 0.10523230209545982),
#  ('watching', 0.10523230209545982),
#  ('breathe', 0.10509821532479563),
#  ('satisfied', 0.10461222283429475),
#  ('eat', 0.10453635101724754),
#  ('nice', 0.10451668138645619),
#  ('stage', 0.10423560334541711),
#  ('film', 0.10311590051439083),
#  ('goodbye', 0.10288001031188847),
#  ('closed', 0.10250891322153748),
#  ('subscribe', 0.10129808839354515),
#  ('smooth', 0.10129001221637762),
#  ('future', 0.10105098049497716),
#  ('stanza', 0.1007756461661712),
#  ('sad', 0.09978501619150863),
#  ('bling', 0.0992464459122865),
#  ('ho', 0.0992464459122865),
#  ('gon', 0.09907874781372907),
#  ('finished', 0.0989161535458942),
#  ('knows', 0.098311834658348),
#  ('던和', 0.09759809604354201),
#  ('push', 0.09711371815901995),
#  ('leaving', 0.09628969356410781),
#  ('sign', 0.0962075165944312),
#  ('nights', 0.09613949813583765),
#  ('makes', 0.0947607289234819),
#  ('woah', 0.09462043384258616),
#  ('sure', 0.09423857275108527),
#  ('friends', 0.09419254487997074),
#  ('grow', 0.09407760088729411),
#  ('edge', 0.09373833436773708),
#  ('higher', 0.09297090526770717),
#  ('saying', 0.09230790376142918),
#  ('thoughts', 0.09226522671534901),
#  ('sea', 0.09217428486088082),
#  ('hell', 0.09157231213366412),
#  ('facebook', 0.09150560043550823),
#  ('fate', 0.09115888961834057),
#  ('near', 0.09090555160142487),
#  ('party', 0.09049182471243222),
#  ('hide', 0.09035935255330876),
#  ('page', 0.08994118208017773),
#  ('zero', 0.08994118208017773),
#  ('laugh', 0.08849864011618076),
#  ('busy', 0.08734854986638113),
#  ('appearance', 0.08635209144972164),
#  ('kind', 0.08539383652488595),
#  ('broken', 0.08533899673598751),
#  ('working', 0.0850545276309476),
#  ('buy', 0.08300344950946709),
#  ('drama', 0.08297117794886366),
#  ('comes', 0.08162865591592437),
#  ('heaven', 0.08074056035753203),
#  ('bed', 0.08038563049650466),
#  ('first', 0.08033612838677485),
#  ('tea', 0.08031776316567968),
#  ('calling', 0.07937187285021335),
#  ('persons', 0.07859549958920156),
#  ('zoom', 0.07802420195098284),
#  ('medicine', 0.07767275828192455),
#  ('rose', 0.07767275828192455),
#  ('tried', 0.0775452344149821),
#  ('whoa', 0.07669321315513399),
#  ('pain', 0.07614553823129463),
#  ('ha', 0.07551409308083107),
#  ('magic', 0.07551409308083107),
#  ('fun', 0.07516768416887076),
#  ('young', 0.07516768416887076),
#  ('amazing', 0.07482348950300144),
#  ('yo', 0.07455170408806797),
#  ('rate', 0.07362086945399589),
#  ('history', 0.07314681519032425),
#  ('invalid', 0.07166277528968766),
#  ('skip', 0.07166277528968766),
#  ('mother', 0.07133385222285658),
#  ('white', 0.07110492159308222),
#  ('sweat', 0.07021727130543172),
#  ('blue', 0.06821881692998454),
#  ('return', 0.06796703726558911),
#  ('diamonds', 0.06755877510797573),
#  ('reason', 0.06618598076920615),
#  ('feelings', 0.06576633249369428),
#  ('signs', 0.06554779624669833),
#  ('burns', 0.0642704538829276),
#  ('special', 0.06417559220087037),
#  ('dreamed', 0.06309219650599239),
#  ('share', 0.062407516440344965),
#  ('try', 0.06207938625143628),
#  ('drop', 0.0615595346361678),
#  ('sky', 0.06120113460218352),
#  ('goes', 0.06117565905369946),
#  ('running', 0.060822940730961166),
#  ('smile', 0.06078916925579105),
#  ('flash', 0.05861308906346662),
#  ('looking', 0.0584397336309038),
#  ('friend', 0.0566044444655382),
#  ('hand', 0.05540483443784813),
#  ('price', 0.053426324079064225),
#  ('enjoy', 0.051034027167362155),
#  ('sounds', 0.049958850830732496),
#  ('english', 0.04962322295614325),
#  ('straight', 0.04947140252969664),
#  ('blowing', 0.0467916240295063),
#  ('ping', 0.046071006435556394),
#  ('song', 0.041567971865212945),
#  ('hiding', 0.04131612603498586),
#  ('attempted', 0.03966741164843576),
#  ('damn', 0.03557173348395199),
#  ('shoes', 0.03294981826693005),
#  ('generating', 0.03225824463632198),
#  ('dive', 0.031546098252996195),
#  ('wanted', 0.029963188914236924),
#  ('door', 0.029446435281519315),
#  ('waste', 0.028111822087511187),
#  ('part', 0.02737709403650163),
#  ('phone', 0.02733582125478584),
#  ('word', 0.024104844825225034),
#  ('temperature', 0.0228260793653693),
#  ('message', 0.022532614658995566),
#  ('calm', 0.022100195848897258),
#  ('atmosphere', 0.01963117515591171),
#  ('understand', 0.017963986950065756),
#  ('dynamite', 0.011857244494650662),
#  ('passion', 0.011550381610449805),
#  ('speed', 0.011050097924448629),
#  ('zione', 0.010650629116052112),
#  ('heat', 0.010318079831840596),
#  ('maybe', 0.0010201973441130612)]

# %% [markdown]
# ### Topic analysis

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
def save_lda_vis(lda, corpus, dictionary, filename):
    vis = gensimvis.prepare(lda, corpus, dictionary)
    pyLDAvis.save_html(vis, filename)
    
    with open(filename, "r") as f:
        html = f.read()
        
    return html, vis

# %%
def pre_process(df_lyrics):
    # tokenize lyrics
    lyrics_processed = df_lyrics.fillna("").str.split()

    for _list in lyrics_processed:
        for cnt in range(len(_list)):
            _list[cnt] = _list[cnt].replace(".", "").replace(",", "").replace("?", "").replace("\\", "").replace("/", "").replace(":", "").lower()
            
            if is_stopword(_list[cnt]):
                _list[cnt] = ""
                
    # remove empty string
    for cnt in range(len(lyrics_processed)):
        while(True):
            try:
                lyrics_processed[cnt].remove("")
            except:
                break

    return lyrics_processed

# %% [markdown]
# #### Among global

# %%
df_looking = df[df["grouping"].isin(target_and_global)].reset_index(drop=True)

# %%
#train model
lyrics_processed = pre_process(df_looking["lyrics"])
dictionary = Dictionary(lyrics_processed)
corpus = [dictionary.doc2bow(text) for text in lyrics_processed]
lda = LdaModel(corpus=corpus, id2word=dictionary, num_topics=100)

# %% [markdown]
# all topics

# %%
lda_html_global, vis = save_lda_vis(lda, corpus, dictionary, "lda.html")

vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 57     0.092387 -0.048408       1        1  3.283710
# 60     0.089717 -0.039305       2        1  2.776482
# 30     0.111992 -0.065036       3        1  2.741017
# 44     0.069789 -0.014851       4        1  2.568751
# 21    -0.279776 -0.310737       5        1  2.527943
# ...         ...       ...     ...      ...       ...
# 34    -0.084809  0.053001      96        1  0.303823
# 17    -0.173009  0.076600      97        1  0.255255
# 27    -0.079329  0.056883      98        1  0.232348
# 75    -0.067037  0.058842      99        1  0.224647
# 0     -0.149979 -0.110891     100        1  0.211946
#
# [100 rows x 5 columns], topic_info=        Term         Freq        Total  Category  logprob  loglift
# 4853  labour  6806.000000  6806.000000   Default  30.0000  30.0000
# 862     cake  1829.000000  1829.000000   Default  29.0000  29.0000
# 88      baby  4967.000000  4967.000000   Default  28.0000  28.0000
# 707     work  2634.000000  2634.000000   Default  27.0000  27.0000
# 33      love  7052.000000  7052.000000   Default  26.0000  26.0000
# ...      ...          ...          ...       ...      ...      ...
# 96      down     4.053847  2429.043884  Topic100  -5.4449  -0.2390
# 194      yes     3.897431  2186.194269  Topic100  -5.4843  -0.1730
# 333      say     3.755487  3220.060021  Topic100  -5.5214  -0.5973
# 497     girl     3.654713  2392.468475  Topic100  -5.5486  -0.3275
# 527    money     3.557706  1189.203869  Topic100  -5.5755   0.3447
#
# [6667 rows x 6 columns], token_table=       Topic      Freq      Term
# term
# 18169     87  0.381587        "a
# 16619     36  0.570958     "burp
# 16408     44  0.552334     "call
# 2335      16  0.202787     "come
# 2335      21  0.101393     "come
# ...      ...       ...       ...
# 14858     45  0.575809      zula
# 11742     56  0.847342        “i
# 14005     49  0.882020  “khalifa
# 14619     14  0.872576    “we’re
# 162       43  0.683404        和지
#
# [49963 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[58, 61, 31, 45, 22, 56, 38, 42, 9, 89, 92, 64, 43, 53, 48, 25, 5, 15, 98, 75, 95, 10, 91, 27, 4, 72, 79, 71, 81, 17, 37, 32, 59, 39, 29, 2, 88, 87, 67, 13, 69, 74, 50, 26, 85, 33, 54, 47, 80, 11, 40, 86, 96, 20, 19, 66, 68, 77, 12, 78, 30, 51, 44, 14, 97, 55, 21, 57, 99, 84, 60, 8, 90, 70, 100, 82, 73, 93, 16, 7, 24, 65, 62, 41, 63, 83, 46, 49, 23, 34, 94, 36, 6, 3, 52, 35, 18, 28, 76, 1])

# %% [markdown]
# what topics are in kpop?

# %%
threshold = 0.3

counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    topics = lda.get_document_topics(corpus[cnt], minimum_probability=0)
    
    for topic in topics:
        if topic[1] > threshold:
            counter[topic[0]] = counter.get(topic[0], 0) + 1
            
        summer[topic[0]] = summer.get(topic[0], 0) + float(topic[1])

# %%
_lda_counter_global = sort_dictionary(counter)
lda_counter_global = []
for tup in _lda_counter_global:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_counter_global.append(new_tup)
    
lda_counter_global
# Out:
# [[60,
#   5,
#   [('night', 0.032860707),
#    ('baby', 0.01748109),
#    ('awake', 0.015840512),
#    ('put', 0.015284688),
#    ('let', 0.013912941),
#    ('sorry', 0.011289967),
#    ('need', 0.011113763),
#    ("let's", 0.010872562),
#    ("we're", 0.010855437),
#    ('only', 0.010647571)]],
#  [3,
#   4,
#   [('dance', 0.15623459),
#    ('take', 0.021970028),
#    ('back', 0.014065792),
#    ('only', 0.011694177),
#    ('feel', 0.011261701),
#    ('love', 0.011122922),
#    ("let's", 0.01012209),
#    ('once', 0.009636374),
#    ('bottom', 0.00954894),
#    ("can't", 0.009354201)]],
#  [80,
#   4,
#   [('think', 0.030435959),
#    ('lose', 0.015799498),
#    ('hard', 0.0127345715),
#    ('take', 0.012161051),
#    ('new', 0.010120002),
#    ('give', 0.009799788),
#    ('bye', 0.009224499),
#    ('let', 0.009114276),
#    ('am', 0.009088236),
#    ('only', 0.008822472)]],
#  [55,
#   4,
#   [('feel', 0.026136218),
#    ('mind', 0.022587433),
#    ('coming', 0.013278444),
#    ('girl', 0.0127936965),
#    ('love', 0.011802135),
#    ('say', 0.011079406),
#    ("can't", 0.010525564),
#    ('night', 0.0096738655),
#    ('let', 0.009664745),
#    ('woo', 0.007209554)]],
#  [63,
#   3,
#   [('think', 0.019424383),
#    ('am', 0.018479193),
#    ('bad', 0.014891152),
#    ('problems', 0.008137777),
#    ('love', 0.008021859),
#    ('shit', 0.0073229424),
#    ('keep', 0.0072224755),
#    ('man', 0.00654025),
#    ('try', 0.006386263),
#    ('bleeding', 0.006340031)]],
#  [36,
#   3,
#   [('worry', 0.022394314),
#    ('baby', 0.009861896),
#    ("chi't", 0.009071086),
#    ('night', 0.00893742),
#    ('power', 0.0088928575),
#    ("doesn't", 0.007238574),
#    ('bouncin', 0.006893215),
#    ('hit', 0.006877911),
#    ('little', 0.0065881866),
#    ('wants', 0.0065581184)]],
#  [10,
#   3,
#   [('destra', 0.02160133),
#    ('fall', 0.016630193),
#    ('die', 0.014749734),
#    ('che', 0.013866635),
#    ('life', 0.013599987),
#    ('non', 0.012398755),
#    ('give', 0.011652201),
#    ('take', 0.011509154),
#    ('love', 0.010315989),
#    ('let', 0.009595395)]],
#  [32,
#   2,
#   [('love', 0.022364276),
#    ('shy', 0.0149327265),
#    ("we're", 0.0139377685),
#    ('say', 0.013549959),
#    ('born', 0.013124716),
#    ('late', 0.012767798),
#    ('hands', 0.0124785835),
#    ('lucky', 0.012134799),
#    ('applause', 0.011680228),
#    ('take', 0.010690802)]],
#  [94,
#   2,
#   [('love', 0.024096606),
#    ('alone', 0.0159423),
#    ('say', 0.014227303),
#    ('am', 0.012581388),
#    ('take', 0.011519663),
#    ('business', 0.011301445),
#    ('matter', 0.01074271),
#    ('fault', 0.009397965),
#    ('bitch', 0.009047865),
#    ("can't", 0.008712203)]],
#  [54,
#   2,
#   [('mad', 0.052204728),
#    ('ring', 0.03734826),
#    ('put', 0.02765043),
#    ('gimme', 0.021075362),
#    ('ladies', 0.0104890475),
#    ('liked', 0.009872762),
#    ('single', 0.009493311),
#    ('cherry', 0.0080773365),
#    ('(uh-huh)', 0.0076408046),
#    ('love', 0.0071651256)]],
#  [30,
#   2,
#   [('love', 0.14383829),
#    ('leave', 0.017477382),
#    ('fight', 0.017241152),
#    ('let', 0.016216269),
#    ('mine', 0.016096054),
#    ('heart', 0.014562006),
#    ('yes', 0.011197337),
#    ('need', 0.009733325),
#    ('tell', 0.008992288),
#    ('give', 0.008937499)]],
#  [39,
#   2,
#   [('thunder', 0.05187917),
#    ('take', 0.023085294),
#    ('hear', 0.019198699),
#    ('labour', 0.012265394),
#    ('night', 0.011744234),
#    ('follow', 0.010816059),
#    ('lightning', 0.008318945),
#    ('feel', 0.007105238),
#    ('say', 0.0070667868),
#    ('riding', 0.0069982805)]],
#  [74,
#   2,
#   [('hot', 0.13831882),
#    ('imma', 0.037455466),
#    ('girl', 0.011893309),
#    ('run', 0.010374306),
#    ("that's", 0.01036128),
#    ("can't", 0.008678368),
#    ('night', 0.008173989),
#    ('life', 0.00787242),
#    ('baby', 0.006881184),
#    ('love', 0.0066078734)]],
#  [15,
#   2,
#   [('work', 0.048769932),
#    ('labour', 0.032405365),
#    ('dance', 0.02961154),
#    ('say', 0.021202587),
#    ('spicy', 0.017478183),
#    ('ay', 0.015798816),
#    ('feel', 0.012790361),
#    ('(hello)', 0.012417247),
#    ('let', 0.011884585),
#    ('move', 0.011328761)]],
#  [18,
#   2,
#   [('head', 0.04348086),
#    ('girl', 0.043084003),
#    ('came', 0.022225369),
#    ('gurl', 0.016947841),
#    ('happy', 0.014087098),
#    ('stay', 0.0132232215),
#    ('stuck', 0.012377906),
#    ("that's", 0.012023304),
#    ('makes', 0.011849266),
#    ("can't", 0.010982354)]],
#  [26,
#   2,
#   [('baby', 0.45459947),
#    ('love', 0.018430516),
#    ('wild', 0.011755012),
#    ('fun', 0.010289021),
#    ('girl', 0.008258204),
#    ('yes', 0.008169714),
#    ('made', 0.008139171),
#    ('think', 0.0069449474),
#    ("who's", 0.006325021),
#    ('blood', 0.0049101263)]],
#  [82,
#   2,
#   [('flower', 0.10265996),
#    ('g6', 0.047584765),
#    ('drive', 0.037694693),
#    ('love', 0.021921981),
#    ('purple', 0.014927023),
#    ('put', 0.012697897),
#    ('me!', 0.01162722),
#    ('still', 0.010535603),
#    ('bottles', 0.010233404),
#    ('let', 0.009814454)]],
#  [42,
#   1,
#   [('call', 0.029030176),
#    ("we're", 0.0208307),
#    ("can't", 0.016084407),
#    ('dance', 0.015986267),
#    ('stay', 0.009865734),
#    ('night', 0.009460997),
#    ('need', 0.008694368),
#    ('keep', 0.0074453023),
#    ('life', 0.0074065984),
#    ('low', 0.0069645527)]],
#  [44,
#   1,
#   [('love', 0.019908585),
#    ('say', 0.014980935),
#    ('need', 0.013607578),
#    ('give', 0.012551892),
#    ('life', 0.012355512),
#    ('tell', 0.009664286),
#    ('down', 0.008688899),
#    ('night', 0.008069489),
#    ("can't", 0.00795034),
#    ('mmm', 0.007189389)]],
#  [49,
#   1,
#   [('nana', 0.17088841),
#    ('yes', 0.028125763),
#    ('boom', 0.023853226),
#    ('yes)', 0.020822104),
#    ('hi', 0.017098138),
#    ('(yes', 0.016881198),
#    ('moon', 0.014800098),
#    ('let', 0.0118862875),
#    ('feel', 0.009596546),
#    ('say', 0.008660524)]],
#  [68,
#   1,
#   [('summer', 0.057285264),
#    ("let's", 0.038119156),
#    ('back', 0.021974787),
#    ('floor', 0.018624676),
#    ('air', 0.018169716),
#    ('new', 0.017698357),
#    ('ibiza', 0.010451789),
#    ('york', 0.010398234),
#    ('life', 0.010126384),
#    ('cha', 0.008932164)]],
#  [93,
#   1,
#   [('home', 0.083676994),
#    ('tired', 0.034444246),
#    ('dat', 0.028203635),
#    ('tonight', 0.024564343),
#    ('songs', 0.022916256),
#    ('call', 0.019936262),
#    ('love', 0.019479789),
#    ('proud', 0.013353766),
#    ('put', 0.008924872),
#    ('back', 0.008886514)]],
#  [86,
#   1,
#   [('share', 0.015708974),
#    ('end', 0.011064958),
#    ('feel', 0.009950247),
#    ('sta', 0.009941662),
#    ('walk', 0.009119106),
#    ("i've", 0.008996909),
#    ('dead', 0.007871934),
#    ('made', 0.00741247),
#    ('say', 0.0073922444),
#    ('thinking', 0.0069676866)]],
#  [8,
#   1,
#   [('girl', 0.021690562),
#    ('love', 0.01703343),
#    ("can't", 0.013399231),
#    ('friends', 0.01310549),
#    ('back', 0.011010429),
#    ('problem', 0.010934262),
#    ('house', 0.009802179),
#    ('yes', 0.009243922),
#    ('say', 0.008671484),
#    ('bitch', 0.008034594)]],
#  [47,
#   1,
#   [('fuck', 0.03303462),
#    ('wake', 0.025765305),
#    ('shit', 0.015838085),
#    ('life', 0.013140921),
#    ('put', 0.009433572),
#    ('back', 0.008915963),
#    ('long', 0.0078999875),
#    ('power', 0.0075632576),
#    ('take', 0.0072390363),
#    ('bitch', 0.007130413)]],
#  [14,
#   1,
#   [('way', 0.04725867),
#    ('let', 0.023954356),
#    ('love', 0.01862898),
#    ('find', 0.013273726),
#    ('middle', 0.012181019),
#    ('cry', 0.011804106),
#    ('meet', 0.010450458),
#    ('bit', 0.0099277105),
#    ('give', 0.009424955),
#    ('words', 0.008628183)]],
#  [2,
#   1,
#   [('id', 0.057724107),
#    ('love', 0.029644832),
#    ('higher', 0.028402045),
#    ('that)', 0.019955434),
#    ('bring', 0.015783487),
#    ('boy', 0.012935483),
#    ('ella', 0.011931835),
#    ('love)', 0.011477454),
#    ('tell', 0.010291617),
#    ('destroyed', 0.010182014)]],
#  [4,
#   1,
#   [('need', 0.018496849),
#    ('say', 0.018463176),
#    ('girl', 0.015648281),
#    ('down', 0.014573951),
#    ('feel', 0.013832175),
#    ('beautiful', 0.012875499),
#    ('let', 0.012441997),
#    ('yes', 0.012037823),
#    ('today', 0.011098475),
#    ('am', 0.010818439)]],
#  [19,
#   1,
#   [('pedal', 0.025291152),
#    ('take', 0.019629154),
#    ('domino', 0.015698688),
#    ('started', 0.013919111),
#    ('old', 0.011739435),
#    ('gas', 0.009832626),
#    ('mediocre', 0.009693556),
#    ('club', 0.009188057),
#    ('leave', 0.009098672),
#    ('loved', 0.008727233)]],
#  [33,
#   1,
#   [('shots', 0.077695265),
#    ('waiting', 0.058241885),
#    ('pass', 0.016475612),
#    ('car', 0.012698126),
#    ('dark', 0.011766961),
#    ('bet', 0.011370408),
#    ('shoe', 0.011188367),
#    ('god!', 0.010773136),
#    ('fucked', 0.01011156),
#    ('fuck', 0.007715325)]],
#  [67,
#   1,
#   [('cake', 0.53953683),
#    ('rock', 0.01839075),
#    ('celebrate', 0.010748935),
#    ('tonight', 0.006608551),
#    ('awake', 0.006149939),
#    ('ocean', 0.0052830875),
#    ('yes', 0.005038736),
#    ('star', 0.0048756516),
#    ('give', 0.0047777495),
#    ('need', 0.004514664)]],
#  [75,
#   1,
#   [('low', 0.0640775),
#    ('girlfriend', 0.04188881),
#    ('"i\'m', 0.020229239),
#    ('swish', 0.019490141),
#    ('believe', 0.013590654),
#    ('feel', 0.011044197),
#    ('club', 0.010381524),
#    ('understand', 0.009754164),
#    ('girls', 0.009722532),
#    ("can't", 0.008979461)]],
#  [40,
#   1,
#   [('fine', 0.06624731),
#    ('club)', 0.019131178),
#    ('stay', 0.012723087),
#    ('am', 0.011263864),
#    ('back', 0.010846847),
#    ('feel', 0.010388891),
#    ('bring', 0.010356317),
#    ('take', 0.008870968),
#    ("there's", 0.007864133),
#    ("we'd", 0.0075369454)]]]

# %%
_lda_summer_global = sort_dictionary(summer)
lda_summer_global = []
for tup in _lda_summer_global:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_summer_global.append(new_tup)
    
lda_summer_global
# Out:
# [[60,
#   4.627612700844111,
#   [('night', 0.032860707),
#    ('baby', 0.01748109),
#    ('awake', 0.015840512),
#    ('put', 0.015284688),
#    ('let', 0.013912941),
#    ('sorry', 0.011289967),
#    ('need', 0.011113763),
#    ("let's", 0.010872562),
#    ("we're", 0.010855437),
#    ('only', 0.010647571)]],
#  [3,
#   3.4884902131584568,
#   [('dance', 0.15623459),
#    ('take', 0.021970028),
#    ('back', 0.014065792),
#    ('only', 0.011694177),
#    ('feel', 0.011261701),
#    ('love', 0.011122922),
#    ("let's", 0.01012209),
#    ('once', 0.009636374),
#    ('bottom', 0.00954894),
#    ("can't", 0.009354201)]],
#  [55,
#   3.4550811987996894,
#   [('feel', 0.026136218),
#    ('mind', 0.022587433),
#    ('coming', 0.013278444),
#    ('girl', 0.0127936965),
#    ('love', 0.011802135),
#    ('say', 0.011079406),
#    ("can't", 0.010525564),
#    ('night', 0.0096738655),
#    ('let', 0.009664745),
#    ('woo', 0.007209554)]],
#  [36,
#   3.029872133140543,
#   [('worry', 0.022394314),
#    ('baby', 0.009861896),
#    ("chi't", 0.009071086),
#    ('night', 0.00893742),
#    ('power', 0.0088928575),
#    ("doesn't", 0.007238574),
#    ('bouncin', 0.006893215),
#    ('hit', 0.006877911),
#    ('little', 0.0065881866),
#    ('wants', 0.0065581184)]],
#  [94,
#   2.8515642024199224,
#   [('love', 0.024096606),
#    ('alone', 0.0159423),
#    ('say', 0.014227303),
#    ('am', 0.012581388),
#    ('take', 0.011519663),
#    ('business', 0.011301445),
#    ('matter', 0.01074271),
#    ('fault', 0.009397965),
#    ('bitch', 0.009047865),
#    ("can't", 0.008712203)]],
#  [10,
#   2.5542153037245043,
#   [('destra', 0.02160133),
#    ('fall', 0.016630193),
#    ('die', 0.014749734),
#    ('che', 0.013866635),
#    ('life', 0.013599987),
#    ('non', 0.012398755),
#    ('give', 0.011652201),
#    ('take', 0.011509154),
#    ('love', 0.010315989),
#    ('let', 0.009595395)]],
#  [74,
#   2.5222400072675555,
#   [('hot', 0.13831882),
#    ('imma', 0.037455466),
#    ('girl', 0.011893309),
#    ('run', 0.010374306),
#    ("that's", 0.01036128),
#    ("can't", 0.008678368),
#    ('night', 0.008173989),
#    ('life', 0.00787242),
#    ('baby', 0.006881184),
#    ('love', 0.0066078734)]],
#  [54,
#   2.2810232920442104,
#   [('mad', 0.052204728),
#    ('ring', 0.03734826),
#    ('put', 0.02765043),
#    ('gimme', 0.021075362),
#    ('ladies', 0.0104890475),
#    ('liked', 0.009872762),
#    ('single', 0.009493311),
#    ('cherry', 0.0080773365),
#    ('(uh-huh)', 0.0076408046),
#    ('love', 0.0071651256)]],
#  [80,
#   2.04351170599557,
#   [('think', 0.030435959),
#    ('lose', 0.015799498),
#    ('hard', 0.0127345715),
#    ('take', 0.012161051),
#    ('new', 0.010120002),
#    ('give', 0.009799788),
#    ('bye', 0.009224499),
#    ('let', 0.009114276),
#    ('am', 0.009088236),
#    ('only', 0.008822472)]],
#  [63,
#   1.9378062680702897,
#   [('think', 0.019424383),
#    ('am', 0.018479193),
#    ('bad', 0.014891152),
#    ('problems', 0.008137777),
#    ('love', 0.008021859),
#    ('shit', 0.0073229424),
#    ('keep', 0.0072224755),
#    ('man', 0.00654025),
#    ('try', 0.006386263),
#    ('bleeding', 0.006340031)]],
#  [30,
#   1.9314778819448293,
#   [('love', 0.14383829),
#    ('leave', 0.017477382),
#    ('fight', 0.017241152),
#    ('let', 0.016216269),
#    ('mine', 0.016096054),
#    ('heart', 0.014562006),
#    ('yes', 0.011197337),
#    ('need', 0.009733325),
#    ('tell', 0.008992288),
#    ('give', 0.008937499)]],
#  [32,
#   1.912958119106861,
#   [('love', 0.022364276),
#    ('shy', 0.0149327265),
#    ("we're", 0.0139377685),
#    ('say', 0.013549959),
#    ('born', 0.013124716),
#    ('late', 0.012767798),
#    ('hands', 0.0124785835),
#    ('lucky', 0.012134799),
#    ('applause', 0.011680228),
#    ('take', 0.010690802)]],
#  [82,
#   1.7935551900795872,
#   [('flower', 0.10265996),
#    ('g6', 0.047584765),
#    ('drive', 0.037694693),
#    ('love', 0.021921981),
#    ('purple', 0.014927023),
#    ('put', 0.012697897),
#    ('me!', 0.01162722),
#    ('still', 0.010535603),
#    ('bottles', 0.010233404),
#    ('let', 0.009814454)]],
#  [42,
#   1.621296095616799,
#   [('call', 0.029030176),
#    ("we're", 0.0208307),
#    ("can't", 0.016084407),
#    ('dance', 0.015986267),
#    ('stay', 0.009865734),
#    ('night', 0.009460997),
#    ('need', 0.008694368),
#    ('keep', 0.0074453023),
#    ('life', 0.0074065984),
#    ('low', 0.0069645527)]],
#  [26,
#   1.5950990094993358,
#   [('baby', 0.45459947),
#    ('love', 0.018430516),
#    ('wild', 0.011755012),
#    ('fun', 0.010289021),
#    ('girl', 0.008258204),
#    ('yes', 0.008169714),
#    ('made', 0.008139171),
#    ('think', 0.0069449474),
#    ("who's", 0.006325021),
#    ('blood', 0.0049101263)]],
#  [44,
#   1.5817990291093338,
#   [('love', 0.019908585),
#    ('say', 0.014980935),
#    ('need', 0.013607578),
#    ('give', 0.012551892),
#    ('life', 0.012355512),
#    ('tell', 0.009664286),
#    ('down', 0.008688899),
#    ('night', 0.008069489),
#    ("can't", 0.00795034),
#    ('mmm', 0.007189389)]],
#  [67,
#   1.3727986591384251,
#   [('cake', 0.53953683),
#    ('rock', 0.01839075),
#    ('celebrate', 0.010748935),
#    ('tonight', 0.006608551),
#    ('awake', 0.006149939),
#    ('ocean', 0.0052830875),
#    ('yes', 0.005038736),
#    ('star', 0.0048756516),
#    ('give', 0.0047777495),
#    ('need', 0.004514664)]],
#  [14,
#   1.2745818501484791,
#   [('way', 0.04725867),
#    ('let', 0.023954356),
#    ('love', 0.01862898),
#    ('find', 0.013273726),
#    ('middle', 0.012181019),
#    ('cry', 0.011804106),
#    ('meet', 0.010450458),
#    ('bit', 0.0099277105),
#    ('give', 0.009424955),
#    ('words', 0.008628183)]],
#  [85,
#   1.252999952434493,
#   [('show', 0.20085736),
#    ('down', 0.105862446),
#    ('stop!', 0.026457151),
#    ('infinite', 0.025756957),
#    ('need', 0.010828099),
#    ('love', 0.009894428),
#    ('24', 0.00983786),
#    ("wouldn't", 0.009635864),
#    ('rode', 0.009590601),
#    ('change', 0.009136828)]],
#  [39,
#   1.0637017429748994,
#   [('thunder', 0.05187917),
#    ('take', 0.023085294),
#    ('hear', 0.019198699),
#    ('labour', 0.012265394),
#    ('night', 0.011744234),
#    ('follow', 0.010816059),
#    ('lightning', 0.008318945),
#    ('feel', 0.007105238),
#    ('say', 0.0070667868),
#    ('riding', 0.0069982805)]],
#  [49,
#   1.0356981230929705,
#   [('nana', 0.17088841),
#    ('yes', 0.028125763),
#    ('boom', 0.023853226),
#    ('yes)', 0.020822104),
#    ('hi', 0.017098138),
#    ('(yes', 0.016881198),
#    ('moon', 0.014800098),
#    ('let', 0.0118862875),
#    ('feel', 0.009596546),
#    ('say', 0.008660524)]],
#  [33,
#   1.023792461476205,
#   [('shots', 0.077695265),
#    ('waiting', 0.058241885),
#    ('pass', 0.016475612),
#    ('car', 0.012698126),
#    ('dark', 0.011766961),
#    ('bet', 0.011370408),
#    ('shoe', 0.011188367),
#    ('god!', 0.010773136),
#    ('fucked', 0.01011156),
#    ('fuck', 0.007715325)]],
#  [16,
#   1.0161138251701232,
#   [('love', 0.076498985),
#    ('shut', 0.033205077),
#    ('animals', 0.016874485),
#    ('lose', 0.015533122),
#    ('feel', 0.014538347),
#    ('bad', 0.013970704),
#    ('ah', 0.012152718),
#    ('need', 0.011098361),
#    ('romance', 0.010088863),
#    ('down', 0.009841994)]],
#  [68,
#   1.005940018840647,
#   [('summer', 0.057285264),
#    ("let's", 0.038119156),
#    ('back', 0.021974787),
#    ('floor', 0.018624676),
#    ('air', 0.018169716),
#    ('new', 0.017698357),
#    ('ibiza', 0.010451789),
#    ('york', 0.010398234),
#    ('life', 0.010126384),
#    ('cha', 0.008932164)]],
#  [46,
#   0.997524535805951,
#   [('baby', 0.025677193),
#    ('back', 0.019546336),
#    ('give', 0.016377052),
#    ('club', 0.015030977),
#    ('su', 0.0109584555),
#    ('love', 0.00945862),
#    ('increasing', 0.0091748005),
#    ('bounce', 0.00876715),
#    ('think', 0.008525766),
#    ('limit', 0.008038961)]],
#  [57,
#   0.9915888390082728,
#   [("can't", 0.04898855),
#    ('heart', 0.028000671),
#    ('think', 0.017729945),
#    ('say', 0.01650279),
#    ('feel', 0.011890303),
#    ('love', 0.011629603),
#    ('keep', 0.011359967),
#    ('take', 0.010961393),
#    ('miss', 0.010901578),
#    ('down', 0.010730914)]],
#  [45,
#   0.9623728009523802,
#   [('hell', 0.06253946),
#    ('hope', 0.059944242),
#    ('gives', 0.054588247),
#    ('piccola', 0.032737453),
#    ('questo', 0.02294018),
#    ('di', 0.018435001),
#    ('face', 0.01384928),
#    ('home', 0.01268886),
#    ('alabama', 0.011621456),
#    ('way', 0.01147562)]],
#  [19,
#   0.9440160822837242,
#   [('pedal', 0.025291152),
#    ('take', 0.019629154),
#    ('domino', 0.015698688),
#    ('started', 0.013919111),
#    ('old', 0.011739435),
#    ('gas', 0.009832626),
#    ('mediocre', 0.009693556),
#    ('club', 0.009188057),
#    ('leave', 0.009098672),
#    ('loved', 0.008727233)]],
#  [18,
#   0.9164033049878526,
#   [('head', 0.04348086),
#    ('girl', 0.043084003),
#    ('came', 0.022225369),
#    ('gurl', 0.016947841),
#    ('happy', 0.014087098),
#    ('stay', 0.0132232215),
#    ('stuck', 0.012377906),
#    ("that's", 0.012023304),
#    ('makes', 0.011849266),
#    ("can't", 0.010982354)]],
#  [8,
#   0.9139931204394998,
#   [('girl', 0.021690562),
#    ('love', 0.01703343),
#    ("can't", 0.013399231),
#    ('friends', 0.01310549),
#    ('back', 0.011010429),
#    ('problem', 0.010934262),
#    ('house', 0.009802179),
#    ('yes', 0.009243922),
#    ('say', 0.008671484),
#    ('bitch', 0.008034594)]],
#  [51,
#   0.8653281195424825,
#   [('yea', 0.08196769),
#    ('made', 0.034769125),
#    ('leave', 0.02502045),
#    ('believer', 0.024663134),
#    ('twice', 0.015961956),
#    ('once', 0.014253698),
#    ('check', 0.011828054),
#    ('trust', 0.011181923),
#    ('pain', 0.01014869),
#    ('let', 0.009815542)]],
#  [41,
#   0.8398140506019445,
#   [('child', 0.06950877),
#    ('down', 0.027954394),
#    ('love', 0.025982857),
#    ('let', 0.023684252),
#    ('name', 0.023482852),
#    ("can't", 0.011779615),
#    ('take', 0.0112777455),
#    ('say', 0.011269327),
#    ('boy', 0.011172353),
#    ('wake', 0.0098344805)]],
#  [15,
#   0.7923432700322337,
#   [('work', 0.048769932),
#    ('labour', 0.032405365),
#    ('dance', 0.02961154),
#    ('say', 0.021202587),
#    ('spicy', 0.017478183),
#    ('ay', 0.015798816),
#    ('feel', 0.012790361),
#    ('(hello)', 0.012417247),
#    ('let', 0.011884585),
#    ('move', 0.011328761)]],
#  [79,
#   0.7908928553647456,
#   [('air', 0.035137244),
#    ('light', 0.0302918),
#    ('smack', 0.019594258),
#    ("that's", 0.018693004),
#    ('breathe', 0.018439766),
#    ('keep', 0.018384576),
#    ('hands', 0.015219448),
#    ('live', 0.013637195),
#    ('smoke', 0.013615495),
#    ('care', 0.011079175)]],
#  [53,
#   0.7865995213055612,
#   [('night', 0.033916622),
#    ('baby', 0.020612227),
#    ('say', 0.014801821),
#    ('back', 0.013224681),
#    ('heart', 0.012760953),
#    ('think', 0.01208644),
#    ('using', 0.010796548),
#    ('free', 0.010649013),
#    ('mind', 0.01060032),
#    ('lost', 0.009639031)]],
#  [2,
#   0.7835801849128075,
#   [('id', 0.057724107),
#    ('love', 0.029644832),
#    ('higher', 0.028402045),
#    ('that)', 0.019955434),
#    ('bring', 0.015783487),
#    ('boy', 0.012935483),
#    ('ella', 0.011931835),
#    ('love)', 0.011477454),
#    ('tell', 0.010291617),
#    ('destroyed', 0.010182014)]],
#  [22,
#   0.7705244483281604,
#   [('dum', 0.066978574),
#    ('blah', 0.05549344),
#    ('boom', 0.035189506),
#    ('num', 0.015186374),
#    ('ha', 0.015127494),
#    ("we're", 0.014120654),
#    ('world', 0.012579942),
#    ('bacon', 0.012414103),
#    ('superstars', 0.007717454),
#    ('har', 0.0077076834)]],
#  [93,
#   0.759579994015894,
#   [('home', 0.083676994),
#    ('tired', 0.034444246),
#    ('dat', 0.028203635),
#    ('tonight', 0.024564343),
#    ('songs', 0.022916256),
#    ('call', 0.019936262),
#    ('love', 0.019479789),
#    ('proud', 0.013353766),
#    ('put', 0.008924872),
#    ('back', 0.008886514)]],
#  [65,
#   0.7570690236170776,
#   [('boom', 0.12378395),
#    ('party', 0.031279728),
#    ('ragazza', 0.019936835),
#    ('stronger', 0.019460274),
#    ('il', 0.015936462),
#    ('super', 0.012394483),
#    ('bass', 0.01210883),
#    ("didn't", 0.01178968),
#    ('badoom', 0.01097758),
#    ('running', 0.009848462)]],
#  [86,
#   0.736219216180416,
#   [('share', 0.015708974),
#    ('end', 0.011064958),
#    ('feel', 0.009950247),
#    ('sta', 0.009941662),
#    ('walk', 0.009119106),
#    ("i've", 0.008996909),
#    ('dead', 0.007871934),
#    ('made', 0.00741247),
#    ('say', 0.0073922444),
#    ('thinking', 0.0069676866)]],
#  [4,
#   0.7351336883862132,
#   [('need', 0.018496849),
#    ('say', 0.018463176),
#    ('girl', 0.015648281),
#    ('down', 0.014573951),
#    ('feel', 0.013832175),
#    ('beautiful', 0.012875499),
#    ('let', 0.012441997),
#    ('yes', 0.012037823),
#    ('today', 0.011098475),
#    ('am', 0.010818439)]],
#  [5,
#   0.727265587686361,
#   [('amazing', 0.018944852),
#    ('way', 0.016806573),
#    ('only', 0.016495153),
#    ("'cause", 0.013291647),
#    ('freedom', 0.012838128),
#    ("there's", 0.011528949),
#    ('face', 0.010526292),
#    ('stops', 0.009481124),
#    ('keep', 0.009442986),
#    ('love', 0.009387013)]],
#  [78,
#   0.7049548434647477,
#   [('work', 0.025585992),
#    ('take', 0.021202665),
#    ('hard', 0.019882595),
#    ('little', 0.014922516),
#    ('feel', 0.012384931),
#    ('need', 0.011615318),
#    ('life', 0.01161327),
#    ('feeling', 0.009621546),
#    ('only', 0.0090700295),
#    ('girl', 0.008644603)]],
#  [88,
#   0.6932139520781675,
#   [('back', 0.03750951),
#    ('break', 0.022151193),
#    ('heart', 0.019156659),
#    ('take', 0.016130835),
#    ('fuck', 0.013469732),
#    ('hurt', 0.010182),
#    ('only', 0.008549509),
#    ('shit', 0.007586339),
#    ('love', 0.007377492),
#    ('let', 0.006794652)]],
#  [40,
#   0.6781954523453351,
#   [('fine', 0.06624731),
#    ('club)', 0.019131178),
#    ('stay', 0.012723087),
#    ('am', 0.011263864),
#    ('back', 0.010846847),
#    ('feel', 0.010388891),
#    ('bring', 0.010356317),
#    ('take', 0.008870968),
#    ("there's", 0.007864133),
#    ("we'd", 0.0075369454)]],
#  [83,
#   0.6672805024486479,
#   [('night', 0.013720987),
#    ('stereo', 0.013431694),
#    ('round', 0.012078267),
#    ('radio', 0.009901532),
#    ('yes', 0.009122973),
#    ('down', 0.009098736),
#    ('take', 0.008146353),
#    ('forget', 0.008122045),
#    ('end', 0.007353299),
#    ('younger', 0.007314436)]],
#  [84,
#   0.6482655043787418,
#   [('need', 0.015332658),
#    ('sail', 0.014211788),
#    ('moment', 0.014153609),
#    ('back', 0.0127012),
#    ('life', 0.011120585),
#    ('hear', 0.01061676),
#    ('take', 0.010546713),
#    ('doctor', 0.009527269),
#    ('microphone', 0.007910564),
#    ('quarter', 0.007880126)]],
#  [72,
#   0.6329236612423301,
#   [('gay', 0.033167504),
#    ('believe', 0.028539259),
#    ('it!', 0.018777512),
#    ("i'd", 0.018065935),
#    ('place', 0.017410174),
#    ("there's", 0.016825426),
#    ('meet', 0.0147676915),
#    ('shit', 0.014678184),
#    ('hit', 0.014202315),
#    ('nice', 0.01311137)]],
#  [9,
#   0.6256980890525483,
#   [('tell', 0.10609549),
#    ('man', 0.036068447),
#    ('cold', 0.028016824),
#    ('girl', 0.02220845),
#    ('am', 0.01207874),
#    ('let', 0.01032637),
#    ('take', 0.010235265),
#    ('child', 0.009899331),
#    ('numbness', 0.00882421),
#    ('say', 0.007156095)]],
#  [24,
#   0.6103909208327423,
#   [('tonight', 0.032633662),
#    ('yes', 0.03094539),
#    ('night', 0.022672946),
#    ('love', 0.01876359),
#    ('wish', 0.012697646),
#    ('gonna', 0.01146821),
#    ('mom', 0.008990748),
#    ('forgotten', 0.00868667),
#    ('leave', 0.0070709055),
#    ('let', 0.006762284)]],
#  [43,
#   0.5764939813584533,
#   [('mama', 0.030808706),
#    ('take', 0.014903663),
#    ('bang', 0.01127266),
#    ("he's", 0.009773453),
#    ('man', 0.009070885),
#    ('tell', 0.008960899),
#    ('love', 0.008716522),
#    ('let', 0.008282961),
#    ('drum', 0.008244486),
#    ('girl', 0.008240145)]],
#  [38,
#   0.5463886868078589,
#   [('party', 0.07504629),
#    ('yes', 0.016325412),
#    ('let', 0.01617144),
#    ('take', 0.015180328),
#    ('way', 0.014066851),
#    ('girl', 0.013270276),
#    ('only', 0.013149569),
#    ('life', 0.011617313),
#    ('tonight', 0.011005165),
#    ('say', 0.009797354)]],
#  [64,
#   0.5313305814329397,
#   [('solosta', 0.12663919),
#    ("can't", 0.037613515),
#    ('hours', 0.027135877),
#    ('take', 0.01988295),
#    ('riding', 0.018643176),
#    ('alone', 0.017450912),
#    ('feel', 0.011828572),
#    ('lost', 0.010002861),
#    ('love', 0.009241138),
#    ('solo', 0.008556311)]],
#  [37,
#   0.5208949873835991,
#   [('need', 0.019911813),
#    ('think', 0.0187666),
#    ('girl', 0.017995862),
#    ('down', 0.014486024),
#    ('love', 0.012878975),
#    ('say', 0.012233328),
#    ('money', 0.010366959),
#    ('keep', 0.009080907),
#    ("let's", 0.008855063),
#    ('long', 0.008726404)]],
#  [47,
#   0.5152781420752035,
#   [('fuck', 0.03303462),
#    ('wake', 0.025765305),
#    ('shit', 0.015838085),
#    ('life', 0.013140921),
#    ('put', 0.009433572),
#    ('back', 0.008915963),
#    ('long', 0.0078999875),
#    ('power', 0.0075632576),
#    ('take', 0.0072390363),
#    ('bitch', 0.007130413)]],
#  [71,
#   0.5152269739105577,
#   [('love', 0.017192781),
#    ('friends', 0.013092336),
#    ('down', 0.010386671),
#    ('am', 0.008404656),
#    ('life', 0.0075553344),
#    ('feel', 0.006917484),
#    ('found', 0.006679415),
#    ('sick', 0.006650875),
#    ('forget', 0.0065300334),
#    ('moe', 0.0064712926)]],
#  [75,
#   0.5011561328560674,
#   [('low', 0.0640775),
#    ('girlfriend', 0.04188881),
#    ('"i\'m', 0.020229239),
#    ('swish', 0.019490141),
#    ('believe', 0.013590654),
#    ('feel', 0.011044197),
#    ('club', 0.010381524),
#    ('understand', 0.009754164),
#    ('girls', 0.009722532),
#    ("can't", 0.008979461)]],
#  [87,
#   0.49243830219893425,
#   [('son', 0.019128995),
#    ('yes', 0.014855304),
#    ('ho', 0.014498502),
#    ('money', 0.013759601),
#    ('give', 0.011814522),
#    ('thought', 0.011693435),
#    ('higher', 0.011361578),
#    ('dem', 0.010921769),
#    ('style', 0.010189286),
#    ('back', 0.009971227)]],
#  [31,
#   0.48076697420583514,
#   [('city', 0.025925022),
#    ('ooh', 0.021466112),
#    ('life', 0.01618596),
#    ('feel', 0.012816559),
#    ('song', 0.011478549),
#    ('hands', 0.011148292),
#    ('(ooh', 0.010206953),
#    ('ohh)', 0.010178904),
#    ('house', 0.009409048),
#    ('head', 0.008748002)]],
#  [97,
#   0.46840204301270205,
#   [('try', 0.031191645),
#    ('ass', 0.016047938),
#    ('club', 0.012349197),
#    ('love', 0.011427515),
#    ('tell', 0.010598794),
#    ("can't", 0.009944637),
#    ('take', 0.009531307),
#    ('welcome', 0.0087447865),
#    ('(hey', 0.0076012774),
#    ('deep', 0.007532764)]],
#  [69,
#   0.45921132991361446,
#   [("we'll", 0.061715037),
#    ('ah', 0.03505676),
#    ('ow', 0.030208133),
#    ('old', 0.022322917),
#    ('baby', 0.01848956),
#    ('stories', 0.015770748),
#    ('house', 0.013397737),
#    ('dry', 0.011417534),
#    ('think', 0.008918499),
#    ('secrets', 0.008531623)]],
#  [58,
#   0.4318157277798491,
#   [('say', 0.018131785),
#    ('dead', 0.018082747),
#    ('think', 0.014676984),
#    ('sing', 0.011595232),
#    ('back', 0.011459004),
#    ('tonight', 0.011136868),
#    ('night', 0.010632324),
#    ('song', 0.009397394),
#    ('way', 0.009004566),
#    ("doesn't", 0.008740647)]],
#  [48,
#   0.42867330493618283,
#   [('whoa', 0.040747195),
#    ('river', 0.030946176),
#    ('water', 0.014281173),
#    ('am', 0.014212445),
#    ('alarm', 0.0132530015),
#    ('yes', 0.013058315),
#    ("doesn't", 0.01291475),
#    ('baby', 0.010376597),
#    ('dirty', 0.009912748),
#    ('dark', 0.0074829776)]],
#  [20,
#   0.4084147513208336,
#   [('love', 0.053464845),
#    ('promise', 0.024485797),
#    ("can't", 0.013966915),
#    ('lie', 0.013811861),
#    ('baby', 0.013689188),
#    ('ready', 0.011898799),
#    ('bidi-bam-bam-bam-bam-bam', 0.009689878),
#    ('life', 0.009623735),
#    ('way', 0.008693894),
#    ('es', 0.0074214805)]],
#  [52,
#   0.39190939405534664,
#   [('need', 0.036737207),
#    ('love', 0.017884266),
#    ('take', 0.012246877),
#    ('kiss', 0.011423216),
#    ('gun', 0.009322182),
#    ('feel', 0.008126607),
#    ('told', 0.007985648),
#    ('let', 0.0073210383),
#    ('ayo', 0.0066803577),
#    ("can't", 0.006665314)]],
#  [77,
#   0.38959984743132736,
#   [('mom', 0.05355011),
#    ('pump', 0.021350145),
#    ('faster', 0.021080878),
#    ('children', 0.01951019),
#    ('woke', 0.015291702),
#    ('flag', 0.012983175),
#    ('need', 0.011550879),
#    ('ruins', 0.011401023),
#    ('bye', 0.010355888),
#    ('heads', 0.010108511)]],
#  [90,
#   0.38471690253072666,
#   [('crazy', 0.03314889),
#    ('love', 0.024176175),
#    ('burn', 0.02056434),
#    ('give', 0.017753229),
#    ('count', 0.015850715),
#    ('burning', 0.015594113),
#    ('fire', 0.015349429),
#    ('night', 0.0143591575),
#    ('think', 0.013083721),
#    ('take', 0.01211394)]],
#  [23,
#   0.37804008064131267,
#   [('count', 0.0659845),
#    ('oh!', 0.05196114),
#    ('dat', 0.045589685),
#    ('love', 0.018590014),
#    ("can't", 0.016438393),
#    ('quiet', 0.01555924),
#    ('interesting', 0.007541498),
#    ('big', 0.0075106393),
#    ('long', 0.0070566586),
#    ('give', 0.007025877)]],
#  [66,
#   0.3681678368507164,
#   [('take', 0.028851412),
#    ('rain', 0.018789202),
#    ('away', 0.018127652),
#    ('sweat', 0.017863242),
#    ('due', 0.016393587),
#    ('born', 0.015145134),
#    ('perché', 0.013663236),
#    ('part', 0.0068006897),
#    ('yes', 0.0066652615),
#    ('button', 0.0065970225)]],
#  [35,
#   0.36769910370685466,
#   [('sexy', 0.08982184),
#    ('(ooh)', 0.024528451),
#    ('know)', 0.019883666),
#    ("that's", 0.014333782),
#    ('yes', 0.013830098),
#    ('hurts', 0.011943775),
#    ('riches', 0.010630217),
#    ('band', 0.010558333),
#    ('mediocre', 0.010036249),
#    ('tricked', 0.008834867)]],
#  [62,
#   0.35461206808258794,
#   [('blame', 0.028585225),
#    ('delayed', 0.02163093),
#    ('angeles', 0.019400781),
#    ('los', 0.019377405),
#    ('knew', 0.019118382),
#    ("can't", 0.015787221),
#    ('language', 0.014826985),
#    ('elegant', 0.014248112),
#    ('panic', 0.013320663),
#    ('tokyo', 0.009373725)]],
#  [6,
#   0.3361970531609586,
#   [('woman', 0.123044975),
#    ('trouble', 0.04805882),
#    ('life', 0.03580902),
#    ('feel', 0.027866494),
#    ('crying', 0.01202994),
#    ('woohoo', 0.010815443),
#    ('beating', 0.009683713),
#    ('heart', 0.009346455),
#    ('eternity', 0.00828342),
#    ("can't", 0.0075508733)]],
#  [89,
#   0.3256804208340327,
#   [('tonight', 0.05704331),
#    ('home', 0.03407481),
#    ('coming', 0.021244152),
#    ('unstoppable', 0.018962929),
#    ('give', 0.016269004),
#    ('world', 0.015109835),
#    ('say', 0.014867691),
#    ('rocking', 0.010640885),
#    ('tell', 0.009464568),
#    ('feel', 0.009280239)]],
#  [25,
#   0.30829970639615567,
#   [('wait', 0.022381674),
#    ('way', 0.021804618),
#    ("that's", 0.020922033),
#    ('feel', 0.017332869),
#    ('little', 0.013301196),
#    ('show', 0.010670053),
#    ('take', 0.010568911),
#    ('makes', 0.008821385),
#    ('need', 0.00858465),
#    ('last', 0.008169138)]],
#  [96,
#   0.30417721833373434,
#   [('shine', 0.041897807),
#    ('diamond', 0.03359957),
#    ('heaven', 0.026367148),
#    ('diamonds', 0.020364061),
#    ('beautiful', 0.01654066),
#    ('wave', 0.014090399),
#    ('take', 0.01193411),
#    ('american', 0.010476445),
#    ('away)', 0.0098990705),
#    ('ground', 0.009838274)]],
#  [70,
#   0.30401258128995323,
#   [('music', 0.020757994),
#    ('say', 0.01710741),
#    ('friday', 0.013784522),
#    ('away', 0.013101783),
#    ('feel', 0.012016078),
#    ('free', 0.0113845365),
#    ("can't", 0.010090157),
#    ('take', 0.009649892),
#    ('think', 0.008988602),
#    ('hope', 0.00869622)]],
#  [50,
#   0.29377338968197364,
#   [('low', 0.08120325),
#    ('yes', 0.013367044),
#    ('work', 0.0132033015),
#    ('count', 0.01299865),
#    ('block', 0.012345202),
#    ('love', 0.012075083),
#    ('life', 0.0119219655),
#    ('only', 0.011115408),
#    ('way', 0.010973696),
#    ('miracle', 0.010733124)]],
#  [12,
#   0.28372682574126884,
#   [('nigger', 0.050211478),
#    ('niggers', 0.02202968),
#    ('wait', 0.015106604),
#    ('little', 0.011813385),
#    ('fuck', 0.011265878),
#    ('mo', 0.011217939),
#    ('let', 0.010165732),
#    ('nigga', 0.009739191),
#    ("he's", 0.008010289),
#    ('fucking', 0.007959188)]],
#  [13,
#   0.282071217020075,
#   [('life', 0.022384845),
#    ('dream', 0.013403085),
#    ('[bleep', 0.010134507),
#    ('nigger', 0.009866383),
#    ('fine', 0.009657199),
#    ('next', 0.00921046),
#    ('happens', 0.009170006),
#    ('back', 0.0083439555),
#    ('speaks', 0.0076157376),
#    ('bad', 0.0070645777)]],
#  [99,
#   0.28170160915624365,
#   [('boys', 0.029204478),
#    ('lady', 0.027621472),
#    ('money', 0.018817492),
#    ('butterfly', 0.014096122),
#    ('low', 0.013016452),
#    ('girl', 0.012295112),
#    ('hide', 0.011815106),
#    ('dance', 0.011345879),
#    ('baby', 0.0111586405),
#    ('sugar', 0.010631924)]],
#  [1,
#   0.25813674139362774,
#   [("can't", 0.016660273),
#    ('hot', 0.015317772),
#    ('girls', 0.013652258),
#    ('lick', 0.0134479385),
#    ('club', 0.012179105),
#    ('call', 0.011553875),
#    ('bass', 0.0112687955),
#    ('shawty', 0.010534752),
#    ('wants', 0.010404564),
#    ('bottles', 0.0095)]],
#  [27,
#   0.2560341222401803,
#   [('cornea', 0.044562466),
#    ('last', 0.03174744),
#    ('fool', 0.031238921),
#    ('night', 0.02818735),
#    ("won't", 0.017279163),
#    ('part', 0.017226486),
#    ('gives', 0.014689533),
#    ('(every', 0.013241074),
#    ('care', 0.010355303),
#    ('back', 0.009314832)]],
#  [73,
#   0.252225716888006,
#   [('dark', 0.07706718),
#    ('only', 0.023046),
#    ('lost', 0.016978687),
#    ('beautiful', 0.013378581),
#    ('fire', 0.0131526),
#    ('am', 0.012218294),
#    ('little', 0.011404826),
#    ('faded', 0.011093387),
#    ('change', 0.01006074),
#    ('maybe', 0.009430275)]],
#  [17,
#   0.2416064503763664,
#   [('ninety-nine', 0.02645854),
#    ('looking', 0.021582415),
#    ('tag', 0.016027344),
#    ('engine', 0.013241414),
#    ('fantastic', 0.012690656),
#    ('dashboard', 0.012685277),
#    ('gonna', 0.011674307),
#    ('memories', 0.011111861),
#    ('lost', 0.0106092915),
#    ('only', 0.010508778)]],
#  [95,
#   0.24049859617525726,
#   [('eyes', 0.16793004),
#    ('sugar', 0.02384578),
#    ('love', 0.02153732),
#    ('fly', 0.02069048),
#    ('dj', 0.019837532),
#    ('girl', 0.012421417),
#    ('put', 0.012322812),
#    ('feel', 0.012029868),
#    ('looks', 0.009447108),
#    ('body', 0.009188533)]],
#  [91,
#   0.23435227102754652,
#   [('love', 0.081044935),
#    ('shake', 0.03335464),
#    ('found', 0.011488509),
#    ('world', 0.010824603),
#    ('place', 0.0102116205),
#    ('say', 0.0091717765),
#    ('yes', 0.008954028),
#    ('girl', 0.0077981385),
#    ('am', 0.0068829805),
#    ('young', 0.0065368493)]],
#  [28,
#   0.22065263910053545,
#   [('dark', 0.02357139),
#    ('let', 0.02298889),
#    ('love', 0.016273808),
#    ('girl', 0.013420072),
#    ('take', 0.012981808),
#    ('play', 0.012666753),
#    ('only', 0.01215593),
#    ('glass', 0.010979356),
#    ('raise', 0.010533926),
#    ('light', 0.009694015)]],
#  [29,
#   0.2204786985444116,
#   [('top', 0.016670397),
#    ('price', 0.014488952),
#    ("let's", 0.0136515815),
#    ('new', 0.012041561),
#    ('dance', 0.011903862),
#    ('transform', 0.011392405),
#    ('bitch', 0.009729099),
#    ('woo', 0.009560783),
#    ('wrist', 0.009165767),
#    ('half', 0.008429136)]],
#  [7,
#   0.21023431247022017,
#   [('bitch', 0.052861143),
#    ('labour', 0.04288768),
#    ('talk', 0.020105405),
#    ('bad', 0.012023081),
#    ('dirty', 0.009749528),
#    ('mediocre', 0.00950692),
#    ('need', 0.009446683),
#    ('city', 0.008789315),
#    ('baby', 0.008684202),
#    ('turn', 0.00857824)]],
#  [59,
#   0.19805090218005716,
#   [('woman', 0.1788321),
#    ('love', 0.016060002),
#    ('baby', 0.011398078),
#    ('takes', 0.010712676),
#    ('symphony', 0.0073050335),
#    ('still', 0.007278882),
#    ("can't", 0.0071668313),
#    ('call', 0.0067305304),
#    ('say', 0.006635248),
#    ('tonight', 0.006566218)]],
#  [76,
#   0.19600931279865108,
#   [('labour', 0.027068807),
#    ('halo', 0.018860595),
#    ('days', 0.018782774),
#    ('made', 0.012510264),
#    ('take', 0.01225509),
#    ('looking', 0.011106973),
#    ('turn', 0.010896686),
#    ('feel', 0.010101143),
#    ('(halo)', 0.0090781255),
#    ('keep', 0.007981791)]],
#  [81,
#   0.18897300413527773,
#   [('rack', 0.068014406),
#    ('worse', 0.06710694),
#    ('bum', 0.06342629),
#    ('shit', 0.02133903),
#    ('run', 0.021001562),
#    ('au', 0.019628806),
#    ('bitch', 0.0152047565),
#    ('dollar', 0.009783975),
#    ('whore', 0.009756722),
#    ("won't", 0.009659437)]],
#  [0,
#   0.18093364960668623,
#   [('labour', 0.121572286),
#    ('head', 0.032639798),
#    ('guns', 0.030241098),
#    ('alive', 0.023448812),
#    ('still', 0.019242117),
#    ("i've", 0.017709302),
#    ('spirits', 0.015132226),
#    ("they've", 0.015130809),
#    ('life', 0.011858766),
#    ('turn', 0.010823126)]],
#  [11,
#   0.18093364960668623,
#   [('life', 0.04231223),
#    ('hands', 0.026440749),
#    ('let', 0.021238511),
#    ('live', 0.0129127875),
#    ('tear', 0.012052035),
#    ("can't", 0.012004815),
#    ('keep', 0.011955082),
#    ('only', 0.011859669),
#    ('ay', 0.011581983),
#    ('take', 0.010502617)]],
#  [21,
#   0.18093364960668623,
#   [('labour', 0.54452825),
#    ('work', 0.18927093),
#    ('turn', 0.03624155),
#    ('dirty', 0.0035940455),
#    ('need', 0.002890484),
#    ('girl', 0.0023538428),
#    ('take', 0.0022161712),
#    ('maybe', 0.0019935255),
#    ('baby', 0.0018790823),
#    ('hurt', 0.0017554787)]],
#  [34,
#   0.18093364960668623,
#   [('[bleep', 0.061647058),
#    ('[bleep]', 0.06155995),
#    ('head', 0.04146704),
#    ("i've", 0.037340906),
#    ('hate', 0.026281293),
#    ('club', 0.0215524),
#    ('throwing', 0.012022911),
#    ('am', 0.010809555),
#    ('bouncin', 0.010296288),
#    ("can't", 0.008480582)]],
#  [56,
#   0.18093364960668623,
#   [('labour', 0.07069493),
#    ('nana', 0.0209729),
#    ('share', 0.013506375),
#    ('am', 0.012959272),
#    ('love', 0.011717378),
#    ('tell', 0.011095798),
#    ('turn', 0.010830714),
#    ('still', 0.010019668),
#    ('facebook', 0.009096997),
#    ('yes)', 0.0071538277)]],
#  [61,
#   0.18093364960668623,
#   [('(louder)', 0.022607861),
#    ('let', 0.019789236),
#    ('rule', 0.012732575),
#    ('forget', 0.010495437),
#    ('sun', 0.009753155),
#    ('care', 0.009445091),
#    ("we're", 0.00871287),
#    ('love', 0.008278228),
#    ('blood', 0.007087136),
#    ('need', 0.0063973786)]],
#  [92,
#   0.18093364960668623,
#   [('lights', 0.11825938),
#    ('pipe', 0.024621628),
#    ('say', 0.017281823),
#    ('life', 0.017228527),
#    ('red', 0.015643837),
#    ('mix', 0.010616315),
#    ('flip', 0.010400276),
#    ('offers', 0.010030152),
#    ('broke', 0.008526471),
#    ('tell', 0.008102769)]],
#  [98,
#   0.18093364960668623,
#   [('baby', 0.042780668),
#    ('kill', 0.016036175),
#    ('say', 0.013525032),
#    ('girls', 0.011651827),
#    ('girl', 0.009410416),
#    ('labour', 0.009123724),
#    ('suicide', 0.007976243),
#    ('bop', 0.007848078),
#    ('california', 0.0071691014),
#    ('tell', 0.006552585)]]]

# %% [markdown]
# #### Among KPOP

# %%
df_looking = df[df["grouping"].isin(target_and_kpop)].reset_index(drop=True)

# %%
#train model
lyrics_processed = pre_process(df_looking["lyrics"])
dictionary = Dictionary(lyrics_processed)
corpus = [dictionary.doc2bow(text) for text in lyrics_processed]
lda = LdaModel(corpus=corpus, id2word=dictionary, num_topics=100)

# observe topics
topics = lda.print_topics()

# %%
threshold = 0.3

counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    topics = lda.get_document_topics(corpus[cnt], minimum_probability=0)
    
    for topic in topics:
        if topic[1] > threshold:
            counter[topic[0]] = counter.get(topic[0], 0) + 1
            
        summer[topic[0]] = summer.get(topic[0], 0) + float(topic[1])

# %%
lda_html_kpop, vis = save_lda_vis(lda, corpus, dictionary, "lda.html")

vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 79    -0.007053 -0.080083       1        1  3.699065
# 13     0.339152  0.059346       2        1  3.400827
# 11     0.045854  0.025310       3        1  2.486130
# 77    -0.027755 -0.051006       4        1  2.234973
# 71    -0.014243 -0.062178       5        1  2.130160
# ...         ...       ...     ...      ...       ...
# 98     0.038073  0.017323      96        1  0.392615
# 15    -0.031665 -0.010091      97        1  0.376427
# 81    -0.026065  0.050204      98        1  0.346985
# 43     0.254848  0.054518      99        1  0.250941
# 5     -0.057932  0.213255     100        1  0.244404
#
# [100 rows x 5 columns], topic_info=         Term         Freq        Total  Category  logprob  loglift
# 280     child  3973.000000  3973.000000   Default  30.0000  30.0000
# 425     drunk  2097.000000  2097.000000   Default  29.0000  29.0000
# 494      cake  1674.000000  1674.000000   Default  28.0000  28.0000
# 1180  invalid   709.000000   709.000000   Default  27.0000  27.0000
# 101     dance  1325.000000  1325.000000   Default  26.0000  26.0000
# ...       ...          ...          ...       ...      ...      ...
# 435      wait     1.972601   214.062873  Topic100  -5.1842   1.3272
# 58       only     2.290834   523.202439  Topic100  -5.0346   0.5831
# 423        ac     1.918620   317.679776  Topic100  -5.2119   0.9047
# 433      need     1.742900   527.784809  Topic100  -5.3080   0.3010
# 129     let's     1.659179   609.524828  Topic100  -5.3572   0.1077
#
# [6625 rows x 6 columns], token_table=       Topic      Freq  Term
# term
# 5866       4  0.071820    !!
# 5866      10  0.071820    !!
# 5866      17  0.071820    !!
# 5866      28  0.359102    !!
# 5866      31  0.071820    !!
# ...      ...       ...   ...
# 6597      49  0.841763  繁體re
# 10444     52  0.553183  跟着偷偷
# 9717       9  0.731464  進むほど
# 8145      18  0.541375    道道
# 4296      58  0.552171    闇夜
#
# [30060 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[80, 14, 12, 78, 72, 43, 96, 13, 56, 23, 4, 83, 39, 84, 61, 53, 7, 93, 45, 70, 48, 89, 50, 74, 46, 31, 3, 60, 49, 67, 21, 86, 55, 18, 40, 88, 42, 26, 30, 73, 51, 76, 37, 75, 81, 91, 38, 36, 90, 77, 27, 47, 68, 1, 19, 97, 69, 34, 20, 58, 57, 33, 52, 59, 25, 94, 2, 41, 11, 17, 62, 64, 85, 66, 100, 87, 24, 35, 79, 9, 29, 63, 15, 22, 65, 92, 95, 98, 32, 5, 8, 28, 10, 54, 71, 99, 16, 82, 44, 6])

# %%
_lda_counter_kpop = sort_dictionary(counter)
lda_counter_kpop = []
for tup in _lda_counter_kpop:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_counter_kpop.append(new_tup)
    
lda_counter_kpop
# Out:
# [[15,
#   4,
#   [('sorry', 0.019177983),
#    ('man', 0.015505934),
#    ('love', 0.01410066),
#    ('top', 0.012325257),
#    ('yes', 0.012061623),
#    ('mob', 0.011231353),
#    ('eyes', 0.009781362),
#    ('cherry', 0.009393422),
#    ('call', 0.008776228),
#    ('cold', 0.0075873663)]],
#  [35,
#   4,
#   [('put', 0.048931114),
#    ("'em", 0.027571443),
#    ('gucci', 0.02247288),
#    ('sneakers', 0.021779431),
#    ('ready', 0.018953884),
#    ('19th', 0.015438336),
#    ('century', 0.015371317),
#    ('goat', 0.0150678065),
#    ('brave', 0.014465645),
#    ('call', 0.013949169)]],
#  [11,
#   3,
#   [('drunk', 0.48934472),
#    ('only', 0.018974105),
#    ('love', 0.01258739),
#    ('help', 0.006337784),
#    ('bomb', 0.0061882157),
#    ('take', 0.0052208225),
#    ('loco', 0.004951508),
#    ('night', 0.004660736),
#    ('me)', 0.004635133),
#    ('dan', 0.0045377)]],
#  [95,
#   3,
#   [('love', 0.10150945),
#    ('crazy', 0.017002089),
#    ('girl', 0.016112667),
#    ('baby', 0.013138875),
#    ('fun', 0.010652551),
#    ('whip', 0.010499436),
#    ('suck', 0.010369708),
#    ('sorry', 0.0094500985),
#    ('only', 0.008957536),
#    ('take', 0.008623593)]],
#  [50,
#   3,
#   [('power', 0.02462957),
#    ('fall', 0.01754716),
#    ('understand', 0.016133178),
#    ('[bleep]', 0.014019408),
#    ('ah', 0.013673815),
#    ("can't", 0.011703327),
#    ('[bleep', 0.010728189),
#    ('need', 0.010704527),
#    ('friends', 0.010660955),
#    ('feel', 0.0106365755)]],
#  [79,
#   3,
#   [('love', 0.13372207),
#    ('bomb', 0.02500698),
#    ('sorry', 0.015574337),
#    ('heart', 0.011753382),
#    ('back', 0.010674056),
#    ('let', 0.01008847),
#    ('la-la', 0.008177623),
#    ('feel', 0.006511066),
#    ('eyes', 0.0060980055),
#    ('say', 0.005840904)]],
#  [67,
#   3,
#   [('tell', 0.022238554),
#    ('name', 0.018631121),
#    ('heart', 0.016828267),
#    ('sorry', 0.013831663),
#    ('id', 0.013170821),
#    ('ooh', 0.012864722),
#    ('best', 0.012843528),
#    ('yes', 0.01226868),
#    ('love', 0.011228547),
#    ('[bleep', 0.008837304)]],
#  [17,
#   3,
#   [('ay', 0.033522647),
#    ('ya', 0.028017163),
#    ('cuz', 0.02162898),
#    ('business', 0.02102332),
#    ('feel', 0.020784901),
#    ('shimmy', 0.017886044),
#    ('down', 0.014459645),
#    ('new', 0.013645619),
#    ('bruce', 0.013619435),
#    ('lee', 0.012469022)]],
#  [1,
#   2,
#   [('work', 0.23099236),
#    ('allora', 0.0962839),
#    ('swipe', 0.016560888),
#    ('ring', 0.016131435),
#    ('dress', 0.014891946),
#    ('black', 0.01392804),
#    ('stronger', 0.013045915),
#    ('love', 0.01064505),
#    ('give', 0.008394569),
#    ('hey!', 0.007119761)]],
#  [10,
#   2,
#   [('zu', 0.053395372),
#    ('ba', 0.022690164),
#    ('shy', 0.019567458),
#    ('down', 0.016651371),
#    ("chi't", 0.0153872855),
#    ('worry', 0.013100097),
#    ('let', 0.012856325),
#    ('chuction', 0.012620537),
#    ('baby', 0.009668436),
#    ("we're", 0.009363526)]],
#  [59,
#   2,
#   [('́â', 0.091438025),
#    ('feel', 0.019784482),
#    ('say', 0.0140502425),
#    ('today', 0.013143392),
#    ('pang', 0.010743654),
#    ('give', 0.010599601),
#    ('up!', 0.01023098),
#    ('back', 0.009937259),
#    ('break', 0.009539232),
#    ('shut', 0.0093537085)]],
#  [39,
#   2,
#   [('seguire', 0.025428753),
#    ('tempo', 0.021742044),
#    ('surf', 0.020424435),
#    ('love', 0.01900057),
#    ('rock', 0.017594812),
#    ('heart', 0.01724366),
#    ('和만', 0.013030869),
#    ('ooh', 0.010789883),
#    ('take', 0.010588166),
#    ('feel', 0.010087417)]],
#  [69,
#   2,
#   [('hot', 0.29573455),
#    ('bussare', 0.01973012),
#    ('love', 0.018407125),
#    ('door', 0.0148289995),
#    ('knock', 0.011533691),
#    ('knocking', 0.0098775085),
#    ('lalisa', 0.008964179),
#    ('bad', 0.008886994),
#    ('home', 0.008114733),
#    ('baby', 0.0072666956)]],
#  [29,
#   2,
#   [('sorry', 0.021216378),
#    ('spicy', 0.02057727),
#    ('home', 0.01796221),
#    ('today', 0.01756598),
#    ('feel', 0.016464895),
#    ('sweet', 0.016020974),
#    ('heart', 0.013174765),
#    ('baby', 0.012760784),
#    ('wow!', 0.012360048),
#    ('hi', 0.00995708)]],
#  [22,
#   2,
#   [('love', 0.030496806),
#    ('woo', 0.018735865),
#    ('heart', 0.018377509),
#    ('world', 0.011463806),
#    ('beautiful', 0.010789728),
#    ('say', 0.008662313),
#    ('follow', 0.008644636),
#    ('shoot', 0.007931957),
#    ('home', 0.0076020914),
#    ("can't", 0.00757542)]],
#  [36,
#   2,
#   [('flower', 0.08875251),
#    ('home', 0.025001505),
#    ("can't", 0.01609401),
#    ('love', 0.015297869),
#    ('sorry', 0.015236079),
#    ('news', 0.013314911),
#    ('am', 0.008734422),
#    ('say', 0.008356031),
#    ('follow', 0.008268185),
#    ('fai!', 0.0074910447)]],
#  [21,
#   1,
#   [('grande', 0.06666327),
#    ('new', 0.033678126),
#    ("can't", 0.026256723),
#    ('shy', 0.024028858),
#    ('prova', 0.022740586),
#    ('heart', 0.019852335),
#    ('face', 0.019471679),
#    ('find', 0.01732748),
#    ('call', 0.01392318),
#    ('harsh', 0.013297068)]],
#  [98,
#   1,
#   [('drunk', 0.33895785),
#    ('invalid', 0.05484575),
#    ('need', 0.014886551),
#    ('point', 0.014212818),
#    ('love', 0.0136489915),
#    ('home', 0.009818946),
#    ('run', 0.008167593),
#    ('night', 0.007847669),
#    ('sorry', 0.005945366),
#    ('let', 0.004847424)]],
#  [93,
#   1,
#   [('dimensioni', 0.08186137),
#    ('bubble', 0.030262562),
#    ('yes', 0.020269835),
#    ('twenty', 0.01502874),
#    ('night', 0.013189637),
#    ('love', 0.012889999),
#    ('pop!', 0.009536721),
#    ('feeling', 0.0088200215),
#    ('back', 0.008030082),
#    ('20', 0.0077468287)]],
#  [86,
#   1,
#   [('child', 0.52266127),
#    ('drunk', 0.031574473),
#    ('sorry', 0.009641075),
#    ('gee', 0.00823933),
#    ('il', 0.006236289),
#    ('song', 0.005916335),
#    ('remedy', 0.005312878),
#    ('still', 0.004917466),
#    ('news', 0.004904997),
#    ('mr', 0.0046946607)]],
#  [52,
#   1,
#   [('poppy', 0.026376106),
#    ('sorry', 0.025401866),
#    ('love', 0.021798402),
#    ("we're", 0.011558697),
#    ('night', 0.010672361),
#    ('heart', 0.009696998),
#    ('only', 0.008715016),
#    ('need', 0.00852358),
#    ('girls', 0.008414292),
#    ('bum', 0.008363504)]],
#  [42,
#   1,
#   [('home', 0.11044108),
#    ('on!', 0.022585314),
#    ('summer', 0.014350723),
#    ('mine', 0.014154384),
#    ('say', 0.012697341),
#    ('only', 0.012453617),
#    ('shut', 0.011066296),
#    ('follow', 0.0105501395),
#    ('signals', 0.009513433),
#    ('heart', 0.0081599895)]],
#  [77,
#   1,
#   [('home', 0.21218365),
#    ('hands', 0.011546376),
#    ('shut', 0.011314601),
#    ('love', 0.011267348),
#    ('rende', 0.011106626),
#    ('let', 0.00985002),
#    ('jump', 0.009379214),
#    ('comment', 0.009186703),
#    ('baby', 0.009135382),
#    ("let's", 0.0071997144)]],
#  [56,
#   1,
#   [('top', 0.043103877),
#    ('dan', 0.03840323),
#    ('light', 0.028803416),
#    ('moon', 0.013261573),
#    ('life', 0.011775709),
#    ('heart', 0.010172459),
#    ("didn't", 0.009842374),
#    ('work', 0.00863606),
#    ('home', 0.008562464),
#    ('dream', 0.008431236)]],
#  [32,
#   1,
#   [('am', 0.027187167),
#    ('swing', 0.020002006),
#    ('sorry', 0.013894724),
#    ('traduzione', 0.010280515),
#    ('mine', 0.010133531),
#    ('flower', 0.009372063),
#    ('yes', 0.008149347),
#    ("can't", 0.008059651),
#    ('heart', 0.0078013362),
#    ('live', 0.007661226)]],
#  [43,
#   1,
#   [('child', 0.22871725),
#    ('night', 0.0338689),
#    ('work', 0.02875877),
#    ("let's", 0.02102277),
#    ('away', 0.019336484),
#    ('dance', 0.016921612),
#    ('allora', 0.015074615),
#    ('itzy', 0.009549953),
#    ('hours', 0.009546532),
#    ('24', 0.009530879)]],
#  [75,
#   1,
#   [('give', 0.033155438),
#    ('feel', 0.015832266),
#    ('say', 0.014261861),
#    ('love', 0.012682229),
#    ('break', 0.012067873),
#    ('eyes', 0.009690926),
#    ('candyfloss', 0.009141569),
#    ('way', 0.008961511),
#    ('yes', 0.00876754),
#    ("can't", 0.008351288)]],
#  [94,
#   1,
#   [('work', 0.020583035),
#    ('detail', 0.014504646),
#    ("can't", 0.014444469),
#    ('vacanza', 0.013705998),
#    ('back', 0.012938556),
#    ('sorry', 0.011171395),
#    ('scream', 0.01027386),
#    ('news', 0.010143635),
#    ('home', 0.00816182),
#    ('care', 0.007858811)]],
#  [54,
#   1,
#   [('aite', 0.037941016),
#    ('rock', 0.018496891),
#    ('love', 0.015932472),
#    ('only', 0.01043294),
#    ('need', 0.010294701),
#    ('feel', 0.00983171),
#    ('head', 0.009095845),
#    ('find', 0.008899584),
#    ("can't", 0.008068511),
#    ('home', 0.0077751903)]],
#  [3,
#   1,
#   [('ка', 0.13358632),
#    ('rende', 0.09121439),
#    ('love', 0.049489625),
#    ('follow', 0.02704563),
#    ('boom', 0.020349901),
#    ('back', 0.018713143),
#    ('crazy', 0.015043805),
#    ('sorry', 0.014235954),
#    ('detail', 0.01006135),
#    ('sexy', 0.010044253)]],
#  [16,
#   1,
#   [('back', 0.037790198),
#    ('yes', 0.037295792),
#    ('home', 0.020920578),
#    ('wild', 0.02049421),
#    ('mind', 0.012711294),
#    ('el', 0.010281733),
#    ('zoo', 0.009861163),
#    ('mariachi', 0.009481682),
#    ('room', 0.009436371),
#    ('247', 0.008143322)]],
#  [37,
#   1,
#   [('love', 0.030410489),
#    ('cold', 0.015129776),
#    ('call', 0.0136261135),
#    ('feel', 0.01284215),
#    ('give', 0.012743631),
#    ('world', 0.010969443),
#    ('yes', 0.010570944),
#    ("let's", 0.008119344),
#    ('sour', 0.008114738),
#    ('chili', 0.008053996)]],
#  [33,
#   1,
#   [('last', 0.02829835),
#    ('love', 0.025871709),
#    ('traduzione', 0.021983277),
#    ('fall', 0.014179106),
#    ('hands', 0.0134486025),
#    ('need', 0.012280163),
#    ('baby', 0.011729334),
#    ('heart', 0.009592074),
#    ('sorry', 0.008892526),
#    ('leave', 0.008468462)]],
#  [48,
#   1,
#   [('top', 0.014910162),
#    ("can't", 0.01275002),
#    ('touch', 0.012553491),
#    ('swan', 0.011881743),
#    ('think', 0.011806836),
#    ('broom', 0.011315789),
#    ('love', 0.009301444),
#    ('dynamite', 0.008965283),
#    ('life', 0.008048781),
#    ('world', 0.0068921084)]],
#  [78,
#   1,
#   [('picky', 0.019846365),
#    ('tanjin', 0.017593939),
#    ('cry', 0.01738039),
#    ('boy', 0.015732028),
#    ('mom', 0.015271844),
#    ('gem', 0.011783773),
#    ('child', 0.0112647535),
#    ('kominboda', 0.008692206),
#    ('fall', 0.008573391),
#    ('take', 0.008550483)]],
#  [40,
#   1,
#   [('home', 0.032683227),
#    ("rollin'", 0.025215156),
#    ("chi't", 0.014279601),
#    ('heart', 0.012421058),
#    ('woo', 0.011545161),
#    ('baby', 0.011468019),
#    ('sorry', 0.010541019),
#    ('healing', 0.010302561),
#    ('only', 0.010176873),
#    ('god', 0.00940859)]],
#  [18,
#   1,
#   [('take', 0.01856879),
#    ('ah', 0.011554421),
#    ('rover', 0.011115314),
#    ('am', 0.009981858),
#    ('(champ)', 0.008678998),
#    ('euphoria', 0.007856909),
#    ('non', 0.007097611),
#    ('thumb', 0.006879139),
#    ('tatata', 0.006731308),
#    ('woah', 0.006721345)]],
#  [12,
#   1,
#   [('cake', 0.53742796),
#    ('dan', 0.02270189),
#    ('heart', 0.008466839),
#    ('sara', 0.0071918755),
#    ('ah!', 0.0071876007),
#    ('island', 0.0071216784),
#    ("can't", 0.006152252),
#    ('sorry', 0.00423058),
#    ('control', 0.0041934894),
#    ('cowboy', 0.0038787806)]],
#  [57,
#   1,
#   [('let', 0.039689805),
#    ('love', 0.024287933),
#    ("chi't", 0.020375006),
#    ('hero', 0.019507885),
#    ('working', 0.017172735),
#    ('man', 0.015170916),
#    ('change', 0.013229592),
#    ('bag', 0.01086179),
#    ('chuction', 0.010748483),
#    ('take', 0.009275026)]],
#  [6,
#   1,
#   [('home', 0.048266225),
#    ('head', 0.023348477),
#    ('rock', 0.0125204595),
#    ('news', 0.011690688),
#    ('cry', 0.009390045),
#    ("can't", 0.009147805),
#    ('love', 0.008676442),
#    ('baila', 0.0086578885),
#    ('sorry', 0.008189719),
#    ('yes', 0.0076402863)]],
#  [28,
#   1,
#   [('beep', 0.13228142),
#    ('dad', 0.0815529),
#    ('pop', 0.01824401),
#    ('traduzione', 0.013228743),
#    ('contact', 0.012426457),
#    ('ora', 0.012078549),
#    ('love', 0.011492944),
#    ('dimmi', 0.009915438),
#    ('cosa', 0.008798163),
#    ("si'", 0.008786897)]],
#  [31,
#   1,
#   [('cake', 0.07912356),
#    ('significa', 0.05089661),
#    ('sorry', 0.016765837),
#    ('sweet', 0.016685538),
#    ('home', 0.014679868),
#    ('heart', 0.012347091),
#    ('dirty', 0.011196171),
#    ('love', 0.0086311875),
#    ('summer', 0.007762555),
#    ('news', 0.006448534)]],
#  [61,
#   1,
#   [('hip', 0.04899708),
#    ('universe', 0.039936375),
#    ('cuse', 0.035561603),
#    ('honey', 0.027424965),
#    ('need', 0.022680588),
#    ('excuse', 0.0218645),
#    ('world', 0.017096136),
#    ('illuminate', 0.013367212),
#    ('inside', 0.013287624),
#    ('put', 0.011086253)]],
#  [91,
#   1,
#   [('back', 0.038433984),
#    ('worry', 0.015569113),
#    ("can't", 0.015201282),
#    ('child', 0.01460118),
#    ('love', 0.013063922),
#    ('ruin', 0.012502051),
#    ('boom', 0.010649486),
#    ('baby', 0.010559895),
#    ('call', 0.010033665),
#    ('name', 0.009552116)]]]

# %%
_lda_summer_kpop = sort_dictionary(summer)
lda_summer_kpop = []
for tup in _lda_summer_kpop:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_summer_kpop.append(new_tup)
    
lda_summer_kpop
# Out:
# [[35,
#   4.108234476310827,
#   [('put', 0.048931114),
#    ("'em", 0.027571443),
#    ('gucci', 0.02247288),
#    ('sneakers', 0.021779431),
#    ('ready', 0.018953884),
#    ('19th', 0.015438336),
#    ('century', 0.015371317),
#    ('goat', 0.0150678065),
#    ('brave', 0.014465645),
#    ('call', 0.013949169)]],
#  [15,
#   4.049603166467932,
#   [('sorry', 0.019177983),
#    ('man', 0.015505934),
#    ('love', 0.01410066),
#    ('top', 0.012325257),
#    ('yes', 0.012061623),
#    ('mob', 0.011231353),
#    ('eyes', 0.009781362),
#    ('cherry', 0.009393422),
#    ('call', 0.008776228),
#    ('cold', 0.0075873663)]],
#  [17,
#   3.2546780708671577,
#   [('ay', 0.033522647),
#    ('ya', 0.028017163),
#    ('cuz', 0.02162898),
#    ('business', 0.02102332),
#    ('feel', 0.020784901),
#    ('shimmy', 0.017886044),
#    ('down', 0.014459645),
#    ('new', 0.013645619),
#    ('bruce', 0.013619435),
#    ('lee', 0.012469022)]],
#  [67,
#   3.0953026868683082,
#   [('tell', 0.022238554),
#    ('name', 0.018631121),
#    ('heart', 0.016828267),
#    ('sorry', 0.013831663),
#    ('id', 0.013170821),
#    ('ooh', 0.012864722),
#    ('best', 0.012843528),
#    ('yes', 0.01226868),
#    ('love', 0.011228547),
#    ('[bleep', 0.008837304)]],
#  [79,
#   3.0644414932630752,
#   [('love', 0.13372207),
#    ('bomb', 0.02500698),
#    ('sorry', 0.015574337),
#    ('heart', 0.011753382),
#    ('back', 0.010674056),
#    ('let', 0.01008847),
#    ('la-la', 0.008177623),
#    ('feel', 0.006511066),
#    ('eyes', 0.0060980055),
#    ('say', 0.005840904)]],
#  [95,
#   2.567339416667892,
#   [('love', 0.10150945),
#    ('crazy', 0.017002089),
#    ('girl', 0.016112667),
#    ('baby', 0.013138875),
#    ('fun', 0.010652551),
#    ('whip', 0.010499436),
#    ('suck', 0.010369708),
#    ('sorry', 0.0094500985),
#    ('only', 0.008957536),
#    ('take', 0.008623593)]],
#  [50,
#   2.521493857488167,
#   [('power', 0.02462957),
#    ('fall', 0.01754716),
#    ('understand', 0.016133178),
#    ('[bleep]', 0.014019408),
#    ('ah', 0.013673815),
#    ("can't", 0.011703327),
#    ('[bleep', 0.010728189),
#    ('need', 0.010704527),
#    ('friends', 0.010660955),
#    ('feel', 0.0106365755)]],
#  [11,
#   2.415036511776634,
#   [('drunk', 0.48934472),
#    ('only', 0.018974105),
#    ('love', 0.01258739),
#    ('help', 0.006337784),
#    ('bomb', 0.0061882157),
#    ('take', 0.0052208225),
#    ('loco', 0.004951508),
#    ('night', 0.004660736),
#    ('me)', 0.004635133),
#    ('dan', 0.0045377)]],
#  [39,
#   2.1942881089507864,
#   [('seguire', 0.025428753),
#    ('tempo', 0.021742044),
#    ('surf', 0.020424435),
#    ('love', 0.01900057),
#    ('rock', 0.017594812),
#    ('heart', 0.01724366),
#    ('和만', 0.013030869),
#    ('ooh', 0.010789883),
#    ('take', 0.010588166),
#    ('feel', 0.010087417)]],
#  [69,
#   2.173931930807157,
#   [('hot', 0.29573455),
#    ('bussare', 0.01973012),
#    ('love', 0.018407125),
#    ('door', 0.0148289995),
#    ('knock', 0.011533691),
#    ('knocking', 0.0098775085),
#    ('lalisa', 0.008964179),
#    ('bad', 0.008886994),
#    ('home', 0.008114733),
#    ('baby', 0.0072666956)]],
#  [36,
#   2.1650074905355723,
#   [('flower', 0.08875251),
#    ('home', 0.025001505),
#    ("can't", 0.01609401),
#    ('love', 0.015297869),
#    ('sorry', 0.015236079),
#    ('news', 0.013314911),
#    ('am', 0.008734422),
#    ('say', 0.008356031),
#    ('follow', 0.008268185),
#    ('fai!', 0.0074910447)]],
#  [10,
#   2.1616655359484866,
#   [('zu', 0.053395372),
#    ('ba', 0.022690164),
#    ('shy', 0.019567458),
#    ('down', 0.016651371),
#    ("chi't", 0.0153872855),
#    ('worry', 0.013100097),
#    ('let', 0.012856325),
#    ('chuction', 0.012620537),
#    ('baby', 0.009668436),
#    ("we're", 0.009363526)]],
#  [22,
#   2.155298796164061,
#   [('love', 0.030496806),
#    ('woo', 0.018735865),
#    ('heart', 0.018377509),
#    ('world', 0.011463806),
#    ('beautiful', 0.010789728),
#    ('say', 0.008662313),
#    ('follow', 0.008644636),
#    ('shoot', 0.007931957),
#    ('home', 0.0076020914),
#    ("can't", 0.00757542)]],
#  [29,
#   2.1516149885301274,
#   [('sorry', 0.021216378),
#    ('spicy', 0.02057727),
#    ('home', 0.01796221),
#    ('today', 0.01756598),
#    ('feel', 0.016464895),
#    ('sweet', 0.016020974),
#    ('heart', 0.013174765),
#    ('baby', 0.012760784),
#    ('wow!', 0.012360048),
#    ('hi', 0.00995708)]],
#  [1,
#   2.1329686217668495,
#   [('work', 0.23099236),
#    ('allora', 0.0962839),
#    ('swipe', 0.016560888),
#    ('ring', 0.016131435),
#    ('dress', 0.014891946),
#    ('black', 0.01392804),
#    ('stronger', 0.013045915),
#    ('love', 0.01064505),
#    ('give', 0.008394569),
#    ('hey!', 0.007119761)]],
#  [59,
#   2.053964958167853,
#   [('́â', 0.091438025),
#    ('feel', 0.019784482),
#    ('say', 0.0140502425),
#    ('today', 0.013143392),
#    ('pang', 0.010743654),
#    ('give', 0.010599601),
#    ('up!', 0.01023098),
#    ('back', 0.009937259),
#    ('break', 0.009539232),
#    ('shut', 0.0093537085)]],
#  [78,
#   1.2284018367372482,
#   [('picky', 0.019846365),
#    ('tanjin', 0.017593939),
#    ('cry', 0.01738039),
#    ('boy', 0.015732028),
#    ('mom', 0.015271844),
#    ('gem', 0.011783773),
#    ('child', 0.0112647535),
#    ('kominboda', 0.008692206),
#    ('fall', 0.008573391),
#    ('take', 0.008550483)]],
#  [16,
#   1.2168315032922692,
#   [('back', 0.037790198),
#    ('yes', 0.037295792),
#    ('home', 0.020920578),
#    ('wild', 0.02049421),
#    ('mind', 0.012711294),
#    ('el', 0.010281733),
#    ('zoo', 0.009861163),
#    ('mariachi', 0.009481682),
#    ('room', 0.009436371),
#    ('247', 0.008143322)]],
#  [21,
#   1.213576023832502,
#   [('grande', 0.06666327),
#    ('new', 0.033678126),
#    ("can't", 0.026256723),
#    ('shy', 0.024028858),
#    ('prova', 0.022740586),
#    ('heart', 0.019852335),
#    ('face', 0.019471679),
#    ('find', 0.01732748),
#    ('call', 0.01392318),
#    ('harsh', 0.013297068)]],
#  [12,
#   1.1788096977743407,
#   [('cake', 0.53742796),
#    ('dan', 0.02270189),
#    ('heart', 0.008466839),
#    ('sara', 0.0071918755),
#    ('ah!', 0.0071876007),
#    ('island', 0.0071216784),
#    ("can't", 0.006152252),
#    ('sorry', 0.00423058),
#    ('control', 0.0041934894),
#    ('cowboy', 0.0038787806)]],
#  [3,
#   1.176819143443936,
#   [('ка', 0.13358632),
#    ('rende', 0.09121439),
#    ('love', 0.049489625),
#    ('follow', 0.02704563),
#    ('boom', 0.020349901),
#    ('back', 0.018713143),
#    ('crazy', 0.015043805),
#    ('sorry', 0.014235954),
#    ('detail', 0.01006135),
#    ('sexy', 0.010044253)]],
#  [33,
#   1.1716427518495038,
#   [('last', 0.02829835),
#    ('love', 0.025871709),
#    ('traduzione', 0.021983277),
#    ('fall', 0.014179106),
#    ('hands', 0.0134486025),
#    ('need', 0.012280163),
#    ('baby', 0.011729334),
#    ('heart', 0.009592074),
#    ('sorry', 0.008892526),
#    ('leave', 0.008468462)]],
#  [52,
#   1.1709203908994823,
#   [('poppy', 0.026376106),
#    ('sorry', 0.025401866),
#    ('love', 0.021798402),
#    ("we're", 0.011558697),
#    ('night', 0.010672361),
#    ('heart', 0.009696998),
#    ('only', 0.008715016),
#    ('need', 0.00852358),
#    ('girls', 0.008414292),
#    ('bum', 0.008363504)]],
#  [93,
#   1.1688691481485876,
#   [('dimensioni', 0.08186137),
#    ('bubble', 0.030262562),
#    ('yes', 0.020269835),
#    ('twenty', 0.01502874),
#    ('night', 0.013189637),
#    ('love', 0.012889999),
#    ('pop!', 0.009536721),
#    ('feeling', 0.0088200215),
#    ('back', 0.008030082),
#    ('20', 0.0077468287)]],
#  [40,
#   1.1676308164333022,
#   [('home', 0.032683227),
#    ("rollin'", 0.025215156),
#    ("chi't", 0.014279601),
#    ('heart', 0.012421058),
#    ('woo', 0.011545161),
#    ('baby', 0.011468019),
#    ('sorry', 0.010541019),
#    ('healing', 0.010302561),
#    ('only', 0.010176873),
#    ('god', 0.00940859)]],
#  [6,
#   1.1665711183177336,
#   [('home', 0.048266225),
#    ('head', 0.023348477),
#    ('rock', 0.0125204595),
#    ('news', 0.011690688),
#    ('cry', 0.009390045),
#    ("can't", 0.009147805),
#    ('love', 0.008676442),
#    ('baila', 0.0086578885),
#    ('sorry', 0.008189719),
#    ('yes', 0.0076402863)]],
#  [91,
#   1.1651094800054125,
#   [('back', 0.038433984),
#    ('worry', 0.015569113),
#    ("can't", 0.015201282),
#    ('child', 0.01460118),
#    ('love', 0.013063922),
#    ('ruin', 0.012502051),
#    ('boom', 0.010649486),
#    ('baby', 0.010559895),
#    ('call', 0.010033665),
#    ('name', 0.009552116)]],
#  [43,
#   1.1615383190383,
#   [('child', 0.22871725),
#    ('night', 0.0338689),
#    ('work', 0.02875877),
#    ("let's", 0.02102277),
#    ('away', 0.019336484),
#    ('dance', 0.016921612),
#    ('allora', 0.015074615),
#    ('itzy', 0.009549953),
#    ('hours', 0.009546532),
#    ('24', 0.009530879)]],
#  [48,
#   1.1555852001638414,
#   [('top', 0.014910162),
#    ("can't", 0.01275002),
#    ('touch', 0.012553491),
#    ('swan', 0.011881743),
#    ('think', 0.011806836),
#    ('broom', 0.011315789),
#    ('love', 0.009301444),
#    ('dynamite', 0.008965283),
#    ('life', 0.008048781),
#    ('world', 0.0068921084)]],
#  [32,
#   1.1543940105493675,
#   [('am', 0.027187167),
#    ('swing', 0.020002006),
#    ('sorry', 0.013894724),
#    ('traduzione', 0.010280515),
#    ('mine', 0.010133531),
#    ('flower', 0.009372063),
#    ('yes', 0.008149347),
#    ("can't", 0.008059651),
#    ('heart', 0.0078013362),
#    ('live', 0.007661226)]],
#  [42,
#   1.1396182039916312,
#   [('home', 0.11044108),
#    ('on!', 0.022585314),
#    ('summer', 0.014350723),
#    ('mine', 0.014154384),
#    ('say', 0.012697341),
#    ('only', 0.012453617),
#    ('shut', 0.011066296),
#    ('follow', 0.0105501395),
#    ('signals', 0.009513433),
#    ('heart', 0.0081599895)]],
#  [86,
#   1.1125189291360584,
#   [('child', 0.52266127),
#    ('drunk', 0.031574473),
#    ('sorry', 0.009641075),
#    ('gee', 0.00823933),
#    ('il', 0.006236289),
#    ('song', 0.005916335),
#    ('remedy', 0.005312878),
#    ('still', 0.004917466),
#    ('news', 0.004904997),
#    ('mr', 0.0046946607)]],
#  [61,
#   1.1104131901975052,
#   [('hip', 0.04899708),
#    ('universe', 0.039936375),
#    ('cuse', 0.035561603),
#    ('honey', 0.027424965),
#    ('need', 0.022680588),
#    ('excuse', 0.0218645),
#    ('world', 0.017096136),
#    ('illuminate', 0.013367212),
#    ('inside', 0.013287624),
#    ('put', 0.011086253)]],
#  [18,
#   1.1006772237178666,
#   [('take', 0.01856879),
#    ('ah', 0.011554421),
#    ('rover', 0.011115314),
#    ('am', 0.009981858),
#    ('(champ)', 0.008678998),
#    ('euphoria', 0.007856909),
#    ('non', 0.007097611),
#    ('thumb', 0.006879139),
#    ('tatata', 0.006731308),
#    ('woah', 0.006721345)]],
#  [37,
#   1.0962899663445569,
#   [('love', 0.030410489),
#    ('cold', 0.015129776),
#    ('call', 0.0136261135),
#    ('feel', 0.01284215),
#    ('give', 0.012743631),
#    ('world', 0.010969443),
#    ('yes', 0.010570944),
#    ("let's", 0.008119344),
#    ('sour', 0.008114738),
#    ('chili', 0.008053996)]],
#  [54,
#   1.086879054279052,
#   [('aite', 0.037941016),
#    ('rock', 0.018496891),
#    ('love', 0.015932472),
#    ('only', 0.01043294),
#    ('need', 0.010294701),
#    ('feel', 0.00983171),
#    ('head', 0.009095845),
#    ('find', 0.008899584),
#    ("can't", 0.008068511),
#    ('home', 0.0077751903)]],
#  [28,
#   1.0794346994352964,
#   [('beep', 0.13228142),
#    ('dad', 0.0815529),
#    ('pop', 0.01824401),
#    ('traduzione', 0.013228743),
#    ('contact', 0.012426457),
#    ('ora', 0.012078549),
#    ('love', 0.011492944),
#    ('dimmi', 0.009915438),
#    ('cosa', 0.008798163),
#    ("si'", 0.008786897)]],
#  [31,
#   1.0751021184714773,
#   [('cake', 0.07912356),
#    ('significa', 0.05089661),
#    ('sorry', 0.016765837),
#    ('sweet', 0.016685538),
#    ('home', 0.014679868),
#    ('heart', 0.012347091),
#    ('dirty', 0.011196171),
#    ('love', 0.0086311875),
#    ('summer', 0.007762555),
#    ('news', 0.006448534)]],
#  [57,
#   1.0311861366008088,
#   [('let', 0.039689805),
#    ('love', 0.024287933),
#    ("chi't", 0.020375006),
#    ('hero', 0.019507885),
#    ('working', 0.017172735),
#    ('man', 0.015170916),
#    ('change', 0.013229592),
#    ('bag', 0.01086179),
#    ('chuction', 0.010748483),
#    ('take', 0.009275026)]],
#  [56,
#   0.9120376633600245,
#   [('top', 0.043103877),
#    ('dan', 0.03840323),
#    ('light', 0.028803416),
#    ('moon', 0.013261573),
#    ('life', 0.011775709),
#    ('heart', 0.010172459),
#    ("didn't", 0.009842374),
#    ('work', 0.00863606),
#    ('home', 0.008562464),
#    ('dream', 0.008431236)]],
#  [77,
#   0.8776818526403076,
#   [('home', 0.21218365),
#    ('hands', 0.011546376),
#    ('shut', 0.011314601),
#    ('love', 0.011267348),
#    ('rende', 0.011106626),
#    ('let', 0.00985002),
#    ('jump', 0.009379214),
#    ('comment', 0.009186703),
#    ('baby', 0.009135382),
#    ("let's", 0.0071997144)]],
#  [98,
#   0.79990412458028,
#   [('drunk', 0.33895785),
#    ('invalid', 0.05484575),
#    ('need', 0.014886551),
#    ('point', 0.014212818),
#    ('love', 0.0136489915),
#    ('home', 0.009818946),
#    ('run', 0.008167593),
#    ('night', 0.007847669),
#    ('sorry', 0.005945366),
#    ('let', 0.004847424)]],
#  [92,
#   0.7967489843449584,
#   [('hot', 0.052660957),
#    ('home', 0.03589862),
#    ('night', 0.030643368),
#    ("can't", 0.012045965),
#    ('hear', 0.010421228),
#    ('say', 0.009662431),
#    ('leave', 0.009290347),
#    ('best', 0.009219),
#    ('run', 0.008783458),
#    ('light', 0.008513494)]],
#  [75,
#   0.7888671112614247,
#   [('give', 0.033155438),
#    ('feel', 0.015832266),
#    ('say', 0.014261861),
#    ('love', 0.012682229),
#    ('break', 0.012067873),
#    ('eyes', 0.009690926),
#    ('candyfloss', 0.009141569),
#    ('way', 0.008961511),
#    ('yes', 0.00876754),
#    ("can't", 0.008351288)]],
#  [94,
#   0.5560353649216268,
#   [('work', 0.020583035),
#    ('detail', 0.014504646),
#    ("can't", 0.014444469),
#    ('vacanza', 0.013705998),
#    ('back', 0.012938556),
#    ('sorry', 0.011171395),
#    ('scream', 0.01027386),
#    ('news', 0.010143635),
#    ('home', 0.00816182),
#    ('care', 0.007858811)]],
#  [73,
#   0.46702447658935853,
#   [('home', 0.0481873),
#    ('wave', 0.037549425),
#    ('yah', 0.02496207),
#    ('girl', 0.013362265),
#    ('love', 0.012944635),
#    ('back', 0.012001463),
#    ('work', 0.009941809),
#    ('yes', 0.008996571),
#    ('bum', 0.008827863),
#    ('new', 0.007765563)]],
#  [71,
#   0.3918382750944147,
#   [('gam3', 0.04146646),
#    ('boom', 0.03779267),
#    ('love', 0.037615556),
#    ('best', 0.0142748775),
#    ('think', 0.01322112),
#    ('upgrade', 0.012946465),
#    ('waiting', 0.012242406),
#    ('say', 0.012225204),
#    ("can't", 0.011932248),
#    ('heart', 0.009453145)]],
#  [89,
#   0.36390920146550343,
#   [('sorry', 0.01964464),
#    ('(eh-oh)', 0.014903662),
#    ('cake', 0.014702311),
#    ('meet', 0.013160284),
#    ('back', 0.012911065),
#    ('leave', 0.010842646),
#    ("can't", 0.010515789),
#    ('name', 0.010070662),
#    ('touch', 0.009895441),
#    ('matter', 0.009402735)]],
#  [2,
#   0.3345726874340471,
#   [('child', 0.08136138),
#    ('bad', 0.0409662),
#    ('home', 0.03347452),
#    ('love', 0.030488439),
#    ('sorry', 0.020337855),
#    ('guy', 0.016353434),
#    ('boy', 0.015128939),
#    ("he's", 0.014319678),
#    ('god', 0.013214505),
#    ('baby', 0.0124302795)]],
#  [53,
#   0.3204329847012559,
#   [('only', 0.021853974),
#    ('put', 0.013655132),
#    ('wish', 0.012439389),
#    ('yes', 0.009763787),
#    ('party', 0.009389874),
#    ('afraid', 0.00914802),
#    ('universe', 0.009107567),
#    ('still', 0.008721187),
#    ('tough', 0.008387285),
#    ('mind', 0.007972881)]],
#  [66,
#   0.31649171113713237,
#   [('boy', 0.030943131),
#    ('ice', 0.01897983),
#    ('cream', 0.015111391),
#    ('am', 0.012620046),
#    ('let', 0.012469489),
#    ('fire', 0.012417539),
#    ('life', 0.012378938),
#    ('night', 0.010307112),
#    ('wow', 0.010059117),
#    ('follow', 0.009122665)]],
#  [24,
#   0.2988308609728847,
#   [('child', 0.26967236),
#    ('stay', 0.025342984),
#    ('love', 0.014873495),
#    ('heart', 0.011649022),
#    ('way', 0.010723026),
#    ('gold', 0.010551815),
#    ('loca', 0.010394875),
#    ("can't", 0.009206968),
#    ('night', 0.0084133465),
#    ('sorry', 0.007971068)]],
#  [8,
#   0.2772818846297014,
#   [('give', 0.022465527),
#    ('break', 0.014736539),
#    ('il', 0.013335014),
#    ('burn', 0.013197863),
#    ('up!', 0.012257195),
#    ('common', 0.01148138),
#    ('sole', 0.011472418),
#    ('say', 0.011277789),
#    ('remedy', 0.010798968),
#    ("can't", 0.0084957015)]],
#  [76,
#   0.25590481229482975,
#   [('boy', 0.060019),
#    ('bump三', 0.03753202),
#    ('love', 0.014698052),
#    ('home', 0.012468972),
#    ('hip', 0.012304689),
#    ('rende', 0.011868202),
#    ('dream', 0.010242304),
#    ('eyes', 0.008898932),
#    ('dreams', 0.008211918),
#    ('feel', 0.008003279)]],
#  [55,
#   0.25423337678330427,
#   [('dance', 0.28569287),
#    ('tock', 0.03514236),
#    ('tick', 0.030013552),
#    ('moon', 0.019117767),
#    ('dawn', 0.0155621935),
#    ('baby', 0.01351255),
#    ('follow', 0.011752037),
#    ('funny', 0.010982711),
#    ('need', 0.009867653),
#    ('deep', 0.0095220655)]],
#  [68,
#   0.2289837487933255,
#   [('pop', 0.16679177),
#    ('bambi', 0.016127888),
#    ('walker', 0.01307314),
#    ('room', 0.010778689),
#    ('ac', 0.008360793),
#    ('[bleep', 0.007873411),
#    ('shoot', 0.007717361),
#    ('hear', 0.006538573),
#    ('desire', 0.006103797),
#    ('night', 0.0060317437)]],
#  [96,
#   0.22575977192354912,
#   [('child', 0.022488307),
#    ('change', 0.021405311),
#    ('fake', 0.014037605),
#    ("can't", 0.013132668),
#    ('let', 0.012272005),
#    ('love', 0.010917709),
#    ('eyes', 0.009840898),
#    ('yes', 0.008841226),
#    ('oh!', 0.008285195),
#    ('beauty', 0.008225028)]],
#  [20,
#   0.22485454500747437,
#   [('hands', 0.2808262),
#    ('feel', 0.016265327),
#    ('non', 0.016057057),
#    ('save', 0.012661264),
#    ('sorry', 0.009217082),
#    ('mani', 0.008624664),
#    ('home', 0.007918024),
#    ('fine', 0.007885704),
#    ('start', 0.007515863),
#    ('heart', 0.007368473)]],
#  [63,
#   0.22389172037401295,
#   [('reale', 0.09440341),
#    ('detail', 0.066119105),
#    ('bam', 0.031425606),
#    ('headphones', 0.014034618),
#    ('dance', 0.009333334),
#    ('della', 0.009209137),
#    ('prova', 0.00848125),
#    ('dam', 0.008296723),
#    ('goodbye', 0.0073835314),
#    ('sorry', 0.0072470433)]],
#  [58,
#   0.22142695096226817,
#   [('dance', 0.07236944),
#    ('live', 0.023114882),
#    ('uh', 0.019541543),
#    ('ok', 0.012063019),
#    ('baby', 0.00936758),
#    ('sorry', 0.009223109),
#    ('yes', 0.007393912),
#    ('noi', 0.0071280515),
#    ('il', 0.00698243),
#    ('chiring', 0.0068054968)]],
#  [46,
#   0.21596700073314423,
#   [('baby', 0.017115429),
#    ("can't", 0.014454348),
#    ('switch', 0.010946123),
#    ('air', 0.010812735),
#    ('night', 0.010644061),
#    ('million', 0.010538979),
#    ('love', 0.010261633),
#    ('eyes', 0.009967436),
#    ('sweet', 0.009645945),
#    ('(you', 0.009419555)]],
#  [19,
#   0.20250571427641262,
#   [('dance', 0.2398375),
#    ('singing', 0.12380477),
#    ('sì', 0.07374844),
#    ('home', 0.013148126),
#    ('mic', 0.0077302116),
#    ('sorry', 0.0069070947),
#    ('think', 0.0062227403),
#    ('goccia', 0.0055226516),
#    ('news', 0.0046683727),
#    ('trauma', 0.0043109856)]],
#  [26,
#   0.1967477128655446,
#   [('invalid', 0.4728042),
#    ('hot', 0.055858914),
#    ('work', 0.018534567),
#    ('red', 0.013993514),
#    ("can't", 0.012673326),
#    ('level', 0.010103605),
#    ('next', 0.009792233),
#    ('keep', 0.008651116),
#    ('world', 0.008155011),
#    ("won't", 0.006876787)]],
#  [13,
#   0.1961029199173936,
#   [('child', 0.541348),
#    ('night', 0.018452208),
#    ("let's", 0.007569515),
#    ('smile', 0.007455116),
#    ('sorry', 0.005648157),
#    ('dance', 0.0054422324),
#    ('gee', 0.005398436),
#    ('away', 0.004396182),
#    ('revoir', 0.0036470671),
#    ('goodbye', 0.003644661)]],
#  [0,
#   0.17939653288522095,
#   [('dad', 0.02819044),
#    ('dimensioni', 0.020726688),
#    ('sorry', 0.015904406),
#    ('star', 0.014451333),
#    ('love', 0.014043313),
#    ('pop', 0.013492216),
#    ('baby', 0.013231017),
#    ("can't", 0.011013707),
#    ('ка', 0.010730985),
#    ('news', 0.008277546)]],
#  [4,
#   0.17939653288522095,
#   [('bang', 0.02707566),
#    ('ice', 0.018735738),
#    ('woo', 0.018653309),
#    ("chi't", 0.016499864),
#    ('cream', 0.013221048),
#    ("let's", 0.01311209),
#    ('chuction', 0.0130441105),
#    ('picky', 0.012733092),
#    ('chill', 0.012582295),
#    ('twitter', 0.012342939)]],
#  [5,
#   0.17939653288522095,
#   [('cake', 0.18774717),
#    ('bad', 0.01695221),
#    ('luv', 0.011073785),
#    ('feel', 0.01083655),
#    ('take', 0.01049273),
#    ('woah', 0.009804929),
#    ('baby', 0.0097087305),
#    ('tell', 0.00958836),
#    ('waiting', 0.008552329),
#    ('singing', 0.008331315)]],
#  [7,
#   0.17939653288522095,
#   [('cake', 0.14696604),
#    ('osserva', 0.06658148),
#    ('luv', 0.035464153),
#    ('lion', 0.014399808),
#    ('sara', 0.009086072),
#    ('picky', 0.009062332),
#    ('back', 0.008865344),
#    ('love', 0.0076312367),
#    ('traduzione', 0.007482656),
#    ('queen', 0.0071995337)]],
#  [9,
#   0.17939653288522095,
#   [('home', 0.05912262),
#    ('meet', 0.02226176),
#    ('love', 0.02172924),
#    ('shut', 0.017627003),
#    ('lost', 0.014845376),
#    ('summer', 0.013848246),
#    ('world', 0.01241691),
#    ("can't", 0.011770142),
#    ('heart', 0.010776309),
#    ('life', 0.009823376)]],
#  [14,
#   0.17939653288522095,
#   [('ка', 0.1393549),
#    ('upgrade', 0.05851363),
#    ('love', 0.03692618),
#    ('baby', 0.02501617),
#    ('rende', 0.023859095),
#    ('crazy', 0.013201952),
#    ('man', 0.012233351),
#    ('sorry', 0.010981763),
#    ('think', 0.00847632),
#    ('bump三', 0.007849194)]],
#  [23,
#   0.17939653288522095,
#   [('cat', 0.024034956),
#    ('hey!', 0.020367071),
#    ('cake', 0.018623127),
#    ('dam', 0.016853957),
#    ('take', 0.014449209),
#    ('home', 0.01441734),
#    ('nekoya', 0.013038084),
#    ('bambi', 0.011521883),
#    ('boom', 0.010950034),
#    ('today', 0.009930297)]],
#  [25,
#   0.17939653288522095,
#   [('change', 0.027001996),
#    ('am', 0.020623658),
#    ('iris', 0.017272413),
#    ('love', 0.014348233),
#    ('play', 0.013827676),
#    ("can't", 0.013798336),
#    ('imma', 0.0134695675),
#    ('well', 0.013431303),
#    ('feel', 0.012011804),
#    ('introduces', 0.011800245)]],
#  [27,
#   0.17939653288522095,
#   [('caldo', 0.03092335),
#    ('home', 0.025340203),
#    ('dream', 0.023719748),
#    ('eyes', 0.017212726),
#    ('world', 0.013390623),
#    ('heart', 0.013159852),
#    ('today', 0.01261458),
#    ('rende', 0.011627386),
#    ('night', 0.010920238),
#    ('say', 0.010521186)]],
#  [30,
#   0.17939653288522095,
#   [('man', 0.05039316),
#    ('love', 0.031792745),
#    ('whatta', 0.022614006),
#    ('point', 0.018862318),
#    ('think', 0.01594925),
#    ('need', 0.011147342),
#    ('meet', 0.010375767),
#    ('baby', 0.010295244),
#    ('sorry', 0.009965349),
#    ('give', 0.009114387)]],
#  [34,
#   0.17939653288522095,
#   [('man', 0.022262853),
#    ('left', 0.019772537),
#    ('heart', 0.01111332),
#    ('take', 0.010933177),
#    ('true', 0.010902999),
#    ('feel', 0.010590973),
#    ('universe', 0.010501966),
#    ('rip', 0.010456011),
#    ('whatta', 0.010330829),
#    ('news', 0.010088465)]],
#  [38,
#   0.17939653288522095,
#   [('singing', 0.043945562),
#    ('prova', 0.043101355),
#    ('oriente', 0.025412668),
#    ("can't", 0.016203191),
#    ('dance', 0.012972394),
#    ("let's", 0.011733666),
#    ('tonight', 0.011071665),
#    ('sorry', 0.010955071),
#    ('ohohohohohohohohohoh', 0.010771617),
#    ('nightmare', 0.010496412)]],
#  [41,
#   0.17939653288522095,
#   [('cake', 0.09813073),
#    ('vacanza', 0.054007754),
#    ('oriente', 0.037275698),
#    ('home', 0.037130505),
#    ('bop', 0.018083515),
#    ('nanana', 0.010314575),
#    ('na-na', 0.009425912),
#    ('nananana', 0.0073383106),
#    ('tonight', 0.0070864935),
#    ('shut', 0.0069172094)]],
#  [44,
#   0.17939653288522095,
#   [('della', 0.051655803),
#    ('singing', 0.034560025),
#    ('invalid', 0.0220612),
#    ('sorry', 0.01984099),
#    ('leave', 0.010696817),
#    ("we're", 0.0097846445),
#    ("can't", 0.0097697275),
#    ('ring', 0.008446193),
#    ('heart', 0.008352096),
#    ("let's", 0.0080390265)]],
#  [45,
#   0.17939653288522095,
#   [('singing', 0.22662243),
#    ('sì', 0.032414142),
#    ('fly', 0.022221101),
#    ('rende', 0.020841269),
#    ('butterfly', 0.020033823),
#    ('warm', 0.014579163),
#    ("that's", 0.014187337),
#    ('wing', 0.012398448),
#    ('wanted', 0.010834509),
#    ('s-o-s', 0.010553501)]],
#  [47,
#   0.17939653288522095,
#   [('anpanman', 0.019858558),
#    ('still', 0.018399196),
#    ('am', 0.017816318),
#    ('new', 0.017728737),
#    ('baby', 0.01733712),
#    ('lan', 0.012267445),
#    ('share', 0.012039173),
#    ('happy', 0.01102643),
#    ('young', 0.010758008),
#    ('afraid', 0.010662823)]],
#  [49,
#   0.17939653288522095,
#   [('best', 0.08715419),
#    ('let', 0.01475803),
#    ('love', 0.012134012),
#    ('bussare', 0.010678796),
#    ('knock', 0.010513027),
#    ('say', 0.008686041),
#    ('music', 0.008481975),
#    ('sorry', 0.008157991),
#    ('news', 0.007947078),
#    ('door', 0.007309129)]],
#  [51,
#   0.17939653288522095,
#   [('yolo', 0.01896338),
#    ('love', 0.016533628),
#    ('let', 0.015133044),
#    ("can't", 0.013416711),
#    ('flower', 0.012526516),
#    ('baby', 0.011205662),
#    ('likey', 0.0094881505),
#    ('sorry', 0.009444547),
#    ('news', 0.009090319),
#    ('hot', 0.008699239)]],
#  [60,
#   0.17939653288522095,
#   [('rende', 0.020672707),
#    ('run', 0.019410178),
#    ('light', 0.012955417),
#    ('baby', 0.012108124),
#    ('power', 0.011600958),
#    ('settings', 0.01063824),
#    ('dynamite', 0.00968296),
#    ('mom', 0.009584812),
#    ('back', 0.009255367),
#    ('stars', 0.009190432)]],
#  [62,
#   0.17939653288522095,
#   [('dan', 0.4514837),
#    ('give', 0.019170877),
#    ('love', 0.014664631),
#    ('boomshakalaka', 0.010770355),
#    ('sorry', 0.008491434),
#    ('cloud', 0.008059948),
#    ('start', 0.005839749),
#    ('della', 0.004674555),
#    ('tie', 0.0046492526),
#    ('end', 0.0045831534)]],
#  [64,
#   0.17939653288522095,
#   [('significa', 0.24679045),
#    ('cake', 0.090571165),
#    ('(na', 0.009537365),
#    ('aite', 0.009202817),
#    ('na)', 0.008466885),
#    ('feel', 0.008171608),
#    ('heart', 0.007585476),
#    ('fire', 0.0072483146),
#    ('let', 0.0065646614),
#    ('yes', 0.006491918)]],
#  [65,
#   0.17939653288522095,
#   [('dad', 0.1100248),
#    ('woo', 0.052571733),
#    ('bum', 0.028331323),
#    ('child', 0.02099501),
#    ('girls', 0.019572048),
#    ('bomb', 0.01664526),
#    ('love', 0.014625111),
#    ('young', 0.013250262),
#    ('wee', 0.012071241),
#    ('sorry', 0.011850404)]],
#  [70,
#   0.17939653288522095,
#   [('́â', 0.074356765),
#    ('heart', 0.032033775),
#    ('thinking', 0.031349465),
#    ('once', 0.02070861),
#    ('dance', 0.014564277),
#    ('love', 0.013194102),
#    ('fever', 0.012139218),
#    ('fire', 0.011233595),
#    ('sorry', 0.0101642255),
#    ('news', 0.009628044)]],
#  [72,
#   0.17939653288522095,
#   [('dream', 0.018987443),
#    ('back', 0.0126456795),
#    ('news', 0.011978871),
#    ('(eh-oh)', 0.011789167),
#    ('sorry', 0.010815643),
#    ('hours', 0.010526056),
#    ('end', 0.008805529),
#    ('bring', 0.0077118995),
#    ('home', 0.007625611),
#    ('love', 0.0069088996)]],
#  [74,
#   0.17939653288522095,
#   [('gno', 0.14761764),
#    ('hip', 0.020489806),
#    ('yes', 0.01595742),
#    ('price_varies}', 0.015268139),
#    ('{{if', 0.013905905),
#    ('{{if}', 0.013530272),
#    ('love', 0.013239329),
#    ('sorry', 0.009275222),
#    ('take', 0.0082806125),
#    ('ho', 0.007081527)]],
#  [80,
#   0.17939653288522095,
#   [('segreta', 0.09116522),
#    ('love', 0.034581535),
#    ('honey', 0.019332357),
#    ('ready', 0.015543296),
#    ('stay', 0.014312638),
#    ('sorry', 0.014138336),
#    ('am', 0.011490246),
#    ('call', 0.011248237),
#    ('alone', 0.01008997),
#    ('heart', 0.0092548635)]],
#  [81,
#   0.17939653288522095,
#   [('gno', 0.04576273),
#    ('mmhh', 0.042210452),
#    ('significa', 0.030464603),
#    ('pop', 0.022525705),
#    ('mmmh', 0.018089792),
#    ('mmmhmh', 0.018089121),
#    ('give', 0.014235977),
#    ('candy', 0.009723477),
#    ('cream', 0.009010445),
#    ('scream', 0.008472151)]],
#  [82,
#   0.17939653288522095,
#   [('baby', 0.09662958),
#    ('ba', 0.069170594),
#    ('yes', 0.024720376),
#    ('next', 0.018593457),
#    ('hold', 0.0130044725),
#    ('let', 0.010556324),
#    ('put', 0.00928539),
#    ('give', 0.007811765),
#    ('crush', 0.0076963804),
#    ('love', 0.0072074602)]],
#  [83,
#   0.17939653288522095,
#   [('love', 0.026085567),
#    ('woo', 0.017328227),
#    ('call', 0.013702494),
#    ('let', 0.013514356),
#    ('dam', 0.013215337),
#    ('dream', 0.009805816),
#    ('attention', 0.0083781555),
#    ('singing', 0.008141589),
#    ('ac', 0.008039262),
#    ('sorry', 0.007969191)]],
#  [84,
#   0.17939653288522095,
#   [('umpah', 0.03301867),
#    ('hot', 0.031514898),
#    ('microphone', 0.018923111),
#    ('(ayy)', 0.014916019),
#    ('pass', 0.014908003),
#    ('give', 0.013857132),
#    ('life', 0.011899236),
#    ('home', 0.010508278),
#    ('forgotten', 0.00926994),
#    ('say', 0.009193618)]],
#  [85,
#   0.17939653288522095,
#   [('non', 0.036526356),
#    ('love', 0.030052342),
#    ('ash', 0.026762802),
#    ('bang', 0.023443127),
#    ('way', 0.015284274),
#    ("we're", 0.012628637),
#    ('baby', 0.010686475),
#    ('click', 0.009281315),
#    ('singing', 0.008575044),
#    ('yes', 0.008349322)]],
#  [87,
#   0.17939653288522095,
#   [('sorry', 0.024967775),
#    ('ti', 0.020002604),
#    ('love', 0.016758582),
#    ('seoul', 0.014058751),
#    ('home', 0.012874632),
#    ('baby', 0.012809893),
#    ('news', 0.01162736),
#    ('antifragile', 0.011338778),
#    ('fragile', 0.010939775),
#    ('feel', 0.010309425)]],
#  [88,
#   0.17939653288522095,
#   [('love', 0.039158992),
#    ('call', 0.021630995),
#    ("can't", 0.015576456),
#    ('take', 0.013726798),
#    ('eyes', 0.01251539),
#    ('back', 0.010316383),
#    ('need', 0.00954422),
#    ('leave', 0.008225534),
#    ('baby', 0.0080089485),
#    ('heart', 0.0070849843)]],
#  [90,
#   0.17939653288522095,
#   [('drunk', 0.07500513),
#    ('feel', 0.025383938),
#    ('woo', 0.015077599),
#    ('kim', 0.01362912),
#    ('special', 0.012850781),
#    ("that's", 0.012310459),
#    ('room', 0.011303398),
#    ('christmas', 0.008394781),
#    ('hello', 0.0076731853),
#    ('dad', 0.007609075)]],
#  [97,
#   0.17939653288522095,
#   [('daydream', 0.04475456),
#    ('home', 0.021596946),
#    ('babe', 0.01899353),
#    ('morning', 0.01807925),
#    ('boy', 0.016807433),
#    ('love', 0.014928132),
#    ('dream', 0.012004947),
#    ('easy', 0.01128013),
#    ('sky', 0.009861242),
#    ('knows', 0.0094246)]],
#  [99,
#   0.17939653288522095,
#   [('mariachi', 0.029771177),
#    ('el', 0.02958568),
#    ('sweet', 0.016189355),
#    ('sky', 0.013878226),
#    ('city', 0.01200624),
#    ('summer', 0.011987944),
#    ('spicy', 0.011483958),
#    ("let's", 0.009746166),
#    ('love', 0.009121828),
#    ('fly', 0.0080900155)]]]

# %% [markdown]
# ### Emotion analysis
# Emotions:
# fear
# anger
# anticipation
# trust
# surprise
# positive
# negative
# sadness
# disgust
# joy

# %%
import numpy as np

# %%
labels = [
    "anger",
    "anticipation",
    "disgust",
    "fear",
    "joy",
    "sadness",
    "surprise",	
    "trust",
    "negative",	
    "positive",
]

emotions = [
    "anger",
    "anticipation",
    "disgust",
    "fear",
    "joy",
    "sadness",
    "surprise",	
    "trust",
]

sentiments = [
    "negative",	
    "positive",
]

# %%
df_nrc = pd.read_csv("NRC.txt", sep="\t", names=["word", "label", "amount"])

words_to_labels = {}

for _, row in df_nrc.iterrows():
    words_to_labels[row["word"]] = words_to_labels.get(row["word"], np.zeros((10, 1)))
    words_to_labels[row["word"]][labels.index(row["label"])] = row["amount"]

# %%
df_label = df.copy()
for label in labels:
    df_label[label] = 0

# %%
for cnt in range(len(df)):
    lyrics = df["lyrics"][cnt]

    if type(lyrics) != str:
        continue

    label_this = np.zeros((10, 1))

    for word in lyrics.split():
        if word in words_to_labels:
            label_this += words_to_labels[word]
            
    emotion_this = label_this[:8]
    sentiment_this = label_this[8:]
            
    if np.linalg.norm(emotion_this) != 0:
        emotion_this /= np.linalg.norm(emotion_this)
        
    if np.linalg.norm(sentiment_this) != 0:
        sentiment_this /= np.linalg.norm(sentiment_this)
        
    label_this = np.concatenate((emotion_this, sentiment_this), axis=None)
    
    for label in labels:
        df_label[label][cnt] = label_this[labels.index(label)]
# Out:
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0810361063877192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5510455234364905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.03241444255508768' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0810361063877192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5834599659915782' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.01620722127754384' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5510455234364905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.1944866553305261' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.17888543819998318' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_17328\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9838699100999074' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]

# %%
df_emotion_global = df_label[df_label["grouping"].isin(global_group)]
mean_emotion_global = df_emotion_global[emotions].mean()
normalized_mean_emotion_global = mean_emotion_global / np.linalg.norm(mean_emotion_global)
mean_sentiment_global = df_emotion_global[sentiments].mean()
normalized_mean_sentiment_global = mean_sentiment_global / np.linalg.norm(mean_sentiment_global)

df_emotion_kpop = df_label[df_label["grouping"].isin(kpop_group)]
mean_emotion_kpop = df_emotion_kpop[emotions].mean()
normalized_mean_emotion_kpop = mean_emotion_kpop / np.linalg.norm(mean_emotion_kpop)
mean_sentiment_kpop = df_emotion_kpop[sentiments].mean()
normalized_mean_sentiment_kpop = mean_sentiment_kpop / np.linalg.norm(mean_sentiment_kpop)

df_emotion_target = df_label[df_label["grouping"] == target_group]
mean_emotion_target = df_emotion_target[emotions].mean()
normalized_mean_emotion_target = mean_emotion_target / np.linalg.norm(mean_emotion_target)
mean_sentiment_target = df_emotion_target[sentiments].mean()
normalized_mean_sentiment_target = mean_sentiment_target / np.linalg.norm(mean_sentiment_target)

# %%
normalized_mean_emotion_target
# Out:
# anger           0.438379
# anticipation    0.375822
# disgust         0.170637
# fear            0.330805
# joy             0.493340
# sadness         0.322054
# surprise        0.200253
# trust           0.375272
# dtype: float64

# %%
normalized_mean_sentiment_target
# Out:
# negative    0.688952
# positive    0.724807
# dtype: float64

# %% [markdown]
# against global

# %%
emotion_percentage_global = (normalized_mean_emotion_target - normalized_mean_emotion_global) / normalized_mean_emotion_global * 100

emotion_percentage_global
# Out:
# anger           45.648572
# anticipation    -8.772393
# disgust        -12.205216
# fear            -0.224858
# joy             -0.273445
# sadness        -12.341296
# surprise       -15.363607
# trust           -5.082505
# dtype: float64

# %%
sentiment_percentage_global = (normalized_mean_sentiment_target - normalized_mean_sentiment_global) / normalized_mean_sentiment_global * 100

sentiment_percentage_global
# Out:
# negative    5.049715
# positive   -3.986985
# dtype: float64

# %% [markdown]
# against KPOP

# %%
emotion_percentage_kpop = (normalized_mean_emotion_target - normalized_mean_emotion_kpop) / normalized_mean_emotion_kpop * 100

emotion_percentage_kpop
# Out:
# anger           97.407605
# anticipation   -17.561263
# disgust         22.265617
# fear            11.910441
# joy            -14.256188
# sadness          1.878356
# surprise       -15.187418
# trust           -2.871784
# dtype: float64

# %%
sentiment_percentage_kpop = (normalized_mean_sentiment_target - normalized_mean_sentiment_kpop) / normalized_mean_sentiment_kpop * 100

sentiment_percentage_kpop
# Out:
# negative    35.117273
# positive   -15.743482
# dtype: float64

# %% [markdown]
# ## Save Data

# %%
# to float
for _sum in lda_summer_global:
    _sum[2] = [(tup[0], float(tup[1])) for tup in _sum[2]]
    
for _sum in lda_summer_kpop:
    _sum[2] = [(tup[0], float(tup[1])) for tup in _sum[2]]
    
for count in lda_counter_global:
    count[2] = [(tup[0], float(tup[1])) for tup in count[2]]

for count in lda_counter_kpop:
    count[2] = [(tup[0], float(tup[1])) for tup in count[2]]

# %%
json_data = {
    "tfidf_counter_global": tfidf_counter_global,
    "tfidf_summer_global": tfidf_summer_global,
    "tfidf_counter_kpop": tfidf_counter_kpop,
    "tfidf_summer_kpop": tfidf_summer_kpop,
    "lda_counter_global": lda_counter_global,
    "lda_summer_global": lda_summer_global,
    "lda_counter_kpop": lda_counter_kpop,
    "lda_summer_kpop": lda_summer_kpop,
    "lda_html_global": lda_html_global,
    "lda_html_kpop": lda_html_kpop,
    "normalized_mean_emotion_target": normalized_mean_emotion_target.astype(float).tolist(),
    "sentiment_percentage_global": sentiment_percentage_global.astype(float).tolist(),
    "emotion_percentage_global": emotion_percentage_global.astype(float).tolist(),
    "sentiment_percentage_global": sentiment_percentage_global.astype(float).tolist(),
    "emotion_percentage_kpop": emotion_percentage_kpop.astype(float).tolist(),
    "sentiment_percentage_kpop": sentiment_percentage_kpop.astype(float).tolist(),
}

# %%
import json
with open("data_"+ target_group +".json", "w") as f:
    json.dump(json_data, f)
