# %% [markdown]
# # Lyrics Analysis

# %%
lyrics_directory = "Lyrics_Data/"
tracks_csv = "tracks.csv"
stopwords_file = "stopwords.txt"

# %% [markdown]
# ## Import data

# %%
import pandas as pd

# %%
df = pd.read_csv(tracks_csv)

df.head(3)
# Out:
#                       track_name                track_id grouping
# 0  Ice Cream (with Selena Gomez)  2J4P46vCFm1rPkNkp9pZWX     kpop
# 1                       Dynamite  0v1x6rN6JHRapa03JElljE     kpop
# 2                    THE BADDEST  2V4Fx72svQRxrFvNT1eq5f     kpop

# %%
df.shape
# Out:
# (3811, 3)

# %%
df["grouping"].unique()
# Out:
# array(['kpop', 'global', 'billboard'], dtype=object)

# %%
def get_lyrics(track_id):
    try:
        lyrics = ""
        with open(lyrics_directory + track_id + ".txt", "r") as f:
            lyrics = f.read()
            
        return lyrics            
    except:
        return None
    
df["lyrics"] = df["track_id"].apply(get_lyrics)

df.shape
# Out:
# (3811, 4)

# %%
# stop words
# https://www.kaggle.com/datasets/rowhitswami/stopwords/
stopwords = set()
with open(stopwords_file, "r") as f:
    stopwords = set(f.read().split("\n"))
    
stopwords
# Out:
# {',',
#  '>',
#  '?',
#  'Just',
#  'Yes',
#  'a',
#  'abaft',
#  'abafter',
#  'abaftest',
#  'about',
#  'abouter',
#  'aboutest',
#  'above',
#  'abover',
#  'abovest',
#  'accordingly',
#  'aer',
#  'aest',
#  'afore',
#  'after',
#  'afterer',
#  'afterest',
#  'afterward',
#  'afterwards',
#  'again',
#  'against',
#  'aid',
#  'ain',
#  'albeit',
#  'all',
#  'aller',
#  'allest',
#  'alls',
#  'allyou',
#  'almost',
#  'along',
#  'alongside',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amid',
#  'amidst',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'andor',
#  'anear',
#  'anent',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anywhere',
#  'apart',
#  'aparter',
#  'apartest',
#  'appear',
#  'appeared',
#  'appearing',
#  'appears',
#  'appropriate',
#  'appropriated',
#  'appropriater',
#  'appropriates',
#  'appropriatest',
#  'appropriating',
#  'are',
#  'ares',
#  'around',
#  'as',
#  'ases',
#  'aside',
#  'asides',
#  'aslant',
#  'astraddle',
#  'astraddler',
#  'astraddlest',
#  'astride',
#  'astrider',
#  'astridest',
#  'at',
#  'athwart',
#  'atop',
#  'atween',
#  'aught',
#  'aughts',
#  'available',
#  'availabler',
#  'availablest',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'becominger',
#  'becomingest',
#  'becomings',
#  'been',
#  'before',
#  'beforehand',
#  'beforehander',
#  'beforehandest',
#  'behind',
#  'behinds',
#  'below',
#  'beneath',
#  'beside',
#  'besides',
#  'better',
#  'bettered',
#  'bettering',
#  'betters',
#  'between',
#  'betwixt',
#  'beyond',
#  'bist',
#  'both',
#  'but',
#  'buts',
#  'by',
#  'by-and-by',
#  'byandby',
#  'c',
#  'can',
#  'cannot',
#  'canst',
#  'cant',
#  'canted',
#  'cantest',
#  'canting',
#  'cants',
#  'cer',
#  'certain',
#  'certainer',
#  'certainest',
#  'cest',
#  'chez',
#  'circa',
#  'co',
#  'come',
#  'come-on',
#  'come-ons',
#  'comeon',
#  'comeons',
#  'concerning',
#  'concerninger',
#  'concerningest',
#  'consequently',
#  'considering',
#  'could',
#  'couldst',
#  'cum',
#  'd',
#  'da',
#  'day',
#  'dday',
#  'ddays',
#  'describe',
#  'described',
#  'describes',
#  'describing',
#  'despite',
#  'despited',
#  'despites',
#  'despiting',
#  'did',
#  'different',
#  'differenter',
#  'differentest',
#  'do',
#  'doe',
#  'does',
#  'doing',
#  'doings',
#  'don',
#  "don't",
#  'done',
#  'doner',
#  'dones',
#  'donest',
#  'dos',
#  'dost',
#  'doth',
#  'downs',
#  'downward',
#  'downwarder',
#  'downwardest',
#  'downwards',
#  'du',
#  'during',
#  'e',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'ere',
#  'et',
#  'etc',
#  'even',
#  'evened',
#  'evenest',
#  'evens',
#  'evenser',
#  'evensest',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'except',
#  'excepted',
#  'excepting',
#  'excepts',
#  'exes',
#  'f',
#  'fact',
#  'facts',
#  'failing',
#  'failings',
#  'few',
#  'fewer',
#  'fewest',
#  'figupon',
#  'figuponed',
#  'figuponing',
#  'figupons',
#  'five',
#  'followthrough',
#  'for',
#  'forby',
#  'forbye',
#  'fore',
#  'forer',
#  'fores',
#  'forever',
#  'former',
#  'formerer',
#  'formerest',
#  'formerly',
#  'formers',
#  'fornenst',
#  'forwhy',
#  'four',
#  'fourscore',
#  'frae',
#  'from',
#  'fs',
#  'further',
#  'furthered',
#  'furtherer',
#  'furtherest',
#  'furthering',
#  'furthermore',
#  'furthers',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'go',
#  'going',
#  'gone',
#  'good',
#  'got',
#  'gotta',
#  'gotten',
#  'h',
#  'had',
#  'hadst',
#  'hae',
#  'hardly',
#  'has',
#  'hast',
#  'hath',
#  'have',
#  'haves',
#  'having',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereafters',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hey',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hitherer',
#  'hitherest',
#  'hoo',
#  'hoos',
#  'how',
#  'how-do-you-do',
#  'howbeit',
#  'howdoyoudo',
#  'however',
#  'hr',
#  'huh',
#  'humph',
#  'i',
#  "i'll",
#  "i'm",
#  'idem',
#  'idemer',
#  'idemest',
#  'ie',
#  'if',
#  'ifs',
#  'immediate',
#  'immediately',
#  'immediater',
#  'immediatest',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'indicating',
#  'info',
#  'information',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'inwarder',
#  'inwardest',
#  'inwards',
#  'is',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'know',
#  'l',
#  'la',
#  'latter',
#  'latterer',
#  'latterest',
#  'latterly',
#  'latters',
#  'layabout',
#  'layabouts',
#  'less',
#  'lest',
#  'like',
#  'll',
#  'look',
#  'lot',
#  'lots',
#  'lotted',
#  'lotting',
#  'm',
#  'main',
#  'make',
#  'many',
#  'mauger',
#  'maugre',
#  'mayest',
#  'me',
#  'meanwhile',
#  'meanwhiles',
#  'midst',
#  'midsts',
#  'might',
#  'mights',
#  'mm',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'mucher',
#  'muchest',
#  'must',
#  'musth',
#  'musths',
#  'musts',
#  'my',
#  'myself',
#  'n',
#  'na',
#  'natheless',
#  'nathless',
#  'neath',
#  'neaths',
#  'necessarier',
#  'necessariest',
#  'necessary',
#  'neither',
#  'nethe',
#  'nethermost',
#  'never',
#  'nevertheless',
#  'nigh',
#  'nigher',
#  'nighest',
#  'nine',
#  'no',
#  'no-one',
#  'nobodies',
#  'nobody',
#  'noes',
#  'none',
#  'noone',
#  'nor',
#  'nos',
#  'not',
#  'nothing',
#  'nothings',
#  'notwithstanding',
#  'now',
#  'nowhere',
#  'nowheres',
#  'o',
#  'of',
#  'off',
#  'offest',
#  'offs',
#  'often',
#  'oftener',
#  'oftenest',
#  'oh',
#  'on',
#  'one',
#  'oneself',
#  'onest',
#  'ons',
#  'onto',
#  'or',
#  'orer',
#  'orest',
#  'other',
#  'others',
#  'otherwise',
#  'otherwiser',
#  'otherwisest',
#  'ought',
#  'oughts',
#  'our',
#  'ours',
#  'ourself',
#  'ourselves',
#  'out',
#  'outed',
#  'outest',
#  'outs',
#  'outside',
#  'outwith',
#  'over',
#  'overall',
#  'overaller',
#  'overallest',
#  'overalls',
#  'overs',
#  'own',
#  'owned',
#  'owning',
#  'owns',
#  'owt',
#  'p',
#  'particular',
#  'particularer',
#  'particularest',
#  'particularly',
#  'particulars',
#  'per',
#  'perhaps',
#  'plaintiff',
#  'please',
#  'pleased',
#  'pleases',
#  'plenties',
#  'plenty',
#  'pro',
#  'probably',
#  'provide',
#  'provided',
#  'provides',
#  'providing',
#  'q',
#  'qua',
#  'que',
#  'quite',
#  'r',
#  'rath',
#  'rathe',
#  'rather',
#  'rathest',
#  're',
#  'really',
#  'regarding',
#  'relate',
#  'related',
#  'relatively',
#  'res',
#  'respecting',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'saider',
#  'saidest',
#  'same',
#  'samer',
#  'sames',
#  'samest',
#  'sans',
#  'sanserif',
#  'sanserifs',
#  'sanses',
#  'saved',
#  'sayid',
#  'sayyid',
#  'see',
#  'seem',
#  'seemed',
#  'seeminger',
#  'seemingest',
#  'seemings',
#  'seems',
#  'send',
#  'sent',
#  'senza',
#  'serious',
#  'seriouser',
#  'seriousest',
#  'seven',
#  'several',
#  'severaler',
#  'severalest',
#  'shall',
#  'shalled',
#  'shalling',
#  'shalls',
#  'she',
#  'should',
#  'shoulded',
#  'shoulding',
#  'shoulds',
#  'since',
#  'sine',
#  'sines',
#  'sith',
#  'six',
#  'so',
#  'sobeit',
#  'soer',
#  'soest',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimer',
#  'sometimes',
#  'sometimest',
#  'somewhat',
#  'somewhere',
#  'stop',
#  'stopped',
#  'such',
#  'summat',
#  'sup',
#  'supped',
#  'supping',
#  'sups',
#  'syn',
#  'syne',
#  't',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'thee',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'thener',
#  'thenest',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'therer',
#  'therest',
#  'thereupon',
#  'these',
#  'they',
#  'thine',
#  'thing',
#  'things',
#  'this',
#  'thises',
#  'thorough',
#  'thorougher',
#  'thoroughest',
#  'thoroughly',
#  'those',
#  'thou',
#  'though',
#  'thous',
#  'thouses',
#  'three',
#  'thro',
#  'through',
#  'througher',
#  'throughest',
#  'throughout',
#  'thru',
#  'thruer',
#  'thruest',
#  'thus',
#  'thy',
#  'thyself',
#  'till',
#  'tilled',
#  'tilling',
#  'tills',
#  'time',
#  'to',
#  'together',
#  'too',
#  'toward',
#  'towarder',
#  'towardest',
#  'towards',
#  'two',
#  'u',
#  'umpteen',
#  'under',
#  'underneath',
#  'unless',
#  'unlike',
#  'unliker',
#  'unlikest',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'uponed',
#  'uponing',
#  'upons',
#  'upped',
#  'upping',
#  'ups',
#  'us',
#  'use',
#  'used',
#  'usedest',
#  'username',
#  'usually',
#  'v',
#  'various',
#  'variouser',
#  'variousest',
#  'verier',
#  'veriest',
#  'versus',
#  'very',
#  'via',
#  'vis-a-vis',
#  'vis-a-viser',
#  'vis-a-visest',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'was',
#  'wast',
#  'we',
#  'were',
#  'wert',
#  'what',
#  'whatever',
#  'whateverer',
#  'whateverest',
#  'whatsoever',
#  'whatsoeverer',
#  'whatsoeverest',
#  'wheen',
#  'when',
#  'whenas',
#  'whence',
#  'whencesoever',
#  'whenever',
#  'whensoever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherefrom',
#  'wherein',
#  'whereinto',
#  'whereof',
#  'whereon',
#  'wheresoever',
#  'whereto',
#  'whereupon',
#  'wherever',
#  'wherewith',
#  'wherewithal',
#  'whether',
#  'which',
#  'whichever',
#  'whichsoever',
#  'while',
#  'whiles',
#  'whilst',
#  'whither',
#  'whithersoever',
#  'who',
#  'whoever',
#  'whomever',
#  'whose',
#  'whoso',
#  'whosoever',
#  'why',
#  'will',
#  'with',
#  'withal',
#  'within',
#  'without',
#  'would',
#  'woulded',
#  'woulding',
#  'woulds',
#  'x',
#  'y',
#  'ye',
#  'yeah',
#  'yet',
#  'yon',
#  'yond',
#  'yonder',
#  'you',
#  "you're",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zillion',
#  'ð',
#  '♪',
#  '♫'}

# %% [markdown]
# ## Analyze

# %%
def is_stopword(word):
    word = word.lower()
    
    if len(word) <= 1:
        return True
    
    # in the list
    if word in stopwords:
        return True
    
    # is Korean
    if ord("가") <= ord(word[0]) <= ord("힣"):
        return True
    
    return False

# %% [markdown]
# ### Characteristic Keyword
# Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer(stop_words=list(stopwords), max_features=1000, min_df=10)

x = vectorizer.fit_transform(df["lyrics"].fillna("")).toarray()

df_tfidf = pd.DataFrame(x, columns=vectorizer.get_feature_names_out()).T
# Out:
# c:\Users\Hiyoko\.conda\envs\data\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['vis', 'viser', 'visest', 'yes'] not in stop_words.
#   warnings.warn(

# %%
threshold = 0.1
counter = {}
summer = {}

for cnt in range(len(df)):
    if df["grouping"][cnt] != "kpop":
        continue
    
    tfidf_series = df_tfidf[cnt]
    
    keywords = tfidf_series[tfidf_series > threshold].index.tolist()
    for keyword in keywords:
        counter[keyword] = counter.get(keyword, 0) + 1
        summer[keyword] = summer.get(keyword, 0) + tfidf_series[keyword]

# %%
def sort_dictionary(dictionary):
    return [(k, dictionary[k]) for k in sorted(dictionary, key=dictionary.get, reverse=True)]

# %%
sort_dictionary(counter)
# Out:
# [('love', 151),
#  ('sorry', 136),
#  ('news', 109),
#  ('let', 91),
#  ('yes', 80),
#  ('home', 76),
#  ('heart', 73),
#  ('follow', 64),
#  ('price_varies', 61),
#  ('eyes', 60),
#  ('feel', 57),
#  ('night', 56),
#  ('baby', 51),
#  ('한국', 51),
#  ('dream', 49),
#  ('new', 47),
#  ('light', 46),
#  ('say', 44),
#  ('room', 43),
#  ('take', 43),
#  ('back', 42),
#  ('world', 41),
#  ('am', 41),
#  ('ah', 41),
#  ('comment', 39),
#  ('woo', 39),
#  ('dance', 38),
#  ('boy', 38),
#  ('end', 37),
#  ('leave', 37),
#  ('한국어', 37),
#  ('only', 37),
#  ('way', 35),
#  ('tell', 35),
#  ('wait', 35),
#  ('give', 35),
#  ('life', 34),
#  ('hot', 34),
#  ('agriculture', 34),
#  ('need', 34),
#  ('을和', 33),
#  ('beautiful', 33),
#  ('informazioni', 33),
#  ('share', 32),
#  ('find', 32),
#  ('bad', 31),
#  ('fire', 30),
#  ('think', 30),
#  ('today', 30),
#  ('mind', 30),
#  ('cancel', 30),
#  ('hands', 30),
#  ('sweet', 29),
#  ('hear', 29),
#  ('teen', 29),
#  ('girl', 29),
#  ('child', 28),
#  ('di', 28),
#  ('looking', 28),
#  ('touch', 28),
#  ('price', 28),
#  ('blue', 28),
#  ('sky', 27),
#  ('god', 27),
#  ('run', 27),
#  ('laughter', 27),
#  ('matter', 27),
#  ('worry', 27),
#  ('read', 27),
#  ('play', 26),
#  ('alone', 26),
#  ('star', 26),
#  ('kingdom', 25),
#  ('united', 25),
#  ('care', 25),
#  ('shut', 25),
#  ('break', 24),
#  ('continue', 24),
#  ('mine', 24),
#  ('down', 24),
#  ('moment', 24),
#  ('show', 24),
#  ('easy', 24),
#  ('true', 23),
#  ('sun', 23),
#  ('fly', 23),
#  ('crazy', 23),
#  ('ready', 23),
#  ('music', 22),
#  ('il', 22),
#  ('deep', 22),
#  ('start', 22),
#  ('ay', 22),
#  ('still', 22),
#  ('ooh', 22),
#  ('call', 22),
#  ('dreams', 22),
#  ('little', 21),
#  ('twitter', 21),
#  ('sleep', 21),
#  ('honey', 21),
#  ('fine', 21),
#  ('okay', 21),
#  ('stay', 21),
#  ('once', 21),
#  ('stanza', 21),
#  ('flowers', 21),
#  ('voice', 20),
#  ('change', 20),
#  ('meet', 20),
#  ('red', 20),
#  ('waiting', 19),
#  ('next', 19),
#  ('body', 19),
#  ('thank', 19),
#  ('friend', 19),
#  ('free', 19),
#  ('hand', 19),
#  ('wow', 19),
#  ('shine', 18),
#  ('stars', 18),
#  ('cry', 18),
#  ('work', 18),
#  ('open', 18),
#  ('doesn', 18),
#  ('cuz', 18),
#  ('best', 18),
#  ('keep', 18),
#  ('bang', 18),
#  ('move', 18),
#  ('top', 18),
#  ('story', 18),
#  ('city', 17),
#  ('happy', 17),
#  ('moon', 17),
#  ('heaven', 17),
#  ('sound', 17),
#  ('uh', 17),
#  ('rain', 17),
#  ('away', 17),
#  ('eye', 17),
#  ('high', 17),
#  ('man', 17),
#  ('real', 16),
#  ('line', 16),
#  ('walking', 16),
#  ('live', 16),
#  ('person', 16),
#  ('hate', 16),
#  ('turn', 16),
#  ('last', 16),
#  ('fall', 16),
#  ('cool', 16),
#  ('ve', 16),
#  ('nice', 16),
#  ('feeling', 16),
#  ('place', 16),
#  ('wind', 16),
#  ('kiss', 15),
#  ('lose', 15),
#  ('power', 15),
#  ('answer', 15),
#  ('hidden', 15),
#  ('pain', 15),
#  ('cold', 15),
#  ('makes', 15),
#  ('name', 15),
#  ('working', 15),
#  ('believe', 15),
#  ('babe', 15),
#  ('long', 15),
#  ('boom', 14),
#  ('kill', 14),
#  ('morning', 14),
#  ('song', 14),
#  ('falling', 14),
#  ('dark', 14),
#  ('view', 14),
#  ('sing', 14),
#  ('year', 14),
#  ('anymore', 14),
#  ('drop', 14),
#  ('hi', 14),
#  ('people', 14),
#  ('google', 14),
#  ('mood', 14),
#  ('sure', 14),
#  ('lost', 14),
#  ('full', 14),
#  ('party', 14),
#  ('ice', 13),
#  ('tonight', 13),
#  ('girlfriend', 13),
#  ('didn', 13),
#  ('forgot', 13),
#  ('watch', 13),
#  ('summer', 13),
#  ('ago', 13),
#  ('left', 13),
#  ('talk', 13),
#  ('understand', 13),
#  ('door', 13),
#  ('moonlight', 13),
#  ('guy', 13),
#  ('sick', 13),
#  ('sad', 13),
#  ('invalid', 13),
#  ('flower', 13),
#  ('fresh', 13),
#  ('lie', 13),
#  ('close', 13),
#  ('step', 13),
#  ('memory', 13),
#  ('coming', 13),
#  ('face', 13),
#  ('feet', 13),
#  ('ride', 13),
#  ('um', 13),
#  ('looks', 12),
#  ('wild', 12),
#  ('bring', 12),
#  ('made', 12),
#  ('history', 12),
#  ('hold', 12),
#  ('pop', 12),
#  ('road', 12),
#  ('feelings', 12),
#  ('hit', 12),
#  ('words', 12),
#  ('ma', 12),
#  ('problem', 12),
#  ('air', 12),
#  ('stupid', 12),
#  ('put', 12),
#  ('bit', 12),
#  ('first', 12),
#  ('miss', 12),
#  ('fun', 11),
#  ('living', 11),
#  ('big', 11),
#  ('question', 11),
#  ('black', 11),
#  ('darkness', 11),
#  ('atmosphere', 11),
#  ('burn', 11),
#  ('low', 11),
#  ('dangerous', 11),
#  ('universe', 11),
#  ('laugh', 11),
#  ('remember', 11),
#  ('days', 11),
#  ('rhythm', 11),
#  ('wish', 11),
#  ('afraid', 11),
#  ('sea', 11),
#  ('learn', 11),
#  ('blood', 11),
#  ('mouth', 11),
#  ('reason', 11),
#  ('young', 11),
#  ('non', 11),
#  ('perfect', 11),
#  ('set', 10),
#  ('woah', 10),
#  ('guys', 10),
#  ('saying', 10),
#  ('warm', 10),
#  ('candy', 10),
#  ('secret', 10),
#  ('great', 10),
#  ('eh', 10),
#  ('second', 10),
#  ('beginning', 10),
#  ('head', 10),
#  ('birthday', 10),
#  ('sounds', 10),
#  ('side', 10),
#  ('try', 10),
#  ('half', 10),
#  ('water', 10),
#  ('promise', 10),
#  ('smile', 10),
#  ('leaving', 10),
#  ('straight', 10),
#  ('shoot', 10),
#  ('girls', 10),
#  ('type', 10),
#  ('hearts', 9),
#  ('being', 9),
#  ('wants', 9),
#  ('shy', 9),
#  ('goodbye', 9),
#  ('fake', 9),
#  ('slow', 9),
#  ('tired', 9),
#  ('word', 9),
#  ('taste', 9),
#  ('ball', 9),
#  ('clear', 9),
#  ('bright', 9),
#  ('beat', 9),
#  ('bomb', 9),
#  ('snow', 9),
#  ('chance', 9),
#  ('ok', 9),
#  ('hello', 9),
#  ('facebook', 9),
#  ('hero', 9),
#  ('push', 9),
#  ('listen', 9),
#  ('wave', 9),
#  ('hair', 9),
#  ('walk', 9),
#  ('della', 9),
#  ('funny', 9),
#  ('higher', 9),
#  ('ya', 9),
#  ('yellow', 9),
#  ('alive', 9),
#  ('tomorrow', 9),
#  ('area', 9),
#  ('maybe', 9),
#  ('phone', 9),
#  ('waste', 9),
#  ('boys', 9),
#  ('lights', 9),
#  ('hide', 9),
#  ('minute', 8),
#  ('running', 8),
#  ('beauty', 8),
#  ('dreaming', 8),
#  ('nights', 8),
#  ('far', 8),
#  ('super', 8),
#  ('won', 8),
#  ('games', 8),
#  ('imma', 8),
#  ('strong', 8),
#  ('favorite', 8),
#  ('magic', 8),
#  ('tears', 8),
#  ('singing', 8),
#  ('well', 8),
#  ('whole', 8),
#  ('luck', 8),
#  ('win', 8),
#  ('style', 8),
#  ('cloud', 8),
#  ('zoom', 8),
#  ('tear', 8),
#  ('white', 8),
#  ('empty', 8),
#  ('ground', 8),
#  ('yo', 8),
#  ('lover', 8),
#  ('ha', 8),
#  ('fool', 8),
#  ('small', 8),
#  ('lips', 8),
#  ('double', 8),
#  ('single', 8),
#  ('save', 8),
#  ('forward', 8),
#  ('butterfly', 8),
#  ('changed', 8),
#  ('cream', 7),
#  ('gold', 7),
#  ('limit', 7),
#  ('rid', 7),
#  ('says', 7),
#  ('10', 7),
#  ('dawn', 7),
#  ('mi', 7),
#  ('shake', 7),
#  ('space', 7),
#  ('return', 7),
#  ('burns', 7),
#  ('fight', 7),
#  ('gonna', 7),
#  ('special', 7),
#  ('ocean', 7),
#  ('front', 7),
#  ('mirror', 7),
#  ('talking', 7),
#  ('bag', 7),
#  ('breath', 7),
#  ('die', 7),
#  ('false', 7),
#  ('hurt', 7),
#  ('truth', 7),
#  ('ask', 7),
#  ('sex', 7),
#  ('cute', 7),
#  ('speed', 7),
#  ('pink', 7),
#  ('roll', 7),
#  ('control', 7),
#  ('rest', 7),
#  ('bam', 7),
#  ('dancing', 7),
#  ('forget', 7),
#  ('careful', 7),
#  ('street', 7),
#  ('ayy', 7),
#  ('broken', 7),
#  ('help', 7),
#  ('memories', 7),
#  ('welcome', 7),
#  ('list', 7),
#  ('wonder', 7),
#  ('floor', 7),
#  ('fill', 7),
#  ('children', 7),
#  ('sir', 7),
#  ('beats', 7),
#  ('gave', 7),
#  ('diamonds', 6),
#  ('rules', 6),
#  ('went', 6),
#  ('boyfriend', 6),
#  ('bird', 6),
#  ('boss', 6),
#  ('plane', 6),
#  ('bye', 6),
#  ('goes', 6),
#  ('catch', 6),
#  ('eat', 6),
#  ('game', 6),
#  ('monster', 6),
#  ('job', 6),
#  ('sugar', 6),
#  ('burning', 6),
#  ('boo', 6),
#  ('later', 6),
#  ('team', 6),
#  ('missing', 6),
#  ('loved', 6),
#  ('ta', 6),
#  ('chi', 6),
#  ('hard', 6),
#  ('hell', 6),
#  ('took', 6),
#  ('mother', 6),
#  ('old', 6),
#  ('screaming', 6),
#  ('blow', 6),
#  ('ey', 6),
#  ('dog', 6),
#  ('knock', 6),
#  ('woman', 6),
#  ('lovers', 6),
#  ('hour', 6),
#  ('cause', 6),
#  ('simple', 6),
#  ('knows', 6),
#  ('shadow', 6),
#  ('continues', 6),
#  ('scream', 6),
#  ('crying', 6),
#  ('money', 6),
#  ('noise', 6),
#  ('happens', 6),
#  ('paradise', 6),
#  ('dad', 6),
#  ('saw', 6),
#  ('breathe', 6),
#  ('slowly', 6),
#  ('case', 6),
#  ('earth', 6),
#  ('mistake', 6),
#  ('seen', 6),
#  ('late', 6),
#  ('raise', 6),
#  ('ho', 6),
#  ('imagine', 6),
#  ('car', 6),
#  ('bringing', 5),
#  ('soul', 5),
#  ('missed', 5),
#  ('sleeping', 5),
#  ('needs', 5),
#  ('closer', 5),
#  ('sign', 5),
#  ('suck', 5),
#  ('doubt', 5),
#  ('drunk', 5),
#  ('pour', 5),
#  ('tip', 5),
#  ('block', 5),
#  ('cross', 5),
#  ('dress', 5),
#  ('mom', 5),
#  ('friends', 5),
#  ('liar', 5),
#  ('finished', 5),
#  ('keeps', 5),
#  ('enter', 5),
#  ('roof', 5),
#  ('choose', 5),
#  ('may', 5),
#  ('blah', 5),
#  ('flight', 5),
#  ('problems', 5),
#  ('lonely', 5),
#  ('weekend', 5),
#  ('nah', 5),
#  ('rush', 5),
#  ('called', 5),
#  ('mean', 5),
#  ('bet', 5),
#  ('count', 5),
#  ('haters', 5),
#  ('learned', 5),
#  ('wake', 5),
#  ('found', 5),
#  ('edge', 5),
#  ('yah', 5),
#  ('swear', 5),
#  ('ba', 5),
#  ('near', 5),
#  ('cup', 5),
#  ('finally', 5),
#  ('loud', 5),
#  ('future', 5),
#  ('standing', 5),
#  ('bling', 5),
#  ('20', 5),
#  ('drink', 5),
#  ('evil', 5),
#  ('relax', 5),
#  ('glass', 5),
#  ('happened', 5),
#  ('ring', 5),
#  ('flying', 5),
#  ('ahead', 5),
#  ('rock', 5),
#  ('queen', 5),
#  ('ladies', 5),
#  ('calls', 5),
#  ('flow', 5),
#  ('wall', 5),
#  ('disappear', 5),
#  ('trying', 5),
#  ('short', 5),
#  ('arms', 5),
#  ('language', 5),
#  ('hope', 5),
#  ('heard', 5),
#  ('finish', 5),
#  ('wanted', 5),
#  ('sexy', 5),
#  ('mercy', 5),
#  ('chest', 5),
#  ('diamond', 4),
#  ('heavy', 4),
#  ('rolling', 4),
#  ('dj', 4),
#  ('million', 4),
#  ('times', 4),
#  ('cake', 4),
#  ('deserve', 4),
#  ('heat', 4),
#  ('tells', 4),
#  ('angry', 4),
#  ('bite', 4),
#  ('inside', 4),
#  ('act', 4),
#  ('fast', 4),
#  ('pa', 4),
#  ('thunder', 4),
#  ('energy', 4),
#  ('jump', 4),
#  ('lucky', 4),
#  ('making', 4),
#  ('aye', 4),
#  ('brings', 4),
#  ('calm', 4),
#  ('window', 4),
#  ('foot', 4),
#  ('lady', 4),
#  ('corner', 4),
#  ('green', 4),
#  ('dead', 4),
#  ('table', 4),
#  ('hours', 4),
#  ('feels', 4),
#  ('fear', 4),
#  ('drug', 4),
#  ('pure', 4),
#  ('sense', 4),
#  ('escape', 4),
#  ('choice', 4),
#  ('twice', 4),
#  ('champagne', 4),
#  ('leaves', 4),
#  ('guess', 4),
#  ('breaks', 4),
#  ('mess', 4),
#  ('whoa', 4),
#  ('check', 4),
#  ('born', 4),
#  ('lo', 4),
#  ('lightning', 4),
#  ('stuck', 4),
#  ('throwing', 4),
#  ('angel', 4),
#  ('key', 4),
#  ('riding', 4),
#  ('attention', 4),
#  ('si', 4),
#  ('poison', 4),
#  ('lord', 4),
#  ('past', 4),
#  ('shot', 4),
#  ('taken', 4),
#  ('speak', 4),
#  ('kind', 4),
#  ('trap', 4),
#  ('week', 4),
#  ('trouble', 4),
#  ('country', 4),
#  ('shooting', 4),
#  ('losing', 4),
#  ('pretend', 4),
#  ('dirty', 4),
#  ('soon', 4),
#  ('clean', 4),
#  ('blind', 4),
#  ('means', 4),
#  ('river', 4),
#  ('men', 4),
#  ('comes', 4),
#  ('shots', 4),
#  ('part', 4),
#  ('wrist', 3),
#  ('came', 3),
#  ('wrong', 3),
#  ('bigger', 3),
#  ('years', 3),
#  ('whip', 3),
#  ('bed', 3),
#  ('throw', 3),
#  ('business', 3),
#  ('yea', 3),
#  ('kick', 3),
#  ('poppin', 3),
#  ('kids', 3),
#  ('sitting', 3),
#  ('bought', 3),
#  ('longer', 3),
#  ('stronger', 3),
#  ('point', 3),
#  ('highway', 3),
#  ('proud', 3),
#  ('family', 3),
#  ('tv', 3),
#  ('middle', 3),
#  ('rose', 3),
#  ('human', 3),
#  ('killing', 3),
#  ('handle', 3),
#  ('player', 3),
#  ('bum', 3),
#  ('nana', 3),
#  ('asked', 3),
#  ('clouds', 3),
#  ('plan', 3),
#  ('loves', 3),
#  ('sunset', 3),
#  ('taking', 3),
#  ('difficult', 3),
#  ('neck', 3),
#  ('hole', 3),
#  ('desire', 3),
#  ('explain', 3),
#  ('number', 3),
#  ('pass', 3),
#  ('celebrate', 3),
#  ('breaking', 3),
#  ('brother', 3),
#  ('pump', 3),
#  ('em', 3),
#  ('skrrt', 3),
#  ('stage', 3),
#  ('faith', 3),
#  ('pull', 3),
#  ('fair', 3),
#  ('moving', 3),
#  ('king', 3),
#  ('bust', 3),
#  ('thinking', 3),
#  ('ways', 3),
#  ('fault', 3),
#  ('age', 3),
#  ('kid', 3),
#  ('gives', 3),
#  ('hip', 3),
#  ('wrote', 3),
#  ('hurts', 3),
#  ('spend', 3),
#  ('gon', 3),
#  ('lil', 3),
#  ('pay', 3),
#  ('weak', 3),
#  ('skin', 3),
#  ('giving', 3),
#  ('buy', 3),
#  ('brought', 3),
#  ('jet', 3),
#  ('mmm', 3),
#  ('mr', 3),
#  ('lying', 3),
#  ('playing', 3),
#  ('thought', 3),
#  ('reach', 3),
#  ('telling', 3),
#  ('turned', 3),
#  ('legs', 3),
#  ('drive', 3),
#  ('tried', 3),
#  ('fell', 3),
#  ('york', 3),
#  ('horse', 3),
#  ('bitch', 2),
#  ('fucking', 2),
#  ('hundred', 2),
#  ('walls', 2),
#  ('stand', 2),
#  ('felt', 2),
#  ('grow', 2),
#  ('known', 2),
#  ('likes', 2),
#  ('flame', 2),
#  ('owe', 2),
#  ('waited', 2),
#  ('round', 2),
#  ('wear', 2),
#  ('drinking', 2),
#  ('damn', 2),
#  ('father', 2),
#  ('smell', 2),
#  ('south', 2),
#  ('broke', 2),
#  ('police', 2),
#  ('ran', 2),
#  ('teeth', 2),
#  ('asshole', 2),
#  ('told', 2),
#  ('met', 2),
#  ('brain', 2),
#  ('thoughts', 2),
#  ('map', 2),
#  ('streets', 2),
#  ('peace', 2),
#  ('paint', 2),
#  ('trip', 2),
#  ('twenty', 2),
#  ('holy', 2),
#  ('wine', 2),
#  ('bands', 2),
#  ('sip', 2),
#  ('bills', 2),
#  ('keys', 2),
#  ('gimme', 2),
#  ('box', 2),
#  ('devil', 2),
#  ('oooh', 2),
#  ('scared', 2),
#  ('heartbeat', 2),
#  ('tight', 2),
#  ('fingers', 2),
#  ('silence', 2),
#  ('lives', 2),
#  ('plans', 2),
#  ('dum', 2),
#  ('strange', 2),
#  ('needed', 2),
#  ('house', 2),
#  ('bop', 2),
#  ('driving', 2),
#  ('bounce', 2),
#  ('kisses', 2),
#  ('songs', 2),
#  ('moves', 2),
#  ('clothes', 2),
#  ('bleeding', 2),
#  ('happen', 2),
#  ('isn', 2),
#  ('ruin', 2),
#  ('photos', 2),
#  ('dying', 2),
#  ('gucci', 2),
#  ('wood', 2),
#  ('wife', 2),
#  ('caught', 2),
#  ('photo', 2),
#  ('started', 2),
#  ('least', 2),
#  ('excuse', 2),
#  ('land', 2),
#  ('calling', 2),
#  ('midnight', 2),
#  ('angeles', 2),
#  ('los', 2),
#  ('yesterday', 2),
#  ('awake', 2),
#  ('bitches', 2),
#  ('shit', 2),
#  ('watching', 2),
#  ('bottom', 2),
#  ('women', 2),
#  ('gun', 2),
#  ('21', 2),
#  ('passed', 2),
#  ('sit', 2),
#  ('falls', 2),
#  ('write', 2),
#  ('couple', 2),
#  ('wet', 2),
#  ('chicken', 2),
#  ('hotel', 2),
#  ('bar', 2),
#  ('hundreds', 2),
#  ('deal', 2),
#  ('fighting', 2),
#  ('shirt', 2),
#  ('war', 2),
#  ('admit', 2),
#  ('bass', 1),
#  ('worst', 1),
#  ('hang', 1),
#  ('faded', 1),
#  ('wasted', 1),
#  ('kitchen', 1),
#  ('cards', 1),
#  ('thousand', 1),
#  ('town', 1),
#  ('sweat', 1),
#  ('stayed', 1),
#  ('works', 1),
#  ('stress', 1),
#  ('shouldn', 1),
#  ('radio', 1),
#  ('dollar', 1),
#  ('pretty', 1),
#  ('dry', 1),
#  ('death', 1),
#  ('ghost', 1),
#  ('chain', 1),
#  ('shoes', 1),
#  ('lately', 1),
#  ('naked', 1),
#  ('looked', 1),
#  ('clap', 1),
#  ('burned', 1),
#  ('lies', 1),
#  ('message', 1),
#  ('pedal', 1),
#  ('rack', 1),
#  ('gas', 1),
#  ('cut', 1),
#  ('slide', 1),
#  ('paid', 1),
#  ('youth', 1),
#  ('search', 1),
#  ('turning', 1),
#  ('blame', 1),
#  ('kissed', 1),
#  ('stone', 1),
#  ('scars', 1),
#  ('couldn', 1),
#  ('tryna', 1),
#  ('shame', 1),
#  ('friday', 1),
#  ('fuck', 1),
#  ('loot', 1),
#  ('track', 1),
#  ('forgive', 1),
#  ('piece', 1),
#  ('bleep', 1),
#  ('wouldn', 1),
#  ('harder', 1),
#  ('stuff', 1),
#  ('dear', 1),
#  ('idiot', 1),
#  ('ohh', 1),
#  ('che', 1),
#  ('mama', 1),
#  ('fix', 1),
#  ('killed', 1),
#  ('woke', 1),
#  ('rap', 1),
#  ('rich', 1),
#  ('freedom', 1),
#  ('threw', 1),
#  ('sippin', 1),
#  ('smoke', 1),
#  ('worse', 1),
#  ('drank', 1),
#  ('flames', 1),
#  ('pray', 1),
#  ('pocket', 1),
#  ('belong', 1),
#  ('bullshit', 1),
#  ('bullets', 1),
#  ('seat', 1),
#  ('truck', 1),
#  ('plug', 1),
#  ('account', 1),
#  ('bank', 1),
#  ('worth', 1),
#  ('crowd', 1),
#  ('destined', 1),
#  ('100', 1),
#  ('knew', 1),
#  ('holding', 1),
#  ('turns', 1),
#  ('build', 1),
#  ('tall', 1),
#  ('wasn', 1),
#  ('mad', 1)]

# %%
sort_dictionary(summer)
# Out:
# [('love', 48.55836047684298),
#  ('sorry', 34.69424650510435),
#  ('home', 30.28655297176334),
#  ('한국', 22.777027998347513),
#  ('news', 22.043043875590087),
#  ('yes', 18.829226822492913),
#  ('heart', 18.620344466903866),
#  ('let', 18.24896449640406),
#  ('follow', 16.059904232588927),
#  ('night', 15.43230471889167),
#  ('woo', 14.590180749286153),
#  ('price_varies', 13.374253222129877),
#  ('ah', 12.953874422087333),
#  ('feel', 12.661176056653932),
#  ('dance', 12.493142718143003),
#  ('hot', 12.36988765332626),
#  ('boy', 12.357121492770778),
#  ('eyes', 12.288759128524024),
#  ('light', 11.830627360202842),
#  ('dream', 11.722361541229729),
#  ('baby', 10.664616374710748),
#  ('new', 10.450066147578717),
#  ('am', 9.7854644596937),
#  ('bad', 9.712276351863487),
#  ('room', 8.96983337258604),
#  ('world', 8.919269765327815),
#  ('say', 8.084704676142914),
#  ('agriculture', 7.968343318560492),
#  ('한국어', 7.881441247623746),
#  ('back', 7.837137995794142),
#  ('을和', 7.755186517134875),
#  ('need', 7.728319155476253),
#  ('fire', 7.64511570295527),
#  ('today', 7.606129171206499),
#  ('give', 7.548016386048329),
#  ('run', 7.509089701320022),
#  ('life', 7.505183244443237),
#  ('way', 7.395968621697394),
#  ('child', 7.345878170041819),
#  ('end', 7.332695495469982),
#  ('call', 7.31867032373913),
#  ('united', 7.288438881822528),
#  ('only', 7.276773924250165),
#  ('beautiful', 7.263015004032444),
#  ('di', 7.087058517658645),
#  ('ay', 6.898726791006811),
#  ('stay', 6.8981414664655505),
#  ('find', 6.855687573075119),
#  ('il', 6.838845908891905),
#  ('informazioni', 6.8287248727042185),
#  ('sky', 6.768766751470663),
#  ('leave', 6.743720835130601),
#  ('comment', 6.741020904337572),
#  ('blue', 6.731673648819251),
#  ('mine', 6.638531915868927),
#  ('take', 6.630841885176958),
#  ('girl', 6.588980265882792),
#  ('invalid', 6.498430593364496),
#  ('wow', 6.40829030927335),
#  ('play', 6.398208152928911),
#  ('cry', 6.3590365059285165),
#  ('boom', 6.345232392173116),
#  ('tell', 6.289916163304958),
#  ('hands', 6.258973763133796),
#  ('ooh', 6.250494603170723),
#  ('kingdom', 6.21401764592534),
#  ('god', 6.206486582967011),
#  ('share', 6.131697709608433),
#  ('shut', 6.090687585990524),
#  ('fine', 6.070388169588227),
#  ('laughter', 6.044467621076745),
#  ('fly', 6.035713096571189),
#  ('sweet', 6.01490948073051),
#  ('bomb', 5.958853430650523),
#  ('worry', 5.954079634312102),
#  ('teen', 5.924616588626821),
#  ('hear', 5.807529931358383),
#  ('stanza', 5.787208092152427),
#  ('bang', 5.7160511718395535),
#  ('wait', 5.653999372759867),
#  ('think', 5.576911350451396),
#  ('babe', 5.571190256936684),
#  ('touch', 5.533023090258712),
#  ('mind', 5.523416287966886),
#  ('eh', 5.482354513727516),
#  ('deep', 5.471675455901676),
#  ('alone', 5.449810374779228),
#  ('matter', 5.443668368405856),
#  ('looking', 5.411052664554724),
#  ('best', 5.3540545891940186),
#  ('price', 5.30863179548005),
#  ('show', 5.201422544932826),
#  ('honey', 5.180028434381317),
#  ('star', 5.169858959066931),
#  ('top', 5.138305484323492),
#  ('last', 5.1363133465771025),
#  ('care', 5.135299600494425),
#  ('thank', 5.135175660646604),
#  ('moon', 5.13318464675031),
#  ('crazy', 5.126289597626558),
#  ('little', 5.053185193987548),
#  ('break', 5.004690067466876),
#  ('man', 4.97393227182492),
#  ('flowers', 4.881236491409114),
#  ('work', 4.871576966773237),
#  ('summer', 4.849114223852243),
#  ('still', 4.810845206103945),
#  ('fall', 4.784759613209379),
#  ('ready', 4.783220439206891),
#  ('move', 4.779515245257987),
#  ('meet', 4.734693697584217),
#  ('power', 4.72124266422468),
#  ('okay', 4.712983738091125),
#  ('easy', 4.65848433400024),
#  ('down', 4.614848848648373),
#  ('twitter', 4.585371832939499),
#  ('sun', 4.557910368274748),
#  ('flower', 4.555116205336307),
#  ('music', 4.5357834829366865),
#  ('red', 4.521849501587666),
#  ('read', 4.447607365012483),
#  ('true', 4.4328564822679555),
#  ('continue', 4.424627969596948),
#  ('cancel', 4.4241721730066255),
#  ('moment', 4.361087396669619),
#  ('ice', 4.278876471590874),
#  ('pop', 4.215148513600248),
#  ('universe', 4.205981695796115),
#  ('name', 4.204863611008427),
#  ('stars', 4.157351178992706),
#  ('high', 4.1569034923446),
#  ('story', 4.146487909099736),
#  ('non', 4.128777177990646),
#  ('shine', 4.115992822646814),
#  ('away', 4.083758447404469),
#  ('start', 4.072757797522121),
#  ('sleep', 4.070251885686466),
#  ('nice', 4.033537570891892),
#  ('waiting', 3.977251498373907),
#  ('uh', 3.9682699021788554),
#  ('dreams', 3.965259856779063),
#  ('friend', 3.9577693952038424),
#  ('walking', 3.9367044384759726),
#  ('bam', 3.900187272346046),
#  ('hi', 3.878782607341264),
#  ('cuz', 3.827901769866747),
#  ('ve', 3.791237287208366),
#  ('next', 3.772261409933998),
#  ('hidden', 3.7698441516850743),
#  ('girls', 3.749841258369002),
#  ('falling', 3.7304790460092834),
#  ('keep', 3.7006152745821335),
#  ('wind', 3.6915591090279327),
#  ('body', 3.691039474132946),
#  ('once', 3.6720664037492776),
#  ('hand', 3.668695647493025),
#  ('ba', 3.6323468101979013),
#  ('change', 3.6226327554594726),
#  ('cool', 3.6198736187321487),
#  ('coming', 3.6087687019117003),
#  ('hate', 3.598105935359333),
#  ('guy', 3.5953560260557054),
#  ('voice', 3.5621611296872895),
#  ('kill', 3.5614266353965203),
#  ('della', 3.560145450456999),
#  ('city', 3.5174703107038217),
#  ('heaven', 3.501610728188375),
#  ('moonlight', 3.4963340955175832),
#  ('chi', 3.4793761972670914),
#  ('girlfriend', 3.455023344884875),
#  ('party', 3.44756158640488),
#  ('burn', 3.444253873410721),
#  ('air', 3.4414903334347766),
#  ('rain', 3.4369524807337597),
#  ('butterfly', 3.3957108513825007),
#  ('hit', 3.377878089838897),
#  ('hero', 3.2935635326212043),
#  ('free', 3.2929624654595386),
#  ('step', 3.287797707081818),
#  ('candy', 3.282843974941912),
#  ('zoom', 3.281803306008846),
#  ('eye', 3.24503683390018),
#  ('year', 3.239720577736031),
#  ('drunk', 3.2313143385840055),
#  ('ride', 3.216629156391462),
#  ('live', 3.2158330710973253),
#  ('working', 3.1888339422259637),
#  ('dad', 3.185138957488219),
#  ('drop', 3.17882976405251),
#  ('feet', 3.169839822968331),
#  ('rhythm', 3.165283219060448),
#  ('left', 3.162914506201815),
#  ('lost', 3.1514068520960867),
#  ('face', 3.1460074717194226),
#  ('doesn', 3.136499647967529),
#  ('feeling', 3.1351455471233427),
#  ('mood', 3.134027578998418),
#  ('forgot', 3.1183586774428775),
#  ('sick', 3.104926702816135),
#  ('google', 3.096493585628814),
#  ('cold', 3.0950261250702256),
#  ('goodbye', 3.078119411871409),
#  ('happy', 3.067653934485422),
#  ('turn', 3.061443929983071),
#  ('song', 3.0528784024528504),
#  ('tonight', 3.052284493051786),
#  ('lie', 3.038005141335379),
#  ('view', 3.0376967888124717),
#  ('shoot', 3.022837734259353),
#  ('woman', 3.01018631390695),
#  ('cream', 2.999292128788068),
#  ('um', 2.9831128634878414),
#  ('memory', 2.9789482681896535),
#  ('remember', 2.9783263502702657),
#  ('fun', 2.946504327822128),
#  ('kiss', 2.941131354607616),
#  ('sing', 2.9405596755587347),
#  ('wish', 2.931889762849517),
#  ('morning', 2.924215610964263),
#  ('door', 2.919984684344441),
#  ('anymore', 2.9172252749937657),
#  ('bit', 2.8736738584430053),
#  ('woah', 2.8729359692479406),
#  ('black', 2.864838988786422),
#  ('didn', 2.853967551735931),
#  ('sure', 2.842645283131566),
#  ('ya', 2.8415535576114546),
#  ('dark', 2.836973487996725),
#  ('person', 2.8146696580553923),
#  ('road', 2.8041088791216024),
#  ('history', 2.802799486343188),
#  ('pain', 2.78105521330173),
#  ('ring', 2.7719588795947208),
#  ('wild', 2.7671883981174004),
#  ('open', 2.745536613597638),
#  ('bye', 2.741443398418827),
#  ('atmosphere', 2.7374967041229974),
#  ('young', 2.7373294929375933),
#  ('fake', 2.7303423342957376),
#  ('long', 2.7288340522371297),
#  ('sound', 2.7211368757434853),
#  ('understand', 2.7208278468276283),
#  ('line', 2.7130098556657036),
#  ('birthday', 2.7060879303429717),
#  ('real', 2.687776838255967),
#  ('side', 2.687325038579959),
#  ('reason', 2.665336399310316),
#  ('guys', 2.6651627849168023),
#  ('bag', 2.6589243387751047),
#  ('ma', 2.650808645501393),
#  ('running', 2.6384507727768693),
#  ('stupid', 2.629609338417445),
#  ('ta', 2.623123579465015),
#  ('answer', 2.6229700550751773),
#  ('mi', 2.608784263344477),
#  ('warm', 2.5945565743197565),
#  ('bring', 2.5902305231889895),
#  ('living', 2.5859625918126197),
#  ('higher', 2.565763665465286),
#  ('beauty', 2.5600879738815197),
#  ('place', 2.555022459822005),
#  ('scream', 2.5512723948993274),
#  ('ha', 2.546367364933069),
#  ('boyfriend', 2.5340402058629805),
#  ('put', 2.5230117383486372),
#  ('talk', 2.5174775971610117),
#  ('type', 2.4623705730745207),
#  ('makes', 2.4354122618152445),
#  ('believe', 2.432651480574105),
#  ('shy', 2.4308291605704366),
#  ('ho', 2.4093833281776904),
#  ('magic', 2.406565937994379),
#  ('people', 2.404635608363246),
#  ('lose', 2.383579631565569),
#  ('die', 2.3471397170538477),
#  ('words', 2.3376580229970227),
#  ('yo', 2.329715273564872),
#  ('ok', 2.3097955767001754),
#  ('big', 2.309378823780156),
#  ('sea', 2.306163425098657),
#  ('knock', 2.2966030249501577),
#  ('special', 2.2903095715516044),
#  ('wall', 2.281637924759987),
#  ('fresh', 2.2769608641452574),
#  ('days', 2.269023731005233),
#  ('taste', 2.2578851935057833),
#  ('hold', 2.244520327805725),
#  ('second', 2.2387149377377358),
#  ('secret', 2.230664275180113),
#  ('darkness', 2.2284684884340256),
#  ('blood', 2.219800032229902),
#  ('super', 2.205643145041378),
#  ('chance', 2.202313060283233),
#  ('boo', 2.19428387717557),
#  ('bum', 2.191649811740898),
#  ('question', 2.191252706909877),
#  ('smile', 2.1801176695848463),
#  ('hurt', 2.1677838747984963),
#  ('breathe', 2.160928945555011),
#  ('ago', 2.1571038944601595),
#  ('push', 2.1513435214927927),
#  ('full', 2.1394191554147386),
#  ('style', 2.133436355794814),
#  ('lights', 2.129326503437713),
#  ('sounds', 2.1247948972542834),
#  ('help', 2.1124829680536097),
#  ('close', 2.0992183818751218),
#  ('hide', 2.0950506608251307),
#  ('imma', 2.0898604152265783),
#  ('money', 2.0872714316649836),
#  ('save', 2.0728976787013753),
#  ('double', 2.07066597183027),
#  ('sad', 2.070648837929258),
#  ('hip', 2.0620574960016325),
#  ('dreaming', 2.0540263205788443),
#  ('rush', 2.0524215470202023),
#  ('looks', 2.0411305055927884),
#  ('perfect', 2.038934016743749),
#  ('dangerous', 2.037450711780793),
#  ('control', 2.037449208025072),
#  ('set', 2.0342900557189747),
#  ('yellow', 2.029546863407318),
#  ('well', 2.017072245240682),
#  ('feelings', 2.0165605696380773),
#  ('first', 2.0009361234333793),
#  ('singing', 1.9827355364483124),
#  ('yah', 1.976583498919876),
#  ('monster', 1.975771944438037),
#  ('wants', 1.9756380220938137),
#  ('try', 1.9694349321487956),
#  ('laugh', 1.969253440623657),
#  ('team', 1.9560974809417528),
#  ('promise', 1.9544854563962302),
#  ('mouth', 1.9528605764918427),
#  ('roll', 1.952108587497072),
#  ('half', 1.9462115045179742),
#  ('bling', 1.9459259246230065),
#  ('rose', 1.9379415786417595),
#  ('miss', 1.9371129140290038),
#  ('nah', 1.9365896909754723),
#  ('boys', 1.9345372645316514),
#  ('beat', 1.9270265309142276),
#  ('win', 1.9140733428074896),
#  ('10', 1.9071418830562323),
#  ('being', 1.8975310170973756),
#  ('hair', 1.8913442606397755),
#  ('water', 1.890055940460681),
#  ('future', 1.8799855295856616),
#  ('funny', 1.8788526077535261),
#  ('watch', 1.8783796814075047),
#  ('learn', 1.8778245351896332),
#  ('shake', 1.873572827167292),
#  ('afraid', 1.8704645629338448),
#  ('whole', 1.8556578459762996),
#  ('hell', 1.8542382384101699),
#  ('head', 1.8515624138355455),
#  ('dawn', 1.8494149357392817),
#  ('favorite', 1.8482358441808546),
#  ('alive', 1.8199568239376005),
#  ('fool', 1.8196697641000796),
#  ('suck', 1.8157252689309196),
#  ('made', 1.81018472545616),
#  ('sexy', 1.804757874689276),
#  ('missed', 1.7897105439563217),
#  ('continues', 1.7880919844987289),
#  ('lover', 1.7827049193038171),
#  ('bite', 1.7815648150329793),
#  ('attention', 1.78084760352867),
#  ('pink', 1.7629198669953123),
#  ('explain', 1.757239079949136),
#  ('problem', 1.7538103542865093),
#  ('children', 1.7503084915644425),
#  ('slow', 1.747085147987446),
#  ('waste', 1.7434145743641687),
#  ('sir', 1.7428465962505784),
#  ('great', 1.7393805589091116),
#  ('bright', 1.7380102371540123),
#  ('straight', 1.72174327245911),
#  ('broken', 1.715017083051685),
#  ('area', 1.705957209373472),
#  ('word', 1.705910727852034),
#  ('excuse', 1.7023706100689187),
#  ('luck', 1.6957938599260078),
#  ('minute', 1.6957489109025292),
#  ('hearts', 1.6882908280282005),
#  ('tear', 1.6857872240912386),
#  ('walk', 1.6856794021720234),
#  ('highway', 1.6801353474483607),
#  ('space', 1.6788044137233809),
#  ('jump', 1.671930703247718),
#  ('beginning', 1.66274601704627),
#  ('won', 1.6615096666937195),
#  ('bop', 1.6560579035800362),
#  ('small', 1.6526115319982613),
#  ('flight', 1.6522791398112235),
#  ('sugar', 1.6463553076711082),
#  ('welcome', 1.6442108913746631),
#  ('knows', 1.6386995831807791),
#  ('careful', 1.632203200924378),
#  ('eat', 1.6312575418549358),
#  ('leaving', 1.6301199629960914),
#  ('si', 1.6205624119149409),
#  ('low', 1.6185296798522066),
#  ('whip', 1.6172753223391385),
#  ('later', 1.616605474121588),
#  ('maybe', 1.6151972627615756),
#  ('rid', 1.6120814618337884),
#  ('clear', 1.6110202286213704),
#  ('bird', 1.6075880634059707),
#  ('says', 1.6039838653728897),
#  ('mistake', 1.6023991052055309),
#  ('cause', 1.60080210034267),
#  ('ayy', 1.599057841172345),
#  ('changed', 1.5973875273997515),
#  ('bottom', 1.5945595336990643),
#  ('snow', 1.5878686778176967),
#  ('goes', 1.5846981003255811),
#  ('ocean', 1.579500147952454),
#  ('em', 1.5754361541467499),
#  ('floor', 1.5712988661136136),
#  ('wave', 1.5678382362772108),
#  ('ey', 1.5671768453947912),
#  ('pretend', 1.5554062057840956),
#  ('memories', 1.5530072756412874),
#  ('listen', 1.5528981765571601),
#  ('strong', 1.5523733374245148),
#  ('haters', 1.5523586404698217),
#  ('beats', 1.5466983511435728),
#  ('list', 1.5449470164750283),
#  ('mirror', 1.541707549517023),
#  ('slowly', 1.5363188828795045),
#  ('lil', 1.517106947963705),
#  ('rest', 1.5012308027420989),
#  ('mr', 1.4986205455751551),
#  ('gonna', 1.4947147449781713),
#  ('poison', 1.494577630039993),
#  ('forget', 1.4904904380559558),
#  ('single', 1.480763533490405),
#  ('games', 1.4758216083393034),
#  ('tired', 1.4744017680648145),
#  ('job', 1.4730125477041964),
#  ('hour', 1.4675253851027223),
#  ('bringing', 1.4531144928046515),
#  ('dancing', 1.4520876394341256),
#  ('blah', 1.4501385517042211),
#  ('empty', 1.4487742806909363),
#  ('case', 1.4414452439828689),
#  ('aye', 1.4328638762473256),
#  ('lips', 1.431793024812107),
#  ('pump', 1.4301160312815409),
#  ('noise', 1.4194665457632218),
#  ('loved', 1.4148341760194851),
#  ('street', 1.4116185679073046),
#  ('choose', 1.4049382671725543),
#  ('fight', 1.399513597064736),
#  ('evil', 1.3987994697567425),
#  ('deserve', 1.3978953850409213),
#  ('sex', 1.396985695651256),
#  ('weekend', 1.3826107626390611),
#  ('tomorrow', 1.3784268686580838),
#  ('hello', 1.371602214329413),
#  ('pure', 1.3651359530370895),
#  ('ground', 1.3584200971926932),
#  ('ball', 1.3574430523144432),
#  ('burning', 1.3554055192034373),
#  ('nights', 1.347613426429348),
#  ('flow', 1.3393683323423924),
#  ('flying', 1.3319047061909706),
#  ('queen', 1.3311038888466584),
#  ('lo', 1.3304583563656414),
#  ('block', 1.326854626276583),
#  ('earth', 1.3235186932421),
#  ('simple', 1.320607704619721),
#  ('bet', 1.3167990629688284),
#  ('loud', 1.3105996527446642),
#  ('twenty', 1.310482178789877),
#  ('fill', 1.3082180834786865),
#  ('lovers', 1.3072578400233923),
#  ('tears', 1.3062413076579744),
#  ('went', 1.3061192509284645),
#  ('phone', 1.3048642851192684),
#  ('crying', 1.3008079172902378),
#  ('saying', 1.299146942796247),
#  ('wonder', 1.2935928734543676),
#  ('edge', 1.2930784176190329),
#  ('tip', 1.292339102634174),
#  ('standing', 1.2909034719062251),
#  ('problems', 1.2895878568854793),
#  ('catch', 1.283734462246822),
#  ('found', 1.2821154813710298),
#  ('cloud', 1.2788156474190346),
#  ('roof', 1.2746425824171983),
#  ('forward', 1.2659926204272283),
#  ('breath', 1.2611446626528773),
#  ('kick', 1.2504541983578505),
#  ('corner', 1.2482728441861775),
#  ('count', 1.245776138856209),
#  ('blow', 1.2388743130845299),
#  ('white', 1.238682891844534),
#  ('20', 1.23833269096561),
#  ('gave', 1.2338795543930212),
#  ('angel', 1.2308951253597045),
#  ('devil', 1.2276828438628509),
#  ('blind', 1.2257744014199703),
#  ('plane', 1.2152031412618158),
#  ('ruin', 1.2034681986835252),
#  ('facebook', 1.1988772269756662),
#  ('champagne', 1.191351958886853),
#  ('paradise', 1.1903126761976937),
#  ('gold', 1.1882147038414437),
#  ('point', 1.1879098742545424),
#  ('brings', 1.1790059256219743),
#  ('may', 1.1772052783665392),
#  ('sense', 1.1734198070066602),
#  ('dog', 1.1728372698679266),
#  ('front', 1.1728048062812388),
#  ('stronger', 1.1704602889706288),
#  ('boss', 1.158477288510813),
#  ('cute', 1.1569786961173285),
#  ('ladies', 1.1561473204158483),
#  ('mean', 1.1542291509485907),
#  ('finally', 1.149793435800563),
#  ('soul', 1.1453313750760374),
#  ('old', 1.144733660143028),
#  ('dead', 1.144330199093931),
#  ('limit', 1.1392127888285575),
#  ('friends', 1.1357507576159163),
#  ('rolling', 1.1329410626808332),
#  ('gucci', 1.1307126432556809),
#  ('dress', 1.1198873739576134),
#  ('doubt', 1.117780959068934),
#  ('far', 1.1062791881583505),
#  ('happened', 1.102086719399233),
#  ('late', 1.1011906778336014),
#  ('mother', 1.099529157756536),
#  ('game', 1.0888592746183128),
#  ('seen', 1.0859887200528355),
#  ('week', 1.085234664374106),
#  ('diamonds', 1.0844351924076276),
#  ('truth', 1.0648826282897779),
#  ('wanted', 1.0642155941336104),
#  ('chicken', 1.0626764433612994),
#  ('soon', 1.0617205131198686),
#  ('glass', 1.0539874521587491),
#  ('rock', 1.050526536862811),
#  ('hard', 1.0500418410503043),
#  ('flame', 1.0499745977132404),
#  ('taking', 1.0487468163242002),
#  ('language', 1.0422460240019142),
#  ('short', 1.0385757668103943),
#  ('talking', 1.03339948285657),
#  ('speed', 1.030675751795233),
#  ('chest', 1.0271684679622626),
#  ('lucky', 1.0263126695208533),
#  ('false', 1.0262008733543069),
#  ('nana', 1.0230776580947945),
#  ('part', 1.020534619727438),
#  ('happen', 1.0142248149413504),
#  ('car', 0.9976358709070524),
#  ('sitting', 0.9971004162902468),
#  ('saw', 0.9970948518709848),
#  ('bleep', 0.9940630209603859),
#  ('stage', 0.9848849439769773),
#  ('took', 0.9846577326133874),
#  ('player', 0.9789782658721045),
#  ('burns', 0.9755775605760657),
#  ('thinking', 0.9670125001408749),
#  ('rules', 0.9609975725672991),
#  ('sign', 0.9604679341016283),
#  ('means', 0.9583949240117164),
#  ('horse', 0.9582333278713158),
#  ('south', 0.9569439771725383),
#  ('idiot', 0.9569066873089176),
#  ('trap', 0.9541516359317068),
#  ('return', 0.9539450088426379),
#  ('shots', 0.9443406947979149),
#  ('finish', 0.9428956603369992),
#  ('needs', 0.9392527113067903),
#  ('mom', 0.9381520381303702),
#  ('disappear', 0.9293046532208964),
#  ('missing', 0.9260728075961601),
#  ('calls', 0.9240121545454366),
#  ('closer', 0.9166923520978649),
#  ('relax', 0.9133108825858794),
#  ('lord', 0.9080612796755926),
#  ('pour', 0.9017843570252735),
#  ('diamond', 0.9001409068302302),
#  ('losing', 0.894348779158814),
#  ('fair', 0.8933630130942343),
#  ('ask', 0.8920452101039804),
#  ('ways', 0.8914888700353445),
#  ('drink', 0.8895022588633787),
#  ('screaming', 0.8866844215634863),
#  ('near', 0.8853951989506826),
#  ('heat', 0.8804054680579478),
#  ('shadow', 0.8521452723896138),
#  ('happens', 0.84777514522526),
#  ('pass', 0.8475125458701824),
#  ('mess', 0.8437872570199152),
#  ('choice', 0.8433463443349054),
#  ('fell', 0.8419587355917438),
#  ('middle', 0.8398897619105559),
#  ('bills', 0.8391070904590616),
#  ('past', 0.8365637890309924),
#  ('hole', 0.8363537788110982),
#  ('born', 0.8293281567730031),
#  ('guess', 0.8198298499078795),
#  ('kids', 0.8173374195504595),
#  ('trouble', 0.8137948091263282),
#  ('enter', 0.8122977430500522),
#  ('liar', 0.8105647583668273),
#  ('hope', 0.8097060699717488),
#  ('strange', 0.8096537904999317),
#  ('taken', 0.809610774141665),
#  ('learned', 0.8094584544121268),
#  ('bigger', 0.8033889125417644),
#  ('wake', 0.8000995578870373),
#  ('escape', 0.7987660031520171),
#  ('kind', 0.7986088370618306),
#  ('raise', 0.7983538711160766),
#  ('business', 0.7958513215542822),
#  ('lady', 0.794079559443471),
#  ('throw', 0.7900148831383932),
#  ('drug', 0.7877127801105219),
#  ('naked', 0.7863487619160419),
#  ('act', 0.7841289644791349),
#  ('shooting', 0.7820912068581034),
#  ('arms', 0.7814562286251779),
#  ('mercy', 0.7804843620942773),
#  ('cross', 0.7778854898731288),
#  ('tells', 0.7766922951037645),
#  ('imagine', 0.7752733377493587),
#  ('lying', 0.7735810246314284),
#  ('ahead', 0.7733845317002132),
#  ('green', 0.7713363528479399),
#  ('house', 0.7692725952832254),
#  ('keeps', 0.7547039328245787),
#  ('weak', 0.7491808812083455),
#  ('fault', 0.7466798706221622),
#  ('bounce', 0.7438845845943782),
#  ('lonely', 0.7389500863770301),
#  ('sleeping', 0.7388072910697235),
#  ('hours', 0.73842748101528),
#  ('men', 0.7376094146320932),
#  ('finished', 0.7351551144946896),
#  ('thunder', 0.7333438831130974),
#  ('cup', 0.7332472318970389),
#  ('gimme', 0.7269307730115548),
#  ('pa', 0.7217393469277524),
#  ('turned', 0.7216351111433161),
#  ('heavy', 0.7203393109080602),
#  ('heard', 0.7202935265458388),
#  ('fear', 0.7188248909636824),
#  ('times', 0.7158794103028356),
#  ('dirty', 0.7062798072737613),
#  ('fingers', 0.7033268937563),
#  ('ohh', 0.6994846775815431),
#  ('million', 0.6979869441827623),
#  ('met', 0.688260660639104),
#  ('angeles', 0.6870746946626274),
#  ('throwing', 0.6813574004106182),
#  ('clouds', 0.6799064520903341),
#  ('telling', 0.6793129493696016),
#  ('country', 0.6740355550360946),
#  ('los', 0.6732947786383345),
#  ('check', 0.6704183397240933),
#  ('angry', 0.6659586980634227),
#  ('inside', 0.6635586547260138),
#  ('oooh', 0.6564224776814696),
#  ('wrote', 0.655184446777379),
#  ('moving', 0.6538328839396482),
#  ('paint', 0.6510213077048975),
#  ('fast', 0.6481946918872258),
#  ('breaking', 0.647701659403815),
#  ('shot', 0.6472470272072887),
#  ('called', 0.6441997469642136),
#  ('told', 0.6200127239503537),
#  ('table', 0.6191418358241747),
#  ('swear', 0.6191410840065561),
#  ('river', 0.6185317634463007),
#  ('wine', 0.6183487870203481),
#  ('gives', 0.6181997665239753),
#  ('clap', 0.6181804868535582),
#  ('longer', 0.6162330171503065),
#  ('mama', 0.6138716192085951),
#  ('mmm', 0.6095366268202763),
#  ('family', 0.6064378388159795),
#  ('tv', 0.6023278908575447),
#  ('riding', 0.600069116388731),
#  ('energy', 0.5993725786413238),
#  ('speak', 0.5979544029752772),
#  ('window', 0.5968410981834481),
#  ('lightning', 0.5960483661737368),
#  ('falls', 0.5952039981791214),
#  ('trying', 0.5879759007366501),
#  ('making', 0.585314034251015),
#  ('leaves', 0.5817526851057854),
#  ('neck', 0.5805707114596479),
#  ('sunset', 0.5804076449133124),
#  ('came', 0.5799499531744755),
#  ('killing', 0.5790888468545398),
#  ('giving', 0.5786065384912753),
#  ('key', 0.5776666339944488),
#  ('difficult', 0.5734683846473532),
#  ('brought', 0.57325218194355),
#  ('clean', 0.5699112231292287),
#  ('poppin', 0.566445197189021),
#  ('loves', 0.5648809069371882),
#  ('cake', 0.5639515848165655),
#  ('pedal', 0.5615883925606432),
#  ('handle', 0.554518436557144),
#  ('pull', 0.5542817056185793),
#  ('king', 0.5491442869244063),
#  ('dum', 0.5481634328425364),
#  ('truck', 0.5430574762714102),
#  ('dj', 0.5429364053762644),
#  ('age', 0.5365255212856765),
#  ('hurts', 0.5362789283265612),
#  ('breaks', 0.5360987695860996),
#  ('feels', 0.5359208972098586),
#  ('years', 0.5356475742540734),
#  ('tried', 0.5312126398142687),
#  ('yea', 0.528135839073975),
#  ('york', 0.5256803708072743),
#  ('wet', 0.5243311532586132),
#  ('whoa', 0.5225893941779491),
#  ('foot', 0.513980307966049),
#  ('gas', 0.5088578361606607),
#  ('proud', 0.508092139866179),
#  ('worst', 0.5048478473830592),
#  ('number', 0.5039551122593411),
#  ('buy', 0.5024842285455913),
#  ('legs', 0.4999791923557085),
#  ('waited', 0.4990923281612409),
#  ('skin', 0.49673581099937425),
#  ('teeth', 0.4936694596917409),
#  ('21', 0.4860626033673414),
#  ('wrong', 0.48297262307789257),
#  ('celebrate', 0.48163406119280017),
#  ('pay', 0.48017912796547285),
#  ('round', 0.4784927961414897),
#  ('calm', 0.47598036597745597),
#  ('reach', 0.4699636636598289),
#  ('asked', 0.46693987889143),
#  ('playing', 0.46475746200949),
#  ('bust', 0.461886971572657),
#  ('stuck', 0.45904359206547873),
#  ('gon', 0.4579026058438345),
#  ('damn', 0.45642695358209834),
#  ('drive', 0.4543147377060899),
#  ('sweat', 0.44691295821094185),
#  ('scared', 0.44245505917039096),
#  ('father', 0.4424414833359933),
#  ('human', 0.4411893681119087),
#  ('midnight', 0.4387949710872592),
#  ('desire', 0.4369852700656712),
#  ('skrrt', 0.4347073304795852),
#  ('bleeding', 0.4303916484703959),
#  ('comes', 0.42796846328480576),
#  ('write', 0.4246179198782474),
#  ('twice', 0.42264424462146627),
#  ('hundreds', 0.4195933906898084),
#  ('known', 0.41910759438273115),
#  ('friday', 0.41519897545118795),
#  ('wife', 0.41285252552878554),
#  ('burned', 0.40368097230381284),
#  ('plan', 0.40078797266290556),
#  ('brother', 0.39831584024800076),
#  ('spend', 0.3974439987204502),
#  ('silence', 0.3936105309504116),
#  ('dying', 0.393379883511884),
#  ('mad', 0.39047854242995006),
#  ('che', 0.3872857241558482),
#  ('thoughts', 0.3867015520915038),
#  ('hundred', 0.3829942907144741),
#  ('kisses', 0.3777639317140602),
#  ('flames', 0.3776682257527441),
#  ('wrist', 0.3769307367867345),
#  ('passed', 0.3741652379605265),
#  ('box', 0.3740262705146632),
#  ('thought', 0.36945548451574556),
#  ('plans', 0.3677150254305427),
#  ('kid', 0.36593215768121296),
#  ('build', 0.35871147685574245),
#  ('keys', 0.3584606046918032),
#  ('wood', 0.3476321771791683),
#  ('clothes', 0.3473955055831185),
#  ('jet', 0.34652931665352416),
#  ('heartbeat', 0.34462718410587556),
#  ('gun', 0.34432343245154073),
#  ('pray', 0.34353482467863694),
#  ('bed', 0.34216945024049317),
#  ('shame', 0.34097053871680544),
#  ('grow', 0.33942183152361194),
#  ('admit', 0.33796334183715304),
#  ('caught', 0.3362428139887841),
#  ('likes', 0.3294663252070419),
#  ('bought', 0.32825302073991863),
#  ('dear', 0.32678088777960707),
#  ('faith', 0.3241134784991728),
#  ('scars', 0.32283089411598304),
#  ('asshole', 0.3165053425353324),
#  ('trip', 0.3160195301086537),
#  ('plug', 0.31495845447689164),
#  ('land', 0.3143236879300329),
#  ('piece', 0.2984911179917478),
#  ('moves', 0.2981798420923496),
#  ('sippin', 0.2976573872624294),
#  ('stand', 0.29533071805958233),
#  ('wear', 0.2906669988447176),
#  ('needed', 0.2875000795551382),
#  ('fucking', 0.28624693627315234),
#  ('sit', 0.2829815634975395),
#  ('stone', 0.2825749259332398),
#  ('driving', 0.2795570432901827),
#  ('photo', 0.27493373162723755),
#  ('calling', 0.2748834921510958),
#  ('bullets', 0.27476177532807805),
#  ('isn', 0.2729876418489068),
#  ('map', 0.27266486134137374),
#  ('started', 0.27187060950085895),
#  ('watching', 0.27124300015023556),
#  ('awake', 0.2691056805561608),
#  ('rich', 0.2671564333084045),
#  ('bitch', 0.26592972737001436),
#  ('fighting', 0.26586750564235295),
#  ('dry', 0.26434466240584625),
#  ('deal', 0.2606487380041571),
#  ('tight', 0.2600608218614482),
#  ('sip', 0.2590030534287435),
#  ('owe', 0.25531370196537995),
#  ('holy', 0.25517429572714617),
#  ('bitches', 0.2548826767946098),
#  ('faded', 0.2545747801022897),
#  ('woke', 0.2543440501475067),
#  ('ghost', 0.25370862790878984),
#  ('ran', 0.2534965390244826),
#  ('bar', 0.25306101138656056),
#  ('lately', 0.2518849238789717),
#  ('brain', 0.24964757126545067),
#  ('war', 0.24830951415373795),
#  ('peace', 0.24799554036506588),
#  ('wasted', 0.24792010873161963),
#  ('police', 0.2476188356858115),
#  ('bands', 0.24651796730328662),
#  ('broke', 0.2452080564163897),
#  ('shit', 0.24371829457844613),
#  ('drinking', 0.2419996854149401),
#  ('women', 0.23812309194802506),
#  ('thousand', 0.23550959911953603),
#  ('photos', 0.23398764494782884),
#  ('account', 0.23330837288767284),
#  ('smell', 0.2317842052709061),
#  ('lives', 0.2307295387446034),
#  ('yesterday', 0.23064231186784814),
#  ('least', 0.23040729991573528),
#  ('town', 0.22949023215988731),
#  ('dollar', 0.2291759248853354),
#  ('hotel', 0.22896832070800224),
#  ('search', 0.22638370986381837),
#  ('crowd', 0.2254062267696139),
#  ('100', 0.22489255211454476),
#  ('shirt', 0.22233252232384193),
#  ('couple', 0.2200854617749875),
#  ('kissed', 0.21975475502699765),
#  ('songs', 0.21907666819981825),
#  ('walls', 0.21663427998952378),
#  ('felt', 0.2139602353677084),
#  ('worse', 0.21371090869481107),
#  ('shoes', 0.21078941082833758),
#  ('chain', 0.2069729800630135),
#  ('streets', 0.2068341819802527),
#  ('bank', 0.20392938314998169),
#  ('wasn', 0.2028874580684993),
#  ('knew', 0.20239529074971938),
#  ('pretty', 0.20110539715152637),
#  ('stuff', 0.20049277810348656),
#  ('turns', 0.19826528890327008),
#  ('drank', 0.1928764797743414),
#  ('message', 0.1904012808021138),
#  ('fuck', 0.1847286216039321),
#  ('destined', 0.18411113886633976),
#  ('tall', 0.18266801448637257),
#  ('smoke', 0.18098468562289277),
#  ('forgive', 0.17159431406584721),
#  ('loot', 0.1652063162050475),
#  ('rack', 0.16483406961820085),
#  ('bullshit', 0.16203748262063594),
#  ('shouldn', 0.15993122809024016),
#  ('slide', 0.15828591757634086),
#  ('freedom', 0.15465884736738894),
#  ('looked', 0.15439942421344272),
#  ('paid', 0.15114154103495434),
#  ('track', 0.14894452368150624),
#  ('stayed', 0.14775971339077026),
#  ('cards', 0.14755156807437148),
#  ('rap', 0.14171831842048663),
#  ('pocket', 0.1368417411600373),
#  ('lies', 0.13401219591106653),
#  ('works', 0.13361688864497878),
#  ('couldn', 0.1328786513928824),
#  ('turning', 0.1304980020027442),
#  ('youth', 0.12856575101803772),
#  ('harder', 0.12542978534006408),
#  ('kitchen', 0.12386465718866606),
#  ('holding', 0.12385574933504166),
#  ('bass', 0.12124169521865195),
#  ('blame', 0.11790686279340813),
#  ('wouldn', 0.11516803960190881),
#  ('tryna', 0.11353756437945947),
#  ('cut', 0.10841589565655321),
#  ('threw', 0.10797783157325022),
#  ('radio', 0.10712560139135929),
#  ('stress', 0.10555010256374357),
#  ('seat', 0.10444187200129736),
#  ('belong', 0.10423368497284613),
#  ('worth', 0.10323447101467274),
#  ('killed', 0.1018933756170476),
#  ('fix', 0.10125924788426177),
#  ('hang', 0.1010320630601548),
#  ('death', 0.10087397638395433)]

# %% [markdown]
# ### Topic analysis

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

# %%
def pre_process(df_lyrics):
    # tokenize lyrics
    lyrics_processed = df_lyrics.fillna("").str.split()

    for _list in lyrics_processed:
        for cnt in range(len(_list)):
            _list[cnt] = _list[cnt].replace(".", "").replace(",", "").replace("?", "").replace("\\", "").replace("/", "").replace(":", "").lower()
            
            if is_stopword(_list[cnt]):
                _list[cnt] = ""
                
    # remove empty string
    for cnt in range(len(lyrics_processed)):
        while(True):
            try:
                lyrics_processed[cnt].remove("")
            except:
                break

    return lyrics_processed

# %%
#train model
lyrics_processed = pre_process(df["lyrics"])
dictionary = Dictionary(lyrics_processed)
corpus = [dictionary.doc2bow(text) for text in lyrics_processed]
lda = LdaModel(corpus=corpus, id2word=dictionary, num_topics=100)

# %% [markdown]
# all topics

# %%
# observe topics
topics = lda.print_topics()

#sort
topics = sorted(topics, key=lambda x: x[0])

topics
# Out:
# [(0,
#   '0.031*"count" + 0.030*"della" + 0.023*"hurt" + 0.015*"love" + 0.012*"stars" + 0.011*"oh)" + 0.010*"nigger" + 0.010*"closer" + 0.008*"night" + 0.008*"moved"'),
#  (10,
#   '0.053*"dream" + 0.023*"christmas" + 0.022*"labour" + 0.019*"family" + 0.015*"deceive" + 0.013*"toy" + 0.012*"flashing" + 0.012*"mascara" + 0.010*"bambi" + 0.008*"true"'),
#  (13,
#   '0.037*"run" + 0.033*"summer" + 0.029*"hero" + 0.024*"bubble" + 0.017*"bring" + 0.014*"new" + 0.013*"attack" + 0.013*"york" + 0.012*"saying" + 0.010*"take"'),
#  (26,
#   '0.033*"say" + 0.020*"can\'t" + 0.015*"lonely" + 0.015*"love" + 0.014*"baby" + 0.014*"maybe" + 0.013*"think" + 0.011*"solosta" + 0.011*"pipe" + 0.008*"pedal"'),
#  (41,
#   '0.039*"home" + 0.024*"lights" + 0.020*"house" + 0.020*"worse" + 0.018*"love" + 0.011*"mediocre" + 0.011*"take" + 0.010*"body" + 0.008*"wild" + 0.007*"say"'),
#  (46,
#   '0.029*"bin" + 0.026*"pop" + 0.016*"fly" + 0.016*"give" + 0.016*"butterfly" + 0.016*"life" + 0.015*"love" + 0.014*"infinite" + 0.012*"crying" + 0.011*"wing"'),
#  (48,
#   '0.020*"segreta" + 0.019*"love" + 0.017*"bit" + 0.016*"united" + 0.014*"little" + 0.012*"can\'t" + 0.011*"hill" + 0.010*"hopes" + 0.010*"kingdom" + 0.010*"great"'),
#  (50,
#   '0.085*"love" + 0.015*"burn" + 0.015*"gno" + 0.015*"song" + 0.014*"leave" + 0.013*"new" + 0.012*"dem" + 0.012*"fire" + 0.012*"let" + 0.010*"need"'),
#  (51,
#   '0.024*"power" + 0.022*"baby" + 0.017*"think" + 0.013*"heart" + 0.010*"hope" + 0.009*"sail" + 0.008*"take" + 0.008*"cursed" + 0.008*"am" + 0.007*"honey"'),
#  (54,
#   '0.159*"nana" + 0.037*"down" + 0.028*"knock" + 0.021*"friends" + 0.013*"there\'s" + 0.010*"way" + 0.010*"dig" + 0.009*"can\'t" + 0.009*"past" + 0.009*"back"'),
#  (55,
#   '0.029*"moon" + 0.028*"freedom" + 0.020*"let" + 0.019*"boom" + 0.018*"heart" + 0.014*"feel" + 0.012*"can\'t" + 0.012*"only" + 0.010*"light" + 0.010*"fire"'),
#  (57,
#   '0.021*"trouble" + 0.021*"lie" + 0.010*"wow" + 0.009*"nigger" + 0.009*"greatest" + 0.009*"sorry" + 0.009*"goat" + 0.008*"can\'t" + 0.007*"fuck" + 0.007*"elegant"'),
#  (63,
#   '0.019*"fly" + 0.018*"that\'s" + 0.016*"way" + 0.014*"liked" + 0.013*"sugar" + 0.010*"eyes" + 0.008*"back" + 0.008*"feel" + 0.008*"love" + 0.008*"honey"'),
#  (76,
#   '0.160*"nana" + 0.057*"solosta" + 0.012*"i\'ve" + 0.012*"can\'t" + 0.011*"head" + 0.010*"bye" + 0.010*"alone" + 0.008*"riding" + 0.008*"edge" + 0.008*"delicate"'),
#  (78,
#   '0.082*"boy" + 0.044*"dark" + 0.021*"coming" + 0.018*"feel" + 0.013*"free" + 0.011*"let" + 0.010*"age" + 0.009*"kissing" + 0.008*"new" + 0.008*"say"'),
#  (86,
#   '0.069*"bad" + 0.023*"guy" + 0.023*"fine" + 0.022*"wants" + 0.012*"tonight" + 0.012*"he\'s" + 0.010*"soup" + 0.009*"let\'s" + 0.008*"boy" + 0.008*"song"'),
#  (87,
#   '0.016*"yes" + 0.012*"gurl" + 0.011*"fool" + 0.011*"helicopter" + 0.010*"shake" + 0.010*"brick" + 0.009*"lady" + 0.008*"baby" + 0.008*"water" + 0.008*"ready"'),
#  (89,
#   '0.063*"love" + 0.031*"yes" + 0.020*"girl" + 0.012*"let" + 0.010*"body" + 0.009*"cardi" + 0.009*"we\'re" + 0.008*"heart" + 0.008*"say" + 0.007*"put"'),
#  (91,
#   '0.022*"down" + 0.014*"damn" + 0.013*"feel" + 0.012*"made" + 0.012*"sexy" + 0.011*"sorry" + 0.010*"late" + 0.010*"believe" + 0.009*"hol" + 0.009*"it!"'),
#  (92,
#   '0.053*"night" + 0.023*"party" + 0.015*"heart" + 0.014*"feel" + 0.012*"light" + 0.012*"give" + 0.011*"life" + 0.011*"back" + 0.010*"take" + 0.007*"dark"')]

# %% [markdown]
# what topics are in kpop?

# %%
threshold = 0.3

counter = {}
summer = {}

for cnt in range(len(df)):
    if df["grouping"][cnt] != "kpop":
        continue
    
    topics = lda.get_document_topics(corpus[cnt], minimum_probability=0)
    
    for topic in topics:
        if topic[1] > threshold:
            counter[topic[0]] = counter.get(topic[0], 0) + 1
            
        summer[topic[0]] = summer.get(topic[0], 0) + topic[1]

# %%
sort_dictionary(counter)
# Out:
# [(30, 46),
#  (98, 27),
#  (92, 20),
#  (50, 20),
#  (93, 16),
#  (44, 16),
#  (61, 16),
#  (40, 14),
#  (41, 13),
#  (1, 13),
#  (94, 12),
#  (23, 12),
#  (12, 12),
#  (6, 12),
#  (49, 11),
#  (35, 11),
#  (45, 11),
#  (4, 11),
#  (67, 11),
#  (84, 11),
#  (46, 10),
#  (82, 10),
#  (2, 9),
#  (79, 9),
#  (91, 9),
#  (57, 9),
#  (17, 9),
#  (71, 9),
#  (95, 8),
#  (13, 8),
#  (31, 8),
#  (43, 8),
#  (66, 8),
#  (37, 8),
#  (53, 8),
#  (7, 8),
#  (22, 8),
#  (86, 8),
#  (55, 7),
#  (78, 7),
#  (51, 7),
#  (29, 7),
#  (80, 7),
#  (85, 7),
#  (16, 7),
#  (36, 7),
#  (3, 6),
#  (58, 6),
#  (27, 6),
#  (33, 6),
#  (52, 6),
#  (97, 6),
#  (89, 6),
#  (48, 6),
#  (19, 6),
#  (8, 6),
#  (47, 6),
#  (11, 5),
#  (42, 5),
#  (24, 5),
#  (26, 5),
#  (9, 5),
#  (81, 5),
#  (96, 5),
#  (18, 5),
#  (83, 4),
#  (76, 4),
#  (59, 4),
#  (14, 4),
#  (65, 4),
#  (15, 4),
#  (70, 4),
#  (34, 4),
#  (90, 4),
#  (5, 3),
#  (10, 3),
#  (63, 3),
#  (62, 3),
#  (75, 3),
#  (99, 3),
#  (60, 3),
#  (28, 3),
#  (21, 2),
#  (88, 2),
#  (73, 2),
#  (38, 2),
#  (20, 2),
#  (0, 2),
#  (32, 2),
#  (54, 1),
#  (69, 1),
#  (74, 1),
#  (72, 1),
#  (77, 1),
#  (25, 1),
#  (68, 1)]

# %%
sums = sort_dictionary(summer)

sums
# Out:
# [(30, 37.79214342489831),
#  (98, 25.07582538252791),
#  (93, 22.731048760017075),
#  (44, 21.263049757983026),
#  (92, 20.702901704595206),
#  (50, 20.20135823242981),
#  (61, 17.648196526062748),
#  (45, 16.111898041186578),
#  (23, 15.445429259269076),
#  (40, 15.301501325649951),
#  (67, 13.846386771010657),
#  (1, 13.829506861306072),
#  (94, 13.614862742733749),
#  (4, 12.98793389853563),
#  (84, 12.96822253495884),
#  (78, 12.95220438692013),
#  (41, 12.875048603176765),
#  (71, 12.838863268838395),
#  (12, 12.64536109927758),
#  (57, 12.576827913130728),
#  (49, 12.40050671051904),
#  (17, 11.97117998788417),
#  (6, 11.886919606245101),
#  (22, 11.68301675963994),
#  (35, 11.187163574993974),
#  (46, 10.65529372347919),
#  (28, 10.60487893975187),
#  (80, 10.555223475324965),
#  (82, 10.44144434577629),
#  (43, 10.378965555699324),
#  (79, 10.333007027758867),
#  (37, 10.18048843890756),
#  (2, 10.037383533328466),
#  (13, 9.740150335348517),
#  (58, 9.52434900694243),
#  (85, 9.343912500115039),
#  (66, 9.278712526820527),
#  (55, 9.205854565139816),
#  (52, 9.036948281527657),
#  (91, 8.994078802248623),
#  (29, 8.986887643039154),
#  (36, 8.97267402820944),
#  (14, 8.938850654712951),
#  (95, 8.769370663025256),
#  (97, 8.707316834201265),
#  (31, 8.682960877440564),
#  (86, 8.657191369164138),
#  (7, 8.652885729998161),
#  (16, 8.134281928401833),
#  (48, 8.105536343546191),
#  (53, 7.970059230176048),
#  (89, 7.947329372078457),
#  (33, 7.7659271352440555),
#  (19, 7.68746746116085),
#  (47, 7.592463459421197),
#  (51, 7.55569809847475),
#  (70, 7.383158125447153),
#  (42, 7.30953452662834),
#  (11, 7.305406723333363),
#  (24, 7.158756892700694),
#  (27, 7.154958725126562),
#  (65, 6.96303925673601),
#  (9, 6.959394637675359),
#  (3, 6.896600585745546),
#  (26, 6.854267584063564),
#  (63, 6.249520709267017),
#  (5, 5.952899475001686),
#  (18, 5.845487040400258),
#  (8, 5.778754198438037),
#  (60, 5.778519080891783),
#  (15, 5.706997889419654),
#  (81, 5.612060150413527),
#  (34, 5.595007383881239),
#  (59, 5.240041347600709),
#  (76, 5.168878217586098),
#  (99, 5.094235193189888),
#  (73, 5.033941564435736),
#  (83, 4.944540441318168),
#  (90, 4.829050703350731),
#  (20, 4.6148327654136665),
#  (96, 4.568057599439271),
#  (0, 4.4988908227114734),
#  (38, 4.434038654477263),
#  (32, 4.317859092263461),
#  (10, 4.288572422714424),
#  (88, 4.241690326254684),
#  (75, 4.10582172679824),
#  (62, 4.010830880144567),
#  (74, 3.7810305605216854),
#  (25, 3.73195016471891),
#  (64, 2.878001894967383),
#  (21, 2.838312057980147),
#  (72, 2.7405816727095953),
#  (54, 2.6398829401787225),
#  (87, 2.5643390551540506),
#  (77, 2.262200899922391),
#  (39, 2.1234173922466653),
#  (68, 1.9867325584509672),
#  (56, 1.8804081996077002),
#  (69, 1.7025467385628872)]

# %%
for _sum in sums[:5]:
    print("Topic ID: " + str(_sum[0]))
    print("Sum: " + str(_sum[1]))
    print("Count: " + str(counter[_sum[0]]))
    
    print("Keywords: ")
    print(lda.print_topic(int(_sum[0])))
    
    print("\n")
# Out:
# Topic ID: 30
# Sum: 37.79214342489831
# Count: 46
# Keywords:
# 0.099*"love" + 0.017*"need" + 0.013*"can't" + 0.012*"take" + 0.011*"feel" + 0.011*"tell" + 0.010*"heart" + 0.009*"let" + 0.008*"place" + 0.007*"way"
#
#
# Topic ID: 98
# Sum: 25.07582538252791
# Count: 27
# Keywords:
# 0.058*"love" + 0.017*"feel" + 0.017*"hope" + 0.015*"baby" + 0.013*"girl" + 0.012*"hell" + 0.011*"gives" + 0.010*"way" + 0.008*"let" + 0.007*"take"
#
#
# Topic ID: 93
# Sum: 22.731048760017075
# Count: 16
# Keywords:
# 0.043*"light" + 0.015*"wish" + 0.014*"detail" + 0.012*"news" + 0.011*"back" + 0.010*"only" + 0.010*"think" + 0.009*"cool" + 0.008*"kids" + 0.008*"makes"
#
#
# Topic ID: 44
# Sum: 21.263049757983026
# Count: 16
# Keywords:
# 0.029*"let's" + 0.016*"love" + 0.015*"baby" + 0.015*"try" + 0.014*"girls" + 0.011*"can't" + 0.010*"oh!" + 0.010*"wrong" + 0.009*"feel" + 0.009*"girl"
#
#
# Topic ID: 92
# Sum: 20.702901704595206
# Count: 20
# Keywords:
# 0.053*"night" + 0.023*"party" + 0.015*"heart" + 0.014*"feel" + 0.012*"light" + 0.012*"give" + 0.011*"life" + 0.011*"back" + 0.010*"take" + 0.007*"dark"
