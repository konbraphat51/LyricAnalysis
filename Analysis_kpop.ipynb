# %% [markdown]
# # Lyrics Analysis

# %%
lyrics_directory = "Lyrics_Data/"
tracks_csv = "tracks_group.csv"
stopwords_file = "stopwords.txt"

# %%
target_group = "kpop"
kpop_group = set(['kpop', 'itzy', 'seventeen', 'bts', 'twice'])
global_group = set(['global', 'billboard'])

target_and_kpop = kpop_group.union(set([target_group]))
target_and_global = global_group.union(set([target_group]))

# %% [markdown]
# ## Import data

# %%
import pandas as pd

# %%
df = pd.read_csv(tracks_csv)

df.head(3)
# Out:
#                       track_name                track_id grouping
# 0  Ice Cream (with Selena Gomez)  2J4P46vCFm1rPkNkp9pZWX     kpop
# 1                       Dynamite  0v1x6rN6JHRapa03JElljE     kpop
# 2                    THE BADDEST  2V4Fx72svQRxrFvNT1eq5f     kpop

# %%
#all to "kpop"
df.loc[df['grouping'].isin(target_and_kpop), 'grouping'] = "kpop"

# %%
df.shape
# Out:
# (4618, 3)

# %%
df["grouping"].unique()
# Out:
# array(['kpop', 'global', 'billboard'], dtype=object)

# %%
def get_lyrics(track_id):
    try:
        lyrics = ""
        with open(lyrics_directory + track_id + ".txt", "r") as f:
            lyrics = f.read()
            
        return lyrics            
    except:
        return None
    
df["lyrics"] = df["track_id"].apply(get_lyrics)

df.shape
# Out:
# (4618, 4)

# %%
# stop words
# https://www.kaggle.com/datasets/rowhitswami/stopwords/
stopwords = set()
with open(stopwords_file, "r") as f:
    stopwords = set(f.read().split("\n"))
    
stopwords
# Out:
# {',',
#  '>',
#  '?',
#  'Just',
#  'Yes',
#  'a',
#  'abaft',
#  'abafter',
#  'abaftest',
#  'about',
#  'abouter',
#  'aboutest',
#  'above',
#  'abover',
#  'abovest',
#  'accordingly',
#  'aer',
#  'aest',
#  'afore',
#  'after',
#  'afterer',
#  'afterest',
#  'afterward',
#  'afterwards',
#  'again',
#  'against',
#  'aid',
#  'ain',
#  'albeit',
#  'all',
#  'aller',
#  'allest',
#  'alls',
#  'allyou',
#  'almost',
#  'along',
#  'alongside',
#  'already',
#  'also',
#  'although',
#  'always',
#  'amid',
#  'amidst',
#  'among',
#  'amongst',
#  'an',
#  'and',
#  'andor',
#  'anear',
#  'anent',
#  'another',
#  'any',
#  'anybody',
#  'anyhow',
#  'anyone',
#  'anything',
#  'anywhere',
#  'apart',
#  'aparter',
#  'apartest',
#  'appear',
#  'appeared',
#  'appearing',
#  'appears',
#  'appropriate',
#  'appropriated',
#  'appropriater',
#  'appropriates',
#  'appropriatest',
#  'appropriating',
#  'are',
#  'ares',
#  'around',
#  'as',
#  'ases',
#  'aside',
#  'asides',
#  'aslant',
#  'astraddle',
#  'astraddler',
#  'astraddlest',
#  'astride',
#  'astrider',
#  'astridest',
#  'at',
#  'athwart',
#  'atop',
#  'atween',
#  'aught',
#  'aughts',
#  'available',
#  'availabler',
#  'availablest',
#  'awfully',
#  'b',
#  'be',
#  'became',
#  'because',
#  'become',
#  'becomes',
#  'becoming',
#  'becominger',
#  'becomingest',
#  'becomings',
#  'been',
#  'before',
#  'beforehand',
#  'beforehander',
#  'beforehandest',
#  'behind',
#  'behinds',
#  'below',
#  'beneath',
#  'beside',
#  'besides',
#  'better',
#  'bettered',
#  'bettering',
#  'betters',
#  'between',
#  'betwixt',
#  'beyond',
#  'bist',
#  'both',
#  'but',
#  'buts',
#  'by',
#  'by-and-by',
#  'byandby',
#  'c',
#  'can',
#  'cannot',
#  'canst',
#  'cant',
#  'canted',
#  'cantest',
#  'canting',
#  'cants',
#  'cer',
#  'certain',
#  'certainer',
#  'certainest',
#  'cest',
#  'chez',
#  'circa',
#  'co',
#  'come',
#  'come-on',
#  'come-ons',
#  'comeon',
#  'comeons',
#  'concerning',
#  'concerninger',
#  'concerningest',
#  'consequently',
#  'considering',
#  'could',
#  'couldst',
#  'cum',
#  'd',
#  'da',
#  'day',
#  'dday',
#  'ddays',
#  'describe',
#  'described',
#  'describes',
#  'describing',
#  'despite',
#  'despited',
#  'despites',
#  'despiting',
#  'did',
#  'different',
#  'differenter',
#  'differentest',
#  'do',
#  'doe',
#  'does',
#  'doing',
#  'doings',
#  'don',
#  "don't",
#  'done',
#  'doner',
#  'dones',
#  'donest',
#  'dos',
#  'dost',
#  'doth',
#  'downs',
#  'downward',
#  'downwarder',
#  'downwardest',
#  'downwards',
#  'du',
#  'during',
#  'e',
#  'each',
#  'eg',
#  'eight',
#  'either',
#  'else',
#  'elsewhere',
#  'enough',
#  'ere',
#  'et',
#  'etc',
#  'even',
#  'evened',
#  'evenest',
#  'evens',
#  'evenser',
#  'evensest',
#  'ever',
#  'every',
#  'everybody',
#  'everyone',
#  'everything',
#  'everywhere',
#  'ex',
#  'except',
#  'excepted',
#  'excepting',
#  'excepts',
#  'exes',
#  'f',
#  'fact',
#  'facts',
#  'failing',
#  'failings',
#  'few',
#  'fewer',
#  'fewest',
#  'figupon',
#  'figuponed',
#  'figuponing',
#  'figupons',
#  'five',
#  'followthrough',
#  'for',
#  'forby',
#  'forbye',
#  'fore',
#  'forer',
#  'fores',
#  'forever',
#  'former',
#  'formerer',
#  'formerest',
#  'formerly',
#  'formers',
#  'fornenst',
#  'forwhy',
#  'four',
#  'fourscore',
#  'frae',
#  'from',
#  'fs',
#  'further',
#  'furthered',
#  'furtherer',
#  'furtherest',
#  'furthering',
#  'furthermore',
#  'furthers',
#  'g',
#  'get',
#  'gets',
#  'getting',
#  'go',
#  'going',
#  'gone',
#  'good',
#  'got',
#  'gotta',
#  'gotten',
#  'h',
#  'had',
#  'hadst',
#  'hae',
#  'hardly',
#  'has',
#  'hast',
#  'hath',
#  'have',
#  'haves',
#  'having',
#  'he',
#  'hence',
#  'her',
#  'here',
#  'hereafter',
#  'hereafters',
#  'hereby',
#  'herein',
#  'hereupon',
#  'hers',
#  'herself',
#  'hey',
#  'him',
#  'himself',
#  'his',
#  'hither',
#  'hitherer',
#  'hitherest',
#  'hoo',
#  'hoos',
#  'how',
#  'how-do-you-do',
#  'howbeit',
#  'howdoyoudo',
#  'however',
#  'hr',
#  'huh',
#  'humph',
#  'i',
#  "i'll",
#  "i'm",
#  'idem',
#  'idemer',
#  'idemest',
#  'ie',
#  'if',
#  'ifs',
#  'immediate',
#  'immediately',
#  'immediater',
#  'immediatest',
#  'in',
#  'inasmuch',
#  'inc',
#  'indeed',
#  'indicate',
#  'indicated',
#  'indicates',
#  'indicating',
#  'info',
#  'information',
#  'insofar',
#  'instead',
#  'into',
#  'inward',
#  'inwarder',
#  'inwardest',
#  'inwards',
#  'is',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'j',
#  'just',
#  'k',
#  'know',
#  'l',
#  'la',
#  'latter',
#  'latterer',
#  'latterest',
#  'latterly',
#  'latters',
#  'layabout',
#  'layabouts',
#  'less',
#  'lest',
#  'like',
#  'll',
#  'look',
#  'lot',
#  'lots',
#  'lotted',
#  'lotting',
#  'm',
#  'main',
#  'make',
#  'many',
#  'mauger',
#  'maugre',
#  'mayest',
#  'me',
#  'meanwhile',
#  'meanwhiles',
#  'midst',
#  'midsts',
#  'might',
#  'mights',
#  'mm',
#  'more',
#  'moreover',
#  'most',
#  'mostly',
#  'much',
#  'mucher',
#  'muchest',
#  'must',
#  'musth',
#  'musths',
#  'musts',
#  'my',
#  'myself',
#  'n',
#  'na',
#  'natheless',
#  'nathless',
#  'neath',
#  'neaths',
#  'necessarier',
#  'necessariest',
#  'necessary',
#  'neither',
#  'nethe',
#  'nethermost',
#  'never',
#  'nevertheless',
#  'nigh',
#  'nigher',
#  'nighest',
#  'nine',
#  'no',
#  'no-one',
#  'nobodies',
#  'nobody',
#  'noes',
#  'none',
#  'noone',
#  'nor',
#  'nos',
#  'not',
#  'nothing',
#  'nothings',
#  'notwithstanding',
#  'now',
#  'nowhere',
#  'nowheres',
#  'o',
#  'of',
#  'off',
#  'offest',
#  'offs',
#  'often',
#  'oftener',
#  'oftenest',
#  'oh',
#  'on',
#  'one',
#  'oneself',
#  'onest',
#  'ons',
#  'onto',
#  'or',
#  'orer',
#  'orest',
#  'other',
#  'others',
#  'otherwise',
#  'otherwiser',
#  'otherwisest',
#  'ought',
#  'oughts',
#  'our',
#  'ours',
#  'ourself',
#  'ourselves',
#  'out',
#  'outed',
#  'outest',
#  'outs',
#  'outside',
#  'outwith',
#  'over',
#  'overall',
#  'overaller',
#  'overallest',
#  'overalls',
#  'overs',
#  'own',
#  'owned',
#  'owning',
#  'owns',
#  'owt',
#  'p',
#  'particular',
#  'particularer',
#  'particularest',
#  'particularly',
#  'particulars',
#  'per',
#  'perhaps',
#  'plaintiff',
#  'please',
#  'pleased',
#  'pleases',
#  'plenties',
#  'plenty',
#  'pro',
#  'probably',
#  'provide',
#  'provided',
#  'provides',
#  'providing',
#  'q',
#  'qua',
#  'que',
#  'quite',
#  'r',
#  'rath',
#  'rathe',
#  'rather',
#  'rathest',
#  're',
#  'really',
#  'regarding',
#  'relate',
#  'related',
#  'relatively',
#  'res',
#  'respecting',
#  'respectively',
#  'right',
#  's',
#  'said',
#  'saider',
#  'saidest',
#  'same',
#  'samer',
#  'sames',
#  'samest',
#  'sans',
#  'sanserif',
#  'sanserifs',
#  'sanses',
#  'saved',
#  'sayid',
#  'sayyid',
#  'see',
#  'seem',
#  'seemed',
#  'seeminger',
#  'seemingest',
#  'seemings',
#  'seems',
#  'send',
#  'sent',
#  'senza',
#  'serious',
#  'seriouser',
#  'seriousest',
#  'seven',
#  'several',
#  'severaler',
#  'severalest',
#  'shall',
#  'shalled',
#  'shalling',
#  'shalls',
#  'she',
#  'should',
#  'shoulded',
#  'shoulding',
#  'shoulds',
#  'since',
#  'sine',
#  'sines',
#  'sith',
#  'six',
#  'so',
#  'sobeit',
#  'soer',
#  'soest',
#  'some',
#  'somebody',
#  'somehow',
#  'someone',
#  'something',
#  'sometime',
#  'sometimer',
#  'sometimes',
#  'sometimest',
#  'somewhat',
#  'somewhere',
#  'stop',
#  'stopped',
#  'such',
#  'summat',
#  'sup',
#  'supped',
#  'supping',
#  'sups',
#  'syn',
#  'syne',
#  't',
#  'ten',
#  'than',
#  'that',
#  'the',
#  'thee',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'thence',
#  'thener',
#  'thenest',
#  'there',
#  'thereafter',
#  'thereby',
#  'therefore',
#  'therein',
#  'therer',
#  'therest',
#  'thereupon',
#  'these',
#  'they',
#  'thine',
#  'thing',
#  'things',
#  'this',
#  'thises',
#  'thorough',
#  'thorougher',
#  'thoroughest',
#  'thoroughly',
#  'those',
#  'thou',
#  'though',
#  'thous',
#  'thouses',
#  'three',
#  'thro',
#  'through',
#  'througher',
#  'throughest',
#  'throughout',
#  'thru',
#  'thruer',
#  'thruest',
#  'thus',
#  'thy',
#  'thyself',
#  'till',
#  'tilled',
#  'tilling',
#  'tills',
#  'time',
#  'to',
#  'together',
#  'too',
#  'toward',
#  'towarder',
#  'towardest',
#  'towards',
#  'two',
#  'u',
#  'umpteen',
#  'under',
#  'underneath',
#  'unless',
#  'unlike',
#  'unliker',
#  'unlikest',
#  'until',
#  'unto',
#  'up',
#  'upon',
#  'uponed',
#  'uponing',
#  'upons',
#  'upped',
#  'upping',
#  'ups',
#  'us',
#  'use',
#  'used',
#  'usedest',
#  'username',
#  'usually',
#  'v',
#  'various',
#  'variouser',
#  'variousest',
#  'verier',
#  'veriest',
#  'versus',
#  'very',
#  'via',
#  'vis-a-vis',
#  'vis-a-viser',
#  'vis-a-visest',
#  'viz',
#  'vs',
#  'w',
#  'want',
#  'was',
#  'wast',
#  'we',
#  'were',
#  'wert',
#  'what',
#  'whatever',
#  'whateverer',
#  'whateverest',
#  'whatsoever',
#  'whatsoeverer',
#  'whatsoeverest',
#  'wheen',
#  'when',
#  'whenas',
#  'whence',
#  'whencesoever',
#  'whenever',
#  'whensoever',
#  'where',
#  'whereafter',
#  'whereas',
#  'whereby',
#  'wherefrom',
#  'wherein',
#  'whereinto',
#  'whereof',
#  'whereon',
#  'wheresoever',
#  'whereto',
#  'whereupon',
#  'wherever',
#  'wherewith',
#  'wherewithal',
#  'whether',
#  'which',
#  'whichever',
#  'whichsoever',
#  'while',
#  'whiles',
#  'whilst',
#  'whither',
#  'whithersoever',
#  'who',
#  'whoever',
#  'whomever',
#  'whose',
#  'whoso',
#  'whosoever',
#  'why',
#  'will',
#  'with',
#  'withal',
#  'within',
#  'without',
#  'would',
#  'woulded',
#  'woulding',
#  'woulds',
#  'x',
#  'y',
#  'ye',
#  'yeah',
#  'yet',
#  'yon',
#  'yond',
#  'yonder',
#  'you',
#  "you're",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'z',
#  'zillion',
#  'ð',
#  '♪',
#  '♫'}

# %% [markdown]
# ## Analyze

# %%
def is_stopword(word):
    word = word.lower()
    
    if len(word) <= 1:
        return True
    
    # in the list
    if word in stopwords:
        return True
    
    # is Korean
    if ord("가") <= ord(word[0]) <= ord("힣"):
        return True
    
    return False

# %% [markdown]
# ### Characteristic Keyword
# Using TF-IDF

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %% [markdown]
# #### Among global

# %%
df_looking = df[df["grouping"].isin(target_and_global)].reset_index(drop=True)

# %%
vectorizer = TfidfVectorizer(stop_words=list(stopwords), max_features=1000, min_df=10)

x = vectorizer.fit_transform(df_looking["lyrics"].fillna("")).toarray()

df_tfidf = pd.DataFrame(x, columns=vectorizer.get_feature_names_out()).T
# Out:
# c:\Users\Hiyoko\.conda\envs\data\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['vis', 'viser', 'visest', 'yes'] not in stop_words.
#   warnings.warn(

# %%
threshold = 0.001
counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    tfidf_series = df_tfidf[cnt]
    
    keywords = tfidf_series[tfidf_series > threshold].index.tolist()
    for keyword in keywords:
        counter[keyword] = counter.get(keyword, 0) + 1
        summer[keyword] = summer.get(keyword, 0) + float(tfidf_series[keyword])

# %%
def sort_dictionary(dictionary):
    return [(k, dictionary[k]) for k in sorted(dictionary, key=dictionary.get, reverse=True)]

# %%
tfidf_counter_global = sort_dictionary(counter)
tfidf_counter_global
# Out:
# [('love', 521),
#  ('let', 507),
#  ('sorry', 497),
#  ('news', 412),
#  ('home', 410),
#  ('heart', 362),
#  ('yes', 345),
#  ('eyes', 313),
#  ('baby', 311),
#  ('feel', 301),
#  ('say', 299),
#  ('think', 292),
#  ('back', 279),
#  ('night', 270),
#  ('take', 267),
#  ('world', 239),
#  ('new', 226),
#  ('follow', 224),
#  ('only', 220),
#  ('am', 217),
#  ('need', 212),
#  ('tell', 206),
#  ('life', 202),
#  ('leave', 202),
#  ('light', 199),
#  ('dream', 199),
#  ('keep', 195),
#  ('room', 190),
#  ('give', 179),
#  ('way', 177),
#  ('end', 171),
#  ('mind', 170),
#  ('down', 162),
#  ('wait', 149),
#  ('still', 146),
#  ('hands', 143),
#  ('child', 142),
#  ('show', 140),
#  ('dance', 139),
#  ('girl', 139),
#  ('looking', 136),
#  ('care', 135),
#  ('price_varies', 133),
#  ('contact', 133),
#  ('little', 130),
#  ('hear', 128),
#  ('ah', 128),
#  ('okay', 126),
#  ('away', 125),
#  ('honey', 122),
#  ('boy', 121),
#  ('beautiful', 121),
#  ('sleep', 119),
#  ('find', 119),
#  ('start', 119),
#  ('ready', 118),
#  ('feeling', 118),
#  ('bad', 117),
#  ('stay', 116),
#  ('call', 115),
#  ('sky', 115),
#  ('body', 115),
#  ('happy', 114),
#  ('share', 112),
#  ('man', 112),
#  ('hand', 110),
#  ('worry', 109),
#  ('alone', 108),
#  ('touch', 106),
#  ('today', 106),
#  ('sweet', 104),
#  ('true', 104),
#  ('comment', 104),
#  ('play', 102),
#  ('shut', 101),
#  ('first', 101),
#  ('한국', 100),
#  ('god', 98),
#  ('hot', 97),
#  ('mine', 97),
#  ('doesn', 97),
#  ('crazy', 96),
#  ('fire', 95),
#  ('didn', 95),
#  ('matter', 95),
#  ('meet', 95),
#  ('break', 93),
#  ('forget', 93),
#  ('change', 92),
#  ('한국어', 92),
#  ('high', 91),
#  ('easy', 90),
#  ('ve', 90),
#  ('informazioni', 90),
#  ('sun', 89),
#  ('people', 88),
#  ('woo', 88),
#  ('once', 86),
#  ('morning', 85),
#  ('top', 85),
#  ('live', 85),
#  ('run', 85),
#  ('name', 85),
#  ('read', 85),
#  ('best', 84),
#  ('music', 84),
#  ('moment', 84),
#  ('waiting', 82),
#  ('place', 82),
#  ('next', 81),
#  ('full', 81),
#  ('tonight', 80),
#  ('turn', 80),
#  ('made', 80),
#  ('fly', 79),
#  ('agriculture', 78),
#  ('star', 78),
#  ('ooh', 77),
#  ('smile', 77),
#  ('을和', 77),
#  ('put', 76),
#  ('dreams', 75),
#  ('blue', 75),
#  ('face', 74),
#  ('move', 74),
#  ('price', 73),
#  ('head', 73),
#  ('last', 73),
#  ('believe', 73),
#  ('real', 72),
#  ('dark', 72),
#  ('long', 72),
#  ('talk', 71),
#  ('fine', 71),
#  ('black', 70),
#  ('free', 69),
#  ('miss', 69),
#  ('work', 69),
#  ('afraid', 69),
#  ('days', 69),
#  ('shine', 68),
#  ('reply', 68),
#  ('won', 67),
#  ('fall', 67),
#  ('words', 67),
#  ('song', 66),
#  ('deep', 66),
#  ('open', 64),
#  ('close', 64),
#  ('nice', 64),
#  ('thank', 64),
#  ('wind', 64),
#  ('friend', 63),
#  ('coming', 63),
#  ('teen', 63),
#  ('voice', 63),
#  ('cancel', 63),
#  ('remember', 63),
#  ('side', 63),
#  ('stars', 62),
#  ('continue', 62),
#  ('lost', 62),
#  ('wow', 62),
#  ('great', 61),
#  ('hit', 61),
#  ('hard', 61),
#  ('story', 61),
#  ('cold', 60),
#  ('bring', 60),
#  ('lose', 60),
#  ('skills', 60),
#  ('di', 60),
#  ('cry', 59),
#  ('answer', 59),
#  ('line', 58),
#  ('walk', 58),
#  ('pain', 58),
#  ('game', 57),
#  ('sound', 57),
#  ('left', 57),
#  ('word', 57),
#  ('road', 57),
#  ('laughter', 57),
#  ('listen', 57),
#  ('cool', 57),
#  ('mean', 56),
#  ('well', 56),
#  ('small', 56),
#  ('uh', 56),
#  ('sure', 56),
#  ('laugh', 56),
#  ('tags', 56),
#  ('moon', 55),
#  ('questions', 55),
#  ('directly', 55),
#  ('sing', 54),
#  ('control', 54),
#  ('walking', 54),
#  ('perfect', 54),
#  ('city', 53),
#  ('united', 53),
#  ('front', 53),
#  ('red', 53),
#  ('understand', 52),
#  ('tomorrow', 52),
#  ('far', 51),
#  ('gonna', 51),
#  ('il', 51),
#  ('anymore', 51),
#  ('kingdom', 51),
#  ('try', 51),
#  ('party', 51),
#  ('makes', 50),
#  ('eye', 50),
#  ('hope', 50),
#  ('fun', 49),
#  ('wrong', 49),
#  ('cuz', 49),
#  ('hidden', 49),
#  ('feet', 49),
#  ('tears', 49),
#  ('young', 49),
#  ('ay', 49),
#  ('phone', 48),
#  ('big', 48),
#  ('twitter', 48),
#  ('strong', 48),
#  ('learn', 48),
#  ('stanza', 48),
#  ('ice', 47),
#  ('money', 47),
#  ('wake', 47),
#  ('hate', 47),
#  ('babe', 47),
#  ('flowers', 47),
#  ('future', 47),
#  ('heaven', 46),
#  ('rain', 46),
#  ('step', 46),
#  ('looks', 45),
#  ('kill', 45),
#  ('friends', 45),
#  ('die', 44),
#  ('ask', 44),
#  ('saw', 44),
#  ('hold', 44),
#  ('hide', 44),
#  ('beat', 43),
#  ('sad', 43),
#  ('compare_at_price_min', 43),
#  ('flow', 43),
#  ('late', 43),
#  ('lie', 43),
#  ('drop', 42),
#  ('view', 42),
#  ('low', 42),
#  ('mom', 42),
#  ('problem', 42),
#  ('um', 42),
#  ('fresh', 41),
#  ('inside', 41),
#  ('forgot', 41),
#  ('watch', 41),
#  ('ago', 41),
#  ('price_min', 41),
#  ('water', 41),
#  ('air', 41),
#  ('eat', 40),
#  ('rock', 40),
#  ('question', 40),
#  ('lights', 40),
#  ('door', 40),
#  ('memory', 40),
#  ('sick', 40),
#  ('bang', 40),
#  ('hi', 40),
#  ('sea', 40),
#  ('dawn', 39),
#  ('kiss', 38),
#  ('woah', 38),
#  ('leaving', 38),
#  ('tired', 38),
#  ('spring', 38),
#  ('year', 38),
#  ('white', 38),
#  ('forward', 38),
#  ('maybe', 38),
#  ('taste', 37),
#  ('set', 37),
#  ('wants', 37),
#  ('living', 37),
#  ('ride', 37),
#  ('bright', 37),
#  ('google', 37),
#  ('working', 37),
#  ('guy', 36),
#  ('chest', 36),
#  ('being', 36),
#  ('summer', 36),
#  ('save', 36),
#  ('fight', 36),
#  ('flower', 36),
#  ('wish', 36),
#  ('breath', 36),
#  ('girls', 36),
#  ('straight', 36),
#  ('mood', 36),
#  ('cause', 35),
#  ('running', 35),
#  ('power', 35),
#  ('color', 35),
#  ('hair', 35),
#  ('old', 35),
#  ('comes', 35),
#  ('broken', 35),
#  ('bit', 35),
#  ('boom', 34),
#  ('falling', 34),
#  ('atmosphere', 34),
#  ('thought', 34),
#  ('throw', 34),
#  ('fast', 34),
#  ('film', 34),
#  ('talking', 34),
#  ('knows', 34),
#  ('soul', 33),
#  ('goes', 33),
#  ('saying', 33),
#  ('history', 33),
#  ('darkness', 33),
#  ('blow', 33),
#  ('ma', 33),
#  ('roll', 32),
#  ('burn', 32),
#  ('universe', 32),
#  ('tight', 32),
#  ('trying', 32),
#  ('help', 32),
#  ('part', 31),
#  ('eh', 31),
#  ('girlfriend', 31),
#  ('car', 31),
#  ('feelings', 31),
#  ('shake', 31),
#  ('person', 31),
#  ('moonlight', 31),
#  ('sex', 31),
#  ('lips', 31),
#  ('soon', 31),
#  ('happiness', 31),
#  ('jump', 30),
#  ('yo', 30),
#  ('blood', 30),
#  ('pop', 30),
#  ('mirror', 30),
#  ('reason', 30),
#  ('alive', 30),
#  ('ball', 29),
#  ('gold', 29),
#  ('special', 29),
#  ('clear', 29),
#  ('years', 29),
#  ('slow', 29),
#  ('warm', 29),
#  ('choose', 29),
#  ('changed', 29),
#  ('rid', 28),
#  ('memories', 28),
#  ('hours', 28),
#  ('sounds', 28),
#  ('magic', 28),
#  ('ha', 28),
#  ('promise', 28),
#  ('truth', 28),
#  ('wild', 27),
#  ('empty', 27),
#  ('says', 27),
#  ('waste', 27),
#  ('check', 27),
#  ('stupid', 27),
#  ('mouth', 27),
#  ('found', 27),
#  ('type', 27),
#  ('breathe', 27),
#  ('kind', 26),
#  ('snow', 26),
#  ('minute', 26),
#  ('act', 26),
#  ('shadow', 26),
#  ('times', 26),
#  ('dangerous', 26),
#  ('near', 26),
#  ('hello', 26),
#  ('24', 26),
#  ('fool', 26),
#  ('whole', 26),
#  ('style', 26),
#  ('winter', 26),
#  ('yeh', 26),
#  ('drink', 26),
#  ('shoot', 26),
#  ('drum', 25),
#  ('wall', 25),
#  ('heat', 25),
#  ('funny', 25),
#  ('space', 25),
#  ('fear', 25),
#  ('singing', 25),
#  ('rhythm', 25),
#  ('hell', 25),
#  ('house', 25),
#  ('cute', 25),
#  ('losing', 25),
#  ('paradise', 25),
#  ('double', 24),
#  ('imma', 24),
#  ('diamond', 24),
#  ('king', 24),
#  ('came', 24),
#  ('shining', 24),
#  ('second', 24),
#  ('beginning', 24),
#  ('invalid', 24),
#  ('ground', 24),
#  ('tear', 24),
#  ('hurt', 24),
#  ('non', 24),
#  ('higher', 24),
#  ('rest', 24),
#  ('thoughts', 24),
#  ('born', 24),
#  ('trust', 24),
#  ('closer', 23),
#  ('shoes', 23),
#  ('ring', 23),
#  ('goodbye', 23),
#  ('wonder', 23),
#  ('return', 23),
#  ('breathing', 23),
#  ('wave', 23),
#  ('busy', 23),
#  ('thinking', 23),
#  ('difficult', 23),
#  ('bag', 22),
#  ('diamonds', 22),
#  ('favorite', 22),
#  ('dancing', 22),
#  ('beauty', 22),
#  ('lonely', 22),
#  ('middle', 22),
#  ('welcome', 22),
#  ('shit', 22),
#  ('number', 22),
#  ('heard', 22),
#  ('children', 22),
#  ('stage', 22),
#  ('infinite', 22),
#  ('cream', 21),
#  ('moving', 21),
#  ('speak', 21),
#  ('dreaming', 21),
#  ('fake', 21),
#  ('games', 21),
#  ('edge', 21),
#  ('gave', 21),
#  ('finally', 21),
#  ('lover', 21),
#  ('ayy', 21),
#  ('loved', 20),
#  ('earth', 20),
#  ('fill', 20),
#  ('nights', 20),
#  ('catch', 20),
#  ('secret', 20),
#  ('chance', 20),
#  ('stronger', 20),
#  ('met', 20),
#  ('half', 20),
#  ('zoom', 20),
#  ('mother', 20),
#  ('twice', 20),
#  ('ya', 20),
#  ('standing', 20),
#  ('si', 20),
#  ('past', 20),
#  ('means', 19),
#  ('calls', 19),
#  ('went', 19),
#  ('sleeping', 19),
#  ('sign', 19),
#  ('seen', 19),
#  ('tip', 19),
#  ('playing', 19),
#  ('buy', 19),
#  ('job', 19),
#  ('burning', 19),
#  ('ok', 19),
#  ('facebook', 19),
#  ('wanted', 19),
#  ('ocean', 19),
#  ('win', 19),
#  ('called', 19),
#  ('cloud', 19),
#  ('area', 19),
#  ('pass', 19),
#  ('told', 19),
#  ('false', 19),
#  ('crying', 19),
#  ('dad', 19),
#  ('single', 19),
#  ('language', 19),
#  ('pull', 19),
#  ('ladies', 18),
#  ('rise', 18),
#  ('guys', 18),
#  ('hearts', 18),
#  ('couple', 18),
#  ('10', 18),
#  ('dress', 18),
#  ('sit', 18),
#  ('birthday', 18),
#  ('push', 18),
#  ('pink', 18),
#  ('table', 18),
#  ('street', 18),
#  ('focus', 18),
#  ('leaves', 18),
#  ('clothes', 18),
#  ('slowly', 18),
#  ('heavy', 17),
#  ('boss', 17),
#  ('rules', 17),
#  ('shy', 17),
#  ('choice', 17),
#  ('bet', 17),
#  ('calm', 17),
#  ('lady', 17),
#  ('loves', 17),
#  ('speed', 17),
#  ('trouble', 17),
#  ('floor', 17),
#  ('finish', 17),
#  ('rolling', 16),
#  ('stone', 16),
#  ('boys', 16),
#  ('round', 16),
#  ('feels', 16),
#  ('queen', 16),
#  ('stand', 16),
#  ('sunset', 16),
#  ('candy', 16),
#  ('desire', 16),
#  ('making', 16),
#  ('problems', 16),
#  ('caught', 16),
#  ('message', 16),
#  ('gon', 16),
#  ('sweat', 16),
#  ('dog', 16),
#  ('simple', 16),
#  ('list', 16),
#  ('butterfly', 16),
#  ('worried', 16),
#  ('write', 16),
#  ('piece', 15),
#  ('bringing', 15),
#  ('business', 15),
#  ('limit', 15),
#  ('bigger', 15),
#  ('doubt', 15),
#  ('drunk', 15),
#  ('grow', 15),
#  ('happens', 15),
#  ('super', 15),
#  ('finished', 15),
#  ('sugar', 15),
#  ('bomb', 15),
#  ('team', 15),
#  ('hero', 15),
#  ('short', 15),
#  ('ta', 15),
#  ('luck', 15),
#  ('click', 15),
#  ('lord', 15),
#  ('yellow', 15),
#  ('couldn', 15),
#  ('tried', 15),
#  ('evil', 15),
#  ('beats', 15),
#  ('disappear', 15),
#  ('lying', 15),
#  ('arms', 15),
#  ('cut', 14),
#  ('cake', 14),
#  ('burns', 14),
#  ('lucky', 14),
#  ('may', 14),
#  ('haters', 14),
#  ('sense', 14),
#  ('glass', 14),
#  ('scream', 14),
#  ('case', 14),
#  ('attention', 14),
#  ('pretty', 14),
#  ('angel', 14),
#  ('fault', 14),
#  ('weird', 14),
#  ('fingers', 14),
#  ('mistake', 14),
#  ('bounce', 14),
#  ('yesterday', 14),
#  ('bass', 13),
#  ('cup', 13),
#  ('million', 13),
#  ('bye', 13),
#  ('tells', 13),
#  ('calling', 13),
#  ('mic', 13),
#  ('took', 13),
#  ('continues', 13),
#  ('devil', 13),
#  ('corner', 13),
#  ('dead', 13),
#  ('della', 13),
#  ('hour', 13),
#  ('noise', 13),
#  ('trip', 13),
#  ('river', 13),
#  ('guess', 13),
#  ('champagne', 13),
#  ('whoa', 13),
#  ('relax', 13),
#  ('spend', 13),
#  ('closed', 13),
#  ('gives', 13),
#  ('clean', 13),
#  ('flying', 12),
#  ('cha', 12),
#  ('crowd', 12),
#  ('missed', 12),
#  ('mi', 12),
#  ('bed', 12),
#  ('york', 12),
#  ('blah', 12),
#  ('photo', 12),
#  ('loud', 12),
#  ('family', 12),
#  ('tv', 12),
#  ('taken', 12),
#  ('imagine', 12),
#  ('sexy', 12),
#  ('rose', 12),
#  ('woman', 12),
#  ('em', 12),
#  ('map', 12),
#  ('bam', 12),
#  ('dry', 12),
#  ('key', 12),
#  ('fair', 12),
#  ('hole', 12),
#  ('shot', 12),
#  ('careful', 12),
#  ('dirty', 12),
#  ('faith', 12),
#  ('sunday', 12),
#  ('country', 12),
#  ('honest', 12),
#  ('men', 12),
#  ('dynamite', 11),
#  ('death', 11),
#  ('likes', 11),
#  ('bird', 11),
#  ('pour', 11),
#  ('monster', 11),
#  ('celebrate', 11),
#  ('angry', 11),
#  ('drive', 11),
#  ('keeps', 11),
#  ('youth', 11),
#  ('owe', 11),
#  ('nah', 11),
#  ('missing', 11),
#  ('damn', 11),
#  ('foot', 11),
#  ('watching', 11),
#  ('ey', 11),
#  ('knock', 11),
#  ('bottom', 11),
#  ('fan', 11),
#  ('yah', 11),
#  ('escape', 11),
#  ('swear', 11),
#  ('ahead', 11),
#  ('scared', 11),
#  ('started', 11),
#  ('week', 11),
#  ('tie', 11),
#  ('track', 11),
#  ('reach', 11),
#  ('school', 11),
#  ('needs', 10),
#  ('wrist', 10),
#  ('heartbeat', 10),
#  ('riding', 10),
#  ('block', 10),
#  ('awake', 10),
#  ('window', 10),
#  ('boo', 10),
#  ('fuck', 10),
#  ('later', 10),
#  ('skin', 10),
#  ('point', 10),
#  ('handle', 10),
#  ('proud', 10),
#  ('plan', 10),
#  ('ho', 10),
#  ('bling', 10),
#  ('raise', 10),
#  ('gun', 10),
#  ('happened', 10),
#  ('pay', 10),
#  ('excuse', 10),
#  ('che', 10),
#  ('traduzione', 10),
#  ('legs', 10),
#  ('kid', 10),
#  ('passed', 10),
#  ('land', 10),
#  ('dust', 10),
#  ('fighting', 10),
#  ('poppin', 9),
#  ('bitch', 9),
#  ('cross', 9),
#  ('roof', 9),
#  ('100', 9),
#  ('chi', 9),
#  ('fell', 9),
#  ('hotel', 9),
#  ('places', 9),
#  ('green', 9),
#  ('asked', 9),
#  ('brain', 9),
#  ('clouds', 9),
#  ('20', 9),
#  ('taking', 9),
#  ('stuck', 9),
#  ('blind', 9),
#  ('isn', 9),
#  ('moves', 9),
#  ('neck', 9),
#  ('photos', 9),
#  ('age', 9),
#  ('hurts', 9),
#  ('release', 9),
#  ('mercy', 9),
#  ('falls', 9),
#  ('bar', 9),
#  ('asking', 9),
#  ('bite', 8),
#  ('deserve', 8),
#  ('breaking', 8),
#  ('boyfriend', 8),
#  ('dj', 8),
#  ('smell', 8),
#  ('shouldn', 8),
#  ('songs', 8),
#  ('kick', 8),
#  ('longer', 8),
#  ('turns', 8),
#  ('count', 8),
#  ('player', 8),
#  ('bottle', 8),
#  ('lo', 8),
#  ('driving', 8),
#  ('breaks', 8),
#  ('peace', 8),
#  ('mess', 8),
#  ('tick', 8),
#  ('dollars', 8),
#  ('ends', 8),
#  ('explain', 8),
#  ('smoke', 8),
#  ('lies', 8),
#  ('silence', 8),
#  ('doctor', 8),
#  ('worth', 8),
#  ('wrote', 8),
#  ('hanging', 8),
#  ('sir', 8),
#  ('dear', 8),
#  ('turned', 8),
#  ('rap', 8),
#  ('holy', 7),
#  ('tryna', 7),
#  ('kids', 7),
#  ('weekend', 7),
#  ('learned', 7),
#  ('search', 7),
#  ('killing', 7),
#  ('stayed', 7),
#  ('lovers', 7),
#  ('stress', 7),
#  ('brother', 7),
#  ('slip', 7),
#  ('son', 7),
#  ('trap', 7),
#  ('mmm', 7),
#  ('shooting', 7),
#  ('pretend', 7),
#  ('blame', 7),
#  ('happen', 7),
#  ('harder', 7),
#  ('chase', 7),
#  ('shots', 7),
#  ('midnight', 7),
#  ('woke', 7),
#  ('war', 7),
#  ('shows', 7),
#  ('course', 7),
#  ('worst', 6),
#  ('box', 6),
#  ('hundred', 6),
#  ('suck', 6),
#  ('walls', 6),
#  ('cards', 6),
#  ('played', 6),
#  ('pa', 6),
#  ('sitting', 6),
#  ('waited', 6),
#  ('holding', 6),
#  ('brings', 6),
#  ('wear', 6),
#  ('strange', 6),
#  ('ran', 6),
#  ('killed', 6),
#  ('ba', 6),
#  ('nana', 6),
#  ('ima', 6),
#  ('gimme', 6),
#  ('crush', 6),
#  ('pressure', 6),
#  ('freedom', 6),
#  ('plans', 6),
#  ('women', 6),
#  ('brought', 6),
#  ('weak', 6),
#  ('rich', 6),
#  ('shirt', 6),
#  ('sip', 5),
#  ('fucking', 5),
#  ('felt', 5),
#  ('known', 5),
#  ('thunder', 5),
#  ('yea', 5),
#  ('swing', 5),
#  ('drinking', 5),
#  ('detail', 5),
#  ('south', 5),
#  ('drug', 5),
#  ('pump', 5),
#  ('paint', 5),
#  ('bands', 5),
#  ('ass', 5),
#  ('throwing', 5),
#  ('keys', 5),
#  ('forgive', 5),
#  ('ayyy', 5),
#  ('wouldn', 5),
#  ('lives', 5),
#  ('jet', 5),
#  ('ways', 5),
#  ('knew', 5),
#  ('pray', 5),
#  ('giving', 5),
#  ('mad', 5),
#  ('knees', 5),
#  ('account', 5),
#  ('wo', 5),
#  ('wet', 5),
#  ('seat', 5),
#  ('takes', 5),
#  ('jeans', 4),
#  ('turning', 4),
#  ('thousand', 4),
#  ('least', 4),
#  ('lil', 4),
#  ('teeth', 4),
#  ('bum', 4),
#  ('streets', 4),
#  ('bleeding', 4),
#  ('dollar', 4),
#  ('bank', 4),
#  ('chain', 4),
#  ('pedal', 4),
#  ('mama', 4),
#  ('wasn', 4),
#  ('hip', 4),
#  ('dan', 4),
#  ('scars', 4),
#  ('dying', 4),
#  ('wife', 4),
#  ('mr', 4),
#  ('clock', 4),
#  ('build', 4),
#  ('21', 4),
#  ('beach', 4),
#  ('deny', 4),
#  ('sippin', 4),
#  ('chicken', 4),
#  ('hop', 4),
#  ('destined', 4),
#  ('mistakes', 4),
#  ('wood', 3),
#  ('wasted', 3),
#  ('whip', 3),
#  ('safe', 3),
#  ('fix', 3),
#  ('club', 3),
#  ('bought', 3),
#  ('ghost', 3),
#  ('father', 3),
#  ('town', 3),
#  ('broke', 3),
#  ('twenty', 3),
#  ('wine', 3),
#  ('band', 3),
#  ('clap', 3),
#  ('oooh', 3),
#  ('stuff', 3),
#  ('doo', 3),
#  ('dum', 3),
#  ('needed', 3),
#  ('shame', 3),
#  ('ruin', 3),
#  ('gucci', 3),
#  ('truck', 3),
#  ('treat', 3),
#  ('ohh', 3),
#  ('angeles', 3),
#  ('los', 3),
#  ('cover', 3),
#  ('worse', 3),
#  ('til', 3),
#  ('tall', 3),
#  ('spent', 3),
#  ('lick', 2),
#  ('kitchen', 2),
#  ('asshole', 2),
#  ('radio', 2),
#  ('bills', 2),
#  ('lately', 2),
#  ('looked', 2),
#  ('bop', 2),
#  ('gas', 2),
#  ('paid', 2),
#  ('record', 2),
#  ('idiot', 2),
#  ('friday', 2),
#  ('bleep', 2),
#  ('bitches', 2),
#  ('cock', 2),
#  ('american', 2),
#  ('belong', 2),
#  ('fame', 2),
#  ('plug', 2),
#  ('bottles', 2),
#  ('pussy', 2),
#  ('animals', 2),
#  ('kept', 2),
#  ('shawty', 1),
#  ('rack', 1),
#  ('drank', 1),
#  ('flames', 1),
#  ('cash', 1),
#  ('pocket', 1),
#  ('bullshit', 1),
#  ('bones', 1),
#  ('nigger', 1),
#  ('hoes', 1),
#  ('miles', 1),
#  ('drinks', 1),
#  ('grass', 1),
#  ('dick', 1),
#  ('gang', 1),
#  ('demons', 1),
#  ('dem', 1),
#  ('thinks', 1)]

# %%
tfidf_summer_global = sort_dictionary(summer)
tfidf_summer_global
# Out:
# [('love', 90.37153562331105),
#  ('home', 76.21004040264718),
#  ('sorry', 69.1397655218261),
#  ('news', 48.08603122812252),
#  ('let', 45.65971006638431),
#  ('heart', 43.53378986841094),
#  ('yes', 39.32657988099398),
#  ('baby', 37.152868190550656),
#  ('한국', 32.36819854379235),
#  ('follow', 32.046654207752745),
#  ('eyes', 30.337788713241792),
#  ('night', 30.09200698624242),
#  ('feel', 28.39620085138629),
#  ('dream', 27.485997323149512),
#  ('back', 27.444226966689936),
#  ('world', 27.138972303382236),
#  ('new', 25.668929887759134),
#  ('say', 25.19307183864961),
#  ('ah', 24.989323963741565),
#  ('light', 24.884317238554694),
#  ('only', 24.528770918077953),
#  ('think', 24.049286804765085),
#  ('woo', 23.311984021567397),
#  ('room', 22.957403813727545),
#  ('am', 22.89032814755495),
#  ('dance', 22.81597776759301),
#  ('need', 22.554843859626192),
#  ('life', 21.359150404595603),
#  ('contact', 20.8388989921961),
#  ('hot', 20.835045446552304),
#  ('give', 20.800300456215705),
#  ('boy', 20.55275934228878),
#  ('end', 19.70533057864628),
#  ('take', 19.318291675734073),
#  ('price_varies', 19.193755756320886),
#  ('child', 19.135232798436007),
#  ('leave', 19.018035723912384),
#  ('tell', 18.81116475926072),
#  ('shut', 18.655254137320437),
#  ('hands', 17.818362758983703),
#  ('bad', 17.728688623770374),
#  ('way', 17.384865109868795),
#  ('call', 16.85016629105963),
#  ('girl', 16.73837204189897),
#  ('happy', 16.516044432842968),
#  ('sweet', 16.315607678216537),
#  ('mind', 16.014488154980945),
#  ('today', 15.790451672289182),
#  ('stay', 15.746839427739275),
#  ('sky', 15.68345935836002),
#  ('find', 15.57924635639395),
#  ('keep', 15.335940004358575),
#  ('worry', 15.03099208506401),
#  ('share', 15.029851682412705),
#  ('wait', 14.952102838546375),
#  ('ooh', 14.938705461961721),
#  ('comment', 14.919284988891382),
#  ('looking', 14.828353618787752),
#  ('still', 14.657587653361437),
#  ('fire', 14.622540646755914),
#  ('ready', 14.484582435402512),
#  ('meet', 14.420616432771048),
#  ('little', 14.235759176723734),
#  ('touch', 13.999995486360804),
#  ('care', 13.992468168308903),
#  ('hear', 13.986493803867058),
#  ('run', 13.915780355767989),
#  ('honey', 13.91040856162477),
#  ('beautiful', 13.857393703303787),
#  ('best', 13.758961810927108),
#  ('show', 13.690035500172831),
#  ('away', 13.626827037238893),
#  ('music', 13.500303662073339),
#  ('god', 13.440556363951757),
#  ('crazy', 13.382512856292596),
#  ('alone', 13.365944274208905),
#  ('down', 13.060574063988584),
#  ('한국어', 12.89651874512279),
#  ('mine', 12.88662676811565),
#  ('wow', 12.8412459049556),
#  ('okay', 12.6942637854943),
#  ('true', 12.664964529270188),
#  ('start', 12.663795449164642),
#  ('fly', 12.61558705004078),
#  ('sleep', 12.498351985823895),
#  ('agriculture', 12.473666949797057),
#  ('fall', 12.279433697120684),
#  ('easy', 12.277546141770996),
#  ('informazioni', 12.197178617909387),
#  ('bang', 12.027426427945825),
#  ('man', 11.96941792606431),
#  ('universe', 11.951940577698146),
#  ('cry', 11.870494953480836),
#  ('star', 11.820014193360064),
#  ('blue', 11.719822751074764),
#  ('play', 11.703752185741614),
#  ('fine', 11.567015675700507),
#  ('change', 11.559304049373184),
#  ('feeling', 11.525340396020448),
#  ('hand', 11.29368611354902),
#  ('matter', 11.273546948689011),
#  ('teen', 11.238492400982517),
#  ('invalid', 11.172593147413076),
#  ('babe', 11.089050502124987),
#  ('waiting', 11.006179862799717),
#  ('il', 10.983142281851453),
#  ('break', 10.94437056086585),
#  ('live', 10.873639619130788),
#  ('ay', 10.854982017524847),
#  ('을和', 10.83004141968757),
#  ('thank', 10.8270460149726),
#  ('sun', 10.811720334220688),
#  ('reply', 10.62673637811119),
#  ('name', 10.48667495739877),
#  ('eh', 10.372981226155197),
#  ('last', 10.326267266886092),
#  ('top', 10.239532683036641),
#  ('di', 10.165996795303569),
#  ('dreams', 10.155323327669823),
#  ('read', 10.119063362209644),
#  ('moon', 10.093203581722992),
#  ('move', 10.035317479313322),
#  ('once', 9.804115352620354),
#  ('smile', 9.799061068662793),
#  ('work', 9.73916879296257),
#  ('deep', 9.699331154246329),
#  ('flower', 9.656441541016893),
#  ('high', 9.579432855448719),
#  ('united', 9.533443805749808),
#  ('morning', 9.522741800689705),
#  ('tonight', 9.497794383780903),
#  ('body', 9.447650515708245),
#  ('didn', 9.392405395013261),
#  ('first', 9.365193386178136),
#  ('song', 9.342208180387164),
#  ('shine', 9.26463407495854),
#  ('doesn', 9.123409276866022),
#  ('moment', 9.082001273757522),
#  ('wind', 9.025201256581415),
#  ('words', 8.96214240957586),
#  ('cancel', 8.935266743368409),
#  ('next', 8.878529708524733),
#  ('ve', 8.857796782545792),
#  ('dark', 8.843424772133089),
#  ('boom', 8.842094234389329),
#  ('skills', 8.685371078975699),
#  ('summer', 8.675466452639842),
#  ('stanza', 8.651699612100812),
#  ('flowers', 8.625128148617257),
#  ('miss', 8.596566914837219),
#  ('story', 8.59099839271049),
#  ('future', 8.557560374614619),
#  ('twitter', 8.51714278488834),
#  ('um', 8.510082220583648),
#  ('people', 8.466421568612542),
#  ('compare_at_price_min', 8.44136460094637),
#  ('uh', 8.40623069597494),
#  ('price', 8.40138695449339),
#  ('stars', 8.353272581055142),
#  ('side', 8.33853164559058),
#  ('laughter', 8.330627191884295),
#  ('price_min', 8.256006534616697),
#  ('kingdom', 8.21413762661017),
#  ('forget', 8.211423270794686),
#  ('face', 8.183288072988347),
#  ('nice', 8.152248874733173),
#  ('tags', 8.076665697938488),
#  ('put', 8.063371089000402),
#  ('rain', 7.987102915407037),
#  ('believe', 7.9776591997062765),
#  ('full', 7.9776412367002125),
#  ('walking', 7.96581464780513),
#  ('place', 7.915885075047525),
#  ('real', 7.912612416073255),
#  ('spring', 7.909641017504015),
#  ('hi', 7.898524737095885),
#  ('city', 7.889002907265548),
#  ('continue', 7.882563636279215),
#  ('sick', 7.865668497390509),
#  ('voice', 7.85357570891632),
#  ('long', 7.82393215800114),
#  ('cold', 7.813080790791908),
#  ('talk', 7.77609210785743),
#  ('laugh', 7.765893609756601),
#  ('remember', 7.747311883614424),
#  ('save', 7.667081856522033),
#  ('black', 7.665036458187591),
#  ('hidden', 7.663431590044243),
#  ('days', 7.64108090446059),
#  ('hit', 7.572221642838357),
#  ('friend', 7.536226221415834),
#  ('line', 7.529738115972814),
#  ('lost', 7.5041994394166744),
#  ('yeh', 7.454158202993782),
#  ('cuz', 7.383690128212224),
#  ('anymore', 7.33641393360436),
#  ('red', 7.33045854934599),
#  ('hate', 7.293552448096992),
#  ('tomorrow', 7.267225840885409),
#  ('directly', 7.260639529611187),
#  ('pain', 7.2002597627687575),
#  ('turn', 7.179837418157154),
#  ('left', 7.175409898072763),
#  ('questions', 7.122937656925247),
#  ('power', 7.118305561565755),
#  ('kill', 7.075706449559849),
#  ('sure', 7.0745665285301245),
#  ('memory', 7.05659370638424),
#  ('ice', 7.004982662870871),
#  ('cool', 7.0026466065149835),
#  ('close', 6.9690924452299345),
#  ('coming', 6.967097221722313),
#  ('wish', 6.952804823410748),
#  ('won', 6.94227780456956),
#  ('step', 6.93324581739936),
#  ('free', 6.869109894714702),
#  ('well', 6.799724525885744),
#  ('year', 6.7965903687235185),
#  ('afraid', 6.752894767266331),
#  ('heaven', 6.7471367112038365),
#  ('far', 6.7312420945183415),
#  ('fun', 6.710890542015774),
#  ('butterfly', 6.69665713730967),
#  ('walk', 6.687247754683266),
#  ('moonlight', 6.663084223766014),
#  ('word', 6.660104573693972),
#  ('young', 6.650310232057058),
#  ('falling', 6.635654609433586),
#  ('road', 6.631840667002531),
#  ('listen', 6.608914664380625),
#  ('hard', 6.608825807217371),
#  ('head', 6.5965236790007085),
#  ('girlfriend', 6.559480006365183),
#  ('living', 6.555128638577306),
#  ('winter', 6.548986707817364),
#  ('girls', 6.543579908666091),
#  ('bomb', 6.5304015014626895),
#  ('forgot', 6.528126752629523),
#  ('air', 6.52252668978883),
#  ('understand', 6.461660075194957),
#  ('answer', 6.456282943297965),
#  ('lose', 6.406503026945199),
#  ('party', 6.405119341102008),
#  ('sing', 6.316430098563307),
#  ('hold', 6.315030726378468),
#  ('eye', 6.280046120639251),
#  ('great', 6.183554967396858),
#  ('google', 6.162207190083694),
#  ('control', 6.1264386173645375),
#  ('question', 6.105403398222256),
#  ('mean', 6.052774339713233),
#  ('non', 6.0423131073950085),
#  ('woah', 6.039245435632706),
#  ('money', 6.025603556304908),
#  ('big', 6.0174556057564725),
#  ('tears', 5.987441023727976),
#  ('dawn', 5.951300512397641),
#  ('lie', 5.941534917778733),
#  ('24', 5.941416864906357),
#  ('drop', 5.916360093451967),
#  ('front', 5.876190529483728),
#  ('made', 5.870618895353933),
#  ('feet', 5.86318094598633),
#  ('pop', 5.859263949184961),
#  ('special', 5.845286599885615),
#  ('perfect', 5.828534185727131),
#  ('bring', 5.772151018930492),
#  ('drunk', 5.764510349474982),
#  ('set', 5.762016737042084),
#  ('small', 5.691039072090051),
#  ('ha', 5.669520032899758),
#  ('candy', 5.666433917148268),
#  ('open', 5.642219658459145),
#  ('snow', 5.621105457499133),
#  ('ride', 5.619651970512773),
#  ('sea', 5.616697266857235),
#  ('mic', 5.517342950242242),
#  ('die', 5.48724468509434),
#  ('problem', 5.4749433697811725),
#  ('kiss', 5.456197701785001),
#  ('running', 5.44109709319728),
#  ('mood', 5.435335536212533),
#  ('bit', 5.427135692240433),
#  ('try', 5.409108993008108),
#  ('view', 5.403456492335435),
#  ('guy', 5.37965177445341),
#  ('person', 5.372633096015138),
#  ('mom', 5.355481942697505),
#  ('ma', 5.350480267436591),
#  ('door', 5.329776797813713),
#  ('strong', 5.303415786563931),
#  ('traduzione', 5.302105909560267),
#  ('sound', 5.279499670818012),
#  ('working', 5.26623010091093),
#  ('singing', 5.264057226765623),
#  ('wild', 5.260696239843014),
#  ('fake', 5.219777467716887),
#  ('burn', 5.218780659428643),
#  ('reason', 5.165991236174365),
#  ('water', 5.1594307887065325),
#  ('makes', 5.159106022786506),
#  ('straight', 5.156437351862412),
#  ('dynamite', 5.155966431162679),
#  ('ta', 5.148401816730508),
#  ('chi', 5.146723662055361),
#  ('stronger', 5.144317090462335),
#  ('ago', 5.131658532624587),
#  ('goodbye', 5.129811488763184),
#  ('hide', 5.119657612155789),
#  ('magic', 5.043946753669218),
#  ('beat', 5.033820564244435),
#  ('forward', 5.000819616926843),
#  ('shoot', 4.990327070025905),
#  ('zoom', 4.988689599242499),
#  ('cream', 4.960916203471597),
#  ('wrong', 4.930051230792915),
#  ('shining', 4.90686538940985),
#  ('roll', 4.9051207541435),
#  ('sad', 4.904568471536327),
#  ('ya', 4.893359413494741),
#  ('higher', 4.890848254721116),
#  ('gonna', 4.885397445855567),
#  ('tear', 4.859012128737235),
#  ('hours', 4.845713569009707),
#  ('chest', 4.844613616310364),
#  ('trust', 4.839016121306798),
#  ('soon', 4.834975912193282),
#  ('jump', 4.834179896153415),
#  ('color', 4.829380209087041),
#  ('rock', 4.822040292534059),
#  ('flow', 4.795157124320175),
#  ('blood', 4.775654128178013),
#  ('looks', 4.77272440671388),
#  ('atmosphere', 4.759878029940927),
#  ('rhythm', 4.7541491822662225),
#  ('choose', 4.745955508125027),
#  ('dad', 4.735366494268707),
#  ('help', 4.727594095505287),
#  ('happiness', 4.718583926108293),
#  ('memories', 4.711168960830832),
#  ('imma', 4.687654095375621),
#  ('learn', 4.674176935877616),
#  ('hope', 4.629045875390652),
#  ('warm', 4.619728339652423),
#  ('second', 4.585374183256806),
#  ('tired', 4.521836184838518),
#  ('stupid', 4.520990846004034),
#  ('hello', 4.500688316080925),
#  ('eat', 4.494414916416001),
#  ('empty', 4.489407248127393),
#  ('soul', 4.478005436705073),
#  ('shy', 4.4583223912068775),
#  ('fresh', 4.451212605360295),
#  ('lips', 4.44834355613321),
#  ('maybe', 4.440182541636837),
#  ('hero', 4.43124813127077),
#  ('darkness', 4.410306109241345),
#  ('phone', 4.376459580136771),
#  ('watch', 4.358230143932588),
#  ('history', 4.35707538065525),
#  ('dangerous', 4.336642081504368),
#  ('breath', 4.313493553349408),
#  ('bam', 4.292119353901581),
#  ('being', 4.286275386365565),
#  ('sex', 4.284270397419239),
#  ('gold', 4.277201314443198),
#  ('finally', 4.267171774873276),
#  ('promise', 4.2641273718047605),
#  ('friends', 4.254326533790228),
#  ('bright', 4.242643832697803),
#  ('ring', 4.241033661140481),
#  ('film', 4.228110340999802),
#  ('lights', 4.2226145803468125),
#  ('fast', 4.214814012454666),
#  ('wave', 4.212156112961845),
#  ('rid', 4.2067023943308275),
#  ('birthday', 4.165532473853278),
#  ('years', 4.159264686355236),
#  ('hair', 4.14493154585391),
#  ('ba', 4.133871241674974),
#  ('taste', 4.131720042038926),
#  ('says', 4.131119647590158),
#  ('feelings', 4.101342787686101),
#  ('slow', 4.095021848938688),
#  ('bye', 4.087978999682838),
#  ('low', 4.066019633552951),
#  ('game', 4.058346382298234),
#  ('wake', 4.042379135141545),
#  ('knock', 4.0413988021569835),
#  ('super', 4.039607026207059),
#  ('hell', 4.0386331998017635),
#  ('wall', 4.035115370024032),
#  ('wants', 4.032575598536099),
#  ('fool', 4.013099824051188),
#  ('fight', 4.007779894873053),
#  ('style', 4.00443782893573),
#  ('della', 4.000054915910287),
#  ('10', 3.9916961977080683),
#  ('type', 3.979543265617661),
#  ('mouth', 3.9753514508437084),
#  ('beauty', 3.974835605036266),
#  ('broken', 3.9604491522824414),
#  ('sounds', 3.9566259408038964),
#  ('ask', 3.9504947622573456),
#  ('mirror', 3.946112042508676),
#  ('funny', 3.934825708072087),
#  ('whole', 3.9097293371517776),
#  ('saying', 3.901210488713258),
#  ('white', 3.8748739564177312),
#  ('welcome', 3.868823911812524),
#  ('leaving', 3.84870512720797),
#  ('breathe', 3.8463284377152003),
#  ('saw', 3.825240485312594),
#  ('found', 3.8131513692255807),
#  ('job', 3.803825267117833),
#  ('crying', 3.8005490013843284),
#  ('yo', 3.7947735560283693),
#  ('late', 3.790050503172479),
#  ('comes', 3.771964697581285),
#  ('clear', 3.765803610214064),
#  ('ayy', 3.739975519305801),
#  ('knows', 3.7321838912798597),
#  ('cause', 3.7245244878753554),
#  ('secret', 3.7208462314759516),
#  ('ok', 3.668374784104661),
#  ('old', 3.6550485292941),
#  ('sugar', 3.651639962508289),
#  ('inside', 3.6506458797954053),
#  ('woman', 3.6491834062665665),
#  ('truth', 3.6447855152363573),
#  ('rest', 3.6435742038842354),
#  ('bag', 3.638883906353022),
#  ('shake', 3.634580113754746),
#  ('em', 3.62435549267082),
#  ('tight', 3.6205132555406743),
#  ('goes', 3.6174775888842046),
#  ('missed', 3.6067668734524188),
#  ('lover', 3.5952945385323987),
#  ('push', 3.5908194818724777),
#  ('changed', 3.580877339053977),
#  ('diamond', 3.5781200751142084),
#  ('part', 3.5608244779903075),
#  ('cute', 3.542150695774806),
#  ('guys', 3.5232858713300463),
#  ('blah', 3.5191154944856065),
#  ('hurt', 3.5095465224372844),
#  ('thoughts', 3.5030616605318214),
#  ('click', 3.4887437716062113),
#  ('talking', 3.4694024317255865),
#  ('bringing', 3.467640095567015),
#  ('double', 3.4527186872163425),
#  ('dreaming', 3.4379658333452285),
#  ('losing', 3.4327274977640374),
#  ('paradise', 3.4086005893618836),
#  ('scream', 3.4007374519106395),
#  ('beginning', 3.3906341141574035),
#  ('thinking', 3.3677817727346815),
#  ('alive', 3.33235871977743),
#  ('dancing', 3.32359229747348),
#  ('blow', 3.2770574293650285),
#  ('ball', 3.265664303034581),
#  ('yellow', 3.26169946853012),
#  ('stage', 3.2515897219342107),
#  ('space', 3.22634367507063),
#  ('lucky', 3.2227464145060463),
#  ('boys', 3.209395024877845),
#  ('crush', 3.198692432258781),
#  ('standing', 3.1797314728629775),
#  ('queen', 3.1485793809585942),
#  ('closer', 3.1325370423266268),
#  ('list', 3.1316448150604836),
#  ('born', 3.1306112994463513),
#  ('waste', 3.106525152769277),
#  ('thought', 3.1012452917468583),
#  ('earth', 3.0838393498660985),
#  ('team', 3.0820086288022885),
#  ('pink', 3.080144517364427),
#  ('house', 3.0794281859107517),
#  ('disappear', 3.0743684719815447),
#  ('tip', 3.0608144148086494),
#  ('car', 3.0566198193301055),
#  ('favorite', 3.0416838743969707),
#  ('times', 3.035808471890084),
#  ('wo', 3.033621919931096),
#  ('breathing', 3.027578691734506),
#  ('chance', 3.026626708669354),
#  ('bet', 3.0164896018138747),
#  ('win', 3.0062023293896534),
#  ('loved', 2.9864457570902005),
#  ('number', 2.986390690168827),
#  ('nah', 2.96608534721491),
#  ('throw', 2.946011559006062),
#  ('si', 2.9288048626254906),
#  ('heat', 2.9068286223466946),
#  ('minute', 2.8975154818144615),
#  ('called', 2.866660246598374),
#  ('ocean', 2.86345449873882),
#  ('simple', 2.861502312973111),
#  ('detail', 2.8582424505524884),
#  ('mistake', 2.853540664248242),
#  ('mi', 2.806018359305036),
#  ('sunday', 2.7937639388738074),
#  ('children', 2.776861288579871),
#  ('busy', 2.7535572019338455),
#  ('near', 2.751779768117089),
#  ('hip', 2.7344162698806023),
#  ('bird', 2.7197731945953127),
#  ('trying', 2.7131038721278804),
#  ('drink', 2.712107873767224),
#  ('dirty', 2.6959565751847157),
#  ('angel', 2.6954974844969133),
#  ('diamonds', 2.6948097232408825),
#  ('infinite', 2.6932605379154113),
#  ('wonder', 2.690582303373882),
#  ('weird', 2.685664514611014),
#  ('check', 2.6855491021164646),
#  ('cloud', 2.6730808622695816),
#  ('burning', 2.671056549147639),
#  ('doubt', 2.6572907334701092),
#  ('boyfriend', 2.6547743516663123),
#  ('business', 2.6545647220525144),
#  ('seen', 2.6439569482368523),
#  ('bling', 2.642993132887922),
#  ('flying', 2.6406767976774717),
#  ('language', 2.6400498371523398),
#  ('rose', 2.6283780859809798),
#  ('pretend', 2.6282210221189737),
#  ('games', 2.6245636681629554),
#  ('single', 2.6118683460104464),
#  ('continues', 2.608954471567892),
#  ('lady', 2.604934422580126),
#  ('met', 2.598380516154144),
#  ('rules', 2.5982620962387677),
#  ('middle', 2.5860497553771755),
#  ('street', 2.582327917583568),
#  ('edge', 2.568474409549961),
#  ('yah', 2.5660081229738196),
#  ('focus', 2.5640341308268635),
#  ('desire', 2.5518076784875006),
#  ('shadow', 2.5515123114130933),
#  ('fill', 2.55040816119095),
#  ('floor', 2.5459818740707747),
#  ('half', 2.5455794415756245),
#  ('gave', 2.5442782061583777),
#  ('sexy', 2.5360091702613596),
#  ('monster', 2.528383038351996),
#  ('area', 2.5192490166923998),
#  ('river', 2.516464491370289),
#  ('million', 2.5095408409746307),
#  ('boo', 2.5069829133817367),
#  ('noise', 2.500013029911264),
#  ('lonely', 2.4999120007360633),
#  ('hole', 2.491431615045431),
#  ('ladies', 2.4809702710020978),
#  ('return', 2.4738755161336403),
#  ('ground', 2.4713784541991446),
#  ('fear', 2.4703696874656895),
#  ('hearts', 2.4576057017108246),
#  ('rolling', 2.4476415035046286),
#  ('haters', 2.4379685783479568),
#  ('later', 2.430677639760329),
#  ('facebook', 2.4159544146746486),
#  ('evil', 2.4007240953027376),
#  ('problems', 2.3976300462032922),
#  ('boss', 2.387891977731452),
#  ('came', 2.381419914194869),
#  ('choice', 2.3647605456837617),
#  ('act', 2.363779752307095),
#  ('attention', 2.3584847126034116),
#  ('difficult', 2.355974545319878),
#  ('ho', 2.349725781654159),
#  ('past', 2.34933303648101),
#  ('nana', 2.348317225806954),
#  ('corner', 2.337304827781378),
#  ('trouble', 2.3348020722680087),
#  ('heard', 2.3345407093098154),
#  ('hour', 2.334330080568525),
#  ('bottom', 2.31606213257824),
#  ('slowly', 2.3159861616022215),
#  ('youth', 2.3070321817554618),
#  ('bounce', 2.305835280316402),
#  ('moving', 2.295629965887496),
#  ('pa', 2.2947201269122184),
#  ('mother', 2.2907261717758787),
#  ('caught', 2.281320626630224),
#  ('explain', 2.2797806638939315),
#  ('bum', 2.2775172233856673),
#  ('beats', 2.27594292029098),
#  ('kind', 2.264408337842173),
#  ('sweat', 2.2615113690617843),
#  ('point', 2.257829587735925),
#  ('loud', 2.2448672606867306),
#  ('lying', 2.2342426672938003),
#  ('write', 2.233206682288374),
#  ('release', 2.228974134128582),
#  ('catch', 2.2218116648827455),
#  ('excuse', 2.219222030463725),
#  ('devil', 2.2126800311639276),
#  ('nights', 2.2039233629414983),
#  ('sense', 2.203132319130563),
#  ('gimme', 2.2000513539539526),
#  ('cake', 2.1942308582158194),
#  ('shoes', 2.182073995007751),
#  ('sleeping', 2.1725780959691603),
#  ('making', 2.1521779824279),
#  ('wanted', 2.148438131061247),
#  ('ohh', 2.1418060398403647),
#  ('taking', 2.1304608920225476),
#  ('went', 2.122691190610211),
#  ('luck', 2.118087614951675),
#  ('may', 2.0880983449354513),
#  ('leaves', 2.0786555322228017),
#  ('short', 2.0703302755653623),
#  ('map', 2.070160995992179),
#  ('dress', 2.0545424687897498),
#  ('relax', 2.0500267078185854),
#  ('worried', 2.0486058249264474),
#  ('false', 2.043780161299307),
#  ('lord', 2.042724275304245),
#  ('twice', 2.0360337640065698),
#  ('case', 2.0254921563900306),
#  ('bite', 2.0251702452445453),
#  ('loves', 2.0249930456630882),
#  ('week', 2.021628043052079),
#  ('arms', 2.0187102652985147),
#  ('limit', 2.0118130788803152),
#  ('burns', 1.9902703967936637),
#  ('clothes', 1.9569814470681919),
#  ('bleep', 1.9528341564746317),
#  ('doo', 1.9518165944897992),
#  ('pull', 1.9513742017215499),
#  ('fingers', 1.9480452327451192),
#  ('kick', 1.9456966641421602),
#  ('happened', 1.9454370250830015),
#  ('means', 1.9379592831049899),
#  ('tick', 1.9342279307590815),
#  ('ey', 1.9282603617126615),
#  ('suck', 1.9214189185725272),
#  ('careful', 1.9211775282838737),
#  ('bigger', 1.9202427945781095),
#  ('blind', 1.9127713681514606),
#  ('finish', 1.9038588454795116),
#  ('heavy', 1.8939037238672487),
#  ('glass', 1.8817825327318713),
#  ('drum', 1.8808608641195448),
#  ('stuck', 1.879956105679979),
#  ('dog', 1.8785804526465202),
#  ('pass', 1.8651916372133162),
#  ('speak', 1.8423263428706744),
#  ('dead', 1.8383431975594213),
#  ('tells', 1.8348809360852174),
#  ('dan', 1.8318445749634473),
#  ('champagne', 1.81948867812633),
#  ('buy', 1.8172064630663531),
#  ('sign', 1.8045198966294067),
#  ('table', 1.8040332783776472),
#  ('yesterday', 1.7977319818082322),
#  ('sir', 1.796583001788685),
#  ('finished', 1.7870479018465284),
#  ('20', 1.7755880334730698),
#  ('speed', 1.7704755133693557),
#  ('taken', 1.7681204125413919),
#  ('rise', 1.7386789786804078),
#  ('guess', 1.7303692704256384),
#  ('grow', 1.7287742061720004),
#  ('likes', 1.7159882015696128),
#  ('calm', 1.7144748491316097),
#  ('mr', 1.7016736427552248),
#  ('clean', 1.692212602010095),
#  ('calls', 1.6812721929869479),
#  ('block', 1.6806119130154555),
#  ('keeps', 1.6682628776254897),
#  ('deserve', 1.6628572234126395),
#  ('ahead', 1.6620962348119883),
#  ('bop', 1.656001678875634),
#  ('king', 1.6559321864685979),
#  ('stone', 1.6453979862920856),
#  ('pour', 1.6451833666715647),
#  ('kids', 1.6384694504975092),
#  ('fair', 1.6286205017365947),
#  ('whip', 1.627629525667363),
#  ('foot', 1.6232685728613432),
#  ('gives', 1.614304880530245),
#  ('piece', 1.614279881479998),
#  ('land', 1.606356471176641),
#  ('lovers', 1.6062926129152069),
#  ('round', 1.6042042120679527),
#  ('reach', 1.5881574379966956),
#  ('feels', 1.5818372965664635),
#  ('shot', 1.5810309992986473),
#  ('pump', 1.5786806199571048),
#  ('shooting', 1.578571554375445),
#  ('school', 1.5696034861181993),
#  ('swing', 1.5681544033825832),
#  ('lo', 1.5481336159894663),
#  ('sunset', 1.5428007354760647),
#  ('player', 1.5417857076776627),
#  ('roof', 1.5389708556685306),
#  ('celebrate', 1.5380960119872333),
#  ('stand', 1.5349298364439217),
#  ('handle', 1.5319774736133462),
#  ('closed', 1.5273715508062586),
#  ('fault', 1.5217453048005591),
#  ('key', 1.5109329453991056),
#  ('che', 1.4864454470590363),
#  ('shit', 1.4809028214697895),
#  ('happen', 1.480360190328436),
#  ('weekend', 1.4711682826397405),
#  ('worth', 1.469546557995919),
#  ('falls', 1.464867676187072),
#  ('tried', 1.4619127467055268),
#  ('shots', 1.4548879637017853),
#  ('happens', 1.452378878599631),
#  ('playing', 1.449245710040286),
#  ('tie', 1.4420973790384115),
#  ('fell', 1.4411352054795672),
#  ('country', 1.4369075804725888),
#  ('count', 1.426439960000345),
#  ('turned', 1.424259978262151),
#  ('whoa', 1.4204659276892424),
#  ('clap', 1.4195957912930723),
#  ('pretty', 1.4157958989262212),
#  ('faith', 1.408878779059567),
#  ('brings', 1.4087377587573497),
#  ('photo', 1.40584863490328),
#  ('twenty', 1.3974569268331822),
#  ('proud', 1.3916969821881635),
#  ('escape', 1.3833380878238055),
#  ('fan', 1.3759256939529285),
#  ('mess', 1.3722282703717164),
#  ('asking', 1.3683982712176475),
#  ('missing', 1.3615073361350605),
#  ('window', 1.3593674231904478),
#  ('needs', 1.3551304665981934),
#  ('took', 1.3481724310697774),
#  ('family', 1.3374733635308476),
#  ('sitting', 1.3344227075796873),
#  ('turns', 1.3238564889633673),
#  ('trip', 1.3216816334623607),
#  ('legs', 1.3138177057249991),
#  ('spend', 1.3138031257917386),
#  ('message', 1.3105238271478474),
#  ('scared', 1.3101436134128575),
#  ('green', 1.3071772393392862),
#  ('couple', 1.3070621550613217),
#  ('blame', 1.3066142759478947),
#  ('ruin', 1.3027764413437046),
#  ('cha', 1.2952727129193746),
#  ('calling', 1.2845197581783696),
#  ('chicken', 1.2821394672876463),
#  ('cut', 1.2623544054779852),
#  ('tv', 1.2573217031919766),
#  ('sit', 1.252687267292562),
#  ('killing', 1.2429876164128308),
#  ('honest', 1.2415075745516886),
#  ('passed', 1.2374947011786852),
#  ('asked', 1.2351789688298955),
#  ('gon', 1.2344556871840173),
#  ('lil', 1.223634817502227),
#  ('men', 1.2203229872201566),
#  ('dj', 1.2170445462794361),
#  ('slip', 1.215322809106855),
#  ('swear', 1.2118226151883271),
#  ('bass', 1.2010809731750374),
#  ('turning', 1.195900538940345),
#  ('gucci', 1.1939615011660427),
#  ('strange', 1.183322268518304),
#  ('course', 1.178744454733386),
#  ('age', 1.1692697039755335),
#  ('york', 1.1653789556469154),
#  ('dust', 1.1593147196539824),
#  ('giving', 1.1548593946580636),
#  ('smell', 1.1449433971343923),
#  ('dry', 1.1401147863233323),
#  ('riding', 1.1388756339886241),
#  ('ways', 1.1337941495474984),
#  ('imagine', 1.1240323449339413),
#  ('dum', 1.123166673267956),
#  ('wrote', 1.1219729062779464),
#  ('longer', 1.120793507795462),
#  ('trap', 1.1200599239867706),
#  ('build', 1.1179383579043187),
#  ('worst', 1.1156573302427566),
#  ('cards', 1.1068705647835597),
#  ('angeles', 1.103176643436983),
#  ('drive', 1.0930270212956121),
#  ('gun', 1.0920853857079775),
#  ('los', 1.08217540294077),
#  ('cross', 1.0819474827822964),
#  ('angry', 1.0811337385405855),
#  ('death', 1.0800612683345596),
#  ('fighting', 1.0761519026470416),
#  ('rap', 1.0719065800753402),
#  ('breaking', 1.0676070683299832),
#  ('weak', 1.0644967557691558),
#  ('waited', 1.0590594839067256),
#  ('south', 1.0541261389601864),
#  ('plan', 1.0411900913152983),
#  ('pay', 1.040536732629865),
#  ('plans', 1.0277016013729854),
#  ('heartbeat', 1.0272788628370981),
#  ('told', 1.0186865422005364),
#  ('war', 1.0060118824233533),
#  ('son', 1.0055133260389986),
#  ('clouds', 0.9962492756424653),
#  ('hurts', 0.9923718075692871),
#  ('owe', 0.9909256267607843),
#  ('moves', 0.9841968397705538),
#  ('cup', 0.9825430232193644),
#  ('shouldn', 0.9808025553072175),
#  ('midnight', 0.9784531012240852),
#  ('idiot', 0.9762997643727472),
#  ('silence', 0.9744062229046594),
#  ('hop', 0.9737925316630136),
#  ('ends', 0.9680878090989479),
#  ('skin', 0.9650334555354856),
#  ('account', 0.9557240534765647),
#  ('kid', 0.9494216872089327),
#  ('couldn', 0.9449831542315643),
#  ('isn', 0.9354763940661239),
#  ('peace', 0.9316639108456224),
#  ('lies', 0.9263598519790465),
#  ('watching', 0.922146572404994),
#  ('harder', 0.9220509531272403),
#  ('crowd', 0.9204178607841876),
#  ('oooh', 0.919554029904458),
#  ('bed', 0.9149410091131979),
#  ('neck', 0.9104929163310997),
#  ('clock', 0.9047924019025453),
#  ('mercy', 0.9036409695390328),
#  ('awake', 0.9012022004406517),
#  ('dear', 0.8930372702426942),
#  ('21', 0.8889126336357933),
#  ('poppin', 0.8840909768389886),
#  ('rich', 0.8822235470493596),
#  ('wrist', 0.8725825440758803),
#  ('drug', 0.8713261869377682),
#  ('smoke', 0.868734257464717),
#  ('takes', 0.8682047813827192),
#  ('thunder', 0.8676378094275256),
#  ('mama', 0.8671392797674952),
#  ('photos', 0.8654077658109209),
#  ('women', 0.859187670703492),
#  ('100', 0.855676586682264),
#  ('pedal', 0.8386306808809814),
#  ('bills', 0.8375366638654473),
#  ('paint', 0.828572839413565),
#  ('brother', 0.8228462071714093),
#  ('raise', 0.8200432377273543),
#  ('breaks', 0.8198628116094792),
#  ('ran', 0.817598509253651),
#  ('mad', 0.8151350704325155),
#  ('learned', 0.8120757125064795),
#  ('stayed', 0.7967203636052683),
#  ('bar', 0.7897459878604293),
#  ('wet', 0.7890257058546403),
#  ('track', 0.7819325044790585),
#  ('shirt', 0.778427696957072),
#  ('started', 0.7690524237345314),
#  ('yea', 0.7672586883481345),
#  ('throwing', 0.7644192252823644),
#  ('brought', 0.7440041807301123),
#  ('shows', 0.7414903862646776),
#  ('bottle', 0.7384801538705933),
#  ('songs', 0.7382433473607393),
#  ('mmm', 0.7288236634689804),
#  ('damn', 0.7258523771339528),
#  ('stress', 0.7160343925538354),
#  ('wine', 0.7038022782385799),
#  ('hotel', 0.7028985700025031),
#  ('places', 0.6988629435904951),
#  ('hundred', 0.697455002806947),
#  ('truck', 0.6965683068182946),
#  ('teeth', 0.6933430238736766),
#  ('woke', 0.6784359007237692),
#  ('pray', 0.6718155442403153),
#  ('search', 0.6680033704320407),
#  ('sippin', 0.6576796198677359),
#  ('hanging', 0.6499565754907068),
#  ('freedom', 0.6453005895715623),
#  ('walls', 0.6330234007503708),
#  ('box', 0.6303718474477749),
#  ('deny', 0.6287043431101536),
#  ('known', 0.6261837033415077),
#  ('scars', 0.6202017671216531),
#  ('driving', 0.6186414929729102),
#  ('bitch', 0.6165983247915239),
#  ('gas', 0.6065604006861),
#  ('streets', 0.6033558560857005),
#  ('brain', 0.591380374867312),
#  ('bands', 0.5889149737672118),
#  ('wife', 0.581830235788397),
#  ('bleeding', 0.5817515996975696),
#  ('fuck', 0.5688592631715603),
#  ('destined', 0.5642862938858676),
#  ('wear', 0.5639179279755933),
#  ('holy', 0.5607247334493564),
#  ('chase', 0.558468555179399),
#  ('dying', 0.5500990320683049),
#  ('fucking', 0.549506387185421),
#  ('keys', 0.5407530943569567),
#  ('kept', 0.5402731480974694),
#  ('jet', 0.5346269619169869),
#  ('played', 0.5339263866529972),
#  ('pressure', 0.5301873287608233),
#  ('doctor', 0.5165288871062813),
#  ('lives', 0.5157516476130466),
#  ('beach', 0.5062858658814215),
#  ('forgive', 0.5053010194472618),
#  ('killed', 0.5036816074387801),
#  ('holding', 0.49952316085926685),
#  ('father', 0.4995219443504467),
#  ('stuff', 0.49591587475014803),
#  ('thousand', 0.4928706580882291),
#  ('wasted', 0.4829007124840994),
#  ('bank', 0.4736643477466374),
#  ('shame', 0.47231442752157116),
#  ('knew', 0.47076795134754723),
#  ('drinking', 0.4652448087351059),
#  ('wasn', 0.4650369966014377),
#  ('worse', 0.46035663091024714),
#  ('ayyy', 0.45707022845019535),
#  ('friday', 0.4474287043258862),
#  ('dollars', 0.4468555944202894),
#  ('tryna', 0.437244940654987),
#  ('cock', 0.42781313932987103),
#  ('mistakes', 0.4260272266600299),
#  ('town', 0.4230451214185642),
#  ('til', 0.42190489884739685),
#  ('dollar', 0.42026478490138786),
#  ('ghost', 0.4201009761423541),
#  ('club', 0.4200395239182534),
#  ('seat', 0.40359575992121743),
#  ('plug', 0.403350770007185),
#  ('needed', 0.39666015724358517),
#  ('spent', 0.39590823822944304),
#  ('wood', 0.392076431502696),
#  ('bought', 0.3735977178306394),
#  ('chain', 0.37290573032718505),
#  ('flames', 0.371912383226229),
#  ('felt', 0.3669821717187491),
#  ('least', 0.3668902398571068),
#  ('ima', 0.36123206822509196),
#  ('sip', 0.35878065920450025),
#  ('fix', 0.35535475860209603),
#  ('safe', 0.3514811156533133),
#  ('asshole', 0.33442789546863017),
#  ('lately', 0.3291051806847339),
#  ('broke', 0.31185703633576795),
#  ('band', 0.3033830120319063),
#  ('tall', 0.30121165128939786),
#  ('wouldn', 0.2767427824418769),
#  ('ass', 0.2679718311468982),
#  ('knees', 0.26411571773882914),
#  ('bitches', 0.2617789020879167),
#  ('looked', 0.2549945665249209),
#  ('belong', 0.25175019387114944),
#  ('paid', 0.2511075286997972),
#  ('animals', 0.2509966265414684),
#  ('cover', 0.24701663167146826),
#  ('treat', 0.2210285697357484),
#  ('radio', 0.22020062788138528),
#  ('record', 0.20247270956666066),
#  ('drank', 0.19487086496382394),
#  ('jeans', 0.1793412688925297),
#  ('bullshit', 0.16584968613060314),
#  ('kitchen', 0.15533498435276466),
#  ('bottles', 0.14714272727356897),
#  ('pocket', 0.1369715843461475),
#  ('fame', 0.11825474529005106),
#  ('dem', 0.11724233199614865),
#  ('thinks', 0.11702170221901034),
#  ('rack', 0.11583307650736217),
#  ('grass', 0.09758933152539896),
#  ('pussy', 0.09200063056986672),
#  ('american', 0.09076006883863755),
#  ('gang', 0.08447498642090176),
#  ('demons', 0.0791314318954147),
#  ('bones', 0.07409352532731533),
#  ('lick', 0.06497193086735695),
#  ('miles', 0.05637201558610661),
#  ('hoes', 0.05425197468777658),
#  ('shawty', 0.04841866987509265),
#  ('nigger', 0.04647677746771743),
#  ('dick', 0.03583672152426443),
#  ('cash', 0.024402201901396418),
#  ('drinks', 0.009946293428382848)]

# %% [markdown]
# #### Among KPOP

# %%
df_looking = df[df["grouping"].isin(target_and_kpop)].reset_index(drop=True)

# %%
vectorizer = TfidfVectorizer(stop_words=list(stopwords), max_features=1000, min_df=10)

x = vectorizer.fit_transform(df_looking["lyrics"].fillna("")).toarray()

df_tfidf = pd.DataFrame(x, columns=vectorizer.get_feature_names_out()).T
# Out:
# c:\Users\Hiyoko\.conda\envs\data\lib\site-packages\sklearn\feature_extraction\text.py:408: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['vis', 'viser', 'visest', 'yes'] not in stop_words.
#   warnings.warn(

# %%
threshold = 0.001
counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    tfidf_series = df_tfidf[cnt]
    
    keywords = tfidf_series[tfidf_series > threshold].index.tolist()
    for keyword in keywords:
        counter[keyword] = counter.get(keyword, 0) + 1
        summer[keyword] = summer.get(keyword, 0) + float(tfidf_series[keyword])

# %%
tfidf_counter_kpop = sort_dictionary(counter)
tfidf_counter_kpop
# Out:
# [('love', 521),
#  ('let', 507),
#  ('sorry', 497),
#  ('news', 413),
#  ('home', 408),
#  ('heart', 363),
#  ('yes', 345),
#  ('eyes', 313),
#  ('baby', 312),
#  ('feel', 301),
#  ('say', 299),
#  ('think', 292),
#  ('back', 279),
#  ('night', 271),
#  ('take', 267),
#  ('world', 239),
#  ('new', 226),
#  ('follow', 224),
#  ('only', 221),
#  ('am', 217),
#  ('need', 212),
#  ('tell', 207),
#  ('life', 202),
#  ('leave', 202),
#  ('light', 199),
#  ('dream', 199),
#  ('keep', 195),
#  ('room', 190),
#  ('give', 179),
#  ('way', 177),
#  ('end', 171),
#  ('mind', 170),
#  ('down', 162),
#  ('wait', 149),
#  ('still', 146),
#  ('hands', 144),
#  ('child', 142),
#  ('show', 140),
#  ('dance', 139),
#  ('girl', 139),
#  ('looking', 136),
#  ('care', 135),
#  ('price_varies', 133),
#  ('contact', 133),
#  ('little', 130),
#  ('hear', 128),
#  ('ah', 128),
#  ('away', 125),
#  ('okay', 125),
#  ('honey', 122),
#  ('boy', 121),
#  ('beautiful', 121),
#  ('sleep', 119),
#  ('find', 119),
#  ('start', 119),
#  ('feeling', 118),
#  ('bad', 117),
#  ('ready', 117),
#  ('stay', 116),
#  ('call', 115),
#  ('sky', 115),
#  ('body', 115),
#  ('happy', 114),
#  ('share', 112),
#  ('man', 112),
#  ('hand', 110),
#  ('worry', 109),
#  ('alone', 108),
#  ('touch', 106),
#  ('today', 106),
#  ('sweet', 104),
#  ('true', 104),
#  ('comment', 104),
#  ('play', 102),
#  ('shut', 101),
#  ('first', 101),
#  ('한국', 100),
#  ('god', 98),
#  ('mine', 97),
#  ('doesn', 97),
#  ('fire', 96),
#  ('crazy', 96),
#  ('hot', 96),
#  ('didn', 95),
#  ('matter', 95),
#  ('meet', 95),
#  ('break', 93),
#  ('forget', 93),
#  ('change', 92),
#  ('한국어', 92),
#  ('high', 91),
#  ('easy', 90),
#  ('ve', 90),
#  ('informazioni', 90),
#  ('sun', 89),
#  ('people', 88),
#  ('woo', 88),
#  ('once', 86),
#  ('morning', 85),
#  ('top', 85),
#  ('live', 85),
#  ('run', 85),
#  ('name', 85),
#  ('read', 85),
#  ('best', 84),
#  ('music', 84),
#  ('moment', 84),
#  ('waiting', 82),
#  ('place', 82),
#  ('next', 81),
#  ('full', 81),
#  ('tonight', 80),
#  ('turn', 80),
#  ('made', 80),
#  ('fly', 79),
#  ('agriculture', 78),
#  ('star', 78),
#  ('ooh', 77),
#  ('smile', 77),
#  ('을和', 77),
#  ('put', 76),
#  ('dreams', 75),
#  ('blue', 75),
#  ('face', 74),
#  ('real', 74),
#  ('move', 74),
#  ('price', 73),
#  ('head', 73),
#  ('last', 73),
#  ('believe', 73),
#  ('dark', 72),
#  ('long', 72),
#  ('talk', 71),
#  ('fine', 71),
#  ('black', 70),
#  ('free', 69),
#  ('miss', 69),
#  ('work', 69),
#  ('afraid', 69),
#  ('days', 69),
#  ('shine', 68),
#  ('reply', 68),
#  ('song', 67),
#  ('won', 67),
#  ('fall', 67),
#  ('words', 67),
#  ('deep', 66),
#  ('open', 64),
#  ('close', 64),
#  ('nice', 64),
#  ('thank', 64),
#  ('wind', 64),
#  ('friend', 63),
#  ('coming', 63),
#  ('teen', 63),
#  ('voice', 63),
#  ('cancel', 63),
#  ('remember', 63),
#  ('side', 63),
#  ('stars', 62),
#  ('continue', 62),
#  ('lost', 62),
#  ('wow', 62),
#  ('great', 61),
#  ('hit', 61),
#  ('hard', 61),
#  ('story', 61),
#  ('cold', 60),
#  ('bring', 60),
#  ('lose', 60),
#  ('skills', 60),
#  ('di', 60),
#  ('cry', 59),
#  ('answer', 59),
#  ('line', 58),
#  ('organization', 58),
#  ('walk', 58),
#  ('pain', 58),
#  ('well', 57),
#  ('game', 57),
#  ('sound', 57),
#  ('left', 57),
#  ('word', 57),
#  ('road', 57),
#  ('laughter', 57),
#  ('listen', 57),
#  ('cool', 57),
#  ('mean', 56),
#  ('small', 56),
#  ('uh', 56),
#  ('sure', 56),
#  ('laugh', 56),
#  ('tags', 56),
#  ('moon', 55),
#  ('questions', 55),
#  ('directly', 55),
#  ('sing', 54),
#  ('control', 54),
#  ('walking', 54),
#  ('perfect', 54),
#  ('city', 53),
#  ('united', 53),
#  ('front', 53),
#  ('red', 53),
#  ('understand', 52),
#  ('inquiry', 52),
#  ('tomorrow', 52),
#  ('makes', 51),
#  ('far', 51),
#  ('gonna', 51),
#  ('il', 51),
#  ('anymore', 51),
#  ('kingdom', 51),
#  ('try', 51),
#  ('party', 51),
#  ('eye', 50),
#  ('hope', 50),
#  ('fun', 49),
#  ('wrong', 49),
#  ('cuz', 49),
#  ('hidden', 49),
#  ('feet', 49),
#  ('tears', 49),
#  ('young', 49),
#  ('phone', 48),
#  ('big', 48),
#  ('twitter', 48),
#  ('strong', 48),
#  ('ay', 48),
#  ('learn', 48),
#  ('stanza', 48),
#  ('ice', 47),
#  ('money', 47),
#  ('wake', 47),
#  ('hate', 47),
#  ('babe', 47),
#  ('flowers', 47),
#  ('future', 47),
#  ('heaven', 46),
#  ('friends', 46),
#  ('rain', 46),
#  ('step', 46),
#  ('looks', 45),
#  ('kill', 45),
#  ('die', 44),
#  ('ask', 44),
#  ('saw', 44),
#  ('hold', 44),
#  ('hide', 44),
#  ('beat', 43),
#  ('sad', 43),
#  ('password', 43),
#  ('compare_at_price_min', 43),
#  ('flow', 43),
#  ('late', 43),
#  ('lie', 43),
#  ('drop', 42),
#  ('view', 42),
#  ('low', 42),
#  ('mom', 42),
#  ('problem', 42),
#  ('um', 42),
#  ('fresh', 41),
#  ('inside', 41),
#  ('forgot', 41),
#  ('watch', 41),
#  ('ago', 41),
#  ('price_min', 41),
#  ('data', 41),
#  ('water', 41),
#  ('air', 41),
#  ('eat', 40),
#  ('rock', 40),
#  ('question', 40),
#  ('pantyhose', 40),
#  ('lights', 40),
#  ('door', 40),
#  ('memory', 40),
#  ('sick', 40),
#  ('subscribe', 40),
#  ('bang', 40),
#  ('hi', 40),
#  ('sea', 40),
#  ('dawn', 39),
#  ('generating', 39),
#  ('maybe', 39),
#  ('kiss', 38),
#  ('woah', 38),
#  ('leaving', 38),
#  ('tired', 38),
#  ('spring', 38),
#  ('year', 38),
#  ('white', 38),
#  ('forward', 38),
#  ('taste', 37),
#  ('set', 37),
#  ('wants', 37),
#  ('living', 37),
#  ('ride', 37),
#  ('bright', 37),
#  ('google', 37),
#  ('working', 37),
#  ('guy', 36),
#  ('chest', 36),
#  ('being', 36),
#  ('summer', 36),
#  ('save', 36),
#  ('fight', 36),
#  ('flower', 36),
#  ('wish', 36),
#  ('territory', 36),
#  ('breath', 36),
#  ('girls', 36),
#  ('straight', 36),
#  ('mood', 36),
#  ('cause', 35),
#  ('running', 35),
#  ('power', 35),
#  ('color', 35),
#  ('hair', 35),
#  ('old', 35),
#  ('comes', 35),
#  ('broken', 35),
#  ('bit', 35),
#  ('boom', 34),
#  ('falling', 34),
#  ('reserved', 34),
#  ('atmosphere', 34),
#  ('thought', 34),
#  ('throw', 34),
#  ('fast', 34),
#  ('film', 34),
#  ('talking', 34),
#  ('knows', 34),
#  ('soul', 33),
#  ('goes', 33),
#  ('saying', 33),
#  ('rights', 33),
#  ('history', 33),
#  ('darkness', 33),
#  ('blow', 33),
#  ('ma', 33),
#  ('izen', 33),
#  ('roll', 32),
#  ('burn', 32),
#  ('universe', 32),
#  ('tight', 32),
#  ('trying', 32),
#  ('help', 32),
#  ('part', 31),
#  ('eh', 31),
#  ('girlfriend', 31),
#  ('car', 31),
#  ('feelings', 31),
#  ('shake', 31),
#  ('person', 31),
#  ('moonlight', 31),
#  ('sex', 31),
#  ('rate', 31),
#  ('lips', 31),
#  ('soon', 31),
#  ('happiness', 31),
#  ('jump', 30),
#  ('yo', 30),
#  ('daily', 30),
#  ('blood', 30),
#  ('pop', 30),
#  ('mirror', 30),
#  ('colombo', 30),
#  ('reason', 30),
#  ('alive', 30),
#  ('ball', 29),
#  ('gold', 29),
#  ('special', 29),
#  ('clear', 29),
#  ('years', 29),
#  ('slow', 29),
#  ('warm', 29),
#  ('하和', 29),
#  ('choose', 29),
#  ('changed', 29),
#  ('orientation', 29),
#  ('rid', 28),
#  ('season', 28),
#  ('rousing', 28),
#  ('mature', 28),
#  ('memories', 28),
#  ('hours', 28),
#  ('sounds', 28),
#  ('magic', 28),
#  ('ha', 28),
#  ('promise', 28),
#  ('truth', 28),
#  ('wild', 27),
#  ('empty', 27),
#  ('says', 27),
#  ('waste', 27),
#  ('check', 27),
#  ('prezzo', 27),
#  ('stupid', 27),
#  ('mouth', 27),
#  ('found', 27),
#  ('던子', 27),
#  ('type', 27),
#  ('breathe', 27),
#  ('kind', 26),
#  ('snow', 26),
#  ('minute', 26),
#  ('act', 26),
#  ('shadow', 26),
#  ('times', 26),
#  ('dangerous', 26),
#  ('near', 26),
#  ('administration', 26),
#  ('hello', 26),
#  ('24', 26),
#  ('fool', 26),
#  ('whole', 26),
#  ('browse', 26),
#  ('style', 26),
#  ('winter', 26),
#  ('yeh', 26),
#  ('drink', 26),
#  ('shoot', 26),
#  ('drum', 25),
#  ('join', 25),
#  ('wall', 25),
#  ('heat', 25),
#  ('funny', 25),
#  ('space', 25),
#  ('fear', 25),
#  ('singing', 25),
#  ('reality', 25),
#  ('skip', 25),
#  ('rhythm', 25),
#  ('enjoy', 25),
#  ('hell', 25),
#  ('house', 25),
#  ('cute', 25),
#  ('losing', 25),
#  ('paradise', 25),
#  ('double', 24),
#  ('imma', 24),
#  ('diamond', 24),
#  ('king', 24),
#  ('came', 24),
#  ('shining', 24),
#  ('sharing', 24),
#  ('second', 24),
#  ('beginning', 24),
#  ('invalid', 24),
#  ('너와', 24),
#  ('ground', 24),
#  ('tear', 24),
#  ('hurt', 24),
#  ('non', 24),
#  ('higher', 24),
#  ('rest', 24),
#  ('thoughts', 24),
#  ('born', 24),
#  ('trust', 24),
#  ('closer', 23),
#  ('shoes', 23),
#  ('ring', 23),
#  ('goodbye', 23),
#  ('wonder', 23),
#  ('return', 23),
#  ('breathing', 23),
#  ('size', 23),
#  ('possible', 23),
#  ('meeting', 23),
#  ('wave', 23),
#  ('busy', 23),
#  ('important', 23),
#  ('sadness', 23),
#  ('thinking', 23),
#  ('difficult', 23),
#  ('meaning', 23),
#  ('bag', 22),
#  ('diamonds', 22),
#  ('favorite', 22),
#  ('dancing', 22),
#  ('beauty', 22),
#  ('destiny', 22),
#  ('sauna', 22),
#  ('action', 22),
#  ('lonely', 22),
#  ('middle', 22),
#  ('welcome', 22),
#  ('shit', 22),
#  ('number', 22),
#  ('heard', 22),
#  ('children', 22),
#  ('filesizehumanreadable', 22),
#  ('stage', 22),
#  ('infinite', 22),
#  ('cream', 21),
#  ('moving', 21),
#  ('speak', 21),
#  ('terms', 21),
#  ('dreaming', 21),
#  ('fake', 21),
#  ('sales', 21),
#  ('copyright', 21),
#  ('games', 21),
#  ('zione', 21),
#  ('edge', 21),
#  ('diving', 21),
#  ('gave', 21),
#  ('finally', 21),
#  ('lover', 21),
#  ('ayy', 21),
#  ('impossible', 21),
#  ('loved', 20),
#  ('tea', 20),
#  ('和만', 20),
#  ('earth', 20),
#  ('fill', 20),
#  ('nights', 20),
#  ('catch', 20),
#  ('secret', 20),
#  ('chance', 20),
#  ('stronger', 20),
#  ('met', 20),
#  ('half', 20),
#  ('zoom', 20),
#  ('mother', 20),
#  ('twice', 20),
#  ('ya', 20),
#  ('standing', 20),
#  ('si', 20),
#  ('past', 20),
#  ('means', 19),
#  ('calls', 19),
#  ('went', 19),
#  ('sleeping', 19),
#  ('bhubaneswar', 19),
#  ('sign', 19),
#  ('seen', 19),
#  ('tip', 19),
#  ('playing', 19),
#  ('buy', 19),
#  ('job', 19),
#  ('그래', 19),
#  ('burning', 19),
#  ('ok', 19),
#  ('facebook', 19),
#  ('hurry', 19),
#  ('movie', 19),
#  ('wanted', 19),
#  ('ocean', 19),
#  ('win', 19),
#  ('called', 19),
#  ('cloud', 19),
#  ('scent', 19),
#  ('area', 19),
#  ('pass', 19),
#  ('told', 19),
#  ('false', 19),
#  ('rule', 19),
#  ('crying', 19),
#  ('dad', 19),
#  ('single', 19),
#  ('language', 19),
#  ('pull', 19),
#  ('ears', 19),
#  ('notice', 19),
#  ('ladies', 18),
#  ('rise', 18),
#  ('guys', 18),
#  ('hearts', 18),
#  ('couple', 18),
#  ('10', 18),
#  ('dress', 18),
#  ('athletic', 18),
#  ('add', 18),
#  ('able', 18),
#  ('sit', 18),
#  ('모두', 18),
#  ('birthday', 18),
#  ('지和지', 18),
#  ('push', 18),
#  ('content', 18),
#  ('tag', 18),
#  ('acrylate', 18),
#  ('pink', 18),
#  ('table', 18),
#  ('perfume', 18),
#  ('street', 18),
#  ('focus', 18),
#  ('leaves', 18),
#  ('clothes', 18),
#  ('slowly', 18),
#  ('seeing', 18),
#  ('dong', 17),
#  ('heavy', 17),
#  ('boss', 17),
#  ('rules', 17),
#  ('shy', 17),
#  ('repeat', 17),
#  ('wings', 17),
#  ('identification', 17),
#  ('choice', 17),
#  ('programme', 17),
#  ('weather', 17),
#  ('bet', 17),
#  ('calm', 17),
#  ('bitter', 17),
#  ('lady', 17),
#  ('loves', 17),
#  ('organiz', 17),
#  ('fate', 17),
#  ('speed', 17),
#  ('points', 17),
#  ('filled', 17),
#  ('trouble', 17),
#  ('joy', 17),
#  ('floor', 17),
#  ('finish', 17),
#  ('test', 17),
#  ('cherry', 16),
#  ('rolling', 16),
#  ('stone', 16),
#  ('boys', 16),
#  ('round', 16),
#  ('feels', 16),
#  ('puri', 16),
#  ('activities', 16),
#  ('queen', 16),
#  ('stand', 16),
#  ('sunset', 16),
#  ('serves', 16),
#  ('candy', 16),
#  ('rice', 16),
#  ('desire', 16),
#  ('dimensions', 16),
#  ('making', 16),
#  ('crown', 16),
#  ('problems', 16),
#  ('caught', 16),
#  ('message', 16),
#  ('draw', 16),
#  ('gon', 16),
#  ('sweat', 16),
#  ('dog', 16),
#  ('hesitate', 16),
#  ('simple', 16),
#  ('list', 16),
#  ('board', 16),
#  ('butterfly', 16),
#  ('worried', 16),
#  ('write', 16),
#  ('piece', 15),
#  ('bringing', 15),
#  ('gentlemen', 15),
#  ('business', 15),
#  ('limit', 15),
#  ('blackpink', 15),
#  ('bigger', 15),
#  ('konark', 15),
#  ('doubt', 15),
#  ('drunk', 15),
#  ('chocolate', 15),
#  ('grow', 15),
#  ('happens', 15),
#  ('super', 15),
#  ('finished', 15),
#  ('island', 15),
#  ('expression', 15),
#  ('sugar', 15),
#  ('bomb', 15),
#  ('fireworks', 15),
#  ('deeper', 15),
#  ('team', 15),
#  ('del', 15),
#  ('hero', 15),
#  ('short', 15),
#  ('ta', 15),
#  ('luck', 15),
#  ('click', 15),
#  ('wing', 15),
#  ('shoulder', 15),
#  ('attitude', 15),
#  ('lord', 15),
#  ('yellow', 15),
#  ('couldn', 15),
#  ('seoul', 15),
#  ('tried', 15),
#  ('evil', 15),
#  ('ora', 15),
#  ('beats', 15),
#  ('rainbow', 15),
#  ('stops', 15),
#  ('scene', 15),
#  ('disappear', 15),
#  ('lying', 15),
#  ('arms', 15),
#  ('steps', 15),
#  ('gauze', 15),
#  ('value', 15),
#  ('dive', 14),
#  ('ding', 14),
#  ('ping', 14),
#  ('cut', 14),
#  ('dreamed', 14),
#  ('fantasy', 14),
#  ('cake', 14),
#  ('teenagers', 14),
#  ('spirit', 14),
#  ('burns', 14),
#  ('final', 14),
#  ('nurse', 14),
#  ('lucky', 14),
#  ('may', 14),
#  ('flashing', 14),
#  ('rainy', 14),
#  ('temperature', 14),
#  ('haters', 14),
#  ('smoking', 14),
#  ('sense', 14),
#  ('glass', 14),
#  ('su', 14),
#  ('smooth', 14),
#  ('coffee', 14),
#  ('scream', 14),
#  ('case', 14),
#  ('attention', 14),
#  ('faster', 14),
#  ('pretty', 14),
#  ('angel', 14),
#  ('fault', 14),
#  ('weird', 14),
#  ('fingers', 14),
#  ('mistake', 14),
#  ('distance', 14),
#  ('bounce', 14),
#  ('date', 14),
#  ('food', 14),
#  ('success', 14),
#  ('yesterday', 14),
#  ('interested', 14),
#  ('bass', 13),
#  ('cup', 13),
#  ('speech', 13),
#  ('attempted', 13),
#  ('idea', 13),
#  ('camera', 13),
#  ('email', 13),
#  ('million', 13),
#  ('bye', 13),
#  ('tells', 13),
#  ('lighter', 13),
#  ('bae', 13),
#  ('energy', 13),
#  ('pow', 13),
#  ('calling', 13),
#  ('match', 13),
#  ('forgotten', 13),
#  ('rush', 13),
#  ('reading', 13),
#  ('waves', 13),
#  ('mic', 13),
#  ('took', 13),
#  ('continues', 13),
#  ('devil', 13),
#  ('laughing', 13),
#  ('corner', 13),
#  ('imagination', 13),
#  ('dead', 13),
#  ('della', 13),
#  ('hour', 13),
#  ('noise', 13),
#  ('whoo', 13),
#  ('trip', 13),
#  ('river', 13),
#  ('guess', 13),
#  ('surprised', 13),
#  ('champagne', 13),
#  ('gaelic', 13),
#  ('scots', 13),
#  ('whoa', 13),
#  ('level', 13),
#  ('relax', 13),
#  ('situation', 13),
#  ('spend', 13),
#  ('shines', 13),
#  ('closed', 13),
#  ('negative', 13),
#  ('solo', 13),
#  ('passion', 13),
#  ('appearance', 13),
#  ('causes', 13),
#  ('gives', 13),
#  ('covered', 13),
#  ('class', 13),
#  ('clean', 13),
#  ('sin', 13),
#  ('flying', 12),
#  ('cha', 12),
#  ('crowd', 12),
#  ('kong', 12),
#  ('medicine', 12),
#  ('spit', 12),
#  ('missed', 12),
#  ('video', 12),
#  ('mi', 12),
#  ('bed', 12),
#  ('mobile', 12),
#  ('movement', 12),
#  ('order', 12),
#  ('york', 12),
#  ('blah', 12),
#  ('photo', 12),
#  ('wanna', 12),
#  ('loud', 12),
#  ('family', 12),
#  ('tv', 12),
#  ('taken', 12),
#  ('imagine', 12),
#  ('sexy', 12),
#  ('rose', 12),
#  ('blowing', 12),
#  ('woman', 12),
#  ('em', 12),
#  ('map', 12),
#  ('satisfied', 12),
#  ('un', 12),
#  ('bam', 12),
#  ('butterflies', 12),
#  ('fashion', 12),
#  ('glad', 12),
#  ('flash', 12),
#  ('dry', 12),
#  ('quiet', 12),
#  ('iron', 12),
#  ('key', 12),
#  ('scary', 12),
#  ('fair', 12),
#  ('hole', 12),
#  ('shot', 12),
#  ('careful', 12),
#  ('difference', 12),
#  ('dirty', 12),
#  ('persons', 12),
#  ('natural', 12),
#  ('healing', 12),
#  ('faith', 12),
#  ('sunday', 12),
#  ('country', 12),
#  ('forest', 12),
#  ('enemy', 12),
#  ('amazing', 12),
#  ('member', 12),
#  ('training', 12),
#  ('honest', 12),
#  ('men', 12),
#  ('dynamite', 11),
#  ('milk', 11),
#  ('death', 11),
#  ('danger', 11),
#  ('likes', 11),
#  ('bird', 11),
#  ('shadows', 11),
#  ('signs', 11),
#  ('매일', 11),
#  ('pour', 11),
#  ('lighting', 11),
#  ('monster', 11),
#  ('celebrate', 11),
#  ('angry', 11),
#  ('drive', 11),
#  ('toc', 11),
#  ('keeps', 11),
#  ('piracy', 11),
#  ('니和까', 11),
#  ('youth', 11),
#  ('autumn', 11),
#  ('rollin', 11),
#  ('rewind', 11),
#  ('flight', 11),
#  ('nah', 11),
#  ('missing', 11),
#  ('wonderful', 11),
#  ('damn', 11),
#  ('foot', 11),
#  ('categories', 11),
#  ('watching', 11),
#  ('니和', 11),
#  ('ey', 11),
#  ('knock', 11),
#  ('lana', 11),
#  ('bottom', 11),
#  ('fan', 11),
#  ('yah', 11),
#  ('escape', 11),
#  ('swear', 11),
#  ('journey', 11),
#  ('prepare', 11),
#  ('오늘', 11),
#  ('ahead', 11),
#  ('self', 11),
#  ('scared', 11),
#  ('하和하', 11),
#  ('fog', 11),
#  ('challenge', 11),
#  ('started', 11),
#  ('race', 11),
#  ('criminal', 11),
#  ('garden', 11),
#  ('week', 11),
#  ('supposed', 11),
#  ('tie', 11),
#  ('track', 11),
#  ('starting', 11),
#  ('teach', 11),
#  ('reach', 11),
#  ('school', 11),
#  ('frozen', 10),
#  ('needs', 10),
#  ('surprise', 10),
#  ('wrist', 10),
#  ('ching', 10),
#  ('overload', 10),
#  ('pong', 10),
#  ('drip', 10),
#  ('heartbeat', 10),
#  ('riding', 10),
#  ('tariffa', 10),
#  ('changes', 10),
#  ('drama', 10),
#  ('block', 10),
#  ('create', 10),
#  ('menu', 10),
#  ('reaction', 10),
#  ('soft', 10),
#  ('paris', 10),
#  ('original', 10),
#  ('awake', 10),
#  ('window', 10),
#  ('flame', 10),
#  ('enter', 10),
#  ('lee', 10),
#  ('boo', 10),
#  ('fuck', 10),
#  ('later', 10),
#  ('skin', 10),
#  ('zero', 10),
#  ('nose', 10),
#  ('snowy', 10),
#  ('point', 10),
#  ('handle', 10),
#  ('rough', 10),
#  ('trophy', 10),
#  ('和지', 10),
#  ('모든', 10),
#  ('proud', 10),
#  ('cookies', 10),
#  ('page', 10),
#  ('advice', 10),
#  ('month', 10),
#  ('landscape', 10),
#  ('너무', 10),
#  ('isolated', 10),
#  ('discover', 10),
#  ('dna', 10),
#  ('moments', 10),
#  ('relationship', 10),
#  ('smiling', 10),
#  ('mode', 10),
#  ('ho', 10),
#  ('roller', 10),
#  ('던和', 10),
#  ('bling', 10),
#  ('raise', 10),
#  ('hiding', 10),
#  ('gun', 10),
#  ('happened', 10),
#  ('heal', 10),
#  ('pay', 10),
#  ('日本語', 10),
#  ('excuse', 10),
#  ('habit', 10),
#  ('che', 10),
#  ('te', 10),
#  ('traduzione', 10),
#  ('emotion', 10),
#  ('force', 10),
#  ('legs', 10),
#  ('kid', 10),
#  ('desert', 10),
#  ('umm', 10),
#  ('weight', 10),
#  ('trapped', 10),
#  ('english', 10),
#  ('passed', 10),
#  ('incredible', 10),
#  ('land', 10),
#  ('kuala', 10),
#  ('lumpur', 10),
#  ('fighting', 10)]

# %%
tfidf_summer_kpop = sort_dictionary(summer)
tfidf_summer_kpop
# Out:
# [('love', 93.38607915430586),
#  ('home', 67.60988950474074),
#  ('sorry', 50.59637894638318),
#  ('let', 47.93110110384121),
#  ('heart', 41.116791964066365),
#  ('yes', 41.10677536323856),
#  ('baby', 38.186684222047816),
#  ('news', 31.517989144550324),
#  ('feel', 31.44896588575648),
#  ('night', 31.329232070269644),
#  ('say', 29.465943981617627),
#  ('back', 28.917235907807306),
#  ('only', 27.346261757010232),
#  ('eyes', 27.17744214823235),
#  ('think', 25.90023701555005),
#  ('follow', 25.761256945043133),
#  ('need', 25.761205628558344),
#  ('world', 25.658269008485153),
#  ('한국', 25.315827692846227),
#  ('am', 24.95654988991367),
#  ('take', 24.1156828940417),
#  ('life', 23.881421538952736),
#  ('give', 23.697773262598623),
#  ('new', 23.122089100039577),
#  ('ah', 22.84938734799792),
#  ('dream', 22.769037842367304),
#  ('light', 22.613825747417657),
#  ('dance', 21.8695620276186),
#  ('tell', 21.632868387047996),
#  ('woo', 21.403899689771514),
#  ('boy', 20.841865832124057),
#  ('leave', 20.144998389279486),
#  ('room', 19.638057578267343),
#  ('hot', 19.332288831276525),
#  ('girl', 19.29051998397683),
#  ('way', 19.103128236621465),
#  ('call', 18.920389075986577),
#  ('child', 18.817980201517823),
#  ('end', 18.290677611797832),
#  ('bad', 18.147092709360518),
#  ('keep', 17.554573774978365),
#  ('hands', 17.104031122001004),
#  ('stay', 16.890448992365382),
#  ('find', 16.602703375048193),
#  ('down', 16.358640764264603),
#  ('still', 15.95807682512521),
#  ('mind', 15.949872245087107),
#  ('shut', 15.876440422823134),
#  ('ooh', 15.564286782989871),
#  ('contact', 15.433486636308757),
#  ('crazy', 15.368729566270755),
#  ('honey', 15.254778070147609),
#  ('away', 15.088861252874388),
#  ('little', 14.927620579904335),
#  ('run', 14.888307056442782),
#  ('show', 14.766151614235756),
#  ('happy', 14.743040384521555),
#  ('alone', 14.71060397239347),
#  ('looking', 14.67387986919005),
#  ('best', 14.56895222188019),
#  ('today', 14.383525336664766),
#  ('hear', 14.368894868453907),
#  ('sweet', 14.355570130023187),
#  ('wait', 14.350122931770173),
#  ('fire', 14.333358033049466),
#  ('price_varies', 13.990008303341392),
#  ('god', 13.934322591502664),
#  ('sky', 13.907958825284917),
#  ('share', 13.812355348074936),
#  ('beautiful', 13.557837596909218),
#  ('touch', 13.548117586830209),
#  ('man', 13.537823838737934),
#  ('care', 13.514798610836062),
#  ('mine', 13.419526022162808),
#  ('play', 13.413091374858391),
#  ('worry', 13.245447532549669),
#  ('fall', 13.146105925796057),
#  ('ready', 13.129977730789047),
#  ('meet', 13.090658031345091),
#  ('music', 12.559100221759477),
#  ('fly', 12.461023874461597),
#  ('start', 12.125465638835582),
#  ('okay', 11.97070376516271),
#  ('sleep', 11.792268949456389),
#  ('wow', 11.770288120145077),
#  ('true', 11.627994944948538),
#  ('change', 11.558640166775044),
#  ('feeling', 11.398422500204582),
#  ('cry', 11.353810251099993),
#  ('break', 11.310131355357784),
#  ('bang', 11.257421817417663),
#  ('comment', 11.252209908554713),
#  ('live', 11.23244310542523),
#  ('name', 10.993916582561795),
#  ('blue', 10.91905762408152),
#  ('star', 10.909501738121884),
#  ('fine', 10.891365160818701),
#  ('easy', 10.837974448602536),
#  ('invalid', 10.825563347198736),
#  ('last', 10.72664980271169),
#  ('hand', 10.691176643625619),
#  ('tonight', 10.597797741209009),
#  ('move', 10.589251051123638),
#  ('didn', 10.512858844531738),
#  ('matter', 10.502832872736303),
#  ('sun', 10.464836398231526),
#  ('waiting', 10.458246854576494),
#  ('put', 10.363682549106931),
#  ('universe', 10.345806867871735),
#  ('doesn', 10.243262851637589),
#  ('eh', 10.235018057452269),
#  ('body', 10.196525014546312),
#  ('한국어', 10.123841604766923),
#  ('thank', 10.119937768481524),
#  ('high', 10.022817097380823),
#  ('ay', 9.948094588450463),
#  ('top', 9.813462325210645),
#  ('first', 9.812168112471008),
#  ('work', 9.80041259339878),
#  ('dreams', 9.688398879052887),
#  ('ve', 9.636396665393782),
#  ('once', 9.532240425872464),
#  ('babe', 9.515281706147132),
#  ('informazioni', 9.513382553273026),
#  ('hit', 9.340845595419786),
#  ('smile', 9.181088633952296),
#  ('agriculture', 9.180950479342687),
#  ('morning', 9.101663649250826),
#  ('moon', 9.052746318142603),
#  ('side', 9.036446836521584),
#  ('deep', 8.96765854916842),
#  ('song', 8.882177275760542),
#  ('il', 8.872195047604768),
#  ('people', 8.864796850057768),
#  ('miss', 8.84238255587571),
#  ('believe', 8.838658240701573),
#  ('face', 8.82543672801007),
#  ('real', 8.756854466004462),
#  ('teen', 8.734191026225036),
#  ('read', 8.714247852967029),
#  ('talk', 8.691772100793244),
#  ('words', 8.623911137253561),
#  ('boom', 8.602566699609273),
#  ('city', 8.527937835919664),
#  ('shine', 8.514645929312112),
#  ('head', 8.49526433340252),
#  ('dark', 8.487965538943328),
#  ('을和', 8.478981026869779),
#  ('turn', 8.46294769167712),
#  ('well', 8.424930786434842),
#  ('remember', 8.410794978018627),
#  ('next', 8.388625959107973),
#  ('left', 8.38773075662013),
#  ('long', 8.385384247883339),
#  ('flower', 8.323279603369),
#  ('summer', 8.317944996799554),
#  ('uh', 8.282138314331464),
#  ('forget', 8.217409374054904),
#  ('lost', 8.196395677704574),
#  ('young', 8.187782854269761),
#  ('place', 8.142006345588317),
#  ('twitter', 8.127706444983684),
#  ('stars', 8.117668112698532),
#  ('di', 8.108299481312885),
#  ('won', 8.094192419300708),
#  ('coming', 8.086662501876186),
#  ('moment', 8.07934837246351),
#  ('reply', 7.96439412415359),
#  ('cold', 7.924455358918411),
#  ('save', 7.868042315677496),
#  ('rain', 7.851592948267744),
#  ('wind', 7.84506012429818),
#  ('close', 7.829256146556961),
#  ('free', 7.809537100894445),
#  ('nice', 7.772918527007327),
#  ('sick', 7.768925969383261),
#  ('story', 7.711559062565221),
#  ('girls', 7.687310532519872),
#  ('hard', 7.63259128306323),
#  ('friend', 7.622986374872701),
#  ('wish', 7.618849923265444),
#  ('walking', 7.610992857830518),
#  ('made', 7.605500013530683),
#  ('money', 7.581179697719145),
#  ('united', 7.515783295996369),
#  ('pain', 7.513164674704605),
#  ('full', 7.503959127049541),
#  ('black', 7.471800057754096),
#  ('fun', 7.411830083623142),
#  ('days', 7.400209218804483),
#  ('future', 7.399808241543865),
#  ('price', 7.391320036567757),
#  ('road', 7.38327563951027),
#  ('hate', 7.3557297148815675),
#  ('red', 7.331295253362022),
#  ('hold', 7.242549285425461),
#  ('listen', 7.147328420684191),
#  ('party', 7.117168842831643),
#  ('kill', 7.114186734826969),
#  ('understand', 7.112978455484387),
#  ('afraid', 7.0492013236675986),
#  ('line', 7.045561782233353),
#  ('big', 7.044364288118592),
#  ('um', 7.034204912794293),
#  ('lose', 6.965379475363242),
#  ('laughter', 6.962179260389394),
#  ('voice', 6.929836577657374),
#  ('cancel', 6.9270516824237065),
#  ('hi', 6.925313234032744),
#  ('anymore', 6.923767716384962),
#  ('stanza', 6.897658241632226),
#  ('flowers', 6.891767682963857),
#  ('tomorrow', 6.860776727709953),
#  ('die', 6.852224076046518),
#  ('continue', 6.841422221489004),
#  ('try', 6.820520442055312),
#  ('girlfriend', 6.816300785886704),
#  ('ice', 6.793225235595424),
#  ('walk', 6.776627592218197),
#  ('non', 6.691772665976012),
#  ('sure', 6.691233540148167),
#  ('kingdom', 6.689357413712806),
#  ('control', 6.6643907878050275),
#  ('heaven', 6.6587286255743425),
#  ('laugh', 6.598660161011057),
#  ('year', 6.558814710221888),
#  ('far', 6.556741476130983),
#  ('living', 6.543157030546186),
#  ('compare_at_price_min', 6.525929827375609),
#  ('spring', 6.498166636381949),
#  ('cool', 6.4680552595835925),
#  ('woah', 6.4502214454172595),
#  ('price_min', 6.416631550263316),
#  ('lie', 6.37512828495972),
#  ('skills', 6.374395858571429),
#  ('word', 6.3689690339513065),
#  ('power', 6.360465941190894),
#  ('tags', 6.355807778122295),
#  ('step', 6.354033676663763),
#  ('sing', 6.341815845153399),
#  ('kiss', 6.336117845176811),
#  ('yeh', 6.333207173496716),
#  ('cuz', 6.317978520897443),
#  ('air', 6.302295292769639),
#  ('hidden', 6.301439822300644),
#  ('bring', 6.213439824857899),
#  ('butterfly', 6.192431069069759),
#  ('mean', 6.183782389496738),
#  ('falling', 6.041895344812905),
#  ('memory', 6.016734856198209),
#  ('working', 6.006078102654883),
#  ('drunk', 6.003980933212149),
#  ('rousing', 5.995532728955026),
#  ('questions', 5.947477015554207),
#  ('pop', 5.939933054704523),
#  ('front', 5.937978514636398),
#  ('organization', 5.935218082119536),
#  ('running', 5.905764186450393),
#  ('set', 5.896553527644436),
#  ('winter', 5.889311749837931),
#  ('strong', 5.876257999103573),
#  ('drop', 5.875548615481146),
#  ('ride', 5.855860806329533),
#  ('answer', 5.841317834911313),
#  ('mom', 5.830040251685191),
#  ('makes', 5.825846021378342),
#  ('eye', 5.810216855128253),
#  ('great', 5.796393603501051),
#  ('wrong', 5.772217299264218),
#  ('door', 5.766892732942613),
#  ('small', 5.74358065398113),
#  ('bomb', 5.723947597567969),
#  ('guy', 5.653485368453088),
#  ('feet', 5.6328619828752355),
#  ('directly', 5.602971301710254),
#  ('subscribe', 5.602222981601889),
#  ('open', 5.591372769077467),
#  ('moonlight', 5.581582089904134),
#  ('password', 5.565361134385695),
#  ('perfect', 5.55611115909885),
#  ('tears', 5.554783825852814),
#  ('ha', 5.527089282531758),
#  ('question', 5.504315439998264),
#  ('forgot', 5.481567099922188),
#  ('24', 5.4302099230337255),
#  ('territory', 5.385828225187018),
#  ('beat', 5.37105117242559),
#  ('trust', 5.355028893464513),
#  ('goodbye', 5.337342021039275),
#  ('traduzione', 5.335400222227713),
#  ('google', 5.3323712806357095),
#  ('gonna', 5.324688158355394),
#  ('special', 5.300599386255083),
#  ('problem', 5.270696103356292),
#  ('shoot', 5.255848202038921),
#  ('soul', 5.242295527866851),
#  ('jump', 5.224146915996806),
#  ('water', 5.219383967071781),
#  ('dawn', 5.219284053833287),
#  ('stupid', 5.200997648012472),
#  ('pantyhose', 5.196973652688281),
#  ('rock', 5.186445755220828),
#  ('fake', 5.1835651414049035),
#  ('reason', 5.17408975882361),
#  ('lips', 5.165187693065238),
#  ('stronger', 5.1598331353385065),
#  ('burn', 5.147517301159786),
#  ('candy', 5.147121752072529),
#  ('bit', 5.1458825721212476),
#  ('inquiry', 5.143358107518125),
#  ('cause', 5.140435201975912),
#  ('snow', 5.131471830886522),
#  ('hope', 5.1212033665837815),
#  ('looks', 5.113484993957511),
#  ('sea', 5.112057628411802),
#  ('wild', 5.107144325200114),
#  ('straight', 5.106770296402336),
#  ('hide', 5.090840528361711),
#  ('help', 5.088321097512838),
#  ('mic', 5.068373891587723),
#  ('blood', 5.026348941820617),
#  ('hours', 5.011724081884984),
#  ('roll', 5.010316717902214),
#  ('sound', 5.00168565994545),
#  ('data', 4.97580733589501),
#  ('choose', 4.925504209288344),
#  ('friends', 4.914371297275173),
#  ('ya', 4.873792880772992),
#  ('maybe', 4.871100130839086),
#  ('dad', 4.82311445232896),
#  ('soon', 4.816272060522927),
#  ('being', 4.81160774275302),
#  ('dynamite', 4.791856021048851),
#  ('view', 4.759836537617749),
#  ('ta', 4.731013445692923),
#  ('singing', 4.723822054046909),
#  ('person', 4.711167481169442),
#  ('tear', 4.697888351483105),
#  ('rhythm', 4.688859035363074),
#  ('generating', 4.681742129479661),
#  ('fast', 4.659692777272733),
#  ('second', 4.657965995406859),
#  ('magic', 4.653953990038237),
#  ('phone', 4.645899765245046),
#  ('shining', 4.641818069292448),
#  ('ma', 4.629135025226686),
#  ('mood', 4.625028308252145),
#  ('says', 4.616269701174723),
#  ('inside', 4.6101873578530945),
#  ('wake', 4.597347141825641),
#  ('zoom', 4.596280085937116),
#  ('sad', 4.573598143001125),
#  ('ask', 4.572790796380749),
#  ('tired', 4.551932839557312),
#  ('cream', 4.533454364300584),
#  ('izen', 4.533142942359151),
#  ('flow', 4.516487731032968),
#  ('watch', 4.512196734509547),
#  ('wants', 4.512075968231176),
#  ('하和', 4.508411329235495),
#  ('chest', 4.466161638712942),
#  ('bam', 4.463915036902338),
#  ('slow', 4.461281905654522),
#  ('lights', 4.459935388443436),
#  ('hell', 4.45770810028063),
#  ('rate', 4.454190042353677),
#  ('ago', 4.451661546784511),
#  ('old', 4.442460505592839),
#  ('game', 4.427531887103631),
#  ('fight', 4.417212931032907),
#  ('sadness', 4.414616495146302),
#  ('knock', 4.403971032452724),
#  ('ring', 4.400291499844474),
#  ('years', 4.392250522506211),
#  ('forward', 4.388465488882841),
#  ('hair', 4.383331116337967),
#  ('hello', 4.377936925608705),
#  ('eat', 4.340568698210226),
#  ('comes', 4.335109495959255),
#  ('broken', 4.321727775521623),
#  ('finally', 4.313043052494902),
#  ('gold', 4.302167251761531),
#  ('promise', 4.297562580520384),
#  ('leaving', 4.279300146495176),
#  ('imma', 4.271773682388712),
#  ('saw', 4.257866656230084),
#  ('memories', 4.248219418125121),
#  ('taste', 4.247435118743285),
#  ('fool', 4.243104843642441),
#  ('empty', 4.242238632412699),
#  ('lee', 4.241983741223535),
#  ('yo', 4.206691447554683),
#  ('learn', 4.177102221329798),
#  ('warm', 4.169008267246533),
#  ('whole', 4.1589581871000325),
#  ('goes', 4.158527192271812),
#  ('truth', 4.143841257013732),
#  ('ayy', 4.143691243523743),
#  ('mouth', 4.1355124333514075),
#  ('found', 4.1346990354657756),
#  ('white', 4.119738160613402),
#  ('late', 4.115390732759691),
#  ('higher', 4.113911801582214),
#  ('feelings', 4.112497594089441),
#  ('breath', 4.094863994604614),
#  ('knows', 4.078161633035206),
#  ('shy', 4.077203275080897),
#  ('color', 4.048596809949844),
#  ('bag', 4.037395596012342),
#  ('push', 4.026867551853559),
#  ('style', 4.018512050124543),
#  ('sex', 4.012930665843825),
#  ('lover', 4.012342537205054),
#  ('history', 4.006204920716553),
#  ('happiness', 3.9949624078437793),
#  ('blow', 3.9941680973491045),
#  ('della', 3.9801646448275276),
#  ('bright', 3.970005668703084),
#  ('hero', 3.964570253539548),
#  ('saying', 3.9589271266563917),
#  ('atmosphere', 3.9577785985372103),
#  ('low', 3.9558504012698146),
#  ('rid', 3.9531695849339243),
#  ('super', 3.9503350044451517),
#  ('part', 3.9466744878469324),
#  ('crying', 3.946611271179421),
#  ('thought', 3.9351437526291013),
#  ('wall', 3.9336971257424036),
#  ('click', 3.931888432006465),
#  ('fresh', 3.931291802386774),
#  ('funny', 3.916006088636849),
#  ('wave', 3.896057968543399),
#  ('queen', 3.8816820786413455),
#  ('darkness', 3.862918664440544),
#  ('orientation', 3.8328842843502136),
#  ('woman', 3.832441585790882),
#  ('hurt', 3.8320157694666737),
#  ('talking', 3.8259564706639506),
#  ('dangerous', 3.818693662933846),
#  ('blackpink', 3.818533815500785),
#  ('welcome', 3.810516727339092),
#  ('sounds', 3.7982711273027583),
#  ('breathe', 3.7977515267761994),
#  ('film', 3.78440643560584),
#  ('shake', 3.7706043864847554),
#  ('house', 3.7494258825423925),
#  ('clear', 3.744217994003705),
#  ('dancing', 3.7350634261089333),
#  ('rest', 3.734167975369572),
#  ('diamond', 3.7052147692508965),
#  ('dna', 3.692124159077543),
#  ('type', 3.6920719084973768),
#  ('thinking', 3.6809441732173434),
#  ('beauty', 3.657198387077874),
#  ('daily', 3.6490140540562357),
#  ('colombo', 3.643238716243076),
#  ('guys', 3.6416098023274226),
#  ('bye', 3.636419902845689),
#  ('reality', 3.625669617537397),
#  ('10', 3.616275224479464),
#  ('filesizehumanreadable', 3.59751863559428),
#  ('secret', 3.5794043855746),
#  ('season', 3.57598507696479),
#  ('throw', 3.573447739608198),
#  ('reserved', 3.570918408862963),
#  ('boys', 3.5399858874557375),
#  ('mirror', 3.5276844724451895),
#  ('drink', 3.5249588163056775),
#  ('scream', 3.521037230069803),
#  ('job', 3.517372678256899),
#  ('add', 3.510364489554691),
#  ('birthday', 3.4985282523975703),
#  ('alive', 3.468185994717833),
#  ('ok', 3.4617526572710657),
#  ('sugar', 3.4458597568771143),
#  ('changed', 3.4404271965369277),
#  ('bringing', 3.432785439782635),
#  ('standing', 3.430173121714992),
#  ('losing', 3.412576002353717),
#  ('rights', 3.412386089802638),
#  ('came', 3.3804749804240517),
#  ('joy', 3.371817703473832),
#  ('missed', 3.3681444292059575),
#  ('beginning', 3.3625220497915635),
#  ('和만', 3.36002565528883),
#  ('paradise', 3.3513739418635295),
#  ('dreaming', 3.3494106565137387),
#  ('times', 3.340910663371538),
#  ('sauna', 3.335436361762134),
#  ('em', 3.313866916264711),
#  ('destiny', 3.3137911798032413),
#  ('tight', 3.3059818922688935),
#  ('double', 3.3015139104999705),
#  ('bet', 3.283045190492702),
#  ('cute', 3.278813202237623),
#  ('browse', 3.277956745800227),
#  ('car', 3.255348547595547),
#  ('meaning', 3.255342296504672),
#  ('loved', 3.2501749916718943),
#  ('space', 3.2444749943589373),
#  ('waste', 3.243914465418712),
#  ('mature', 3.2318363414481386),
#  ('training', 3.22203016909621),
#  ('lucky', 3.215954897402657),
#  ('children', 3.196013596675251),
#  ('prezzo', 3.193247416366393),
#  ('disappear', 3.1797188907135174),
#  ('mi', 3.177590368078973),
#  ('favorite', 3.173942990131192),
#  ('thoughts', 3.172500812754124),
#  ('trying', 3.169926229937362),
#  ('yellow', 3.164178591556627),
#  ('closer', 3.159049292559501),
#  ('chance', 3.1583703126159555),
#  ('gauze', 3.152831526909691),
#  ('whoo', 3.148999867349087),
#  ('born', 3.1442023090287265),
#  ('hurry', 3.1408978487612256),
#  ('team', 3.132634067360323),
#  ('list', 3.114665222359086),
#  ('called', 3.1130908560249493),
#  ('movie', 3.1016166275293626),
#  ('ball', 3.06989144987925),
#  ('able', 3.0689267070317374),
#  ('wing', 3.0589063614416836),
#  ('diving', 3.051495569019286),
#  ('blah', 3.0455985484447217),
#  ('board', 3.0437809653336285),
#  ('number', 3.043392080566774),
#  ('pink', 3.034755669309782),
#  ('wings', 3.0338075604573045),
#  ('nah', 3.019357947509415),
#  ('stage', 3.008020386105706),
#  ('gave', 3.0059460918573166),
#  ('burning', 2.9922246548025146),
#  ('tip', 2.989677096119731),
#  ('administration', 2.9881705941002545),
#  ('seen', 2.9822448302757647),
#  ('skip', 2.9815936525212616),
#  ('dirty', 2.9756995760403626),
#  ('minute', 2.964276314432261),
#  ('met', 2.9477054717721143),
#  ('wonder', 2.9438312699490012),
#  ('diamonds', 2.9405445052150325),
#  ('floor', 2.937776656667282),
#  ('distance', 2.935096701667012),
#  ('meeting', 2.9343926237715245),
#  ('sales', 2.9167730752889995),
#  ('win', 2.9090812766063046),
#  ('그래', 2.907592249540381),
#  ('million', 2.898565082768958),
#  ('bae', 2.888624481537989),
#  ('near', 2.868036230578355),
#  ('boo', 2.8603200148780217),
#  ('island', 2.8572885884277452),
#  ('simple', 2.84725693093134),
#  ('zione', 2.844746209752935),
#  ('rush', 2.816261310004027),
#  ('area', 2.8057711084071344),
#  ('heard', 2.7997691904602506),
#  ('earth', 2.788432121548021),
#  ('lana', 2.7672750819417207),
#  ('enjoy', 2.7451426467923956),
#  ('hearts', 2.72857394627207),
#  ('rose', 2.726267972472409),
#  ('bounce', 2.720847844588037),
#  ('heat', 2.718316443030281),
#  ('waves', 2.7174248573497093),
#  ('date', 2.7147097106458498),
#  ('ho', 2.713415282854923),
#  ('street', 2.7096713267212866),
#  ('lady', 2.7069462159047397),
#  ('sunday', 2.703640568923885),
#  ('sexy', 2.7004861204814743),
#  ('ocean', 2.7002007176973892),
#  ('business', 2.6971813069436923),
#  ('scent', 2.6941439070615107),
#  ('join', 2.681998774844071),
#  ('check', 2.6792435733667586),
#  ('toc', 2.6784343109473254),
#  ('si', 2.6743922168156553),
#  ('action', 2.6741035568233884),
#  ('angel', 2.662230716342069),
#  ('del', 2.6558973603669602),
#  ('seoul', 2.65515332511838),
#  ('던子', 2.651508225393351),
#  ('half', 2.648095525448964),
#  ('flying', 2.6465207052202278),
#  ('went', 2.642354393230264),
#  ('ground', 2.641925598132555),
#  ('enemy', 2.634671613537888),
#  ('single', 2.6257300493465907),
#  ('bird', 2.6154889730520274),
#  ('breathing', 2.615387585866118),
#  ('bling', 2.6139504577310353),
#  ('doubt', 2.606989923886039),
#  ('bottom', 2.6055688511078627),
#  ('fear', 2.5830753040111567),
#  ('sharing', 2.58209838843045),
#  ('wanted', 2.580213392242056),
#  ('monster', 2.576885602832081),
#  ('language', 2.5750581443025986),
#  ('mother', 2.574560978228188),
#  ('dimensions', 2.5691618311012965),
#  ('return', 2.568894815243534),
#  ('rules', 2.5669699252894245),
#  ('fill', 2.563073681383283),
#  ('hole', 2.5608498736373044),
#  ('weather', 2.5373592283240045),
#  ('past', 2.533889617712309),
#  ('solo', 2.5325163243262425),
#  ('middle', 2.527483218692792),
#  ('act', 2.5258772313562043),
#  ('너와', 2.5169842068426074),
#  ('haters', 2.515919582186361),
#  ('lonely', 2.5134892830631514),
#  ('edge', 2.507652762596504),
#  ('tag', 2.505963616728013),
#  ('rule', 2.5020491426217295),
#  ('desire', 2.491087258094873),
#  ('games', 2.4869650975273543),
#  ('problems', 2.4864044619867403),
#  ('write', 2.483378077729766),
#  ('nights', 2.479610210961068),
#  ('evil', 2.4793661842732346),
#  ('difficult', 2.4734010776784685),
#  ('lying', 2.4724972925458846),
#  ('seeing', 2.469592093744412),
#  ('weird', 2.454547253510991),
#  ('athletic', 2.4536042614928495),
#  ('yah', 2.4507952538634665),
#  ('bhubaneswar', 2.4503427542937226),
#  ('final', 2.4494698046369177),
#  ('bitter', 2.4429113605751587),
#  ('kind', 2.4385736985480198),
#  ('slowly', 2.4356991156163916),
#  ('fireworks', 2.4346747727251667),
#  ('test', 2.4337569900437908),
#  ('beats', 2.426141672851327),
#  ('busy', 2.4243679185434637),
#  ('boss', 2.421141387871898),
#  ('noise', 2.4171922531973715),
#  ('mistake', 2.416391276774066),
#  ('success', 2.4121325062520436),
#  ('un', 2.410015986336651),
#  ('flashing', 2.404618840495557),
#  ('later', 2.3946569150303763),
#  ('cloud', 2.3943574750267302),
#  ('rainy', 2.38368615686622),
#  ('ladies', 2.3802815257016547),
#  ('point', 2.3763795328469492),
#  ('corner', 2.3741920959430964),
#  ('rewind', 2.369589258101477),
#  ('shit', 2.3657491205114396),
#  ('지和지', 2.3576157917231217),
#  ('caught', 2.356119544464807),
#  ('healing', 2.355813159773968),
#  ('clothes', 2.342195295804187),
#  ('making', 2.332454097133172),
#  ('categories', 2.3308115882565277),
#  ('river', 2.326424821686339),
#  ('glass', 2.3262318478124278),
#  ('mode', 2.3183576363121743),
#  ('attention', 2.317739916319405),
#  ('shadow', 2.3155452172219695),
#  ('facebook', 2.3153320465641296),
#  ('continues', 2.314098354524049),
#  ('tea', 2.310008407778985),
#  ('rolling', 2.3088042363776227),
#  ('cake', 2.3017605322352956),
#  ('dress', 2.298161179572148),
#  ('smooth', 2.296637708873215),
#  ('hesitate', 2.289669325425774),
#  ('loud', 2.2883960852720535),
#  ('content', 2.2817671048879844),
#  ('youth', 2.2781288426711526),
#  ('race', 2.2729040763110504),
#  ('idea', 2.2662936690578293),
#  ('infinite', 2.2634907569237384),
#  ('puri', 2.2610859502575185),
#  ('crown', 2.2591256481172013),
#  ('moving', 2.2587761200952468),
#  ('dong', 2.256394293920505),
#  ('dead', 2.2496407712594615),
#  ('rollin', 2.242938481882458),
#  ('excuse', 2.2421240269645075),
#  ('ears', 2.238527731321022),
#  ('shoulder', 2.238188209376031),
#  ('fate', 2.2357807376945398),
#  ('hour', 2.2325252130063538),
#  ('activities', 2.228052663385466),
#  ('imagination', 2.2206057771962886),
#  ('sweat', 2.20618413005991),
#  ('pull', 2.204566840178986),
#  ('possible', 2.193754970785485),
#  ('lighter', 2.1883877307913164),
#  ('steps', 2.1788172780422483),
#  ('catch', 2.178218266414312),
#  ('tried', 2.1761202956565837),
#  ('week', 2.173855981292278),
#  ('모두', 2.1726005937252424),
#  ('choice', 2.1700534626107717),
#  ('important', 2.1659836569691238),
#  ('organiz', 2.1576874799128207),
#  ('pass', 2.1513227488206654),
#  ('shoes', 2.1485641605194816),
#  ('relax', 2.1419988316756173),
#  ('case', 2.1328871009525736),
#  ('devil', 2.131214884312913),
#  ('may', 2.1291286348529384),
#  ('trouble', 2.1274772376239244),
#  ('니和까', 2.1213607308053732),
#  ('scary', 2.11466486804804),
#  ('happened', 2.109290402397615),
#  ('match', 2.109212619394087),
#  ('attitude', 2.107545130929682),
#  ('konark', 2.1052560840542034),
#  ('cherry', 2.1019703284387488),
#  ('took', 2.098152462104593),
#  ('impossible', 2.0935441830915305),
#  ('perfume', 2.0909031761800967),
#  ('flight', 2.0903273525991946),
#  ('sleeping', 2.0807412052604324),
#  ('pour', 2.079106982674055),
#  ('filled', 2.0762515217498536),
#  ('luck', 2.074515265880015),
#  ('arms', 2.0744265048891393),
#  ('loves', 2.0706881946671927),
#  ('ora', 2.07064259516331),
#  ('twice', 2.065041795205272),
#  ('terms', 2.0545668547329),
#  ('fog', 2.0528924283044807),
#  ('careful', 2.0527731213586264),
#  ('page', 2.052017617019164),
#  ('buy', 2.0508080935939503),
#  ('autumn', 2.0470750364326697),
#  ('deeper', 2.0432796557762645),
#  ('ping', 2.0392308211469468),
#  ('celebrate', 2.037256090807535),
#  ('self', 2.0350080554227126),
#  ('playing', 2.0343273040827388),
#  ('scene', 2.0316438803409844),
#  ('sense', 2.026974605364166),
#  ('short', 2.0215696358026665),
#  ('lord', 2.021223054136864),
#  ('notice', 2.0155176917291353),
#  ('level', 2.0095116589708386),
#  ('burns', 2.006939006556581),
#  ('points', 2.0051842612152404),
#  ('ding', 2.003039786657035),
#  ('stops', 1.999571319768143),
#  ('scared', 1.9980173408430568),
#  ('worried', 1.997455777171005),
#  ('guess', 1.991004845755469),
#  ('advice', 1.9808937147144572),
#  ('expression', 1.9787900825782014),
#  ('told', 1.9771455902167454),
#  ('video', 1.9769493052110534),
#  ('su', 1.9768745091279243),
#  ('interested', 1.975342367315632),
#  ('tariffa', 1.9683019938432391),
#  ('nurse', 1.967979892854088),
#  ('leaves', 1.9668675819046697),
#  ('speak', 1.9657312768443094),
#  ('focus', 1.9653588683211647),
#  ('map', 1.9575443660253726),
#  ('coffee', 1.9556729507848762),
#  ('causes', 1.9540285931227652),
#  ('king', 1.9518479920623217),
#  ('heavy', 1.9500253370979745),
#  ('sign', 1.9495457739474822),
#  ('dog', 1.9396194198103436),
#  ('means', 1.9370463229278478),
#  ('programme', 1.935203029337243),
#  ('persons', 1.9263562941426104),
#  ('finish', 1.913015645486757),
#  ('flame', 1.8987781660903407),
#  ('gaelic', 1.8961613548513359),
#  ('scots', 1.8961613548513359),
#  ('table', 1.8896118416881387),
#  ('temperature', 1.8846131981350385),
#  ('situation', 1.8841705363687546),
#  ('te', 1.8830928845839972),
#  ('shot', 1.8826879576850692),
#  ('repeat', 1.8815352776050116),
#  ('satisfied', 1.8782585025189023),
#  ('stand', 1.8755456731896112),
#  ('keeps', 1.8746179338455755),
#  ('limit', 1.8738463781449206),
#  ('fingers', 1.8721271937771868),
#  ('feels', 1.8720121435472352),
#  ('copyright', 1.8677631892608333),
#  ('sin', 1.8675026863259578),
#  ('drum', 1.8596624576366931),
#  ('kuala', 1.8541534951376781),
#  ('lumpur', 1.8541534951376781),
#  ('paris', 1.8512190843136995),
#  ('changes', 1.8474492633851725),
#  ('ey', 1.8429635152153443),
#  ('fashion', 1.8333435711596655),
#  ('faster', 1.8318163660090863),
#  ('false', 1.8209303376171933),
#  ('journey', 1.8185726315182156),
#  ('laughing', 1.8144847089634855),
#  ('garden', 1.805680359138914),
#  ('yesterday', 1.8031504852807902),
#  ('chocolate', 1.8028220709803158),
#  ('moments', 1.8004082494339748),
#  ('finished', 1.7998115893061999),
#  ('draw', 1.793320922217589),
#  ('clean', 1.7881415212356684),
#  ('forgotten', 1.787844063373831),
#  ('grow', 1.7870844361112852),
#  ('fantasy', 1.7815780153299117),
#  ('class', 1.7786453562202538),
#  ('lighting', 1.7695540340656633),
#  ('smoking', 1.7672726218951873),
#  ('weight', 1.7663588894602296),
#  ('block', 1.7642633175098774),
#  ('bigger', 1.7636994612803065),
#  ('ahead', 1.7612345372360458),
#  ('quiet', 1.7594839958136006),
#  ('stone', 1.7547169251676484),
#  ('closed', 1.753733280896137),
#  ('land', 1.752074822971072),
#  ('reach', 1.7505206834489109),
#  ('wanna', 1.7495635026046097),
#  ('taken', 1.7368349947186177),
#  ('tells', 1.7325811247524627),
#  ('piece', 1.7295588441384915),
#  ('identification', 1.7230104992162403),
#  ('drip', 1.7142284871008533),
#  ('champagne', 1.7107264557064847),
#  ('gun', 1.710634019546247),
#  ('日本語', 1.6997007585838637),
#  ('school', 1.697225681594221),
#  ('teenagers', 1.6971119974121114),
#  ('emotion', 1.6951991023535757),
#  ('calls', 1.6917789657197941),
#  ('difference', 1.691495535750347),
#  ('key', 1.689677826900973),
#  ('iron', 1.6888583682171896),
#  ('appearance', 1.688158430017045),
#  ('니和', 1.6843307262615452),
#  ('gives', 1.6820766987232654),
#  ('acrylate', 1.6817334694167432),
#  ('round', 1.6791758780527362),
#  ('glad', 1.6765020700443987),
#  ('desert', 1.6752605932874747),
#  ('roller', 1.6742346650157443),
#  ('fair', 1.6699324522096581),
#  ('smiling', 1.6630081740647866),
#  ('likes', 1.6373852736549848),
#  ('rise', 1.6312456642092799),
#  ('rainbow', 1.6295175431919207),
#  ('speed', 1.6234024005968473),
#  ('trophy', 1.6067792349178773),
#  ('challenge', 1.6060646378764565),
#  ('rough', 1.6029596987555539),
#  ('모든', 1.5987246759191895),
#  ('foot', 1.5932863316279373),
#  ('fault', 1.5862060406393061),
#  ('reading', 1.5855484984774066),
#  ('dreamed', 1.5827456542058709),
#  ('sit', 1.5804818447583178),
#  ('rice', 1.579680239370861),
#  ('force', 1.5711488941213003),
#  ('size', 1.5704038154049522),
#  ('men', 1.5634161902855133),
#  ('needs', 1.562039042577949),
#  ('soft', 1.5610857770529656),
#  ('covered', 1.5514874772022735),
#  ('heal', 1.5509335589393989),
#  ('whoa', 1.5497620496154694),
#  ('kong', 1.5481261754653692),
#  ('spirit', 1.5466913265360764),
#  ('sunset', 1.5439066799841688),
#  ('handle', 1.5423288518619211),
#  ('serves', 1.5416446124593945),
#  ('prepare', 1.5350758176803376),
#  ('happens', 1.5307694885367489),
#  ('calm', 1.5270534554057944),
#  ('swear', 1.516567992037736),
#  ('teach', 1.5156964128989332),
#  ('message', 1.5112142829099406),
#  ('couple', 1.5063545117293196),
#  ('nose', 1.5041640879930434),
#  ('spend', 1.4988554604791973),
#  ('value', 1.4901166477930807),
#  ('tie', 1.4900628114042134),
#  ('cookies', 1.4849374890867697),
#  ('drama', 1.4840942396744978),
#  ('window', 1.4834135051357245),
#  ('dive', 1.4825625268695957),
#  ('shines', 1.4819245023446637),
#  ('reaction', 1.476089060078684),
#  ('photo', 1.4668813392303284),
#  ('faith', 1.4634464230158417),
#  ('spit', 1.4552934627505045),
#  ('cut', 1.4550108748895307),
#  ('family', 1.454296458595761),
#  ('email', 1.4495503906184708),
#  ('create', 1.448534975904486),
#  ('wonderful', 1.4475027107304554),
#  ('relationship', 1.4449771266949305),
#  ('和지', 1.438056136182556),
#  ('camera', 1.4380523862187078),
#  ('missing', 1.4357204278881404),
#  ('heartbeat', 1.4347371668812754),
#  ('piracy', 1.4255688633796075),
#  ('passed', 1.4112169748898382),
#  ('danger', 1.4053206323673861),
#  ('discover', 1.398923019639176),
#  ('english', 1.3984185074343227),
#  ('escape', 1.39593233076093),
#  ('trip', 1.3940702453669878),
#  ('pretty', 1.3869945496489784),
#  ('member', 1.385336461454267),
#  ('country', 1.3842445486122),
#  ('couldn', 1.3836615027715349),
#  ('blowing', 1.3823507249089741),
#  ('surprised', 1.3813172230273754),
#  ('던和', 1.3797705844256838),
#  ('trapped', 1.3797615505336336),
#  ('movement', 1.3709621668091403),
#  ('fan', 1.3628998327723112),
#  ('pow', 1.359043439306786),
#  ('매일', 1.3586597770846331),
#  ('food', 1.342491294959208),
#  ('flash', 1.3421968021069992),
#  ('passion', 1.3385367207142425),
#  ('calling', 1.3364379574582799),
#  ('enter', 1.3229845199901138),
#  ('mobile', 1.3224512799762627),
#  ('drive', 1.3219424553539194),
#  ('negative', 1.320584390577098),
#  ('pay', 1.3146726613819761),
#  ('che', 1.3125981175855987),
#  ('하和하', 1.3095828198614863),
#  ('amazing', 1.3088826444706692),
#  ('gon', 1.3071018122664753),
#  ('umm', 1.304418247921235),
#  ('proud', 1.3009814408165248),
#  ('snowy', 1.293833292325523),
#  ('dry', 1.289689137276315),
#  ('honest', 1.2853025408493302),
#  ('legs', 1.283193063026604),
#  ('skin', 1.282454851073882),
#  ('shadows', 1.2813834379487057),
#  ('hiding', 1.2728763050207998),
#  ('bass', 1.2718785081562176),
#  ('butterflies', 1.2700391490854417),
#  ('criminal', 1.2603928788286918),
#  ('gentlemen', 1.2497037397614439),
#  ('너무', 1.2495679944728513),
#  ('frozen', 1.245321422350587),
#  ('imagine', 1.2391054657566225),
#  ('menu', 1.2315510264790144),
#  ('signs', 1.2308171210332413),
#  ('bed', 1.2084348220127121),
#  ('original', 1.2077619122197696),
#  ('track', 1.1955796532125391),
#  ('death', 1.1896046155874478),
#  ('cha', 1.1853672856481468),
#  ('month', 1.1843189145467423),
#  ('energy', 1.174689082417046),
#  ('cup', 1.162157988794419),
#  ('landscape', 1.1557681795669978),
#  ('angry', 1.1555679839002209),
#  ('order', 1.1547139904856927),
#  ('supposed', 1.1534284548639797),
#  ('watching', 1.146304034768482),
#  ('forest', 1.144532072141567),
#  ('awake', 1.1430887790677993),
#  ('york', 1.1391183326815417),
#  ('habit', 1.1263723824997878),
#  ('riding', 1.126175305552013),
#  ('tv', 1.1260696817796223),
#  ('fighting', 1.1193984237336987),
#  ('starting', 1.090706499994026),
#  ('fuck', 1.0671935852120893),
#  ('damn', 1.0578227929885835),
#  ('isolated', 1.0535606896302898),
#  ('natural', 1.0492017685649406),
#  ('raise', 1.0173306440870724),
#  ('crowd', 1.0157623758113479),
#  ('ching', 1.008258021371125),
#  ('pong', 1.0004497364632117),
#  ('오늘', 0.9610930866821339),
#  ('zero', 0.9563476477917476),
#  ('started', 0.950872566346389),
#  ('incredible', 0.9508441741373269),
#  ('kid', 0.9462175718409076),
#  ('wrist', 0.9370746328469681),
#  ('overload', 0.9309170158274713),
#  ('surprise', 0.9240082518162509),
#  ('milk', 0.9203338011134119),
#  ('attempted', 0.9009888035727509),
#  ('medicine', 0.7711178103201938),
#  ('speech', 0.5880307184444579)]

# %% [markdown]
# ### Topic analysis

# %%
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaModel

# %%
import pyLDAvis
import pyLDAvis.gensim_models as gensimvis
def save_lda_vis(lda, corpus, dictionary, filename):
    vis = gensimvis.prepare(lda, corpus, dictionary)
    pyLDAvis.save_html(vis, filename)
    
    with open(filename, "r") as f:
        html = f.read()
        
    return html, vis

# %%
def pre_process(df_lyrics):
    # tokenize lyrics
    lyrics_processed = df_lyrics.fillna("").str.split()

    for _list in lyrics_processed:
        for cnt in range(len(_list)):
            _list[cnt] = _list[cnt].replace(".", "").replace(",", "").replace("?", "").replace("\\", "").replace("/", "").replace(":", "").lower()
            
            if is_stopword(_list[cnt]):
                _list[cnt] = ""
                
    # remove empty string
    for cnt in range(len(lyrics_processed)):
        while(True):
            try:
                lyrics_processed[cnt].remove("")
            except:
                break

    return lyrics_processed

# %% [markdown]
# #### Among global

# %%
df_looking = df[df["grouping"].isin(target_and_global)].reset_index(drop=True)

# %%
#train model
lyrics_processed = pre_process(df_looking["lyrics"])
dictionary = Dictionary(lyrics_processed)
corpus = [dictionary.doc2bow(text) for text in lyrics_processed]
lda = LdaModel(corpus=corpus, id2word=dictionary, num_topics=100)

# %% [markdown]
# all topics

# %%
lda_html_global, vis = save_lda_vis(lda, corpus, dictionary, "lda.html")

vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 49     0.097738 -0.045292       1        1  5.544577
# 55     0.127943  0.032959       2        1  3.134141
# 85     0.098773  0.000078       3        1  2.875993
# 12     0.088042 -0.003466       4        1  2.165881
# 10     0.075653 -0.012632       5        1  2.030444
# ...         ...       ...     ...      ...       ...
# 72    -0.080508 -0.071964      96        1  0.289373
# 6     -0.149071 -0.072596      97        1  0.271226
# 70    -0.044351 -0.069961      98        1  0.263486
# 8     -0.171477 -0.071043      99        1  0.225784
# 21    -0.089682 -0.050406     100        1  0.152273
#
# [100 rows x 5 columns], topic_info=        Term         Freq        Total  Category  logprob  loglift
# 280    child  5643.000000  5643.000000   Default  30.0000  30.0000
# 7603  labour  5031.000000  5031.000000   Default  29.0000  29.0000
# 120     home  4570.000000  4570.000000   Default  28.0000  28.0000
# 494     cake  2466.000000  2466.000000   Default  27.0000  27.0000
# 292      hot  3104.000000  3104.000000   Default  26.0000  26.0000
# ...      ...          ...          ...       ...      ...      ...
# 176     best     3.473996  1094.830094  Topic100  -5.5352   0.7342
# 245    world     3.604644  1854.754378  Topic100  -5.4983   0.2440
# 661     show     3.515612  1318.192863  Topic100  -5.5233   0.5604
# 137    night     3.683693  2995.350709  Topic100  -5.4766  -0.2137
# 77      take     3.539273  3478.295839  Topic100  -5.5166  -0.4031
#
# [5968 rows x 6 columns], token_table=       Topic      Freq  Term
# term
# 5816       2  0.107311  "all
# 5816       9  0.053655  "all
# 5816      73  0.053655  "all
# 5816      78  0.643864  "all
# 13290      1  0.979958   "be
# ...      ...       ...   ...
# 1418      90  0.288046    和지
# 3872      10  0.895717    和집
# 4415      14  0.018022    和하
# 4415      29  0.964154    和하
# 2617      25  0.923220   日本語
#
# [47524 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[50, 56, 86, 13, 11, 79, 28, 12, 33, 31, 32, 40, 27, 65, 6, 44, 15, 42, 77, 87, 47, 91, 2, 63, 90, 68, 26, 39, 75, 76, 3, 99, 45, 52, 70, 94, 41, 24, 74, 29, 78, 96, 89, 21, 66, 30, 83, 16, 64, 55, 92, 23, 1, 72, 4, 8, 97, 57, 60, 38, 43, 98, 59, 48, 49, 37, 54, 58, 20, 18, 62, 81, 14, 34, 95, 80, 5, 36, 61, 82, 46, 17, 35, 19, 93, 67, 10, 85, 88, 51, 100, 53, 84, 69, 25, 73, 7, 71, 9, 22])

# %% [markdown]
# what topics are in kpop?

# %%
threshold = 0.3

counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    topics = lda.get_document_topics(corpus[cnt], minimum_probability=0)
    
    for topic in topics:
        if topic[1] > threshold:
            counter[topic[0]] = counter.get(topic[0], 0) + 1
            
        summer[topic[0]] = summer.get(topic[0], 0) + float(topic[1])

# %%
_lda_counter_global = sort_dictionary(counter)
lda_counter_global = []
for tup in _lda_counter_global:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_counter_global.append(new_tup)
    
lda_counter_global
# Out:
# [[25,
#   48,
#   [('home', 0.19895926),
#    ('contact', 0.055756584),
#    ('shut', 0.053006604),
#    ('sorry', 0.048653252),
#    ('news', 0.026734227),
#    ('comment', 0.025891567),
#    ('follow', 0.017419903),
#    ('questions', 0.012008961),
#    ('heart', 0.011360186),
#    ('today', 0.011045514)]],
#  [55,
#   41,
#   [('only', 0.04016433),
#    ('love', 0.030677944),
#    ('heart', 0.02519656),
#    ('let', 0.02446092),
#    ('way', 0.021316916),
#    ('mine', 0.013390415),
#    ('tell', 0.0131320665),
#    ('miss', 0.013013426),
#    ("can't", 0.009383079),
#    ('snow', 0.009055935)]],
#  [30,
#   39,
#   [('love', 0.34617913),
#    ('mean', 0.022285886),
#    ('happy', 0.02022777),
#    ('need', 0.0151625965),
#    ('ah', 0.014091778),
#    ("can't", 0.013451934),
#    ('you)', 0.011442575),
#    ('labour', 0.0107748015),
#    ('bad', 0.010251835),
#    ('heart', 0.010216874)]],
#  [11,
#   38,
#   [('eyes', 0.046342023),
#    ('world', 0.018914998),
#    ('news', 0.015251838),
#    ('love', 0.013297308),
#    ('{{if', 0.0130068585),
#    ('end', 0.012363636),
#    ('afraid', 0.011569055),
#    ('price_varies}', 0.010235928),
#    ('sky', 0.009793846),
#    ("let's", 0.009372898)]],
#  [91,
#   32,
#   [('home', 0.43406788),
#    ('non', 0.04872294),
#    ('worry', 0.03264145),
#    ("chi't", 0.031123687),
#    ('bang', 0.022596978),
#    ('chuction', 0.021109613),
#    ('che', 0.019119283),
#    ('chiudi', 0.014340149),
#    ('trouble', 0.013512732),
#    ('sono', 0.010716322)]],
#  [86,
#   29,
#   [('heart', 0.06467693),
#    ("can't", 0.058447268),
#    ('reply', 0.024557637),
#    ('swing', 0.022068653),
#    ('cancel', 0.021043682),
#    ('news', 0.021034084),
#    ('leave', 0.013435159),
#    ('tears', 0.011778797),
#    ('inquiry', 0.011242818),
#    ('directly', 0.010822034)]],
#  [26,
#   24,
#   [('ash', 0.024752125),
#    ("can't", 0.016293202),
#    ('chill', 0.011914457),
#    ('world', 0.011167348),
#    ('am', 0.010958163),
#    ('domino', 0.010726764),
#    ('back', 0.009622936),
#    ('take', 0.009555222),
#    ('girl', 0.009272065),
#    ('love', 0.009238177)]],
#  [85,
#   23,
#   [('baby', 0.22401668),
#    ('dynamite', 0.01175141),
#    ('girl', 0.011227221),
#    ('city', 0.0107597085),
#    ('tonight', 0.009448275),
#    ('let', 0.008842913),
#    ('love', 0.008202659),
#    ('fun', 0.007849212),
#    ('need', 0.0078044445),
#    ('shine', 0.0070298486)]],
#  [14,
#   23,
#   [('drunk', 0.2782605),
#    ('invalid', 0.11639201),
#    ('love', 0.010970543),
#    ('yes', 0.008044911),
#    ('shut', 0.00802908),
#    ('baby', 0.0065716463),
#    ('need', 0.006233945),
#    ('let', 0.0059323832),
#    ('say', 0.0058130664),
#    ('new', 0.0053548208)]],
#  [32,
#   22,
#   [('love', 0.08320164),
#    ('give', 0.05531836),
#    ('let', 0.029520534),
#    ("let's", 0.027620358),
#    ('night', 0.015548285),
#    ('fall', 0.015395584),
#    ('girl', 0.015255217),
#    ('take', 0.013808018),
#    ('sweet', 0.012707822),
#    ("won't", 0.011996228)]],
#  [39,
#   20,
#   [('love', 0.038794544),
#    ('waiting', 0.029818162),
#    ('hard', 0.025576748),
#    ('name', 0.023888811),
#    ('alone', 0.014872185),
#    ('night', 0.0141484765),
#    ('tell', 0.013050088),
#    ('summer', 0.011804219),
#    ('only', 0.010973056),
#    ('dream', 0.0109618865)]],
#  [41,
#   19,
#   [('take', 0.036552895),
#    ('away', 0.028199563),
#    ('rain', 0.024080846),
#    ('id', 0.020036574),
#    ('stay', 0.012304469),
#    ('love', 0.011024567),
#    ('tears', 0.01037053),
#    ('shaker', 0.009383734),
#    ('yes', 0.0088363215),
#    ('honey', 0.007978096)]],
#  [89,
#   19,
#   [('sorry', 0.032352243),
#    ('say', 0.018515436),
#    ('think', 0.017248027),
#    ('10', 0.015854262),
#    ("can't", 0.015134229),
#    ('need', 0.014524663),
#    ('love', 0.012680049),
#    ('tt', 0.011490749),
#    ('forgot', 0.011433413),
#    ('password', 0.0099566765)]],
#  [67,
#   19,
#   [('hey!', 0.030352509),
#    ('singing', 0.021854447),
#    ('take', 0.016578723),
#    ("can't", 0.016082551),
#    ('care', 0.012178163),
#    ('heart', 0.010370693),
#    ('today', 0.009982178),
#    ('hush', 0.00981714),
#    ('away', 0.009268753),
#    ('pain', 0.009047155)]],
#  [79,
#   18,
#   [('ка', 0.14396137),
#    ('imma', 0.073668696),
#    ('thinking', 0.042840697),
#    ('love', 0.041390758),
#    ('ay', 0.032757957),
#    ('ya', 0.031389005),
#    ('girl', 0.02503323),
#    ('cuz', 0.023190161),
#    ('crazy', 0.022277527),
#    ('sorry', 0.022134542)]],
#  [73,
#   18,
#   [('babe', 0.051262923),
#    ('sweet', 0.04663795),
#    ('fire', 0.040059615),
#    ('stronger', 0.034800354),
#    ('world', 0.01927848),
#    ('honey', 0.016629232),
#    ('real', 0.015486197),
#    ('burn', 0.015040767),
#    ("can't", 0.01343632),
#    ('oh-oh-oh', 0.013144565)]],
#  [10,
#   17,
#   [('dream', 0.046960663),
#    ('spicy', 0.022241138),
#    ('wish', 0.014359629),
#    ('take', 0.0127617065),
#    ('big', 0.0099212425),
#    ('feel', 0.009574538),
#    ('new', 0.007841814),
#    ('love', 0.007794028),
#    ('money', 0.0077018235),
#    ('life', 0.007216392)]],
#  [31,
#   17,
#   [('give', 0.032258008),
#    ('say', 0.022439733),
#    ('fine', 0.013869102),
#    ('love', 0.013321884),
#    ('feel', 0.012641433),
#    ('night', 0.012298029),
#    ('club', 0.012202537),
#    ("we're", 0.009284414),
#    ('back', 0.008618958),
#    ('think', 0.0075864047)]],
#  [60,
#   17,
#   [('back', 0.15869196),
#    ('woo', 0.119860224),
#    ('room', 0.037831396),
#    ('ac', 0.036011357),
#    ('wow', 0.030444875),
#    ('step', 0.028308166),
#    ('line', 0.025509896),
#    ('heart', 0.024757542),
#    ('google', 0.0219818),
#    ('say', 0.020435032)]],
#  [76,
#   17,
#   [('dimensioni', 0.08445808),
#    ('yes', 0.027509479),
#    ('girls', 0.018171173),
#    ('crush', 0.016808797),
#    ('(still', 0.010666102),
#    ('take', 0.01063229),
#    ('ayy', 0.010161986),
#    ('baby!', 0.009807648),
#    ('say', 0.0086646695),
#    ('feeling', 0.008416493)]],
#  [77,
#   16,
#   [('best', 0.08683627),
#    ('dad', 0.046388905),
#    ('say', 0.033943158),
#    ('touch', 0.02929626),
#    ('rousing', 0.022909373),
#    ('higher', 0.014393715),
#    ('course', 0.012053537),
#    ('mean', 0.011439532),
#    ('prova', 0.011302627),
#    ('girl', 0.010516344)]],
#  [22,
#   15,
#   [('kim', 0.05699465),
#    ('mob', 0.028613826),
#    ('room', 0.0262661),
#    ('city', 0.022121303),
#    ('luv', 0.01863229),
#    ('god', 0.015538269),
#    ('organization', 0.015106941),
#    ('life', 0.014818886),
#    ('mafioso', 0.014225719),
#    ('gucci', 0.013337095)]],
#  [51,
#   15,
#   [('save', 0.03472461),
#    ('feel', 0.02809663),
#    ('share', 0.028010488),
#    ('welcome', 0.020168547),
#    ('new', 0.015833242),
#    ('need', 0.015702346),
#    ('takes', 0.01368266),
#    ('facebook', 0.013540221),
#    ("that's", 0.012854733),
#    ('love', 0.011746582)]],
#  [95,
#   15,
#   [('night', 0.11453562),
#    ('meet', 0.033344146),
#    ('funny', 0.021247284),
#    ('hide', 0.019376095),
#    ('love', 0.017893884),
#    ('feel', 0.01514925),
#    ('ba', 0.014225498),
#    ('gonna', 0.012977333),
#    ('news', 0.0122351805),
#    ('teen', 0.011830764)]],
#  [1,
#   14,
#   [('dance', 0.30848926),
#    ("let's", 0.022657897),
#    ('celebrate', 0.014044733),
#    ('closer', 0.012419896),
#    ('feel', 0.0114891045),
#    ('music', 0.009373203),
#    ('night', 0.00844071),
#    ('sorry', 0.007967253),
#    ("can't", 0.007802324),
#    ('move', 0.006736298)]],
#  [34,
#   14,
#   [('sì', 0.23879538),
#    ('traduzione', 0.038151804),
#    ('di', 0.027272189),
#    ('cry', 0.021103015),
#    ('solo', 0.01895189),
#    ('browse', 0.018764416),
#    ('compare_at_price_min', 0.015985101),
#    ('beep', 0.01441003),
#    ('price_min}}', 0.013681279),
#    ('tempo', 0.013360067)]],
#  [12,
#   14,
#   [('life', 0.0736887),
#    ('give', 0.02194238),
#    ('up!', 0.0217082),
#    ('tonight', 0.02106818),
#    ('baby', 0.011181026),
#    ('love', 0.009209522),
#    ('night', 0.0084577445),
#    ("we'll", 0.008179838),
#    ('let', 0.008083917),
#    ('say', 0.007933808)]],
#  [42,
#   13,
#   [('surf', 0.050267503),
#    ('cream', 0.018669294),
#    ('enemy', 0.017963532),
#    ('ice', 0.016519265),
#    ('down', 0.016311748),
#    ('taste', 0.012494651),
#    ('need', 0.01040391),
#    ('mama', 0.009795302),
#    ('throw', 0.009278572),
#    ("can't", 0.008920882)]],
#  [5,
#   13,
#   [('matter', 0.022506401),
#    ('made', 0.019806935),
#    ('business', 0.019588733),
#    ('love', 0.0165584),
#    ('lose', 0.015191164),
#    ('trust', 0.01506504),
#    ('bad', 0.014885587),
#    ("can't", 0.013773497),
#    ("doesn't", 0.012640899),
#    ('say', 0.011724572)]],
#  [2,
#   13,
#   [('love', 0.0738129),
#    ('sick', 0.029269082),
#    ('back', 0.015632225),
#    ('need', 0.014733804),
#    ('place', 0.013221959),
#    ('found', 0.012813675),
#    ('ooh', 0.012205012),
#    ('loved', 0.009903704),
#    ('take', 0.00954871),
#    ('say', 0.008515551)]],
#  [98,
#   13,
#   [('love', 0.08148447),
#    ('diamond', 0.030077007),
#    ('yes', 0.024238873),
#    ('shine', 0.01860627),
#    ('diamonds', 0.018186985),
#    ('fall', 0.017470947),
#    ('leave', 0.01722321),
#    ('last', 0.015025219),
#    ('am', 0.014921744),
#    ('let', 0.011273792)]],
#  [47,
#   12,
#   [('call', 0.13171755),
#    ('uh', 0.07498968),
#    ('bad', 0.04706074),
#    ('god', 0.03789002),
#    ('ayyyy', 0.024573173),
#    ('special', 0.018129505),
#    ('yes', 0.012916254),
#    ('guy', 0.0128711),
#    ('rose', 0.011891123),
#    ('new', 0.011289679)]],
#  [59,
#   11,
#   [('it!', 0.03587605),
#    ('sexy', 0.03304312),
#    ('yes!', 0.023314359),
#    ('little', 0.022647528),
#    ('365', 0.01907017),
#    ('damn', 0.018896721),
#    ('worry', 0.016143125),
#    ('fire', 0.015680978),
#    ('am', 0.013617086),
#    ('seoul', 0.013488521)]],
#  [64,
#   11,
#   [('tell', 0.040972237),
#    ('love', 0.01806909),
#    ('need', 0.010992198),
#    ("you'll", 0.010064148),
#    ('only', 0.008261214),
#    ('girl', 0.007919303),
#    ('night', 0.0077102715),
#    ('fine', 0.0074148024),
#    ('little', 0.0072851386),
#    ('city', 0.007140543)]],
#  [48,
#   11,
#   [('hot', 0.24992394),
#    ('[bleep', 0.0486153),
#    ('[bleep]', 0.027786616),
#    ('sorry', 0.026670044),
#    ('hi', 0.016597582),
#    ('24', 0.015706016),
#    ('healing', 0.011465513),
#    ('heart', 0.010302881),
#    ("can't", 0.009996161),
#    ('say', 0.009799116)]],
#  [54,
#   10,
#   [('happiness', 0.030433642),
#    ('detail', 0.018208954),
#    ('cold', 0.017671047),
#    ('ah', 0.015978327),
#    ('story', 0.012090088),
#    ('truth', 0.010784457),
#    ('star', 0.010536576),
#    ('yeh)', 0.010054286),
#    ('years', 0.009249652),
#    ('rum', 0.008440611)]],
#  [56,
#   10,
#   [('trauma', 0.0327033),
#    ('stop!', 0.026077872),
#    ('dat', 0.022093285),
#    ('lover', 0.021007612),
#    ('goodbye', 0.01735226),
#    ('saying', 0.015249173),
#    ('animals', 0.013356608),
#    ('later', 0.012958717),
#    ('lee', 0.012686428),
#    ("rollin'", 0.010554815)]],
#  [50,
#   10,
#   [('osserva', 0.102344744),
#    ('air', 0.03695378),
#    ('bomb', 0.03337775),
#    ('expression', 0.024016103),
#    ('fighting', 0.020046216),
#    ('sorry', 0.018760994),
#    ("can't", 0.018326057),
#    ('nice', 0.01746305),
#    ('rice', 0.017220685),
#    ('news', 0.016668756)]],
#  [96,
#   9,
#   [('thank', 0.053789318),
#    ('up!', 0.042005133),
#    ('yes)', 0.018736683),
#    ('lucky', 0.018255848),
#    ('understand', 0.017910145),
#    ('kill', 0.017899299),
#    ('(yes', 0.01758307),
#    ('next', 0.014160181),
#    ('on!', 0.011373303),
#    ('training', 0.010844131)]],
#  [84,
#   9,
#   [('universe', 0.15500216),
#    ('woman', 0.13590617),
#    ('candy', 0.07841022),
#    ('inside', 0.030216774),
#    ('ac', 0.028097274),
#    ('sweet', 0.027705181),
#    ('put', 0.01778958),
#    ('first', 0.016481204),
#    ('weird', 0.010606293),
#    ('pop', 0.008589777)]],
#  [40,
#   9,
#   [('boom', 0.12921028),
#    ('eyes', 0.033174306),
#    ('say', 0.017379683),
#    ("can't", 0.014215315),
#    ('slip', 0.014189122),
#    ('super', 0.014013476),
#    ('bum', 0.013104503),
#    ('wow', 0.012555275),
#    ('tie', 0.0122083025),
#    ('(not', 0.010109168)]],
#  [7,
#   9,
#   [('night', 0.055256758),
#    ("we're", 0.047623813),
#    ('awake', 0.0346223),
#    ('yeh', 0.033885177),
#    ('yes', 0.020722058),
#    ('ready', 0.019295515),
#    ("who's", 0.012568956),
#    ('luck', 0.012134784),
#    ('rises', 0.011965904),
#    ('ay', 0.008933972)]],
#  [90,
#   9,
#   [('feel', 0.047384266),
#    ('woman', 0.032211628),
#    ('keep', 0.012011487),
#    ('love', 0.011964954),
#    ('minus', 0.011699976),
#    ('calling', 0.010639804),
#    ('aya', 0.010389726),
#    ('heart', 0.010169044),
#    ('close', 0.009708212),
#    ("there's", 0.0096915485)]],
#  [37,
#   9,
#   [('ha', 0.049549304),
#    ('future', 0.038857747),
#    ('fun', 0.031135904),
#    ('call', 0.029187093),
#    ('honey', 0.026804341),
#    ('alone', 0.018667927),
#    ('turning', 0.018491007),
#    ('wants', 0.017377894),
#    ('heart', 0.015907189),
#    ('dum', 0.015367319)]],
#  [43,
#   8,
#   [('man', 0.05569924),
#    ('back', 0.022797778),
#    ('only', 0.011426748),
#    ('和만', 0.010964951),
#    ('real', 0.008826452),
#    ('hot', 0.008812449),
#    ('canta', 0.007601249),
#    ('nigger', 0.007199542),
#    ('shit', 0.0070855613),
#    ('yes', 0.006365992)]],
#  [61,
#   8,
#   [('shake', 0.051304925),
#    ('release', 0.03719419),
#    ('orientation', 0.026253968),
#    ('illuminate', 0.0230604),
#    ('bubble', 0.01904332),
#    ('dam', 0.01722123),
#    ('candy', 0.015832985),
#    ('world', 0.014905487),
#    ('io', 0.013728535),
#    ('(all)', 0.012258533)]],
#  [17,
#   8,
#   [('low', 0.0902053),
#    ('rewind', 0.04191687),
#    ('shining', 0.027669929),
#    ('jump', 0.020565871),
#    ('armor', 0.01850969),
#    ('gno', 0.013207977),
#    ('job', 0.011835017),
#    ('love', 0.0105117485),
#    ('upstairs', 0.010495934),
#    ('film', 0.010492478)]],
#  [38,
#   8,
#   [('child', 0.7034142),
#    ('down', 0.017776199),
#    ('girls', 0.0072799986),
#    ('love', 0.0070581795),
#    ('goccia', 0.0055193333),
#    ('sunflower', 0.0051059215),
#    ('mic', 0.005095512),
#    ('take', 0.004565072),
#    ('boy', 0.0037422024),
#    ('sorry', 0.002677049)]],
#  [58,
#   8,
#   [('change', 0.08469744),
#    ('moon', 0.055819407),
#    ('hidden', 0.025291096),
#    ('say', 0.020288374),
#    ('leave', 0.019155346),
#    ('u)', 0.019046025),
#    ('breakage', 0.015427631),
#    ('let', 0.014321459),
#    ('think', 0.013796785),
#    ('love', 0.012349018)]],
#  [49,
#   8,
#   [('girl', 0.0171612),
#    ('shit', 0.015333962),
#    ('tell', 0.013078495),
#    ('say', 0.012333948),
#    ('love', 0.011472015),
#    ('fuck', 0.008677294),
#    ('back', 0.008446011),
#    ('take', 0.007195744),
#    ('yes', 0.0069325543),
#    ("can't", 0.006735494)]],
#  [57,
#   8,
#   [('follow', 0.11478444),
#    ('wait', 0.052110054),
#    ('dark', 0.04507332),
#    ('spring', 0.024186153),
#    ('winter', 0.022902597),
#    ('little', 0.021903384),
#    ('year', 0.01949816),
#    ('subscribe', 0.017105091),
#    ('pantyhose', 0.01644439),
#    ('came', 0.0127096195)]],
#  [69,
#   8,
#   [('oh!', 0.066283464),
#    ('fake', 0.024878781),
#    ('let', 0.021516744),
#    ("can't", 0.020142922),
#    ('click', 0.01729176),
#    ('am', 0.015631247),
#    ('down', 0.015024753),
#    ('party', 0.013906181),
#    ('are)', 0.012436578),
#    ('shooting', 0.011188896)]],
#  [93,
#   7,
#   [('back', 0.047184207),
#    ('woo', 0.034440275),
#    ('home', 0.018371398),
#    ('coming', 0.016773082),
#    ('whoa', 0.01583216),
#    ('dead', 0.015730942),
#    ('take', 0.012389356),
#    ('comfort', 0.010603907),
#    ("let's", 0.010258655),
#    ('(come', 0.010116122)]],
#  [78,
#   7,
#   [('put', 0.020354992),
#    ('back', 0.016249271),
#    ("can't", 0.013606757),
#    ('take', 0.010577544),
#    ('talk', 0.00928698),
#    ('say', 0.007885847),
#    ('drops', 0.0077857487),
#    ('call', 0.006908496),
#    ('life', 0.0059991847),
#    ('drip', 0.0057698255)]],
#  [13,
#   7,
#   [('share', 0.06606616),
#    ('twitter', 0.052653745),
#    ('knocking', 0.023543227),
#    ("can't", 0.022266457),
#    ('zione', 0.02048428),
#    ('baby', 0.01848413),
#    ("we're", 0.018163495),
#    ('yes', 0.015175381),
#    ('making', 0.014806433),
#    ('hands', 0.014692622)]],
#  [88,
#   7,
#   [("let's", 0.03072364),
#    ('youth', 0.023291195),
#    ('happy', 0.019138908),
#    ('sorry', 0.017598413),
#    ("we're", 0.01720091),
#    ('low', 0.014872645),
#    ('number', 0.014556353),
#    ('take', 0.01239703),
#    ('points', 0.011744869),
#    ('disappear', 0.010896692)]],
#  [3,
#   7,
#   [('boy', 0.1654604),
#    ('hell', 0.02034674),
#    ('song', 0.02019815),
#    ('hope', 0.018074585),
#    ('(for', 0.014498117),
#    ('say', 0.011531952),
#    ('gives', 0.011385535),
#    ('ago', 0.011314686),
#    ("can't", 0.010576813),
#    ('face', 0.010479076)]],
#  [19,
#   7,
#   [('247', 0.054766815),
#    ('bull', 0.050476674),
#    ('gimme', 0.045491394),
#    ('bass', 0.022113414),
#    ('headphones', 0.021519877),
#    ('thunder', 0.020976337),
#    ('work', 0.019814195),
#    ('ride', 0.019684087),
#    ('labour', 0.019140186),
#    ("can't", 0.01364367)]],
#  [35,
#   7,
#   [('straight', 0.034245495),
#    ('free', 0.019748393),
#    ('smile', 0.017632484),
#    ('ah', 0.015214432),
#    ('lost', 0.014974008),
#    ('poison', 0.013504513),
#    ('honey', 0.013024521),
#    ('well', 0.012684485),
#    ('pink', 0.011644017),
#    ('take', 0.0104367975)]],
#  [9,
#   6,
#   [('mom', 0.11189391),
#    ('nightmare', 0.057129446),
#    ('brave', 0.05190845),
#    ('find', 0.031763468),
#    ("can't", 0.029931275),
#    ('interested', 0.016101979),
#    ('um', 0.014749037),
#    ('live', 0.011101333),
#    ('way', 0.0097900145),
#    ('parts', 0.009503523)]],
#  [82,
#   6,
#   [('rock', 0.11332923),
#    ('paradise', 0.023018938),
#    ('believer', 0.01374557),
#    ('think', 0.01286694),
#    ('fight', 0.012157058),
#    ('ideal', 0.011930462),
#    ('let', 0.010003414),
#    ('take', 0.0099121835),
#    ('pow', 0.00980944),
#    ('ocean', 0.007897445)]],
#  [92,
#   6,
#   [('singing', 0.39517233),
#    ('run', 0.05775776),
#    ('hours', 0.028331913),
#    ('on!', 0.023793455),
#    ('tan', 0.021938318),
#    ('24', 0.02181257),
#    ('young', 0.01458546),
#    ('save', 0.00878448),
#    ("let's", 0.008589118),
#    ('bulletproof', 0.00827128)]],
#  [52,
#   6,
#   [('dan', 0.16362746),
#    ('butterfly', 0.088384554),
#    ('fly', 0.041441545),
#    ('(no', 0.021222657),
#    ('love', 0.019150903),
#    ('woah', 0.017639171),
#    ('don’t', 0.017548375),
#    ('letters', 0.017004509),
#    ('dark', 0.015962124),
#    ('no)', 0.014678423)]],
#  [74,
#   5,
#   [('need', 0.07408588),
#    ('love', 0.037497345),
#    ('shy', 0.031550974),
#    ('entertainment', 0.026956983),
#    ('lights', 0.02662481),
#    ('try', 0.022376096),
#    ('kiss', 0.01953364),
#    ('和하', 0.015186337),
#    ('eyes', 0.014465623),
#    ('control', 0.011203371)]],
#  [18,
#   5,
#   [('on!', 0.12897941),
#    ('wow!', 0.07267064),
#    ('meet', 0.029656526),
#    ('says', 0.019766003),
#    ('it!', 0.016727366),
#    ('believe', 0.015462855),
#    ('boy!', 0.013409931),
#    ('life', 0.011490451),
#    ('nice', 0.011046905),
#    ('prepared', 0.010974722)]],
#  [20,
#   5,
#   [('nana', 0.09782183),
#    ('ready', 0.019734679),
#    ('sweat', 0.01887766),
#    ('bitter', 0.017866336),
#    ('love', 0.016389068),
#    ('(a', 0.0148761505),
#    ("can't", 0.014776029),
#    ('keep', 0.013091063),
#    ('feel', 0.0123198),
#    ('face', 0.012214629)]],
#  [0,
#   5,
#   [('head', 0.12192987),
#    ('down', 0.06088545),
#    ('coming', 0.031411506),
#    ('round', 0.021818278),
#    ('magic', 0.019732546),
#    ('tick', 0.018030629),
#    ('swing', 0.01694208),
#    ('imagination', 0.015898082),
#    ('teacher', 0.013987745),
#    ('united', 0.013962499)]],
#  [44,
#   5,
#   [('bang', 0.042040586),
#    ('think', 0.037475456),
#    ('down', 0.025432074),
#    ('bad', 0.023174508),
#    ('try', 0.018915294),
#    ('let', 0.017960114),
#    ('whoo', 0.016275296),
#    ('worried', 0.014443348),
#    ('lonely', 0.012944216),
#    ('yes', 0.011824008)]],
#  [36,
#   5,
#   [('once', 0.04053071),
#    ('think', 0.03518917),
#    ('let', 0.012448102),
#    ('say', 0.011807763),
#    ('stay', 0.011725586),
#    ('fog', 0.010116031),
#    ('baby', 0.009680726),
#    ('love', 0.009581682),
#    ('celebrate', 0.009441653),
#    ('honey', 0.008668378)]],
#  [81,
#   5,
#   [('dawn', 0.05557831),
#    ('need', 0.029528243),
#    ('rid', 0.028725231),
#    ('love', 0.022414116),
#    ('persons', 0.020633973),
#    ('laughter', 0.014801815),
#    ('only', 0.014488948),
#    ('dream)', 0.013527168),
#    ('life', 0.012782691),
#    ("let's", 0.011709998)]],
#  [33,
#   5,
#   [('man', 0.0341499),
#    ('blame', 0.03200434),
#    ('tell', 0.023848558),
#    ('sunday', 0.022386612),
#    ('time)', 0.019105798),
#    ("(i'll", 0.017980866),
#    ('challenge', 0.015865318),
#    ('bop', 0.014857993),
#    ('neighborhood', 0.01326729),
#    ('whip', 0.010324881)]],
#  [65,
#   5,
#   [('party', 0.066201046),
#    ('hold', 0.040974744),
#    ('blowing', 0.021869093),
#    ('love', 0.02070788),
#    ("doesn't", 0.016453069),
#    ('let', 0.012274657),
#    ('frightened', 0.009830695),
#    ('girl', 0.008984818),
#    ('honey', 0.008600653),
#    ('trip', 0.0075706337)]],
#  [27,
#   5,
#   [('top', 0.016772356),
#    ('(i', 0.012125332),
#    ('diving', 0.012046751),
#    ('love', 0.011201115),
#    ('little', 0.010725307),
#    ('leave', 0.010431624),
#    ("can't", 0.008630378),
#    ('girl', 0.008480087),
#    ('take', 0.007711877),
#    ('feel', 0.0076112323)]],
#  [97,
#   5,
#   [('cake', 0.61338764),
#    ('hands', 0.066236444),
#    ('wave', 0.036832523),
#    ('clap', 0.005810886),
#    ('stay', 0.003399607),
#    ('way', 0.003260044),
#    ('air', 0.00312807),
#    ('me)', 0.0029963416),
#    ('hours', 0.0028663478),
#    ('fan', 0.0026942026)]],
#  [15,
#   5,
#   [('heart', 0.027939018),
#    ('million', 0.025297454),
#    ('night', 0.021547081),
#    ('stay', 0.020897493),
#    ('give', 0.01883172),
#    ('sauna', 0.016143082),
#    ('run', 0.014614806),
#    ('break', 0.012263804),
#    ('purple', 0.010744826),
#    ('distant', 0.010479394)]],
#  [63,
#   5,
#   [('hot', 0.3432136),
#    ('say', 0.017715786),
#    ('hello', 0.013693642),
#    ("can't", 0.008044257),
#    ('win', 0.0066984924),
#    ('feel', 0.0064815856),
#    ('burn', 0.006206147),
#    ('waterfall', 0.006026934),
#    ('type', 0.0056799534),
#    ('world', 0.005304905)]],
#  [94,
#   4,
#   [('bang', 0.0709449),
#    ('blah', 0.06934606),
#    ('power', 0.0398639),
#    ('wait', 0.022381235),
#    ('rules', 0.018429717),
#    ('shots', 0.015230147),
#    ('say', 0.012658972),
#    ('(ah)', 0.011939815),
#    ('let', 0.011784439),
#    ('only', 0.011653552)]],
#  [83,
#   4,
#   [('yes', 0.14486383),
#    ('swan', 0.023117596),
#    ('eh-eh', 0.022700083),
#    ('loss', 0.020411698),
#    ('yay', 0.018468253),
#    ('ashes', 0.017921401),
#    ('heart', 0.017479096),
#    ('tu', 0.010676481),
#    ('(oh', 0.010192858),
#    ('light', 0.009850415)]],
#  [16,
#   4,
#   [('words', 0.04407917),
#    ('end', 0.02723807),
#    ('lady', 0.027118133),
#    ('loco', 0.024239462),
#    ('love', 0.022965454),
#    ('reflex', 0.019308496),
#    ('taking', 0.017723024),
#    ('mask', 0.016835619),
#    ('back)', 0.015437755),
#    ('set', 0.015399086)]],
#  [24,
#   4,
#   [('light', 0.19909275),
#    ("'em", 0.061109744),
#    ('sneakers', 0.059134703),
#    ('put', 0.056393992),
#    ('ready', 0.019764353),
#    ('blind', 0.015459333),
#    ('turn', 0.01385791),
#    ('makes', 0.013693021),
#    ('wood', 0.013440635),
#    ('call', 0.011744291)]],
#  [28,
#   4,
#   [('music', 0.07082229),
#    ('wild', 0.031727526),
#    ('place', 0.022935236),
#    ('na-na', 0.01949871),
#    ('worse', 0.017303124),
#    ('take', 0.014759796),
#    ("there's", 0.014376883),
#    ('say', 0.013920232),
#    ('blessing', 0.013704708),
#    ('thoughts', 0.012733403)]],
#  [71,
#   4,
#   [('knock', 0.059480418),
#    ('show', 0.041357283),
#    ('money', 0.024824379),
#    ('bitch', 0.021037618),
#    ('asia', 0.020396303),
#    ('praying', 0.016936557),
#    ('mine)', 0.013351243),
#    ('(what)', 0.011140433),
#    ('jelly', 0.009306374),
#    ('hope', 0.00903522)]],
#  [66,
#   4,
#   [('singing', 0.21292783),
#    ('summer', 0.06326996),
#    ('break', 0.05893881),
#    ('heart', 0.020965708),
#    ('play', 0.015503079),
#    ('missed', 0.011443177),
#    ('games', 0.008946673),
#    ('mariachi', 0.008883928),
#    ("how's", 0.0084161395),
#    ('baby', 0.008266518)]],
#  [72,
#   3,
#   [('pop', 0.105402626),
#    ('sugar', 0.060881462),
#    ('shoot', 0.0318886),
#    ('nana', 0.023765502),
#    ('kick', 0.02305243),
#    ('desire', 0.020003133),
#    ('bass', 0.016768616),
#    ('walker', 0.010731153),
#    ('only', 0.009589817),
#    ('love', 0.009345922)]],
#  [23,
#   3,
#   [('days', 0.039948307),
#    ("can't", 0.020499727),
#    ('moonlight', 0.016059186),
#    ('head', 0.015862305),
#    ('take', 0.015832612),
#    ('clover', 0.011860096),
#    ('honey', 0.010533591),
#    ('girl', 0.009761283),
#    ('love', 0.009579947),
#    ('walk', 0.009056649)]],
#  [4,
#   3,
#   [('problem', 0.086722836),
#    ('show', 0.05519405),
#    ('ooh', 0.045836046),
#    ('ragazza', 0.024291422),
#    ('ta', 0.024254061),
#    ('tutto', 0.018769268),
#    ('difference', 0.016071597),
#    ('administration', 0.01513543),
#    ('se', 0.0141327465),
#    ('el', 0.0137111405)]],
#  [45,
#   3,
#   [('girlfriend', 0.043215465),
#    ('yes', 0.02055377),
#    ('drop', 0.018347852),
#    ("that's", 0.017094303),
#    ('account', 0.015260761),
#    ('money', 0.013479343),
#    ('love', 0.013043477),
#    ('round', 0.010828309),
#    ('fall', 0.009994531),
#    ('"lord', 0.009674306)]],
#  [68,
#   3,
#   [('tock', 0.119067796),
#    ('crazy', 0.06870877),
#    ('tick', 0.06343204),
#    ('worth', 0.04163387),
#    ('nana', 0.028764948),
#    ('high', 0.015005967),
#    ('bounce', 0.014979409),
#    ('beauty', 0.011442124),
#    ('give', 0.011343857),
#    ('you!', 0.010193084)]],
#  [53,
#   3,
#   [('born', 0.047384843),
#    ('solosta', 0.03341801),
#    ('datafilesizehumanreadable', 0.020682378),
#    ('{{', 0.020681128),
#    ('}}', 0.020669201),
#    ('cloud', 0.02052784),
#    ('dragon', 0.018846639),
#    ('solo', 0.018741636),
#    ('path', 0.01793307),
#    ('sorry', 0.01613334)]],
#  [6,
#   3,
#   [('true', 0.09177806),
#    ('dirty', 0.08430994),
#    ('wish', 0.03737389),
#    ('want)', 0.036539797),
#    ('deep', 0.031835172),
#    ('(you', 0.030675523),
#    ('first', 0.029430255),
#    ('simple', 0.02756196),
#    ('sharp', 0.022644976),
#    ('background', 0.012448589)]],
#  [29,
#   3,
#   [('work', 0.3816636),
#    ('labour', 0.15371114),
#    ('sugar', 0.0049180444),
#    ('line', 0.004861687),
#    ('back', 0.0044452953),
#    ('m-m-m', 0.003924769),
#    ('fly', 0.0038253043),
#    ('take', 0.003435926),
#    ('impatient', 0.0034321358),
#    ('doo-doo-doo-doo-doo-doo-doo', 0.0034235748)]],
#  [87,
#   3,
#   [('flower', 0.24121794),
#    ('river', 0.051884487),
#    ('count', 0.033247333),
#    ('watch', 0.02664857),
#    ("let's", 0.024124663),
#    ('christmas', 0.019648254),
#    ('freedom', 0.019481152),
#    ('beauty', 0.019433465),
#    ('anymore', 0.013892146),
#    ('back', 0.0134593155)]],
#  [75,
#   3,
#   [('move', 0.028011994),
#    ('feel', 0.02266842),
#    ('back', 0.02230954),
#    ('mind', 0.01914963),
#    ('emotions', 0.014539329),
#    ('memories', 0.013010803),
#    ('handle', 0.012725987),
#    ('best', 0.011973913),
#    ('attack', 0.011793885),
#    ('let', 0.009430332)]],
#  [62,
#   2,
#   [('girl', 0.025374651),
#    ('yes', 0.01933646),
#    ('take', 0.017657736),
#    ('left', 0.011298806),
#    ('money', 0.010887263),
#    ('body', 0.0102577545),
#    ('feel', 0.010087151),
#    ('love', 0.008242419),
#    ('head', 0.0073418543),
#    ('kiss', 0.007197045)]],
#  [8,
#   2,
#   [('black', 0.103064716),
#    ('yellow', 0.079059236),
#    ('programme', 0.0477396),
#    ('autumn', 0.03467388),
#    ('school', 0.032785084),
#    ('diamonds', 0.025235876),
#    ('festival', 0.024265556),
#    ('difficulty', 0.01778811),
#    ('stupid', 0.012321081),
#    ('last', 0.01222975)]],
#  [21,
#   2,
#   [('start', 0.083147496),
#    ('reason', 0.05791335),
#    ('create', 0.024208086),
#    ('person', 0.01597738),
#    ('deliver', 0.01303981),
#    ('hairdryer', 0.011967209),
#    ('news', 0.0105876215),
#    ('end', 0.010506778),
#    ('likes', 0.0104965735),
#    ('[bleep', 0.009050454)]],
#  [80,
#   2,
#   [('wake', 0.043334678),
#    ('beautiful', 0.032518264),
#    ('sauce', 0.017811852),
#    ('cardi', 0.016100358),
#    ('love', 0.0152256265),
#    ('part', 0.01004495),
#    ('open', 0.009285573),
#    ('give', 0.009115783),
#    ('bitch', 0.009069145),
#    ('question', 0.008900689)]],
#  [70,
#   1,
#   [('nana', 0.053961318),
#    ('siren', 0.036342904),
#    ('noise', 0.032970257),
#    ('bow', 0.017362589),
#    ('hol', 0.01582123),
#    ('iron', 0.0116092665),
#    ('lemonade', 0.010014624),
#    ('pa', 0.009132034),
#    ('lana', 0.0090112565),
#    ('days', 0.00867894)]],
#  [99,
#   1,
#   [('part', 0.03264001),
#    ('easy', 0.029613018),
#    ('build', 0.02210361),
#    ('shot', 0.017409246),
#    ('near', 0.017200092),
#    ('guessing', 0.016893763),
#    ('science', 0.016843785),
#    ('numbers', 0.015846591),
#    ('love', 0.010748454),
#    ('say', 0.010550664)]]]

# %%
_lda_summer_global = sort_dictionary(summer)
lda_summer_global = []
for tup in _lda_summer_global:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_summer_global.append(new_tup)
    
lda_summer_global
# Out:
# [[25,
#   73.60478117740195,
#   [('home', 0.19895926),
#    ('contact', 0.055756584),
#    ('shut', 0.053006604),
#    ('sorry', 0.048653252),
#    ('news', 0.026734227),
#    ('comment', 0.025891567),
#    ('follow', 0.017419903),
#    ('questions', 0.012008961),
#    ('heart', 0.011360186),
#    ('today', 0.011045514)]],
#  [11,
#   56.46132238308701,
#   [('eyes', 0.046342023),
#    ('world', 0.018914998),
#    ('news', 0.015251838),
#    ('love', 0.013297308),
#    ('{{if', 0.0130068585),
#    ('end', 0.012363636),
#    ('afraid', 0.011569055),
#    ('price_varies}', 0.010235928),
#    ('sky', 0.009793846),
#    ("let's", 0.009372898)]],
#  [55,
#   48.20537126318459,
#   [('only', 0.04016433),
#    ('love', 0.030677944),
#    ('heart', 0.02519656),
#    ('let', 0.02446092),
#    ('way', 0.021316916),
#    ('mine', 0.013390415),
#    ('tell', 0.0131320665),
#    ('miss', 0.013013426),
#    ("can't", 0.009383079),
#    ('snow', 0.009055935)]],
#  [30,
#   45.253874326370806,
#   [('love', 0.34617913),
#    ('mean', 0.022285886),
#    ('happy', 0.02022777),
#    ('need', 0.0151625965),
#    ('ah', 0.014091778),
#    ("can't", 0.013451934),
#    ('you)', 0.011442575),
#    ('labour', 0.0107748015),
#    ('bad', 0.010251835),
#    ('heart', 0.010216874)]],
#  [86,
#   42.585066009901766,
#   [('heart', 0.06467693),
#    ("can't", 0.058447268),
#    ('reply', 0.024557637),
#    ('swing', 0.022068653),
#    ('cancel', 0.021043682),
#    ('news', 0.021034084),
#    ('leave', 0.013435159),
#    ('tears', 0.011778797),
#    ('inquiry', 0.011242818),
#    ('directly', 0.010822034)]],
#  [85,
#   34.86249735249612,
#   [('baby', 0.22401668),
#    ('dynamite', 0.01175141),
#    ('girl', 0.011227221),
#    ('city', 0.0107597085),
#    ('tonight', 0.009448275),
#    ('let', 0.008842913),
#    ('love', 0.008202659),
#    ('fun', 0.007849212),
#    ('need', 0.0078044445),
#    ('shine', 0.0070298486)]],
#  [39,
#   31.655770935959026,
#   [('love', 0.038794544),
#    ('waiting', 0.029818162),
#    ('hard', 0.025576748),
#    ('name', 0.023888811),
#    ('alone', 0.014872185),
#    ('night', 0.0141484765),
#    ('tell', 0.013050088),
#    ('summer', 0.011804219),
#    ('only', 0.010973056),
#    ('dream', 0.0109618865)]],
#  [26,
#   29.60663017963134,
#   [('ash', 0.024752125),
#    ("can't", 0.016293202),
#    ('chill', 0.011914457),
#    ('world', 0.011167348),
#    ('am', 0.010958163),
#    ('domino', 0.010726764),
#    ('back', 0.009622936),
#    ('take', 0.009555222),
#    ('girl', 0.009272065),
#    ('love', 0.009238177)]],
#  [91,
#   28.969081140065555,
#   [('home', 0.43406788),
#    ('non', 0.04872294),
#    ('worry', 0.03264145),
#    ("chi't", 0.031123687),
#    ('bang', 0.022596978),
#    ('chuction', 0.021109613),
#    ('che', 0.019119283),
#    ('chiudi', 0.014340149),
#    ('trouble', 0.013512732),
#    ('sono', 0.010716322)]],
#  [60,
#   28.18157742344556,
#   [('back', 0.15869196),
#    ('woo', 0.119860224),
#    ('room', 0.037831396),
#    ('ac', 0.036011357),
#    ('wow', 0.030444875),
#    ('step', 0.028308166),
#    ('line', 0.025509896),
#    ('heart', 0.024757542),
#    ('google', 0.0219818),
#    ('say', 0.020435032)]],
#  [41,
#   26.338481120471442,
#   [('take', 0.036552895),
#    ('away', 0.028199563),
#    ('rain', 0.024080846),
#    ('id', 0.020036574),
#    ('stay', 0.012304469),
#    ('love', 0.011024567),
#    ('tears', 0.01037053),
#    ('shaker', 0.009383734),
#    ('yes', 0.0088363215),
#    ('honey', 0.007978096)]],
#  [32,
#   25.612012476901327,
#   [('love', 0.08320164),
#    ('give', 0.05531836),
#    ('let', 0.029520534),
#    ("let's", 0.027620358),
#    ('night', 0.015548285),
#    ('fall', 0.015395584),
#    ('girl', 0.015255217),
#    ('take', 0.013808018),
#    ('sweet', 0.012707822),
#    ("won't", 0.011996228)]],
#  [14,
#   25.456448119533434,
#   [('drunk', 0.2782605),
#    ('invalid', 0.11639201),
#    ('love', 0.010970543),
#    ('yes', 0.008044911),
#    ('shut', 0.00802908),
#    ('baby', 0.0065716463),
#    ('need', 0.006233945),
#    ('let', 0.0059323832),
#    ('say', 0.0058130664),
#    ('new', 0.0053548208)]],
#  [89,
#   25.295129805796478,
#   [('sorry', 0.032352243),
#    ('say', 0.018515436),
#    ('think', 0.017248027),
#    ('10', 0.015854262),
#    ("can't", 0.015134229),
#    ('need', 0.014524663),
#    ('love', 0.012680049),
#    ('tt', 0.011490749),
#    ('forgot', 0.011433413),
#    ('password', 0.0099566765)]],
#  [98,
#   24.597845147811768,
#   [('love', 0.08148447),
#    ('diamond', 0.030077007),
#    ('yes', 0.024238873),
#    ('shine', 0.01860627),
#    ('diamonds', 0.018186985),
#    ('fall', 0.017470947),
#    ('leave', 0.01722321),
#    ('last', 0.015025219),
#    ('am', 0.014921744),
#    ('let', 0.011273792)]],
#  [67,
#   24.56540779136276,
#   [('hey!', 0.030352509),
#    ('singing', 0.021854447),
#    ('take', 0.016578723),
#    ("can't", 0.016082551),
#    ('care', 0.012178163),
#    ('heart', 0.010370693),
#    ('today', 0.009982178),
#    ('hush', 0.00981714),
#    ('away', 0.009268753),
#    ('pain', 0.009047155)]],
#  [77,
#   24.359053775497614,
#   [('best', 0.08683627),
#    ('dad', 0.046388905),
#    ('say', 0.033943158),
#    ('touch', 0.02929626),
#    ('rousing', 0.022909373),
#    ('higher', 0.014393715),
#    ('course', 0.012053537),
#    ('mean', 0.011439532),
#    ('prova', 0.011302627),
#    ('girl', 0.010516344)]],
#  [95,
#   24.164850642468537,
#   [('night', 0.11453562),
#    ('meet', 0.033344146),
#    ('funny', 0.021247284),
#    ('hide', 0.019376095),
#    ('love', 0.017893884),
#    ('feel', 0.01514925),
#    ('ba', 0.014225498),
#    ('gonna', 0.012977333),
#    ('news', 0.0122351805),
#    ('teen', 0.011830764)]],
#  [5,
#   23.18776427477178,
#   [('matter', 0.022506401),
#    ('made', 0.019806935),
#    ('business', 0.019588733),
#    ('love', 0.0165584),
#    ('lose', 0.015191164),
#    ('trust', 0.01506504),
#    ('bad', 0.014885587),
#    ("can't", 0.013773497),
#    ("doesn't", 0.012640899),
#    ('say', 0.011724572)]],
#  [12,
#   23.00463680650546,
#   [('life', 0.0736887),
#    ('give', 0.02194238),
#    ('up!', 0.0217082),
#    ('tonight', 0.02106818),
#    ('baby', 0.011181026),
#    ('love', 0.009209522),
#    ('night', 0.0084577445),
#    ("we'll", 0.008179838),
#    ('let', 0.008083917),
#    ('say', 0.007933808)]],
#  [73,
#   21.607513348110388,
#   [('babe', 0.051262923),
#    ('sweet', 0.04663795),
#    ('fire', 0.040059615),
#    ('stronger', 0.034800354),
#    ('world', 0.01927848),
#    ('honey', 0.016629232),
#    ('real', 0.015486197),
#    ('burn', 0.015040767),
#    ("can't", 0.01343632),
#    ('oh-oh-oh', 0.013144565)]],
#  [51,
#   21.59927057887444,
#   [('save', 0.03472461),
#    ('feel', 0.02809663),
#    ('share', 0.028010488),
#    ('welcome', 0.020168547),
#    ('new', 0.015833242),
#    ('need', 0.015702346),
#    ('takes', 0.01368266),
#    ('facebook', 0.013540221),
#    ("that's", 0.012854733),
#    ('love', 0.011746582)]],
#  [10,
#   21.388338352131996,
#   [('dream', 0.046960663),
#    ('spicy', 0.022241138),
#    ('wish', 0.014359629),
#    ('take', 0.0127617065),
#    ('big', 0.0099212425),
#    ('feel', 0.009574538),
#    ('new', 0.007841814),
#    ('love', 0.007794028),
#    ('money', 0.0077018235),
#    ('life', 0.007216392)]],
#  [57,
#   21.33317784602741,
#   [('follow', 0.11478444),
#    ('wait', 0.052110054),
#    ('dark', 0.04507332),
#    ('spring', 0.024186153),
#    ('winter', 0.022902597),
#    ('little', 0.021903384),
#    ('year', 0.01949816),
#    ('subscribe', 0.017105091),
#    ('pantyhose', 0.01644439),
#    ('came', 0.0127096195)]],
#  [79,
#   21.04565708088603,
#   [('ка', 0.14396137),
#    ('imma', 0.073668696),
#    ('thinking', 0.042840697),
#    ('love', 0.041390758),
#    ('ay', 0.032757957),
#    ('ya', 0.031389005),
#    ('girl', 0.02503323),
#    ('cuz', 0.023190161),
#    ('crazy', 0.022277527),
#    ('sorry', 0.022134542)]],
#  [31,
#   19.84461768565643,
#   [('give', 0.032258008),
#    ('say', 0.022439733),
#    ('fine', 0.013869102),
#    ('love', 0.013321884),
#    ('feel', 0.012641433),
#    ('night', 0.012298029),
#    ('club', 0.012202537),
#    ("we're", 0.009284414),
#    ('back', 0.008618958),
#    ('think', 0.0075864047)]],
#  [76,
#   19.821364965492194,
#   [('dimensioni', 0.08445808),
#    ('yes', 0.027509479),
#    ('girls', 0.018171173),
#    ('crush', 0.016808797),
#    ('(still', 0.010666102),
#    ('take', 0.01063229),
#    ('ayy', 0.010161986),
#    ('baby!', 0.009807648),
#    ('say', 0.0086646695),
#    ('feeling', 0.008416493)]],
#  [58,
#   19.599617856763416,
#   [('change', 0.08469744),
#    ('moon', 0.055819407),
#    ('hidden', 0.025291096),
#    ('say', 0.020288374),
#    ('leave', 0.019155346),
#    ('u)', 0.019046025),
#    ('breakage', 0.015427631),
#    ('let', 0.014321459),
#    ('think', 0.013796785),
#    ('love', 0.012349018)]],
#  [50,
#   19.216116449265883,
#   [('osserva', 0.102344744),
#    ('air', 0.03695378),
#    ('bomb', 0.03337775),
#    ('expression', 0.024016103),
#    ('fighting', 0.020046216),
#    ('sorry', 0.018760994),
#    ("can't", 0.018326057),
#    ('nice', 0.01746305),
#    ('rice', 0.017220685),
#    ('news', 0.016668756)]],
#  [22,
#   19.079869842368225,
#   [('kim', 0.05699465),
#    ('mob', 0.028613826),
#    ('room', 0.0262661),
#    ('city', 0.022121303),
#    ('luv', 0.01863229),
#    ('god', 0.015538269),
#    ('organization', 0.015106941),
#    ('life', 0.014818886),
#    ('mafioso', 0.014225719),
#    ('gucci', 0.013337095)]],
#  [1,
#   18.042160381093254,
#   [('dance', 0.30848926),
#    ("let's", 0.022657897),
#    ('celebrate', 0.014044733),
#    ('closer', 0.012419896),
#    ('feel', 0.0114891045),
#    ('music', 0.009373203),
#    ('night', 0.00844071),
#    ('sorry', 0.007967253),
#    ("can't", 0.007802324),
#    ('move', 0.006736298)]],
#  [34,
#   17.56666010244362,
#   [('sì', 0.23879538),
#    ('traduzione', 0.038151804),
#    ('di', 0.027272189),
#    ('cry', 0.021103015),
#    ('solo', 0.01895189),
#    ('browse', 0.018764416),
#    ('compare_at_price_min', 0.015985101),
#    ('beep', 0.01441003),
#    ('price_min}}', 0.013681279),
#    ('tempo', 0.013360067)]],
#  [47,
#   16.869623429950025,
#   [('call', 0.13171755),
#    ('uh', 0.07498968),
#    ('bad', 0.04706074),
#    ('god', 0.03789002),
#    ('ayyyy', 0.024573173),
#    ('special', 0.018129505),
#    ('yes', 0.012916254),
#    ('guy', 0.0128711),
#    ('rose', 0.011891123),
#    ('new', 0.011289679)]],
#  [59,
#   16.415600603075745,
#   [('it!', 0.03587605),
#    ('sexy', 0.03304312),
#    ('yes!', 0.023314359),
#    ('little', 0.022647528),
#    ('365', 0.01907017),
#    ('damn', 0.018896721),
#    ('worry', 0.016143125),
#    ('fire', 0.015680978),
#    ('am', 0.013617086),
#    ('seoul', 0.013488521)]],
#  [90,
#   16.412026529008017,
#   [('feel', 0.047384266),
#    ('woman', 0.032211628),
#    ('keep', 0.012011487),
#    ('love', 0.011964954),
#    ('minus', 0.011699976),
#    ('calling', 0.010639804),
#    ('aya', 0.010389726),
#    ('heart', 0.010169044),
#    ('close', 0.009708212),
#    ("there's", 0.0096915485)]],
#  [2,
#   16.372776372887984,
#   [('love', 0.0738129),
#    ('sick', 0.029269082),
#    ('back', 0.015632225),
#    ('need', 0.014733804),
#    ('place', 0.013221959),
#    ('found', 0.012813675),
#    ('ooh', 0.012205012),
#    ('loved', 0.009903704),
#    ('take', 0.00954871),
#    ('say', 0.008515551)]],
#  [42,
#   16.14509067320114,
#   [('surf', 0.050267503),
#    ('cream', 0.018669294),
#    ('enemy', 0.017963532),
#    ('ice', 0.016519265),
#    ('down', 0.016311748),
#    ('taste', 0.012494651),
#    ('need', 0.01040391),
#    ('mama', 0.009795302),
#    ('throw', 0.009278572),
#    ("can't", 0.008920882)]],
#  [64,
#   16.10307301215971,
#   [('tell', 0.040972237),
#    ('love', 0.01806909),
#    ('need', 0.010992198),
#    ("you'll", 0.010064148),
#    ('only', 0.008261214),
#    ('girl', 0.007919303),
#    ('night', 0.0077102715),
#    ('fine', 0.0074148024),
#    ('little', 0.0072851386),
#    ('city', 0.007140543)]],
#  [96,
#   15.948140679349763,
#   [('thank', 0.053789318),
#    ('up!', 0.042005133),
#    ('yes)', 0.018736683),
#    ('lucky', 0.018255848),
#    ('understand', 0.017910145),
#    ('kill', 0.017899299),
#    ('(yes', 0.01758307),
#    ('next', 0.014160181),
#    ('on!', 0.011373303),
#    ('training', 0.010844131)]],
#  [74,
#   15.697320417887113,
#   [('need', 0.07408588),
#    ('love', 0.037497345),
#    ('shy', 0.031550974),
#    ('entertainment', 0.026956983),
#    ('lights', 0.02662481),
#    ('try', 0.022376096),
#    ('kiss', 0.01953364),
#    ('和하', 0.015186337),
#    ('eyes', 0.014465623),
#    ('control', 0.011203371)]],
#  [40,
#   15.662881689963342,
#   [('boom', 0.12921028),
#    ('eyes', 0.033174306),
#    ('say', 0.017379683),
#    ("can't", 0.014215315),
#    ('slip', 0.014189122),
#    ('super', 0.014013476),
#    ('bum', 0.013104503),
#    ('wow', 0.012555275),
#    ('tie', 0.0122083025),
#    ('(not', 0.010109168)]],
#  [69,
#   15.614432957169356,
#   [('oh!', 0.066283464),
#    ('fake', 0.024878781),
#    ('let', 0.021516744),
#    ("can't", 0.020142922),
#    ('click', 0.01729176),
#    ('am', 0.015631247),
#    ('down', 0.015024753),
#    ('party', 0.013906181),
#    ('are)', 0.012436578),
#    ('shooting', 0.011188896)]],
#  [54,
#   15.479746837313087,
#   [('happiness', 0.030433642),
#    ('detail', 0.018208954),
#    ('cold', 0.017671047),
#    ('ah', 0.015978327),
#    ('story', 0.012090088),
#    ('truth', 0.010784457),
#    ('star', 0.010536576),
#    ('yeh)', 0.010054286),
#    ('years', 0.009249652),
#    ('rum', 0.008440611)]],
#  [49,
#   15.35373801940068,
#   [('girl', 0.0171612),
#    ('shit', 0.015333962),
#    ('tell', 0.013078495),
#    ('say', 0.012333948),
#    ('love', 0.011472015),
#    ('fuck', 0.008677294),
#    ('back', 0.008446011),
#    ('take', 0.007195744),
#    ('yes', 0.0069325543),
#    ("can't", 0.006735494)]],
#  [13,
#   14.927356701180997,
#   [('share', 0.06606616),
#    ('twitter', 0.052653745),
#    ('knocking', 0.023543227),
#    ("can't", 0.022266457),
#    ('zione', 0.02048428),
#    ('baby', 0.01848413),
#    ("we're", 0.018163495),
#    ('yes', 0.015175381),
#    ('making', 0.014806433),
#    ('hands', 0.014692622)]],
#  [37,
#   14.866437009026868,
#   [('ha', 0.049549304),
#    ('future', 0.038857747),
#    ('fun', 0.031135904),
#    ('call', 0.029187093),
#    ('honey', 0.026804341),
#    ('alone', 0.018667927),
#    ('turning', 0.018491007),
#    ('wants', 0.017377894),
#    ('heart', 0.015907189),
#    ('dum', 0.015367319)]],
#  [93,
#   14.417166494892172,
#   [('back', 0.047184207),
#    ('woo', 0.034440275),
#    ('home', 0.018371398),
#    ('coming', 0.016773082),
#    ('whoa', 0.01583216),
#    ('dead', 0.015730942),
#    ('take', 0.012389356),
#    ('comfort', 0.010603907),
#    ("let's", 0.010258655),
#    ('(come', 0.010116122)]],
#  [3,
#   14.339951494941943,
#   [('boy', 0.1654604),
#    ('hell', 0.02034674),
#    ('song', 0.02019815),
#    ('hope', 0.018074585),
#    ('(for', 0.014498117),
#    ('say', 0.011531952),
#    ('gives', 0.011385535),
#    ('ago', 0.011314686),
#    ("can't", 0.010576813),
#    ('face', 0.010479076)]],
#  [61,
#   13.628537132126894,
#   [('shake', 0.051304925),
#    ('release', 0.03719419),
#    ('orientation', 0.026253968),
#    ('illuminate', 0.0230604),
#    ('bubble', 0.01904332),
#    ('dam', 0.01722123),
#    ('candy', 0.015832985),
#    ('world', 0.014905487),
#    ('io', 0.013728535),
#    ('(all)', 0.012258533)]],
#  [56,
#   13.572238636403654,
#   [('trauma', 0.0327033),
#    ('stop!', 0.026077872),
#    ('dat', 0.022093285),
#    ('lover', 0.021007612),
#    ('goodbye', 0.01735226),
#    ('saying', 0.015249173),
#    ('animals', 0.013356608),
#    ('later', 0.012958717),
#    ('lee', 0.012686428),
#    ("rollin'", 0.010554815)]],
#  [38,
#   13.32347849010921,
#   [('child', 0.7034142),
#    ('down', 0.017776199),
#    ('girls', 0.0072799986),
#    ('love', 0.0070581795),
#    ('goccia', 0.0055193333),
#    ('sunflower', 0.0051059215),
#    ('mic', 0.005095512),
#    ('take', 0.004565072),
#    ('boy', 0.0037422024),
#    ('sorry', 0.002677049)]],
#  [35,
#   13.297731954315623,
#   [('straight', 0.034245495),
#    ('free', 0.019748393),
#    ('smile', 0.017632484),
#    ('ah', 0.015214432),
#    ('lost', 0.014974008),
#    ('poison', 0.013504513),
#    ('honey', 0.013024521),
#    ('well', 0.012684485),
#    ('pink', 0.011644017),
#    ('take', 0.0104367975)]],
#  [0,
#   13.079404718523165,
#   [('head', 0.12192987),
#    ('down', 0.06088545),
#    ('coming', 0.031411506),
#    ('round', 0.021818278),
#    ('magic', 0.019732546),
#    ('tick', 0.018030629),
#    ('swing', 0.01694208),
#    ('imagination', 0.015898082),
#    ('teacher', 0.013987745),
#    ('united', 0.013962499)]],
#  [17,
#   12.955139557232997,
#   [('low', 0.0902053),
#    ('rewind', 0.04191687),
#    ('shining', 0.027669929),
#    ('jump', 0.020565871),
#    ('armor', 0.01850969),
#    ('gno', 0.013207977),
#    ('job', 0.011835017),
#    ('love', 0.0105117485),
#    ('upstairs', 0.010495934),
#    ('film', 0.010492478)]],
#  [92,
#   12.95475512108851,
#   [('singing', 0.39517233),
#    ('run', 0.05775776),
#    ('hours', 0.028331913),
#    ('on!', 0.023793455),
#    ('tan', 0.021938318),
#    ('24', 0.02181257),
#    ('young', 0.01458546),
#    ('save', 0.00878448),
#    ("let's", 0.008589118),
#    ('bulletproof', 0.00827128)]],
#  [88,
#   12.782945798233868,
#   [("let's", 0.03072364),
#    ('youth', 0.023291195),
#    ('happy', 0.019138908),
#    ('sorry', 0.017598413),
#    ("we're", 0.01720091),
#    ('low', 0.014872645),
#    ('number', 0.014556353),
#    ('take', 0.01239703),
#    ('points', 0.011744869),
#    ('disappear', 0.010896692)]],
#  [52,
#   12.613699107219418,
#   [('dan', 0.16362746),
#    ('butterfly', 0.088384554),
#    ('fly', 0.041441545),
#    ('(no', 0.021222657),
#    ('love', 0.019150903),
#    ('woah', 0.017639171),
#    ('don’t', 0.017548375),
#    ('letters', 0.017004509),
#    ('dark', 0.015962124),
#    ('no)', 0.014678423)]],
#  [78,
#   12.608982497819397,
#   [('put', 0.020354992),
#    ('back', 0.016249271),
#    ("can't", 0.013606757),
#    ('take', 0.010577544),
#    ('talk', 0.00928698),
#    ('say', 0.007885847),
#    ('drops', 0.0077857487),
#    ('call', 0.006908496),
#    ('life', 0.0059991847),
#    ('drip', 0.0057698255)]],
#  [81,
#   12.444892059681024,
#   [('dawn', 0.05557831),
#    ('need', 0.029528243),
#    ('rid', 0.028725231),
#    ('love', 0.022414116),
#    ('persons', 0.020633973),
#    ('laughter', 0.014801815),
#    ('only', 0.014488948),
#    ('dream)', 0.013527168),
#    ('life', 0.012782691),
#    ("let's", 0.011709998)]],
#  [15,
#   12.40061601203206,
#   [('heart', 0.027939018),
#    ('million', 0.025297454),
#    ('night', 0.021547081),
#    ('stay', 0.020897493),
#    ('give', 0.01883172),
#    ('sauna', 0.016143082),
#    ('run', 0.014614806),
#    ('break', 0.012263804),
#    ('purple', 0.010744826),
#    ('distant', 0.010479394)]],
#  [48,
#   12.399679220531652,
#   [('hot', 0.24992394),
#    ('[bleep', 0.0486153),
#    ('[bleep]', 0.027786616),
#    ('sorry', 0.026670044),
#    ('hi', 0.016597582),
#    ('24', 0.015706016),
#    ('healing', 0.011465513),
#    ('heart', 0.010302881),
#    ("can't", 0.009996161),
#    ('say', 0.009799116)]],
#  [7,
#   12.254239803819019,
#   [('night', 0.055256758),
#    ("we're", 0.047623813),
#    ('awake', 0.0346223),
#    ('yeh', 0.033885177),
#    ('yes', 0.020722058),
#    ('ready', 0.019295515),
#    ("who's", 0.012568956),
#    ('luck', 0.012134784),
#    ('rises', 0.011965904),
#    ('ay', 0.008933972)]],
#  [27,
#   12.24477100984359,
#   [('top', 0.016772356),
#    ('(i', 0.012125332),
#    ('diving', 0.012046751),
#    ('love', 0.011201115),
#    ('little', 0.010725307),
#    ('leave', 0.010431624),
#    ("can't", 0.008630378),
#    ('girl', 0.008480087),
#    ('take', 0.007711877),
#    ('feel', 0.0076112323)]],
#  [20,
#   12.229835663236827,
#   [('nana', 0.09782183),
#    ('ready', 0.019734679),
#    ('sweat', 0.01887766),
#    ('bitter', 0.017866336),
#    ('love', 0.016389068),
#    ('(a', 0.0148761505),
#    ("can't", 0.014776029),
#    ('keep', 0.013091063),
#    ('feel', 0.0123198),
#    ('face', 0.012214629)]],
#  [44,
#   12.20079042448242,
#   [('bang', 0.042040586),
#    ('think', 0.037475456),
#    ('down', 0.025432074),
#    ('bad', 0.023174508),
#    ('try', 0.018915294),
#    ('let', 0.017960114),
#    ('whoo', 0.016275296),
#    ('worried', 0.014443348),
#    ('lonely', 0.012944216),
#    ('yes', 0.011824008)]],
#  [36,
#   12.17560898704187,
#   [('once', 0.04053071),
#    ('think', 0.03518917),
#    ('let', 0.012448102),
#    ('say', 0.011807763),
#    ('stay', 0.011725586),
#    ('fog', 0.010116031),
#    ('baby', 0.009680726),
#    ('love', 0.009581682),
#    ('celebrate', 0.009441653),
#    ('honey', 0.008668378)]],
#  [28,
#   12.145159977230378,
#   [('music', 0.07082229),
#    ('wild', 0.031727526),
#    ('place', 0.022935236),
#    ('na-na', 0.01949871),
#    ('worse', 0.017303124),
#    ('take', 0.014759796),
#    ("there's", 0.014376883),
#    ('say', 0.013920232),
#    ('blessing', 0.013704708),
#    ('thoughts', 0.012733403)]],
#  [83,
#   11.681150032356982,
#   [('yes', 0.14486383),
#    ('swan', 0.023117596),
#    ('eh-eh', 0.022700083),
#    ('loss', 0.020411698),
#    ('yay', 0.018468253),
#    ('ashes', 0.017921401),
#    ('heart', 0.017479096),
#    ('tu', 0.010676481),
#    ('(oh', 0.010192858),
#    ('light', 0.009850415)]],
#  [82,
#   11.499574861966266,
#   [('rock', 0.11332923),
#    ('paradise', 0.023018938),
#    ('believer', 0.01374557),
#    ('think', 0.01286694),
#    ('fight', 0.012157058),
#    ('ideal', 0.011930462),
#    ('let', 0.010003414),
#    ('take', 0.0099121835),
#    ('pow', 0.00980944),
#    ('ocean', 0.007897445)]],
#  [4,
#   11.485858996099068,
#   [('problem', 0.086722836),
#    ('show', 0.05519405),
#    ('ooh', 0.045836046),
#    ('ragazza', 0.024291422),
#    ('ta', 0.024254061),
#    ('tutto', 0.018769268),
#    ('difference', 0.016071597),
#    ('administration', 0.01513543),
#    ('se', 0.0141327465),
#    ('el', 0.0137111405)]],
#  [66,
#   11.376580919999924,
#   [('singing', 0.21292783),
#    ('summer', 0.06326996),
#    ('break', 0.05893881),
#    ('heart', 0.020965708),
#    ('play', 0.015503079),
#    ('missed', 0.011443177),
#    ('games', 0.008946673),
#    ('mariachi', 0.008883928),
#    ("how's", 0.0084161395),
#    ('baby', 0.008266518)]],
#  [63,
#   11.332402885864667,
#   [('hot', 0.3432136),
#    ('say', 0.017715786),
#    ('hello', 0.013693642),
#    ("can't", 0.008044257),
#    ('win', 0.0066984924),
#    ('feel', 0.0064815856),
#    ('burn', 0.006206147),
#    ('waterfall', 0.006026934),
#    ('type', 0.0056799534),
#    ('world', 0.005304905)]],
#  [53,
#   11.0730112606293,
#   [('born', 0.047384843),
#    ('solosta', 0.03341801),
#    ('datafilesizehumanreadable', 0.020682378),
#    ('{{', 0.020681128),
#    ('}}', 0.020669201),
#    ('cloud', 0.02052784),
#    ('dragon', 0.018846639),
#    ('solo', 0.018741636),
#    ('path', 0.01793307),
#    ('sorry', 0.01613334)]],
#  [24,
#   10.951951689891303,
#   [('light', 0.19909275),
#    ("'em", 0.061109744),
#    ('sneakers', 0.059134703),
#    ('put', 0.056393992),
#    ('ready', 0.019764353),
#    ('blind', 0.015459333),
#    ('turn', 0.01385791),
#    ('makes', 0.013693021),
#    ('wood', 0.013440635),
#    ('call', 0.011744291)]],
#  [23,
#   10.908112196610546,
#   [('days', 0.039948307),
#    ("can't", 0.020499727),
#    ('moonlight', 0.016059186),
#    ('head', 0.015862305),
#    ('take', 0.015832612),
#    ('clover', 0.011860096),
#    ('honey', 0.010533591),
#    ('girl', 0.009761283),
#    ('love', 0.009579947),
#    ('walk', 0.009056649)]],
#  [75,
#   10.868503802642863,
#   [('move', 0.028011994),
#    ('feel', 0.02266842),
#    ('back', 0.02230954),
#    ('mind', 0.01914963),
#    ('emotions', 0.014539329),
#    ('memories', 0.013010803),
#    ('handle', 0.012725987),
#    ('best', 0.011973913),
#    ('attack', 0.011793885),
#    ('let', 0.009430332)]],
#  [43,
#   10.77644723286221,
#   [('man', 0.05569924),
#    ('back', 0.022797778),
#    ('only', 0.011426748),
#    ('和만', 0.010964951),
#    ('real', 0.008826452),
#    ('hot', 0.008812449),
#    ('canta', 0.007601249),
#    ('nigger', 0.007199542),
#    ('shit', 0.0070855613),
#    ('yes', 0.006365992)]],
#  [19,
#   10.677255791013977,
#   [('247', 0.054766815),
#    ('bull', 0.050476674),
#    ('gimme', 0.045491394),
#    ('bass', 0.022113414),
#    ('headphones', 0.021519877),
#    ('thunder', 0.020976337),
#    ('work', 0.019814195),
#    ('ride', 0.019684087),
#    ('labour', 0.019140186),
#    ("can't", 0.01364367)]],
#  [94,
#   10.540016867675604,
#   [('bang', 0.0709449),
#    ('blah', 0.06934606),
#    ('power', 0.0398639),
#    ('wait', 0.022381235),
#    ('rules', 0.018429717),
#    ('shots', 0.015230147),
#    ('say', 0.012658972),
#    ('(ah)', 0.011939815),
#    ('let', 0.011784439),
#    ('only', 0.011653552)]],
#  [84,
#   10.41824446365581,
#   [('universe', 0.15500216),
#    ('woman', 0.13590617),
#    ('candy', 0.07841022),
#    ('inside', 0.030216774),
#    ('ac', 0.028097274),
#    ('sweet', 0.027705181),
#    ('put', 0.01778958),
#    ('first', 0.016481204),
#    ('weird', 0.010606293),
#    ('pop', 0.008589777)]],
#  [9,
#   10.19886713171627,
#   [('mom', 0.11189391),
#    ('nightmare', 0.057129446),
#    ('brave', 0.05190845),
#    ('find', 0.031763468),
#    ("can't", 0.029931275),
#    ('interested', 0.016101979),
#    ('um', 0.014749037),
#    ('live', 0.011101333),
#    ('way', 0.0097900145),
#    ('parts', 0.009503523)]],
#  [33,
#   10.08683046723172,
#   [('man', 0.0341499),
#    ('blame', 0.03200434),
#    ('tell', 0.023848558),
#    ('sunday', 0.022386612),
#    ('time)', 0.019105798),
#    ("(i'll", 0.017980866),
#    ('challenge', 0.015865318),
#    ('bop', 0.014857993),
#    ('neighborhood', 0.01326729),
#    ('whip', 0.010324881)]],
#  [65,
#   9.340761122470667,
#   [('party', 0.066201046),
#    ('hold', 0.040974744),
#    ('blowing', 0.021869093),
#    ('love', 0.02070788),
#    ("doesn't", 0.016453069),
#    ('let', 0.012274657),
#    ('frightened', 0.009830695),
#    ('girl', 0.008984818),
#    ('honey', 0.008600653),
#    ('trip', 0.0075706337)]],
#  [97,
#   9.278599007107005,
#   [('cake', 0.61338764),
#    ('hands', 0.066236444),
#    ('wave', 0.036832523),
#    ('clap', 0.005810886),
#    ('stay', 0.003399607),
#    ('way', 0.003260044),
#    ('air', 0.00312807),
#    ('me)', 0.0029963416),
#    ('hours', 0.0028663478),
#    ('fan', 0.0026942026)]],
#  [16,
#   9.142514175619453,
#   [('words', 0.04407917),
#    ('end', 0.02723807),
#    ('lady', 0.027118133),
#    ('loco', 0.024239462),
#    ('love', 0.022965454),
#    ('reflex', 0.019308496),
#    ('taking', 0.017723024),
#    ('mask', 0.016835619),
#    ('back)', 0.015437755),
#    ('set', 0.015399086)]],
#  [18,
#   9.095897073728793,
#   [('on!', 0.12897941),
#    ('wow!', 0.07267064),
#    ('meet', 0.029656526),
#    ('says', 0.019766003),
#    ('it!', 0.016727366),
#    ('believe', 0.015462855),
#    ('boy!', 0.013409931),
#    ('life', 0.011490451),
#    ('nice', 0.011046905),
#    ('prepared', 0.010974722)]],
#  [45,
#   9.011790368175298,
#   [('girlfriend', 0.043215465),
#    ('yes', 0.02055377),
#    ('drop', 0.018347852),
#    ("that's", 0.017094303),
#    ('account', 0.015260761),
#    ('money', 0.013479343),
#    ('love', 0.013043477),
#    ('round', 0.010828309),
#    ('fall', 0.009994531),
#    ('"lord', 0.009674306)]],
#  [71,
#   8.985450781794952,
#   [('knock', 0.059480418),
#    ('show', 0.041357283),
#    ('money', 0.024824379),
#    ('bitch', 0.021037618),
#    ('asia', 0.020396303),
#    ('praying', 0.016936557),
#    ('mine)', 0.013351243),
#    ('(what)', 0.011140433),
#    ('jelly', 0.009306374),
#    ('hope', 0.00903522)]],
#  [6,
#   8.810761002313939,
#   [('true', 0.09177806),
#    ('dirty', 0.08430994),
#    ('wish', 0.03737389),
#    ('want)', 0.036539797),
#    ('deep', 0.031835172),
#    ('(you', 0.030675523),
#    ('first', 0.029430255),
#    ('simple', 0.02756196),
#    ('sharp', 0.022644976),
#    ('background', 0.012448589)]],
#  [87,
#   8.738119196464595,
#   [('flower', 0.24121794),
#    ('river', 0.051884487),
#    ('count', 0.033247333),
#    ('watch', 0.02664857),
#    ("let's", 0.024124663),
#    ('christmas', 0.019648254),
#    ('freedom', 0.019481152),
#    ('beauty', 0.019433465),
#    ('anymore', 0.013892146),
#    ('back', 0.0134593155)]],
#  [72,
#   8.671738723975523,
#   [('pop', 0.105402626),
#    ('sugar', 0.060881462),
#    ('shoot', 0.0318886),
#    ('nana', 0.023765502),
#    ('kick', 0.02305243),
#    ('desire', 0.020003133),
#    ('bass', 0.016768616),
#    ('walker', 0.010731153),
#    ('only', 0.009589817),
#    ('love', 0.009345922)]],
#  [62,
#   8.066950567339973,
#   [('girl', 0.025374651),
#    ('yes', 0.01933646),
#    ('take', 0.017657736),
#    ('left', 0.011298806),
#    ('money', 0.010887263),
#    ('body', 0.0102577545),
#    ('feel', 0.010087151),
#    ('love', 0.008242419),
#    ('head', 0.0073418543),
#    ('kiss', 0.007197045)]],
#  [68,
#   7.930352989069888,
#   [('tock', 0.119067796),
#    ('crazy', 0.06870877),
#    ('tick', 0.06343204),
#    ('worth', 0.04163387),
#    ('nana', 0.028764948),
#    ('high', 0.015005967),
#    ('bounce', 0.014979409),
#    ('beauty', 0.011442124),
#    ('give', 0.011343857),
#    ('you!', 0.010193084)]],
#  [80,
#   7.928523589246197,
#   [('wake', 0.043334678),
#    ('beautiful', 0.032518264),
#    ('sauce', 0.017811852),
#    ('cardi', 0.016100358),
#    ('love', 0.0152256265),
#    ('part', 0.01004495),
#    ('open', 0.009285573),
#    ('give', 0.009115783),
#    ('bitch', 0.009069145),
#    ('question', 0.008900689)]],
#  [8,
#   7.457770494002489,
#   [('black', 0.103064716),
#    ('yellow', 0.079059236),
#    ('programme', 0.0477396),
#    ('autumn', 0.03467388),
#    ('school', 0.032785084),
#    ('diamonds', 0.025235876),
#    ('festival', 0.024265556),
#    ('difficulty', 0.01778811),
#    ('stupid', 0.012321081),
#    ('last', 0.01222975)]],
#  [99,
#   6.790170890719764,
#   [('part', 0.03264001),
#    ('easy', 0.029613018),
#    ('build', 0.02210361),
#    ('shot', 0.017409246),
#    ('near', 0.017200092),
#    ('guessing', 0.016893763),
#    ('science', 0.016843785),
#    ('numbers', 0.015846591),
#    ('love', 0.010748454),
#    ('say', 0.010550664)]],
#  [29,
#   6.556639877257567,
#   [('work', 0.3816636),
#    ('labour', 0.15371114),
#    ('sugar', 0.0049180444),
#    ('line', 0.004861687),
#    ('back', 0.0044452953),
#    ('m-m-m', 0.003924769),
#    ('fly', 0.0038253043),
#    ('take', 0.003435926),
#    ('impatient', 0.0034321358),
#    ('doo-doo-doo-doo-doo-doo-doo', 0.0034235748)]],
#  [70,
#   6.4589134424827535,
#   [('nana', 0.053961318),
#    ('siren', 0.036342904),
#    ('noise', 0.032970257),
#    ('bow', 0.017362589),
#    ('hol', 0.01582123),
#    ('iron', 0.0116092665),
#    ('lemonade', 0.010014624),
#    ('pa', 0.009132034),
#    ('lana', 0.0090112565),
#    ('days', 0.00867894)]],
#  [21,
#   6.384752001199104,
#   [('start', 0.083147496),
#    ('reason', 0.05791335),
#    ('create', 0.024208086),
#    ('person', 0.01597738),
#    ('deliver', 0.01303981),
#    ('hairdryer', 0.011967209),
#    ('news', 0.0105876215),
#    ('end', 0.010506778),
#    ('likes', 0.0104965735),
#    ('[bleep', 0.009050454)]],
#  [46,
#   3.4256450776524616,
#   [('labour', 0.50193155),
#    ('turn', 0.051754933),
#    ('dirty', 0.006612174),
#    ('need', 0.006127194),
#    ('rollin', 0.004999986),
#    ('work', 0.004763175),
#    ('say', 0.0034474449),
#    ('love', 0.0033197773),
#    ('dirt', 0.0031220645),
#    ('girl', 0.003106673)]]]

# %% [markdown]
# #### Among KPOP

# %%
df_looking = df[df["grouping"].isin(target_and_kpop)].reset_index(drop=True)

# %%
#train model
lyrics_processed = pre_process(df_looking["lyrics"])
dictionary = Dictionary(lyrics_processed)
corpus = [dictionary.doc2bow(text) for text in lyrics_processed]
lda = LdaModel(corpus=corpus, id2word=dictionary, num_topics=100)

# observe topics
topics = lda.print_topics()

# %%
threshold = 0.3

counter = {}
summer = {}

for cnt in range(len(df_looking)):
    if df_looking["grouping"][cnt] != target_group:
        continue
    
    topics = lda.get_document_topics(corpus[cnt], minimum_probability=0)
    
    for topic in topics:
        if topic[1] > threshold:
            counter[topic[0]] = counter.get(topic[0], 0) + 1
            
        summer[topic[0]] = summer.get(topic[0], 0) + float(topic[1])

# %%
lda_html_kpop, vis = save_lda_vis(lda, corpus, dictionary, "lda.html")

vis
# Out:
# PreparedData(topic_coordinates=              x         y  topics  cluster      Freq
# topic
# 42    -0.329163  0.072097       1        1  3.691575
# 94     0.014687 -0.001615       2        1  3.033688
# 46     0.084148  0.292050       3        1  2.618133
# 97     0.015496 -0.030331       4        1  2.493525
# 70    -0.005393 -0.012400       5        1  1.911457
# ...         ...       ...     ...      ...       ...
# 99     0.011053 -0.012487      96        1  0.452940
# 18     0.014994 -0.023869      97        1  0.443615
# 49     0.015575 -0.018848      98        1  0.344424
# 61    -0.314936  0.064302      99        1  0.331858
# 14     0.027791 -0.031690     100        1  0.233532
#
# [100 rows x 5 columns], topic_info=        Term         Freq        Total  Category  logprob  loglift
# 280    child  4067.000000  4067.000000   Default  30.0000  30.0000
# 425    drunk  2238.000000  2238.000000   Default  29.0000  29.0000
# 494     cake  1278.000000  1278.000000   Default  28.0000  28.0000
# 780  singing   809.000000   809.000000   Default  27.0000  27.0000
# 292      hot   935.000000   935.000000   Default  26.0000  26.0000
# ..       ...          ...          ...       ...      ...      ...
# 565      new     2.328766   440.832022  Topic100  -4.9727   0.8163
# 239   that's     1.943103   310.757947  Topic100  -5.1537   0.9849
# 152     soul     1.620424    93.027175  Topic100  -5.3353   2.0094
# 148    shine     1.678837   141.665814  Topic100  -5.2999   1.6242
# 0       baby     2.031473   973.777282  Topic100  -5.1093  -0.1128
#
# [6567 rows x 6 columns], token_table=       Topic      Freq    Term
# term
# 5866       1  0.069987      !!
# 5866      15  0.069987      !!
# 5866      21  0.069987      !!
# 5866      28  0.209962      !!
# 5866      67  0.279949      !!
# ...      ...       ...     ...
# 10443     92  0.534134  看左看右看着
# 6597       1  0.636019    繁體re
# 10444     92  0.533979    跟着偷偷
# 8145      55  0.459109      道道
# 10127     58  0.712590     飲み干
#
# [30314 rows x 3 columns], R=30, lambda_step=0.01, plot_opts={'xlab': 'PC1', 'ylab': 'PC2'}, topic_order=[43, 95, 47, 98, 71, 46, 58, 82, 54, 11, 53, 68, 36, 48, 10, 34, 76, 72, 91, 65, 81, 8, 3, 79, 29, 49, 20, 39, 89, 63, 16, 73, 85, 84, 37, 78, 18, 33, 5, 4, 52, 96, 92, 14, 59, 60, 56, 40, 26, 87, 17, 69, 51, 1, 61, 9, 42, 27, 67, 99, 75, 22, 44, 77, 57, 83, 88, 12, 80, 21, 13, 7, 41, 23, 45, 31, 74, 97, 30, 64, 25, 6, 28, 90, 94, 2, 86, 55, 70, 66, 24, 35, 32, 93, 38, 100, 19, 50, 62, 15])

# %%
_lda_counter_kpop = sort_dictionary(counter)
lda_counter_kpop = []
for tup in _lda_counter_kpop:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_counter_kpop.append(new_tup)
    
lda_counter_kpop
# Out:
# [[97,
#   50,
#   [('love', 0.16675065),
#    ('top', 0.023729648),
#    ('home', 0.016499445),
#    ('crazy', 0.01575896),
#    ("can't", 0.012429796),
#    ('sorry', 0.010583185),
#    ('ay', 0.010504948),
#    ('night', 0.009325708),
#    ('baby', 0.009185769),
#    ('heart', 0.007038093)]],
#  [94,
#   47,
#   [('home', 0.12782477),
#    ('love', 0.01474947),
#    ('let', 0.010766711),
#    ('sorry', 0.01061506),
#    ('heart', 0.009993936),
#    ("let's", 0.00993831),
#    ('shut', 0.009267275),
#    ('say', 0.008660195),
#    ("can't", 0.0063858465),
#    ('baby', 0.0060902163)]],
#  [57,
#   30,
#   [('baby', 0.016240522),
#    ('back', 0.0155747505),
#    ('home', 0.015504847),
#    ('moon', 0.012761522),
#    ('dawn', 0.012319786),
#    ('star', 0.012195145),
#    ("can't", 0.01165075),
#    ('run', 0.010799802),
#    ('night', 0.010342201),
#    ('next', 0.0096074855)]],
#  [10,
#   28,
#   [('home', 0.15137497),
#    ('love', 0.023484707),
#    ('shoot', 0.016338661),
#    ('sorry', 0.01571999),
#    ('give', 0.0153519055),
#    ('shut', 0.012703807),
#    ('dream', 0.008807938),
#    ('comment', 0.0077899126),
#    ('walker', 0.0071673337),
#    ('feel', 0.005373561)]],
#  [52,
#   26,
#   [('gam3', 0.04410344),
#    ('reale', 0.042252503),
#    ('ba', 0.029749516),
#    ('love', 0.023303105),
#    ('need', 0.018589756),
#    ('bum', 0.016174788),
#    ('baby', 0.014435369),
#    ('sorry', 0.011500346),
#    ('am', 0.010890098),
#    ('hold', 0.009286301)]],
#  [53,
#   25,
#   [('della', 0.038019788),
#    ('night', 0.021569919),
#    ('love', 0.016944107),
#    ('home', 0.014112615),
#    ('back', 0.014081619),
#    ('invalid', 0.013511042),
#    ('yes', 0.012554431),
#    ("can't", 0.012269899),
#    ('run', 0.011379417),
#    ('let', 0.010020102)]],
#  [84,
#   24,
#   [('yes', 0.01774208),
#    ('sorry', 0.015195052),
#    ('baby', 0.013851429),
#    ('eyes', 0.012509505),
#    ('woo', 0.011741408),
#    ('love', 0.0114305),
#    ('think', 0.010225064),
#    ("can't", 0.009982516),
#    ('bang', 0.009372565),
#    ('ay', 0.0092297075)]],
#  [80,
#   24,
#   [("can't", 0.040989485),
#    ('love', 0.04065456),
#    ('touch', 0.013810544),
#    ('name', 0.012911736),
#    ('light', 0.011666647),
#    ('understand', 0.011651601),
#    ('only', 0.011345807),
#    ('upgrade', 0.010691658),
#    ('ohohohohohohohohohoh', 0.010554179),
#    ('heart', 0.010374143)]],
#  [81,
#   24,
#   [('bomb', 0.07011091),
#    ('love', 0.04263088),
#    ('home', 0.0356484),
#    ('segreta', 0.028765256),
#    ('detail', 0.025016181),
#    ('girl', 0.02062954),
#    ('nice', 0.017192377),
#    ('back', 0.012323488),
#    ("let's", 0.012305878),
#    ('need', 0.0099079255)]],
#  [64,
#   24,
#   [('new', 0.030782318),
#    ('face', 0.012385703),
#    ('love', 0.012210028),
#    ('nightmare', 0.012089078),
#    ('news', 0.011110859),
#    ('girls', 0.010513647),
#    ('crush', 0.010034666),
#    ('bussare', 0.009615419),
#    ('baby', 0.009034691),
#    ('sorry', 0.008178584)]],
#  [71,
#   23,
#   [('boy', 0.04331147),
#    ('home', 0.021881385),
#    ('love', 0.01725243),
#    ('heart', 0.014947685),
#    ('baby', 0.014437842),
#    ('ay', 0.012835817),
#    ('ya', 0.010650968),
#    ('seguire', 0.010111804),
#    ('cuz', 0.00966705),
#    ('dance', 0.009488817)]],
#  [2,
#   23,
#   [('invalid', 0.1467197),
#    ('love', 0.030205268),
#    ("can't", 0.019210862),
#    ('yes', 0.012165884),
#    ('red', 0.011720955),
#    ('power', 0.01048106),
#    ('back', 0.0075523416),
#    ('grande', 0.0074034804),
#    ('sorry', 0.007027368),
#    ('baby', 0.0068559367)]],
#  [17,
#   23,
#   [('upgrade', 0.038973052),
#    ('boy', 0.020850975),
#    ('love', 0.020786623),
#    ('give', 0.018798122),
#    ('feel', 0.0130616),
#    ('heart', 0.0126218395),
#    ("can't", 0.0118156085),
#    ('home', 0.009471307),
#    ('news', 0.009320715),
#    ('let', 0.008927532)]],
#  [67,
#   23,
#   [('eyes', 0.017556662),
#    ('mom', 0.016612366),
#    ('sorry', 0.013501793),
#    ('next', 0.012673479),
#    ("can't", 0.012566901),
#    ("we're", 0.011424663),
#    ('love', 0.011327522),
#    ('butterfly', 0.009924907),
#    ('oriente', 0.009261157),
#    ('point', 0.008632729)]],
#  [4,
#   22,
#   [('invalid', 0.097449444),
#    ('ring', 0.015943803),
#    ('baby', 0.014935152),
#    ("can't", 0.013949086),
#    ('swipe', 0.012088089),
#    ('night', 0.011110958),
#    ('give', 0.010371956),
#    ('next', 0.010259953),
#    ('sorry', 0.00991315),
#    ('yes', 0.009641248)]],
#  [19,
#   22,
#   [('heart', 0.022139592),
#    ('sorry', 0.021523768),
#    ('love', 0.020401856),
#    ("we're", 0.019081226),
#    ("let's", 0.016824378),
#    ('eyes', 0.011836874),
#    ('air', 0.009486957),
#    ('light', 0.008992257),
#    ('fine', 0.008247175),
#    ('world', 0.006883051)]],
#  [47,
#   22,
#   [('vacanza', 0.05634885),
#    ('zu', 0.033729784),
#    ('home', 0.021260737),
#    ('love', 0.020623356),
#    ('cry', 0.016015451),
#    ('baby', 0.012914427),
#    ('[bleep]', 0.0127738165),
#    ('heart', 0.011490742),
#    ('[bleep', 0.0107541),
#    ('girl', 0.010652701)]],
#  [90,
#   21,
#   [('gno', 0.069748685),
#    ('yes', 0.020196497),
#    ('(eh-oh)', 0.016220946),
#    ('sorry', 0.012572533),
#    ('pain', 0.012522928),
#    ('care', 0.0088795815),
#    ('find', 0.008777268),
#    ('hey!', 0.008344996),
#    ("can't", 0.008141631),
#    ('bring', 0.008079871)]],
#  [48,
#   21,
#   [('universe', 0.03295549),
#    ('(you', 0.015924724),
#    ('way', 0.015259403),
#    ('are)', 0.012769747),
#    ('world', 0.011893589),
#    ('hand', 0.010686648),
#    ('light', 0.009092204),
#    ("we're", 0.007938073),
#    ('lipstick', 0.0078414865),
#    ('first', 0.0077448953)]],
#  [72,
#   20,
#   [('am', 0.024005208),
#    ('ash', 0.019334652),
#    ('take', 0.018108932),
#    ('bussare', 0.01608987),
#    ('bad', 0.01493204),
#    ('leave', 0.014365306),
#    ('love', 0.013882952),
#    ('door', 0.011768866),
#    ('knock', 0.011710851),
#    ('attention', 0.011579622)]],
#  [38,
#   20,
#   [('sorry', 0.023194546),
#    ('love', 0.019957138),
#    ("let's", 0.015475284),
#    ('honey', 0.012757257),
#    ('na-na', 0.01027287),
#    ('news', 0.009914957),
#    ("i've", 0.008999681),
#    ('heart', 0.008952724),
#    ("can't", 0.008245187),
#    ('let', 0.007502725)]],
#  [70,
#   20,
#   [('hands', 0.2389585),
#    ('summer', 0.019433027),
#    ('fall', 0.017144646),
#    ('boy', 0.01173957),
#    ('on!', 0.0097527485),
#    ('love', 0.008895098),
#    ("can't", 0.0082551045),
#    ('let', 0.0075842133),
#    ('prova', 0.0073293145),
#    ('roll', 0.0072203446)]],
#  [36,
#   19,
#   [('run', 0.024904426),
#    ('yes', 0.023118686),
#    ('let', 0.020142414),
#    ('stay', 0.016333582),
#    ('love', 0.014170385),
#    ('back', 0.01357604),
#    ('century', 0.011099443),
#    ('19th', 0.010749071),
#    ('am', 0.010444905),
#    ('sorry', 0.010080393)]],
#  [15,
#   19,
#   [('gno', 0.067851275),
#    ('love', 0.023838514),
#    ('gold', 0.015075807),
#    ('beep', 0.015070767),
#    ('heart', 0.014877637),
#    ('stay', 0.0127385035),
#    ('chica', 0.012166175),
#    ('woman', 0.012151501),
#    ('sorry', 0.011505805),
#    ('let', 0.010732237)]],
#  [35,
#   19,
#   [('put', 0.027048219),
#    ('beep', 0.016669672),
#    ("'em", 0.01509921),
#    ('sì', 0.015057823),
#    ('sneakers', 0.0126046175),
#    ('uh', 0.011904652),
#    ('traduzione', 0.0106969),
#    ('back', 0.010129745),
#    ('ready', 0.0098672705),
#    ('yes', 0.009020781)]],
#  [68,
#   18,
#   [('only', 0.04065752),
#    ("rollin'", 0.021173371),
#    ('feel', 0.020832602),
#    ('love', 0.019719439),
#    ('million', 0.011293748),
#    ('need', 0.010741646),
#    ('dream', 0.010487443),
#    ('mind', 0.00963994),
#    ('special', 0.009523569),
#    ('loco', 0.008743172)]],
#  [3,
#   18,
#   [('love', 0.025814928),
#    ('running', 0.0152249895),
#    ("can't", 0.014994677),
#    ('let', 0.01419843),
#    ('contact', 0.01387562),
#    ('fly', 0.011978124),
#    ('true', 0.010869492),
#    ('segreta', 0.010686398),
#    ('take', 0.010381715),
#    ('sorry', 0.009161433)]],
#  [78,
#   18,
#   [('ка', 0.19221826),
#    ('dad', 0.11388306),
#    ('love', 0.027028587),
#    ('crazy', 0.024651166),
#    ('pop', 0.01952387),
#    ('sorry', 0.01908923),
#    ('bad', 0.0102052335),
#    ('only', 0.008839579),
#    ('sweet', 0.00706711),
#    ('sick', 0.0069154873)]],
#  [62,
#   18,
#   [('hot', 0.018369637),
#    ('sorry', 0.012071122),
#    ('segreta', 0.011824048),
#    ('stronger', 0.010379045),
#    ('love', 0.009224176),
#    ('feel', 0.009106674),
#    ('fight', 0.00838961),
#    ('hi', 0.008314073),
#    ('say', 0.008293412),
#    ('sky', 0.008101289)]],
#  [58,
#   18,
#   [('non', 0.026367392),
#    ('call', 0.025913093),
#    ("can't", 0.014400341),
#    ('sorry', 0.012324833),
#    ('miss', 0.009326279),
#    ('fun', 0.008431896),
#    ('find', 0.008393804),
#    ('beat', 0.008297535),
#    ('home', 0.008226919),
#    ('watch', 0.0075188624)]],
#  [41,
#   18,
#   [('signals', 0.02785127),
#    ('meet', 0.016889729),
#    ('sorry', 0.015623756),
#    ('mago', 0.012044867),
#    ('tak', 0.012032399),
#    ('heart', 0.011665599),
#    ("can't", 0.010775586),
#    ('news', 0.009660988),
#    ('let', 0.00909104),
#    ('yes', 0.008718114)]],
#  [28,
#   17,
#   [('boy', 0.055597596),
#    ('dam', 0.03964145),
#    ('bad', 0.028448788),
#    ('love', 0.021010324),
#    ('yes', 0.019931275),
#    ('twenty', 0.017122813),
#    ('fine', 0.012547638),
#    ('segreta', 0.011898808),
#    ('problem', 0.0110663595),
#    ('kill', 0.009981343)]],
#  [7,
#   17,
#   [('invalid', 0.1635583),
#    ('detail', 0.035763755),
#    ('jump', 0.018646777),
#    ('yes', 0.015002492),
#    ('bang', 0.014338299),
#    ('let', 0.013172389),
#    ('job', 0.011795936),
#    ('feel', 0.010764498),
#    ("chi't", 0.009885976),
#    ('top', 0.008967736)]],
#  [59,
#   17,
#   [('dan', 0.016670235),
#    ('last', 0.012956485),
#    ('{{if', 0.011810652),
#    ('price_varies}', 0.011760713),
#    ('left', 0.0112735),
#    ('take', 0.010398725),
#    ('light', 0.010326407),
#    ('sequence', 0.010083502),
#    ('final', 0.009681232),
#    ('wave', 0.008483041)]],
#  [50,
#   16,
#   [('rock', 0.05680049),
#    ('head', 0.025273122),
#    ('down', 0.016805148),
#    ('shy', 0.014366384),
#    ("that's", 0.013490187),
#    ('detail', 0.012205601),
#    ('let', 0.011451162),
#    ('take', 0.010229913),
#    ('top', 0.009694538),
#    ('sorry', 0.009519365)]],
#  [83,
#   16,
#   [('oriente', 0.061350603),
#    ('love', 0.0161338),
#    ('call', 0.014333189),
#    ('ha', 0.01412979),
#    ('hero', 0.013585727),
#    ('rose', 0.013223643),
#    ('play', 0.01223138),
#    ('vie', 0.01139422),
#    ('man', 0.010213635),
#    ('heart', 0.008712601)]],
#  [91,
#   16,
#   [('sorry', 0.018290225),
#    ('baby', 0.01817035),
#    ('ruin', 0.01483631),
#    ('shimmy', 0.013541033),
#    ('seguire', 0.0133542195),
#    ('only', 0.012860307),
#    ('armoured', 0.0114243245),
#    ('ah!', 0.011211329),
#    ('tempo', 0.010968776),
#    ("can't", 0.010539905)]],
#  [26,
#   16,
#   [('ba', 0.06454483),
#    ('afraid', 0.020321049),
#    ('hands', 0.018077316),
#    ('love', 0.017283518),
#    ('ha', 0.015571563),
#    ('easy', 0.012959202),
#    ('gimme', 0.0112502705),
#    ('blessing', 0.009803197),
#    ('dream', 0.009165996),
#    ('butterfly', 0.008771283)]],
#  [88,
#   16,
#   [('prova', 0.031918596),
#    ('woo', 0.027318813),
#    ('wee', 0.02513513),
#    ('love', 0.016427498),
#    ('switch', 0.01486969),
#    ('ring', 0.014096509),
#    ('heart', 0.01252456),
#    ('mic', 0.011530383),
#    ('home', 0.011286949),
#    ('life', 0.011198598)]],
#  [20,
#   16,
#   [('love', 0.043926246),
#    ('pop', 0.0372166),
#    ('prova', 0.010394848),
#    ('let', 0.010178246),
#    ("chi't", 0.009850608),
#    ('man', 0.009219298),
#    ('(na', 0.008105732),
#    ('na)', 0.008099732),
#    ('dirty', 0.007476477),
#    ('tell', 0.006790014)]],
#  [0,
#   16,
#   [('man', 0.061766244),
#    ('whatta', 0.028369728),
#    ('best', 0.023839528),
#    ('love', 0.021238513),
#    ('bubble', 0.021181045),
#    ('baby', 0.0142415995),
#    ('yes', 0.012061024),
#    ('say', 0.011899711),
#    ('night', 0.009450593),
#    ('heart', 0.009325863)]],
#  [25,
#   16,
#   [('love', 0.062191084),
#    ('cake', 0.014859403),
#    ('loca', 0.013856141),
#    ('let', 0.011028794),
#    ('heart', 0.0109806),
#    ('home', 0.010826456),
#    ('call', 0.010116969),
#    ('shut', 0.009329641),
#    ('way', 0.0092163915),
#    ('stay', 0.008794205)]],
#  [21,
#   15,
#   [('love', 0.092039645),
#    ('waiting', 0.027104432),
#    ('think', 0.017853366),
#    ('take', 0.016014399),
#    ('yes', 0.013774362),
#    ('say', 0.012184987),
#    ('well', 0.011969483),
#    ('sky', 0.0115696695),
#    ('(i', 0.0111594675),
#    ('so)', 0.010691265)]],
#  [46,
#   15,
#   [('drunk', 0.37810928),
#    ('change', 0.033891786),
#    ('point', 0.0258711),
#    ('need', 0.025026241),
#    ('love', 0.0121508045),
#    ('girlfriend', 0.008735027),
#    ('girl', 0.0067348443),
#    ('umpah', 0.0067023775),
#    ('bop', 0.006249436),
#    ('(you', 0.006025819)]],
#  [74,
#   15,
#   [('sì', 0.065745845),
#    ('hot', 0.04234014),
#    ('work', 0.041778658),
#    ('home', 0.025550852),
#    ('room', 0.021155758),
#    ('gucci', 0.017914021),
#    ('allora', 0.015652182),
#    ('give', 0.013753315),
#    ('back', 0.010260431),
#    ('worry', 0.009951646)]],
#  [75,
#   15,
#   [('hot', 0.33217305),
#    ('bambi', 0.015140148),
#    ('black', 0.013315636),
#    ('home', 0.011875219),
#    ("can't", 0.009423721),
#    ('il', 0.008856888),
#    ('tension', 0.006976954),
#    ('essere', 0.0065735155),
#    ('traduzione', 0.005677446),
#    ('yeppi', 0.005182898)]],
#  [95,
#   15,
#   [('flower', 0.03289057),
#    ('love', 0.027179161),
#    ('id', 0.017620396),
#    ("can't", 0.014475669),
#    ('lan', 0.011638505),
#    ('beauty', 0.011171827),
#    ('happy', 0.01094539),
#    ('beautiful', 0.010769623),
#    ('tell', 0.009469915),
#    ('life', 0.006511573)]],
#  [22,
#   15,
#   [('love', 0.08604053),
#    ('ка', 0.079865605),
#    ('singing', 0.030994484),
#    ('sorry', 0.014861855),
#    ('pop', 0.013242024),
#    ("what's", 0.007464135),
#    ('bad', 0.0071271667),
#    ('united', 0.007038172),
#    ('night', 0.0068030995),
#    ('crazy', 0.0067810873)]],
#  [55,
#   15,
#   [('child', 0.14024436),
#    ('hip', 0.0398372),
#    ('sorry', 0.012123374),
#    ('say', 0.011863151),
#    ('jealousy', 0.010944251),
#    ('need', 0.009320234),
#    ('smile', 0.008599838),
#    ('success', 0.008112317),
#    ('home', 0.008078587),
#    ('am', 0.007960319)]],
#  [13,
#   15,
#   [('work', 0.06923002),
#    ('allora', 0.034011077),
#    ('heart', 0.01736851),
#    ("can't", 0.01348277),
#    ('ice', 0.012850218),
#    ('eyes', 0.012220254),
#    ('tock', 0.011405128),
#    ('news', 0.011203831),
#    ('cream', 0.010753737),
#    ('tick', 0.010214511)]],
#  [16,
#   14,
#   [('yah', 0.028439738),
#    ('rumor', 0.019114949),
#    ('love', 0.017190551),
#    ('back', 0.016907668),
#    ("can't", 0.014066648),
#    ('chill', 0.013016455),
#    ("let's", 0.011986745),
#    ('sorry', 0.010150496),
#    ('need', 0.010099822),
#    ('let', 0.009616325)]],
#  [45,
#   14,
#   [('dance', 0.3033098),
#    ('child', 0.029406147),
#    ('love', 0.025659032),
#    ('osserva', 0.018813588),
#    ('aite', 0.013425089),
#    ('home', 0.010289455),
#    ('feel', 0.007676298),
#    ('broom', 0.006517511),
#    ('cat', 0.0064567225),
#    ('heart', 0.005998057)]],
#  [30,
#   14,
#   [('drunk', 0.23156549),
#    ('sweet', 0.013722219),
#    ('air', 0.010685753),
#    ('end', 0.010263331),
#    ('night', 0.010181703),
#    ('away', 0.009999718),
#    ('home', 0.009851022),
#    ('back', 0.009594443),
#    ('sorry', 0.009546763),
#    ('sick', 0.008341609)]],
#  [40,
#   14,
#   [('mmhh', 0.02537566),
#    ('feel', 0.023744177),
#    ('24', 0.019615913),
#    ('hours', 0.018294876),
#    ('love', 0.018054409),
#    ('il', 0.014531644),
#    ("let's", 0.012340932),
#    ('follow', 0.012245654),
#    ('dreams', 0.011499257),
#    ('mmmhmh', 0.010928765)]],
#  [51,
#   13,
#   [('flower', 0.04077202),
#    ('ice', 0.028174408),
#    ('cream', 0.026731823),
#    ('break', 0.023649918),
#    ('say', 0.021323401),
#    ('give', 0.020489147),
#    ('up!', 0.01811475),
#    ('take', 0.01529375),
#    ('love', 0.014009119),
#    ('thank', 0.013132597)]],
#  [33,
#   13,
#   [('dimensioni', 0.11008065),
#    ('dynamite', 0.025371088),
#    ('life', 0.01829436),
#    ('light', 0.01535134),
#    ('tonight', 0.014427159),
#    ('night', 0.014380046),
#    ('city', 0.013678118),
#    ('soul', 0.013159316),
#    ('shine', 0.011936128),
#    ('fun', 0.011616529)]],
#  [89,
#   13,
#   [('boom', 0.09240718),
#    ('love', 0.023060221),
#    ('dream', 0.02147024),
#    ('goodbye', 0.015627593),
#    ('ba', 0.015357102),
#    ('home', 0.014514715),
#    ('au', 0.01374836),
#    ('adiós', 0.013695519),
#    ('revoir', 0.013656602),
#    ('prova', 0.013390743)]],
#  [42,
#   13,
#   [('child', 0.529462),
#    ('bad', 0.014312775),
#    ('sorry', 0.009959731),
#    ('gee', 0.007947575),
#    ('leave', 0.005028693),
#    ('feel', 0.0049420116),
#    ('upgrade', 0.004890622),
#    ('guy', 0.0043856455),
#    ('boy', 0.00404479),
#    ("let's", 0.0038717557)]],
#  [82,
#   13,
#   [('child', 0.3100499),
#    ('world', 0.017043564),
#    ('dream', 0.011275698),
#    ('lucky', 0.009984028),
#    ('only', 0.006483898),
#    ('take', 0.005844566),
#    ('think', 0.005346433),
#    ("that's", 0.005285736),
#    ('life', 0.005178685),
#    ("can't", 0.0050761905)]],
#  [87,
#   13,
#   [('daydream', 0.029361421),
#    ('today', 0.019439893),
#    ('life', 0.017386056),
#    ('love', 0.017173868),
#    ('diamond', 0.015908014),
#    ('heart', 0.014678262),
#    ('yes', 0.014136368),
#    ('sorry', 0.013791416),
#    ('work', 0.012519074),
#    ('dream', 0.012318204)]],
#  [66,
#   13,
#   [('boom', 0.05603376),
#    ('love', 0.01825352),
#    ('home', 0.013333194),
#    ('thinking', 0.01227948),
#    ('back', 0.010816285),
#    ('candy', 0.009672),
#    ('night', 0.009453255),
#    ('move', 0.0093199555),
#    ('think', 0.008588634),
#    ('once', 0.008416219)]],
#  [96,
#   12,
#   [('la-la', 0.019878259),
#    ('news', 0.016411496),
#    ('sorry', 0.016224325),
#    ('home', 0.01401547),
#    ('ice', 0.009543262),
#    ('give', 0.009112594),
#    ('bad', 0.008876448),
#    ('hate', 0.0085240165),
#    ('down', 0.008191018),
#    ('love', 0.0075372765)]],
#  [43,
#   12,
#   [('surf', 0.030336717),
#    ('back', 0.021965176),
#    ('leave', 0.018255673),
#    ('left', 0.016751312),
#    ('rewind', 0.015321151),
#    ('girl', 0.01335266),
#    ('feel', 0.012923975),
#    ('imma', 0.012080902),
#    ('heart', 0.010924916),
#    ('comment', 0.010578357)]],
#  [27,
#   12,
#   [('home', 0.030241624),
#    ('fire', 0.01945983),
#    ('on!', 0.016258297),
#    ('ooh', 0.014707643),
#    ('anpanman', 0.013789481),
#    ('new', 0.010440144),
#    ("let's", 0.009939312),
#    ('news', 0.008682965),
#    ('am', 0.008057744),
#    ('keep', 0.007727151)]],
#  [8,
#   12,
#   [('last', 0.024786772),
#    ('love', 0.024155105),
#    ('worth', 0.02044323),
#    ('mariachi', 0.0144631155),
#    ('el', 0.014450647),
#    ('(what', 0.0093905935),
#    ('good)', 0.009252832),
#    ('news', 0.009244875),
#    ('dan', 0.008438703),
#    ('loco', 0.008104973)]],
#  [12,
#   12,
#   [('non', 0.034276806),
#    ('love', 0.023031171),
#    ('run', 0.016879855),
#    ('follow', 0.01569168),
#    ('eyes', 0.014131827),
#    ('light', 0.012228445),
#    ('bang', 0.01075618),
#    ("can't", 0.0103287585),
#    ('heart', 0.010088881),
#    ('beautiful', 0.010001795)]],
#  [98,
#   12,
#   [('night', 0.04704274),
#    ('put', 0.0250068),
#    ('need', 0.017888948),
#    ("'em", 0.012468293),
#    ('new', 0.011560567),
#    ('bad', 0.011096286),
#    ('della', 0.01072171),
#    ('follow', 0.010549609),
#    ('shimmy', 0.009958435),
#    ('lee', 0.009656411)]],
#  [86,
#   12,
#   [('love', 0.019955695),
#    ('mob', 0.01741438),
#    ('wild', 0.013860785),
#    ('sorry', 0.012640278),
#    ('back', 0.011973612),
#    ('end', 0.010803406),
#    ('think', 0.010498294),
#    ('night', 0.009639251),
#    ('mafioso', 0.009181428),
#    ('heart', 0.00872241)]],
#  [63,
#   12,
#   [('today', 0.019620938),
#    ('ah', 0.018317208),
#    ('girlfriend', 0.013727766),
#    ('love', 0.012167097),
#    ('play', 0.012065029),
#    ('cruel', 0.011410603),
#    ('hey!', 0.011287718),
#    ('take', 0.011058081),
#    ("can't", 0.011038713),
#    ('well', 0.011031374)]],
#  [76,
#   12,
#   [('non', 0.043021087),
#    ('woo', 0.036839496),
#    ('mine', 0.027027572),
#    ('ash', 0.018782705),
#    ('sara', 0.012174713),
#    ('only', 0.012091483),
#    ('stanza', 0.010633397),
#    ('dance', 0.01049649),
#    ('yes', 0.009717724),
#    ('say', 0.009585541)]],
#  [56,
#   12,
#   [('́â', 0.17266646),
#    ('dance', 0.014286587),
#    ('help', 0.013465667),
#    ('yes', 0.010062442),
#    ('feel', 0.009755083),
#    ('me)', 0.00941278),
#    ('(help', 0.009405776),
#    ('take', 0.008864219),
#    ('ole-oh-eh-oh', 0.008168664),
#    ('night', 0.008104185)]],
#  [11,
#   11,
#   [('cuse', 0.031645138),
#    ('excuse', 0.019612357),
#    ('price_min}}', 0.017869694),
#    ('compare_at_price_min', 0.017691571),
#    ('honey', 0.017656457),
#    ('still', 0.015057174),
#    ('call', 0.014680906),
#    ('cold', 0.013391599),
#    ('zoom', 0.011110471),
#    ('dance', 0.0099)]],
#  [24,
#   11,
#   [('back', 0.063243404),
#    ('woo', 0.05829973),
#    ('bull', 0.053361632),
#    ('fire', 0.028725026),
#    ('siren', 0.019420713),
#    ('wow', 0.014459816),
#    ('mariachi', 0.012612276),
#    ('up!', 0.011732962),
#    ('el', 0.011651007),
#    ("we're", 0.010326228)]],
#  [39,
#   11,
#   [('dan', 0.30746484),
#    ('love', 0.025958179),
#    ('shake', 0.014447619),
#    ('headphones', 0.011618023),
#    ('wild', 0.009894304),
#    ('still', 0.007539305),
#    ('heart', 0.007365626),
#    ('sorry', 0.0071626888),
#    ('boomshakalaka', 0.0071600336),
#    ("can't", 0.0070198355)]],
#  [79,
#   11,
#   [('[bleep', 0.030858496),
#    ('aite', 0.027834028),
#    ('[bleep]', 0.020420847),
#    ('pump', 0.018949913),
#    ('bear', 0.01263732),
#    ('teddy', 0.012635942),
#    ('hip', 0.011744753),
#    ('diamond', 0.009983177),
#    ('love', 0.009828105),
#    ('shooting', 0.008924426)]],
#  [32,
#   11,
#   [('child', 0.15313853),
#    ('baby', 0.11914802),
#    ('bad', 0.010472446),
#    ('guys', 0.010135877),
#    ("we're", 0.009247667),
#    ('up!', 0.0088568935),
#    ('house', 0.008646428),
#    ('save', 0.008451523),
#    ('say', 0.006685243),
#    ('signals', 0.0061660097)]],
#  [5,
#   11,
#   [('home', 0.07843423),
#    ('bam', 0.029832143),
#    ('wow!', 0.018684294),
#    ('ti', 0.014126459),
#    ('qui', 0.013870817),
#    ('falling', 0.012807644),
#    ('gno', 0.011959775),
#    ('drunk', 0.011257242),
#    ('head', 0.010567271),
#    ('shut', 0.010077151)]],
#  [29,
#   10,
#   [('work', 0.07742845),
#    ('allora', 0.036556672),
#    ('business', 0.03386591),
#    ('live', 0.025813362),
#    ('love', 0.02121238),
#    ('only', 0.020948745),
#    ('city', 0.018002233),
#    ('let', 0.014576256),
#    ('am', 0.0113207055),
#    ('start', 0.01082228)]],
#  [85,
#   10,
#   [('home', 0.058354102),
#    ('caldo', 0.049870674),
#    ('summer', 0.015362801),
#    ('moon', 0.014587112),
#    ('dance', 0.013847947),
#    ('woo', 0.012309965),
#    ('whoo', 0.0120288795),
#    ('sweet', 0.011367634),
#    ('cold', 0.010941578),
#    ('hands', 0.009020627)]],
#  [69,
#   9,
#   [('beep', 0.04443333),
#    ('home', 0.024311947),
#    ('tell', 0.016979713),
#    ('name', 0.0154676605),
#    ('dang', 0.012196977),
#    ('dong', 0.012193042),
#    ('ding', 0.012189892),
#    ('young', 0.009930226),
#    ('way', 0.009674433),
#    ('head', 0.009504029)]],
#  [31,
#   9,
#   [('bop', 0.033118304),
#    ('home', 0.021930182),
#    ('flower', 0.01773906),
#    ('hot', 0.014959344),
#    ("won't", 0.01181915),
#    ('clap', 0.010956208),
#    ('ti', 0.010517741),
#    ('love', 0.010395627),
#    ('hurt', 0.009627927),
#    ('girl', 0.009403187)]],
#  [1,
#   9,
#   [('night', 0.019154308),
#    ('life', 0.01643308),
#    ('love', 0.012566737),
#    ('home', 0.012518224),
#    ('boys', 0.012313719),
#    ('anpanman', 0.012295506),
#    ('new', 0.011905159),
#    ('still', 0.011557481),
#    ('wussup', 0.0114468),
#    ('man', 0.01137817)]],
#  [65,
#   9,
#   [('pop', 0.032374837),
#    ('prova', 0.02672466),
#    ('dreams', 0.013517804),
#    ('dream', 0.013416306),
#    ('yes', 0.009832746),
#    ('baby', 0.009530068),
#    ('let', 0.009337664),
#    ("we're", 0.008417661),
#    ('big', 0.005922715),
#    ('night', 0.005608055)]],
#  [60,
#   9,
#   [('best', 0.11334997),
#    ('pop', 0.11281519),
#    ('baby', 0.027982207),
#    ('burn', 0.013625734),
#    ('down', 0.010123409),
#    ('walker', 0.009186124),
#    ('hey!', 0.007767734),
#    ('girl', 0.0074176383),
#    ('share', 0.007275059),
#    ('love', 0.0069119437)]],
#  [44,
#   8,
#   [('wave', 0.07190029),
#    ('grande', 0.050484907),
#    ('swing', 0.039395787),
#    ('picky', 0.03641766),
#    ('traduzione', 0.018729212),
#    ('shy', 0.017532138),
#    ('thinking', 0.016197424),
#    ('am', 0.0133841345),
#    ('leave', 0.012601483),
#    ('(oh', 0.010301796)]],
#  [99,
#   8,
#   [('rende', 0.27943),
#    ('woo', 0.026563538),
#    ('́â', 0.020632494),
#    ('say', 0.019326964),
#    ('(eh-oh)', 0.016849348),
#    ('kick', 0.01466721),
#    ("can't", 0.012153877),
#    ('rain', 0.011763625),
#    ('sorry', 0.011032897),
#    ('hey!', 0.008574779)]],
#  [92,
#   8,
#   [('sunday', 0.025019996),
#    ('music', 0.01597113),
#    ('real', 0.013790313),
#    ('say', 0.012800722),
#    ('night', 0.011986875),
#    ('share', 0.009419783),
#    ('true', 0.009121162),
#    ('heart', 0.00888952),
#    ('love', 0.008731515),
#    ('domenica', 0.008347428)]],
#  [49,
#   8,
#   [('rumor', 0.027935725),
#    ("let's", 0.016543161),
#    ('la-la-la-la-la', 0.014345653),
#    ('let', 0.013747152),
#    ('say', 0.013385601),
#    ('di', 0.012998783),
#    ('pum', 0.012366554),
#    ('believer', 0.011953649),
#    ('love', 0.011197025),
#    ('tell', 0.010471925)]],
#  [34,
#   8,
#   [('poppy', 0.090776205),
#    ('love', 0.036058825),
#    ('take', 0.017769989),
#    ('poison', 0.01391739),
#    ('bring', 0.013777275),
#    ('life', 0.013744541),
#    ('tatata', 0.013714152),
#    ('pink', 0.013058262),
#    ('ah', 0.0121137),
#    ('woah', 0.011616823)]],
#  [18,
#   8,
#   [('luv', 0.040192917),
#    ('domino', 0.017950999),
#    ('home', 0.012969797),
#    ('worry', 0.0123957135),
#    ('hey!', 0.011009396),
#    ('keep', 0.009581944),
#    ('room', 0.009053838),
#    ('love', 0.008949396),
#    ('tonight', 0.008146538),
#    ('dynamite', 0.007821336)]],
#  [73,
#   8,
#   [('drunk', 0.27010503),
#    ('singing', 0.10852752),
#    ('bump三', 0.032125108),
#    ('sì', 0.019545516),
#    ('kim', 0.015703304),
#    ('pang', 0.011363085),
#    ('music', 0.009559903),
#    ('love', 0.008702314),
#    ('hello', 0.008364315),
#    ('entertainment', 0.008316542)]],
#  [61,
#   7,
#   [('child', 0.47804928),
#    ('fun', 0.010626237),
#    ('ok', 0.0076657035),
#    ('sorry', 0.0070935874),
#    ('light', 0.006989395),
#    ('wants', 0.005473366),
#    ('gee', 0.005189109),
#    ('bhubaneswar', 0.005049773),
#    ('little', 0.0050075185),
#    ('puri', 0.004894411)]],
#  [23,
#   7,
#   [('night', 0.015898487),
#    ('anymore', 0.014013213),
#    ('swan', 0.01399463),
#    ('end', 0.011827116),
#    ('solo', 0.011279071),
#    ('dragon', 0.011244341),
#    ('love', 0.01051846),
#    ('dream', 0.007660113),
#    ('way', 0.0076407096),
#    ('child', 0.007515946)]],
#  [6,
#   7,
#   [('significa', 0.20171717),
#    ('best', 0.04868715),
#    ('feel', 0.01712575),
#    ('(you', 0.013344943),
#    ('tell', 0.009832914),
#    ('rush)', 0.009823713),
#    ('love', 0.009629834),
#    ('la-la', 0.009538505),
#    ('eyes', 0.008787619),
#    ('home', 0.008105159)]],
#  [54,
#   7,
#   [('money', 0.031405568),
#    ('baby', 0.027244745),
#    ('dun', 0.01296881),
#    ('bills', 0.012751957),
#    ("dolla's", 0.012663661),
#    ('tonight', 0.01255244),
#    ('drop', 0.010478953),
#    ('clover', 0.01014211),
#    ('new', 0.010115022),
#    ('girl', 0.009109461)]],
#  [37,
#   7,
#   [('spicy', 0.03537732),
#    ('heart', 0.022931175),
#    ('sorry', 0.019054443),
#    ('bang', 0.01904978),
#    ('news', 0.01499999),
#    ('tt', 0.014701377),
#    ('baby', 0.013557164),
#    ('joy', 0.00876573),
#    ('home', 0.008185696),
#    ('say', 0.007990433)]],
#  [93,
#   6,
#   [('drunk', 0.32196745),
#    ('home', 0.052490886),
#    ('shut', 0.01153504),
#    ('god', 0.008450634),
#    ('love', 0.008288853),
#    ('on!', 0.007958634),
#    ('whoo', 0.0065948498),
#    ('heart', 0.0063012317),
#    ('man', 0.00564038),
#    ('sorry', 0.0053891987)]],
#  [77,
#   6,
#   [('singing', 0.35616028),
#    ('sì', 0.044218812),
#    ('alli-alli-alli-alligator', 0.012588368),
#    ('love', 0.0120876385),
#    ('feel', 0.009820381),
#    ('trauma', 0.009319098),
#    ('power', 0.008387879),
#    ('woo', 0.0080012195),
#    ('ministry', 0.007749929),
#    ('back', 0.0065855114)]],
#  [14,
#   5,
#   [('deep', 0.02292794),
#    ('night', 0.019093098),
#    ('yes', 0.0165558),
#    ('am', 0.01647405),
#    ('contact', 0.014758141),
#    ('blame', 0.0131443115),
#    ('woah', 0.011695645),
#    ('dynamite', 0.010781388),
#    ('life', 0.008303548),
#    ('baraba', 0.008239836)]],
#  [9,
#   5,
#   [('cake', 0.635276),
#    ('singing', 0.035392083),
#    ('follow', 0.020645544),
#    ('sì', 0.00730549),
#    ('today', 0.00587797),
#    ('yes', 0.0056750593),
#    ('trust', 0.004331992),
#    ('(again)', 0.0037791317),
#    ('pie', 0.0035155893),
#    ('up!', 0.0028037662)]]]

# %%
_lda_summer_kpop = sort_dictionary(summer)
lda_summer_kpop = []
for tup in _lda_summer_kpop:
    new_tup = [tup[0], tup[1], lda.show_topic(tup[0])]
    lda_summer_kpop.append(new_tup)
    
lda_summer_kpop
# Out:
# [[97,
#   47.682332408456205,
#   [('love', 0.16675065),
#    ('top', 0.023729648),
#    ('home', 0.016499445),
#    ('crazy', 0.01575896),
#    ("can't", 0.012429796),
#    ('sorry', 0.010583185),
#    ('ay', 0.010504948),
#    ('night', 0.009325708),
#    ('baby', 0.009185769),
#    ('heart', 0.007038093)]],
#  [94,
#   45.566633995336815,
#   [('home', 0.12782477),
#    ('love', 0.01474947),
#    ('let', 0.010766711),
#    ('sorry', 0.01061506),
#    ('heart', 0.009993936),
#    ("let's", 0.00993831),
#    ('shut', 0.009267275),
#    ('say', 0.008660195),
#    ("can't", 0.0063858465),
#    ('baby', 0.0060902163)]],
#  [57,
#   30.085410467845577,
#   [('baby', 0.016240522),
#    ('back', 0.0155747505),
#    ('home', 0.015504847),
#    ('moon', 0.012761522),
#    ('dawn', 0.012319786),
#    ('star', 0.012195145),
#    ("can't", 0.01165075),
#    ('run', 0.010799802),
#    ('night', 0.010342201),
#    ('next', 0.0096074855)]],
#  [10,
#   28.65112317668718,
#   [('home', 0.15137497),
#    ('love', 0.023484707),
#    ('shoot', 0.016338661),
#    ('sorry', 0.01571999),
#    ('give', 0.0153519055),
#    ('shut', 0.012703807),
#    ('dream', 0.008807938),
#    ('comment', 0.0077899126),
#    ('walker', 0.0071673337),
#    ('feel', 0.005373561)]],
#  [80,
#   26.06400705708984,
#   [("can't", 0.040989485),
#    ('love', 0.04065456),
#    ('touch', 0.013810544),
#    ('name', 0.012911736),
#    ('light', 0.011666647),
#    ('understand', 0.011651601),
#    ('only', 0.011345807),
#    ('upgrade', 0.010691658),
#    ('ohohohohohohohohohoh', 0.010554179),
#    ('heart', 0.010374143)]],
#  [67,
#   24.993672392900407,
#   [('eyes', 0.017556662),
#    ('mom', 0.016612366),
#    ('sorry', 0.013501793),
#    ('next', 0.012673479),
#    ("can't", 0.012566901),
#    ("we're", 0.011424663),
#    ('love', 0.011327522),
#    ('butterfly', 0.009924907),
#    ('oriente', 0.009261157),
#    ('point', 0.008632729)]],
#  [64,
#   24.624629751984685,
#   [('new', 0.030782318),
#    ('face', 0.012385703),
#    ('love', 0.012210028),
#    ('nightmare', 0.012089078),
#    ('news', 0.011110859),
#    ('girls', 0.010513647),
#    ('crush', 0.010034666),
#    ('bussare', 0.009615419),
#    ('baby', 0.009034691),
#    ('sorry', 0.008178584)]],
#  [52,
#   24.53279828910854,
#   [('gam3', 0.04410344),
#    ('reale', 0.042252503),
#    ('ba', 0.029749516),
#    ('love', 0.023303105),
#    ('need', 0.018589756),
#    ('bum', 0.016174788),
#    ('baby', 0.014435369),
#    ('sorry', 0.011500346),
#    ('am', 0.010890098),
#    ('hold', 0.009286301)]],
#  [19,
#   23.95365964676057,
#   [('heart', 0.022139592),
#    ('sorry', 0.021523768),
#    ('love', 0.020401856),
#    ("we're", 0.019081226),
#    ("let's", 0.016824378),
#    ('eyes', 0.011836874),
#    ('air', 0.009486957),
#    ('light', 0.008992257),
#    ('fine', 0.008247175),
#    ('world', 0.006883051)]],
#  [71,
#   23.79679432260491,
#   [('boy', 0.04331147),
#    ('home', 0.021881385),
#    ('love', 0.01725243),
#    ('heart', 0.014947685),
#    ('baby', 0.014437842),
#    ('ay', 0.012835817),
#    ('ya', 0.010650968),
#    ('seguire', 0.010111804),
#    ('cuz', 0.00966705),
#    ('dance', 0.009488817)]],
#  [70,
#   23.42194755906712,
#   [('hands', 0.2389585),
#    ('summer', 0.019433027),
#    ('fall', 0.017144646),
#    ('boy', 0.01173957),
#    ('on!', 0.0097527485),
#    ('love', 0.008895098),
#    ("can't", 0.0082551045),
#    ('let', 0.0075842133),
#    ('prova', 0.0073293145),
#    ('roll', 0.0072203446)]],
#  [53,
#   23.16566842287466,
#   [('della', 0.038019788),
#    ('night', 0.021569919),
#    ('love', 0.016944107),
#    ('home', 0.014112615),
#    ('back', 0.014081619),
#    ('invalid', 0.013511042),
#    ('yes', 0.012554431),
#    ("can't", 0.012269899),
#    ('run', 0.011379417),
#    ('let', 0.010020102)]],
#  [17,
#   22.456436332422527,
#   [('upgrade', 0.038973052),
#    ('boy', 0.020850975),
#    ('love', 0.020786623),
#    ('give', 0.018798122),
#    ('feel', 0.0130616),
#    ('heart', 0.0126218395),
#    ("can't", 0.0118156085),
#    ('home', 0.009471307),
#    ('news', 0.009320715),
#    ('let', 0.008927532)]],
#  [81,
#   22.38219198466504,
#   [('bomb', 0.07011091),
#    ('love', 0.04263088),
#    ('home', 0.0356484),
#    ('segreta', 0.028765256),
#    ('detail', 0.025016181),
#    ('girl', 0.02062954),
#    ('nice', 0.017192377),
#    ('back', 0.012323488),
#    ("let's", 0.012305878),
#    ('need', 0.0099079255)]],
#  [2,
#   22.318873744543453,
#   [('invalid', 0.1467197),
#    ('love', 0.030205268),
#    ("can't", 0.019210862),
#    ('yes', 0.012165884),
#    ('red', 0.011720955),
#    ('power', 0.01048106),
#    ('back', 0.0075523416),
#    ('grande', 0.0074034804),
#    ('sorry', 0.007027368),
#    ('baby', 0.0068559367)]],
#  [84,
#   22.299428728163548,
#   [('yes', 0.01774208),
#    ('sorry', 0.015195052),
#    ('baby', 0.013851429),
#    ('eyes', 0.012509505),
#    ('woo', 0.011741408),
#    ('love', 0.0114305),
#    ('think', 0.010225064),
#    ("can't", 0.009982516),
#    ('bang', 0.009372565),
#    ('ay', 0.0092297075)]],
#  [35,
#   22.00108774583532,
#   [('put', 0.027048219),
#    ('beep', 0.016669672),
#    ("'em", 0.01509921),
#    ('sì', 0.015057823),
#    ('sneakers', 0.0126046175),
#    ('uh', 0.011904652),
#    ('traduzione', 0.0106969),
#    ('back', 0.010129745),
#    ('ready', 0.0098672705),
#    ('yes', 0.009020781)]],
#  [48,
#   21.944917080598316,
#   [('universe', 0.03295549),
#    ('(you', 0.015924724),
#    ('way', 0.015259403),
#    ('are)', 0.012769747),
#    ('world', 0.011893589),
#    ('hand', 0.010686648),
#    ('light', 0.009092204),
#    ("we're", 0.007938073),
#    ('lipstick', 0.0078414865),
#    ('first', 0.0077448953)]],
#  [90,
#   21.721996789083278,
#   [('gno', 0.069748685),
#    ('yes', 0.020196497),
#    ('(eh-oh)', 0.016220946),
#    ('sorry', 0.012572533),
#    ('pain', 0.012522928),
#    ('care', 0.0088795815),
#    ('find', 0.008777268),
#    ('hey!', 0.008344996),
#    ("can't", 0.008141631),
#    ('bring', 0.008079871)]],
#  [47,
#   20.982508640210654,
#   [('vacanza', 0.05634885),
#    ('zu', 0.033729784),
#    ('home', 0.021260737),
#    ('love', 0.020623356),
#    ('cry', 0.016015451),
#    ('baby', 0.012914427),
#    ('[bleep]', 0.0127738165),
#    ('heart', 0.011490742),
#    ('[bleep', 0.0107541),
#    ('girl', 0.010652701)]],
#  [4,
#   20.904405772429527,
#   [('invalid', 0.097449444),
#    ('ring', 0.015943803),
#    ('baby', 0.014935152),
#    ("can't", 0.013949086),
#    ('swipe', 0.012088089),
#    ('night', 0.011110958),
#    ('give', 0.010371956),
#    ('next', 0.010259953),
#    ('sorry', 0.00991315),
#    ('yes', 0.009641248)]],
#  [38,
#   20.82515703532954,
#   [('sorry', 0.023194546),
#    ('love', 0.019957138),
#    ("let's", 0.015475284),
#    ('honey', 0.012757257),
#    ('na-na', 0.01027287),
#    ('news', 0.009914957),
#    ("i've", 0.008999681),
#    ('heart', 0.008952724),
#    ("can't", 0.008245187),
#    ('let', 0.007502725)]],
#  [72,
#   20.61821358040288,
#   [('am', 0.024005208),
#    ('ash', 0.019334652),
#    ('take', 0.018108932),
#    ('bussare', 0.01608987),
#    ('bad', 0.01493204),
#    ('leave', 0.014365306),
#    ('love', 0.013882952),
#    ('door', 0.011768866),
#    ('knock', 0.011710851),
#    ('attention', 0.011579622)]],
#  [62,
#   20.423696958170694,
#   [('hot', 0.018369637),
#    ('sorry', 0.012071122),
#    ('segreta', 0.011824048),
#    ('stronger', 0.010379045),
#    ('love', 0.009224176),
#    ('feel', 0.009106674),
#    ('fight', 0.00838961),
#    ('hi', 0.008314073),
#    ('say', 0.008293412),
#    ('sky', 0.008101289)]],
#  [36,
#   19.88586207237131,
#   [('run', 0.024904426),
#    ('yes', 0.023118686),
#    ('let', 0.020142414),
#    ('stay', 0.016333582),
#    ('love', 0.014170385),
#    ('back', 0.01357604),
#    ('century', 0.011099443),
#    ('19th', 0.010749071),
#    ('am', 0.010444905),
#    ('sorry', 0.010080393)]],
#  [3,
#   19.846065053947314,
#   [('love', 0.025814928),
#    ('running', 0.0152249895),
#    ("can't", 0.014994677),
#    ('let', 0.01419843),
#    ('contact', 0.01387562),
#    ('fly', 0.011978124),
#    ('true', 0.010869492),
#    ('segreta', 0.010686398),
#    ('take', 0.010381715),
#    ('sorry', 0.009161433)]],
#  [68,
#   19.71369420370138,
#   [('only', 0.04065752),
#    ("rollin'", 0.021173371),
#    ('feel', 0.020832602),
#    ('love', 0.019719439),
#    ('million', 0.011293748),
#    ('need', 0.010741646),
#    ('dream', 0.010487443),
#    ('mind', 0.00963994),
#    ('special', 0.009523569),
#    ('loco', 0.008743172)]],
#  [83,
#   19.0511827009268,
#   [('oriente', 0.061350603),
#    ('love', 0.0161338),
#    ('call', 0.014333189),
#    ('ha', 0.01412979),
#    ('hero', 0.013585727),
#    ('rose', 0.013223643),
#    ('play', 0.01223138),
#    ('vie', 0.01139422),
#    ('man', 0.010213635),
#    ('heart', 0.008712601)]],
#  [28,
#   18.830941153764797,
#   [('boy', 0.055597596),
#    ('dam', 0.03964145),
#    ('bad', 0.028448788),
#    ('love', 0.021010324),
#    ('yes', 0.019931275),
#    ('twenty', 0.017122813),
#    ('fine', 0.012547638),
#    ('segreta', 0.011898808),
#    ('problem', 0.0110663595),
#    ('kill', 0.009981343)]],
#  [78,
#   18.762554430848468,
#   [('ка', 0.19221826),
#    ('dad', 0.11388306),
#    ('love', 0.027028587),
#    ('crazy', 0.024651166),
#    ('pop', 0.01952387),
#    ('sorry', 0.01908923),
#    ('bad', 0.0102052335),
#    ('only', 0.008839579),
#    ('sweet', 0.00706711),
#    ('sick', 0.0069154873)]],
#  [21,
#   18.53589831019599,
#   [('love', 0.092039645),
#    ('waiting', 0.027104432),
#    ('think', 0.017853366),
#    ('take', 0.016014399),
#    ('yes', 0.013774362),
#    ('say', 0.012184987),
#    ('well', 0.011969483),
#    ('sky', 0.0115696695),
#    ('(i', 0.0111594675),
#    ('so)', 0.010691265)]],
#  [88,
#   18.516247828994892,
#   [('prova', 0.031918596),
#    ('woo', 0.027318813),
#    ('wee', 0.02513513),
#    ('love', 0.016427498),
#    ('switch', 0.01486969),
#    ('ring', 0.014096509),
#    ('heart', 0.01252456),
#    ('mic', 0.011530383),
#    ('home', 0.011286949),
#    ('life', 0.011198598)]],
#  [15,
#   18.315232378068686,
#   [('gno', 0.067851275),
#    ('love', 0.023838514),
#    ('gold', 0.015075807),
#    ('beep', 0.015070767),
#    ('heart', 0.014877637),
#    ('stay', 0.0127385035),
#    ('chica', 0.012166175),
#    ('woman', 0.012151501),
#    ('sorry', 0.011505805),
#    ('let', 0.010732237)]],
#  [0,
#   18.303855605472563,
#   [('man', 0.061766244),
#    ('whatta', 0.028369728),
#    ('best', 0.023839528),
#    ('love', 0.021238513),
#    ('bubble', 0.021181045),
#    ('baby', 0.0142415995),
#    ('yes', 0.012061024),
#    ('say', 0.011899711),
#    ('night', 0.009450593),
#    ('heart', 0.009325863)]],
#  [91,
#   18.272788363696236,
#   [('sorry', 0.018290225),
#    ('baby', 0.01817035),
#    ('ruin', 0.01483631),
#    ('shimmy', 0.013541033),
#    ('seguire', 0.0133542195),
#    ('only', 0.012860307),
#    ('armoured', 0.0114243245),
#    ('ah!', 0.011211329),
#    ('tempo', 0.010968776),
#    ("can't", 0.010539905)]],
#  [58,
#   18.20396621362852,
#   [('non', 0.026367392),
#    ('call', 0.025913093),
#    ("can't", 0.014400341),
#    ('sorry', 0.012324833),
#    ('miss', 0.009326279),
#    ('fun', 0.008431896),
#    ('find', 0.008393804),
#    ('beat', 0.008297535),
#    ('home', 0.008226919),
#    ('watch', 0.0075188624)]],
#  [50,
#   18.20071930415179,
#   [('rock', 0.05680049),
#    ('head', 0.025273122),
#    ('down', 0.016805148),
#    ('shy', 0.014366384),
#    ("that's", 0.013490187),
#    ('detail', 0.012205601),
#    ('let', 0.011451162),
#    ('take', 0.010229913),
#    ('top', 0.009694538),
#    ('sorry', 0.009519365)]],
#  [25,
#   18.046562269892092,
#   [('love', 0.062191084),
#    ('cake', 0.014859403),
#    ('loca', 0.013856141),
#    ('let', 0.011028794),
#    ('heart', 0.0109806),
#    ('home', 0.010826456),
#    ('call', 0.010116969),
#    ('shut', 0.009329641),
#    ('way', 0.0092163915),
#    ('stay', 0.008794205)]],
#  [59,
#   17.860037569849737,
#   [('dan', 0.016670235),
#    ('last', 0.012956485),
#    ('{{if', 0.011810652),
#    ('price_varies}', 0.011760713),
#    ('left', 0.0112735),
#    ('take', 0.010398725),
#    ('light', 0.010326407),
#    ('sequence', 0.010083502),
#    ('final', 0.009681232),
#    ('wave', 0.008483041)]],
#  [7,
#   17.8557654264132,
#   [('invalid', 0.1635583),
#    ('detail', 0.035763755),
#    ('jump', 0.018646777),
#    ('yes', 0.015002492),
#    ('bang', 0.014338299),
#    ('let', 0.013172389),
#    ('job', 0.011795936),
#    ('feel', 0.010764498),
#    ("chi't", 0.009885976),
#    ('top', 0.008967736)]],
#  [45,
#   17.769209259353374,
#   [('dance', 0.3033098),
#    ('child', 0.029406147),
#    ('love', 0.025659032),
#    ('osserva', 0.018813588),
#    ('aite', 0.013425089),
#    ('home', 0.010289455),
#    ('feel', 0.007676298),
#    ('broom', 0.006517511),
#    ('cat', 0.0064567225),
#    ('heart', 0.005998057)]],
#  [41,
#   17.588553620314997,
#   [('signals', 0.02785127),
#    ('meet', 0.016889729),
#    ('sorry', 0.015623756),
#    ('mago', 0.012044867),
#    ('tak', 0.012032399),
#    ('heart', 0.011665599),
#    ("can't", 0.010775586),
#    ('news', 0.009660988),
#    ('let', 0.00909104),
#    ('yes', 0.008718114)]],
#  [13,
#   17.45423609809768,
#   [('work', 0.06923002),
#    ('allora', 0.034011077),
#    ('heart', 0.01736851),
#    ("can't", 0.01348277),
#    ('ice', 0.012850218),
#    ('eyes', 0.012220254),
#    ('tock', 0.011405128),
#    ('news', 0.011203831),
#    ('cream', 0.010753737),
#    ('tick', 0.010214511)]],
#  [95,
#   17.438534364884617,
#   [('flower', 0.03289057),
#    ('love', 0.027179161),
#    ('id', 0.017620396),
#    ("can't", 0.014475669),
#    ('lan', 0.011638505),
#    ('beauty', 0.011171827),
#    ('happy', 0.01094539),
#    ('beautiful', 0.010769623),
#    ('tell', 0.009469915),
#    ('life', 0.006511573)]],
#  [75,
#   17.282428202639494,
#   [('hot', 0.33217305),
#    ('bambi', 0.015140148),
#    ('black', 0.013315636),
#    ('home', 0.011875219),
#    ("can't", 0.009423721),
#    ('il', 0.008856888),
#    ('tension', 0.006976954),
#    ('essere', 0.0065735155),
#    ('traduzione', 0.005677446),
#    ('yeppi', 0.005182898)]],
#  [51,
#   17.145461128120587,
#   [('flower', 0.04077202),
#    ('ice', 0.028174408),
#    ('cream', 0.026731823),
#    ('break', 0.023649918),
#    ('say', 0.021323401),
#    ('give', 0.020489147),
#    ('up!', 0.01811475),
#    ('take', 0.01529375),
#    ('love', 0.014009119),
#    ('thank', 0.013132597)]],
#  [26,
#   16.553531600367933,
#   [('ba', 0.06454483),
#    ('afraid', 0.020321049),
#    ('hands', 0.018077316),
#    ('love', 0.017283518),
#    ('ha', 0.015571563),
#    ('easy', 0.012959202),
#    ('gimme', 0.0112502705),
#    ('blessing', 0.009803197),
#    ('dream', 0.009165996),
#    ('butterfly', 0.008771283)]],
#  [22,
#   16.433114985726206,
#   [('love', 0.08604053),
#    ('ка', 0.079865605),
#    ('singing', 0.030994484),
#    ('sorry', 0.014861855),
#    ('pop', 0.013242024),
#    ("what's", 0.007464135),
#    ('bad', 0.0071271667),
#    ('united', 0.007038172),
#    ('night', 0.0068030995),
#    ('crazy', 0.0067810873)]],
#  [55,
#   16.41064107710372,
#   [('child', 0.14024436),
#    ('hip', 0.0398372),
#    ('sorry', 0.012123374),
#    ('say', 0.011863151),
#    ('jealousy', 0.010944251),
#    ('need', 0.009320234),
#    ('smile', 0.008599838),
#    ('success', 0.008112317),
#    ('home', 0.008078587),
#    ('am', 0.007960319)]],
#  [33,
#   16.368449000567125,
#   [('dimensioni', 0.11008065),
#    ('dynamite', 0.025371088),
#    ('life', 0.01829436),
#    ('light', 0.01535134),
#    ('tonight', 0.014427159),
#    ('night', 0.014380046),
#    ('city', 0.013678118),
#    ('soul', 0.013159316),
#    ('shine', 0.011936128),
#    ('fun', 0.011616529)]],
#  [86,
#   16.354400071539203,
#   [('love', 0.019955695),
#    ('mob', 0.01741438),
#    ('wild', 0.013860785),
#    ('sorry', 0.012640278),
#    ('back', 0.011973612),
#    ('end', 0.010803406),
#    ('think', 0.010498294),
#    ('night', 0.009639251),
#    ('mafioso', 0.009181428),
#    ('heart', 0.00872241)]],
#  [20,
#   16.270246274651072,
#   [('love', 0.043926246),
#    ('pop', 0.0372166),
#    ('prova', 0.010394848),
#    ('let', 0.010178246),
#    ("chi't", 0.009850608),
#    ('man', 0.009219298),
#    ('(na', 0.008105732),
#    ('na)', 0.008099732),
#    ('dirty', 0.007476477),
#    ('tell', 0.006790014)]],
#  [46,
#   15.98127491571313,
#   [('drunk', 0.37810928),
#    ('change', 0.033891786),
#    ('point', 0.0258711),
#    ('need', 0.025026241),
#    ('love', 0.0121508045),
#    ('girlfriend', 0.008735027),
#    ('girl', 0.0067348443),
#    ('umpah', 0.0067023775),
#    ('bop', 0.006249436),
#    ('(you', 0.006025819)]],
#  [40,
#   15.794852060667836,
#   [('mmhh', 0.02537566),
#    ('feel', 0.023744177),
#    ('24', 0.019615913),
#    ('hours', 0.018294876),
#    ('love', 0.018054409),
#    ('il', 0.014531644),
#    ("let's", 0.012340932),
#    ('follow', 0.012245654),
#    ('dreams', 0.011499257),
#    ('mmmhmh', 0.010928765)]],
#  [76,
#   15.664365499133055,
#   [('non', 0.043021087),
#    ('woo', 0.036839496),
#    ('mine', 0.027027572),
#    ('ash', 0.018782705),
#    ('sara', 0.012174713),
#    ('only', 0.012091483),
#    ('stanza', 0.010633397),
#    ('dance', 0.01049649),
#    ('yes', 0.009717724),
#    ('say', 0.009585541)]],
#  [32,
#   15.466226326554533,
#   [('child', 0.15313853),
#    ('baby', 0.11914802),
#    ('bad', 0.010472446),
#    ('guys', 0.010135877),
#    ("we're", 0.009247667),
#    ('up!', 0.0088568935),
#    ('house', 0.008646428),
#    ('save', 0.008451523),
#    ('say', 0.006685243),
#    ('signals', 0.0061660097)]],
#  [43,
#   15.26435428338118,
#   [('surf', 0.030336717),
#    ('back', 0.021965176),
#    ('leave', 0.018255673),
#    ('left', 0.016751312),
#    ('rewind', 0.015321151),
#    ('girl', 0.01335266),
#    ('feel', 0.012923975),
#    ('imma', 0.012080902),
#    ('heart', 0.010924916),
#    ('comment', 0.010578357)]],
#  [82,
#   15.151743081098175,
#   [('child', 0.3100499),
#    ('world', 0.017043564),
#    ('dream', 0.011275698),
#    ('lucky', 0.009984028),
#    ('only', 0.006483898),
#    ('take', 0.005844566),
#    ('think', 0.005346433),
#    ("that's", 0.005285736),
#    ('life', 0.005178685),
#    ("can't", 0.0050761905)]],
#  [87,
#   15.126038546002746,
#   [('daydream', 0.029361421),
#    ('today', 0.019439893),
#    ('life', 0.017386056),
#    ('love', 0.017173868),
#    ('diamond', 0.015908014),
#    ('heart', 0.014678262),
#    ('yes', 0.014136368),
#    ('sorry', 0.013791416),
#    ('work', 0.012519074),
#    ('dream', 0.012318204)]],
#  [11,
#   14.846069042732779,
#   [('cuse', 0.031645138),
#    ('excuse', 0.019612357),
#    ('price_min}}', 0.017869694),
#    ('compare_at_price_min', 0.017691571),
#    ('honey', 0.017656457),
#    ('still', 0.015057174),
#    ('call', 0.014680906),
#    ('cold', 0.013391599),
#    ('zoom', 0.011110471),
#    ('dance', 0.0099)]],
#  [98,
#   14.742022174012163,
#   [('night', 0.04704274),
#    ('put', 0.0250068),
#    ('need', 0.017888948),
#    ("'em", 0.012468293),
#    ('new', 0.011560567),
#    ('bad', 0.011096286),
#    ('della', 0.01072171),
#    ('follow', 0.010549609),
#    ('shimmy', 0.009958435),
#    ('lee', 0.009656411)]],
#  [74,
#   14.67769614802637,
#   [('sì', 0.065745845),
#    ('hot', 0.04234014),
#    ('work', 0.041778658),
#    ('home', 0.025550852),
#    ('room', 0.021155758),
#    ('gucci', 0.017914021),
#    ('allora', 0.015652182),
#    ('give', 0.013753315),
#    ('back', 0.010260431),
#    ('worry', 0.009951646)]],
#  [16,
#   14.560262335571679,
#   [('yah', 0.028439738),
#    ('rumor', 0.019114949),
#    ('love', 0.017190551),
#    ('back', 0.016907668),
#    ("can't", 0.014066648),
#    ('chill', 0.013016455),
#    ("let's", 0.011986745),
#    ('sorry', 0.010150496),
#    ('need', 0.010099822),
#    ('let', 0.009616325)]],
#  [66,
#   14.506777952008633,
#   [('boom', 0.05603376),
#    ('love', 0.01825352),
#    ('home', 0.013333194),
#    ('thinking', 0.01227948),
#    ('back', 0.010816285),
#    ('candy', 0.009672),
#    ('night', 0.009453255),
#    ('move', 0.0093199555),
#    ('think', 0.008588634),
#    ('once', 0.008416219)]],
#  [63,
#   14.451293340231132,
#   [('today', 0.019620938),
#    ('ah', 0.018317208),
#    ('girlfriend', 0.013727766),
#    ('love', 0.012167097),
#    ('play', 0.012065029),
#    ('cruel', 0.011410603),
#    ('hey!', 0.011287718),
#    ('take', 0.011058081),
#    ("can't", 0.011038713),
#    ('well', 0.011031374)]],
#  [96,
#   14.42197258289707,
#   [('la-la', 0.019878259),
#    ('news', 0.016411496),
#    ('sorry', 0.016224325),
#    ('home', 0.01401547),
#    ('ice', 0.009543262),
#    ('give', 0.009112594),
#    ('bad', 0.008876448),
#    ('hate', 0.0085240165),
#    ('down', 0.008191018),
#    ('love', 0.0075372765)]],
#  [30,
#   14.391970061516986,
#   [('drunk', 0.23156549),
#    ('sweet', 0.013722219),
#    ('air', 0.010685753),
#    ('end', 0.010263331),
#    ('night', 0.010181703),
#    ('away', 0.009999718),
#    ('home', 0.009851022),
#    ('back', 0.009594443),
#    ('sorry', 0.009546763),
#    ('sick', 0.008341609)]],
#  [42,
#   14.28858882812483,
#   [('child', 0.529462),
#    ('bad', 0.014312775),
#    ('sorry', 0.009959731),
#    ('gee', 0.007947575),
#    ('leave', 0.005028693),
#    ('feel', 0.0049420116),
#    ('upgrade', 0.004890622),
#    ('guy', 0.0043856455),
#    ('boy', 0.00404479),
#    ("let's", 0.0038717557)]],
#  [89,
#   13.850633860090966,
#   [('boom', 0.09240718),
#    ('love', 0.023060221),
#    ('dream', 0.02147024),
#    ('goodbye', 0.015627593),
#    ('ba', 0.015357102),
#    ('home', 0.014514715),
#    ('au', 0.01374836),
#    ('adiós', 0.013695519),
#    ('revoir', 0.013656602),
#    ('prova', 0.013390743)]],
#  [79,
#   13.815534154278794,
#   [('[bleep', 0.030858496),
#    ('aite', 0.027834028),
#    ('[bleep]', 0.020420847),
#    ('pump', 0.018949913),
#    ('bear', 0.01263732),
#    ('teddy', 0.012635942),
#    ('hip', 0.011744753),
#    ('diamond', 0.009983177),
#    ('love', 0.009828105),
#    ('shooting', 0.008924426)]],
#  [27,
#   13.76821289579857,
#   [('home', 0.030241624),
#    ('fire', 0.01945983),
#    ('on!', 0.016258297),
#    ('ooh', 0.014707643),
#    ('anpanman', 0.013789481),
#    ('new', 0.010440144),
#    ("let's", 0.009939312),
#    ('news', 0.008682965),
#    ('am', 0.008057744),
#    ('keep', 0.007727151)]],
#  [8,
#   13.741446932623148,
#   [('last', 0.024786772),
#    ('love', 0.024155105),
#    ('worth', 0.02044323),
#    ('mariachi', 0.0144631155),
#    ('el', 0.014450647),
#    ('(what', 0.0093905935),
#    ('good)', 0.009252832),
#    ('news', 0.009244875),
#    ('dan', 0.008438703),
#    ('loco', 0.008104973)]],
#  [56,
#   13.628162295406582,
#   [('́â', 0.17266646),
#    ('dance', 0.014286587),
#    ('help', 0.013465667),
#    ('yes', 0.010062442),
#    ('feel', 0.009755083),
#    ('me)', 0.00941278),
#    ('(help', 0.009405776),
#    ('take', 0.008864219),
#    ('ole-oh-eh-oh', 0.008168664),
#    ('night', 0.008104185)]],
#  [12,
#   13.498496316717137,
#   [('non', 0.034276806),
#    ('love', 0.023031171),
#    ('run', 0.016879855),
#    ('follow', 0.01569168),
#    ('eyes', 0.014131827),
#    ('light', 0.012228445),
#    ('bang', 0.01075618),
#    ("can't", 0.0103287585),
#    ('heart', 0.010088881),
#    ('beautiful', 0.010001795)]],
#  [24,
#   13.083299021929633,
#   [('back', 0.063243404),
#    ('woo', 0.05829973),
#    ('bull', 0.053361632),
#    ('fire', 0.028725026),
#    ('siren', 0.019420713),
#    ('wow', 0.014459816),
#    ('mariachi', 0.012612276),
#    ('up!', 0.011732962),
#    ('el', 0.011651007),
#    ("we're", 0.010326228)]],
#  [85,
#   12.947586976233652,
#   [('home', 0.058354102),
#    ('caldo', 0.049870674),
#    ('summer', 0.015362801),
#    ('moon', 0.014587112),
#    ('dance', 0.013847947),
#    ('woo', 0.012309965),
#    ('whoo', 0.0120288795),
#    ('sweet', 0.011367634),
#    ('cold', 0.010941578),
#    ('hands', 0.009020627)]],
#  [5,
#   12.770304631454565,
#   [('home', 0.07843423),
#    ('bam', 0.029832143),
#    ('wow!', 0.018684294),
#    ('ti', 0.014126459),
#    ('qui', 0.013870817),
#    ('falling', 0.012807644),
#    ('gno', 0.011959775),
#    ('drunk', 0.011257242),
#    ('head', 0.010567271),
#    ('shut', 0.010077151)]],
#  [60,
#   12.69417763569254,
#   [('best', 0.11334997),
#    ('pop', 0.11281519),
#    ('baby', 0.027982207),
#    ('burn', 0.013625734),
#    ('down', 0.010123409),
#    ('walker', 0.009186124),
#    ('hey!', 0.007767734),
#    ('girl', 0.0074176383),
#    ('share', 0.007275059),
#    ('love', 0.0069119437)]],
#  [29,
#   12.311948204571308,
#   [('work', 0.07742845),
#    ('allora', 0.036556672),
#    ('business', 0.03386591),
#    ('live', 0.025813362),
#    ('love', 0.02121238),
#    ('only', 0.020948745),
#    ('city', 0.018002233),
#    ('let', 0.014576256),
#    ('am', 0.0113207055),
#    ('start', 0.01082228)]],
#  [39,
#   12.251468599652071,
#   [('dan', 0.30746484),
#    ('love', 0.025958179),
#    ('shake', 0.014447619),
#    ('headphones', 0.011618023),
#    ('wild', 0.009894304),
#    ('still', 0.007539305),
#    ('heart', 0.007365626),
#    ('sorry', 0.0071626888),
#    ('boomshakalaka', 0.0071600336),
#    ("can't", 0.0070198355)]],
#  [69,
#   11.797038577557032,
#   [('beep', 0.04443333),
#    ('home', 0.024311947),
#    ('tell', 0.016979713),
#    ('name', 0.0154676605),
#    ('dang', 0.012196977),
#    ('dong', 0.012193042),
#    ('ding', 0.012189892),
#    ('young', 0.009930226),
#    ('way', 0.009674433),
#    ('head', 0.009504029)]],
#  [65,
#   11.397482530965135,
#   [('pop', 0.032374837),
#    ('prova', 0.02672466),
#    ('dreams', 0.013517804),
#    ('dream', 0.013416306),
#    ('yes', 0.009832746),
#    ('baby', 0.009530068),
#    ('let', 0.009337664),
#    ("we're", 0.008417661),
#    ('big', 0.005922715),
#    ('night', 0.005608055)]],
#  [44,
#   11.252060344368147,
#   [('wave', 0.07190029),
#    ('grande', 0.050484907),
#    ('swing', 0.039395787),
#    ('picky', 0.03641766),
#    ('traduzione', 0.018729212),
#    ('shy', 0.017532138),
#    ('thinking', 0.016197424),
#    ('am', 0.0133841345),
#    ('leave', 0.012601483),
#    ('(oh', 0.010301796)]],
#  [1,
#   11.069780918087417,
#   [('night', 0.019154308),
#    ('life', 0.01643308),
#    ('love', 0.012566737),
#    ('home', 0.012518224),
#    ('boys', 0.012313719),
#    ('anpanman', 0.012295506),
#    ('new', 0.011905159),
#    ('still', 0.011557481),
#    ('wussup', 0.0114468),
#    ('man', 0.01137817)]],
#  [92,
#   10.822693639785939,
#   [('sunday', 0.025019996),
#    ('music', 0.01597113),
#    ('real', 0.013790313),
#    ('say', 0.012800722),
#    ('night', 0.011986875),
#    ('share', 0.009419783),
#    ('true', 0.009121162),
#    ('heart', 0.00888952),
#    ('love', 0.008731515),
#    ('domenica', 0.008347428)]],
#  [73,
#   10.590310148954813,
#   [('drunk', 0.27010503),
#    ('singing', 0.10852752),
#    ('bump三', 0.032125108),
#    ('sì', 0.019545516),
#    ('kim', 0.015703304),
#    ('pang', 0.011363085),
#    ('music', 0.009559903),
#    ('love', 0.008702314),
#    ('hello', 0.008364315),
#    ('entertainment', 0.008316542)]],
#  [37,
#   10.561997589948078,
#   [('spicy', 0.03537732),
#    ('heart', 0.022931175),
#    ('sorry', 0.019054443),
#    ('bang', 0.01904978),
#    ('news', 0.01499999),
#    ('tt', 0.014701377),
#    ('baby', 0.013557164),
#    ('joy', 0.00876573),
#    ('home', 0.008185696),
#    ('say', 0.007990433)]],
#  [34,
#   10.52511351339308,
#   [('poppy', 0.090776205),
#    ('love', 0.036058825),
#    ('take', 0.017769989),
#    ('poison', 0.01391739),
#    ('bring', 0.013777275),
#    ('life', 0.013744541),
#    ('tatata', 0.013714152),
#    ('pink', 0.013058262),
#    ('ah', 0.0121137),
#    ('woah', 0.011616823)]],
#  [31,
#   10.430240959691218,
#   [('bop', 0.033118304),
#    ('home', 0.021930182),
#    ('flower', 0.01773906),
#    ('hot', 0.014959344),
#    ("won't", 0.01181915),
#    ('clap', 0.010956208),
#    ('ti', 0.010517741),
#    ('love', 0.010395627),
#    ('hurt', 0.009627927),
#    ('girl', 0.009403187)]],
#  [18,
#   10.344559204188045,
#   [('luv', 0.040192917),
#    ('domino', 0.017950999),
#    ('home', 0.012969797),
#    ('worry', 0.0123957135),
#    ('hey!', 0.011009396),
#    ('keep', 0.009581944),
#    ('room', 0.009053838),
#    ('love', 0.008949396),
#    ('tonight', 0.008146538),
#    ('dynamite', 0.007821336)]],
#  [23,
#   9.873367129514008,
#   [('night', 0.015898487),
#    ('anymore', 0.014013213),
#    ('swan', 0.01399463),
#    ('end', 0.011827116),
#    ('solo', 0.011279071),
#    ('dragon', 0.011244341),
#    ('love', 0.01051846),
#    ('dream', 0.007660113),
#    ('way', 0.0076407096),
#    ('child', 0.007515946)]],
#  [99,
#   9.707153405026475,
#   [('rende', 0.27943),
#    ('woo', 0.026563538),
#    ('́â', 0.020632494),
#    ('say', 0.019326964),
#    ('(eh-oh)', 0.016849348),
#    ('kick', 0.01466721),
#    ("can't", 0.012153877),
#    ('rain', 0.011763625),
#    ('sorry', 0.011032897),
#    ('hey!', 0.008574779)]],
#  [49,
#   9.669419726606066,
#   [('rumor', 0.027935725),
#    ("let's", 0.016543161),
#    ('la-la-la-la-la', 0.014345653),
#    ('let', 0.013747152),
#    ('say', 0.013385601),
#    ('di', 0.012998783),
#    ('pum', 0.012366554),
#    ('believer', 0.011953649),
#    ('love', 0.011197025),
#    ('tell', 0.010471925)]],
#  [54,
#   9.626749279870637,
#   [('money', 0.031405568),
#    ('baby', 0.027244745),
#    ('dun', 0.01296881),
#    ('bills', 0.012751957),
#    ("dolla's", 0.012663661),
#    ('tonight', 0.01255244),
#    ('drop', 0.010478953),
#    ('clover', 0.01014211),
#    ('new', 0.010115022),
#    ('girl', 0.009109461)]],
#  [77,
#   9.422792955764635,
#   [('singing', 0.35616028),
#    ('sì', 0.044218812),
#    ('alli-alli-alli-alligator', 0.012588368),
#    ('love', 0.0120876385),
#    ('feel', 0.009820381),
#    ('trauma', 0.009319098),
#    ('power', 0.008387879),
#    ('woo', 0.0080012195),
#    ('ministry', 0.007749929),
#    ('back', 0.0065855114)]],
#  [6,
#   9.324142489387668,
#   [('significa', 0.20171717),
#    ('best', 0.04868715),
#    ('feel', 0.01712575),
#    ('(you', 0.013344943),
#    ('tell', 0.009832914),
#    ('rush)', 0.009823713),
#    ('love', 0.009629834),
#    ('la-la', 0.009538505),
#    ('eyes', 0.008787619),
#    ('home', 0.008105159)]],
#  [93,
#   9.290340178005408,
#   [('drunk', 0.32196745),
#    ('home', 0.052490886),
#    ('shut', 0.01153504),
#    ('god', 0.008450634),
#    ('love', 0.008288853),
#    ('on!', 0.007958634),
#    ('whoo', 0.0065948498),
#    ('heart', 0.0063012317),
#    ('man', 0.00564038),
#    ('sorry', 0.0053891987)]],
#  [61,
#   8.49750545364941,
#   [('child', 0.47804928),
#    ('fun', 0.010626237),
#    ('ok', 0.0076657035),
#    ('sorry', 0.0070935874),
#    ('light', 0.006989395),
#    ('wants', 0.005473366),
#    ('gee', 0.005189109),
#    ('bhubaneswar', 0.005049773),
#    ('little', 0.0050075185),
#    ('puri', 0.004894411)]],
#  [14,
#   7.8612524380532705,
#   [('deep', 0.02292794),
#    ('night', 0.019093098),
#    ('yes', 0.0165558),
#    ('am', 0.01647405),
#    ('contact', 0.014758141),
#    ('blame', 0.0131443115),
#    ('woah', 0.011695645),
#    ('dynamite', 0.010781388),
#    ('life', 0.008303548),
#    ('baraba', 0.008239836)]],
#  [9,
#   7.551441595929646,
#   [('cake', 0.635276),
#    ('singing', 0.035392083),
#    ('follow', 0.020645544),
#    ('sì', 0.00730549),
#    ('today', 0.00587797),
#    ('yes', 0.0056750593),
#    ('trust', 0.004331992),
#    ('(again)', 0.0037791317),
#    ('pie', 0.0035155893),
#    ('up!', 0.0028037662)]]]

# %% [markdown]
# ### Emotion analysis
# Emotions:
# fear
# anger
# anticipation
# trust
# surprise
# positive
# negative
# sadness
# disgust
# joy

# %%
import numpy as np

# %%
labels = [
    "anger",
    "anticipation",
    "disgust",
    "fear",
    "joy",
    "sadness",
    "surprise",	
    "trust",
    "negative",	
    "positive",
]

emotions = [
    "anger",
    "anticipation",
    "disgust",
    "fear",
    "joy",
    "sadness",
    "surprise",	
    "trust",
]

sentiments = [
    "negative",	
    "positive",
]

# %%
df_nrc = pd.read_csv("NRC.txt", sep="\t", names=["word", "label", "amount"])

words_to_labels = {}

for _, row in df_nrc.iterrows():
    words_to_labels[row["word"]] = words_to_labels.get(row["word"], np.zeros((10, 1)))
    words_to_labels[row["word"]][labels.index(row["label"])] = row["amount"]

# %%
df_label = df.copy()
for label in labels:
    df_label[label] = 0

# %%
for cnt in range(len(df)):
    lyrics = df["lyrics"][cnt]

    if type(lyrics) != str:
        continue

    label_this = np.zeros((10, 1))

    for word in lyrics.split():
        if word in words_to_labels:
            label_this += words_to_labels[word]
            
    emotion_this = label_this[:8]
    sentiment_this = label_this[8:]
            
    if np.linalg.norm(emotion_this) != 0:
        emotion_this /= np.linalg.norm(emotion_this)
        
    if np.linalg.norm(sentiment_this) != 0:
        sentiment_this /= np.linalg.norm(sentiment_this)
        
    label_this = np.concatenate((emotion_this, sentiment_this), axis=None)
    
    for label in labels:
        df_label[label][cnt] = label_this[labels.index(label)]
# Out:
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0810361063877192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5510455234364905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.03241444255508768' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.0810361063877192' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5834599659915782' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.01620722127754384' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.5510455234364905' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.1944866553305261' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.17888543819998318' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_label[label][cnt] = label_this[labels.index(label)]
# C:\Users\Hiyoko\AppData\Local\Temp\ipykernel_16024\3885107406.py:25: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.9838699100999074' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df_label[label][cnt] = label_this[labels.index(label)]

# %%
df_emotion_global = df_label[df_label["grouping"].isin(global_group)]
mean_emotion_global = df_emotion_global[emotions].mean()
normalized_mean_emotion_global = mean_emotion_global / np.linalg.norm(mean_emotion_global)
mean_sentiment_global = df_emotion_global[sentiments].mean()
normalized_mean_sentiment_global = mean_sentiment_global / np.linalg.norm(mean_sentiment_global)

df_emotion_kpop = df_label[df_label["grouping"].isin(kpop_group)]
mean_emotion_kpop = df_emotion_kpop[emotions].mean()
normalized_mean_emotion_kpop = mean_emotion_kpop / np.linalg.norm(mean_emotion_kpop)
mean_sentiment_kpop = df_emotion_kpop[sentiments].mean()
normalized_mean_sentiment_kpop = mean_sentiment_kpop / np.linalg.norm(mean_sentiment_kpop)

df_emotion_target = df_label[df_label["grouping"] == target_group]
mean_emotion_target = df_emotion_target[emotions].mean()
normalized_mean_emotion_target = mean_emotion_target / np.linalg.norm(mean_emotion_target)
mean_sentiment_target = df_emotion_target[sentiments].mean()
normalized_mean_sentiment_target = mean_sentiment_target / np.linalg.norm(mean_sentiment_target)

# %%
normalized_mean_emotion_target
# Out:
# anger           0.222068
# anticipation    0.455881
# disgust         0.139562
# fear            0.295598
# joy             0.575365
# sadness         0.316116
# surprise        0.236113
# trust           0.386367
# dtype: float64

# %%
normalized_mean_sentiment_target
# Out:
# negative    0.509892
# positive    0.860239
# dtype: float64

# %% [markdown]
# against global

# %%
emotion_percentage_global = (normalized_mean_emotion_target - normalized_mean_emotion_global) / normalized_mean_emotion_global * 100

emotion_percentage_global
# Out:
# anger          -26.219371
# anticipation    10.661093
# disgust        -28.193399
# fear           -10.843759
# joy             16.307583
# sadness        -13.957481
# surprise        -0.207739
# trust           -2.276086
# dtype: float64

# %%
sentiment_percentage_global = (normalized_mean_sentiment_target - normalized_mean_sentiment_global) / normalized_mean_sentiment_global * 100

sentiment_percentage_global
# Out:
# negative   -22.252934
# positive    13.953220
# dtype: float64

# %% [markdown]
# against KPOP

# %%
emotion_percentage_kpop = (normalized_mean_emotion_target - normalized_mean_emotion_kpop) / normalized_mean_emotion_kpop * 100

emotion_percentage_kpop
# Out:
# anger           0.0
# anticipation    0.0
# disgust         0.0
# fear            0.0
# joy             0.0
# sadness         0.0
# surprise        0.0
# trust           0.0
# dtype: float64

# %%
sentiment_percentage_kpop = (normalized_mean_sentiment_target - normalized_mean_sentiment_kpop) / normalized_mean_sentiment_kpop * 100

sentiment_percentage_kpop
# Out:
# negative    0.0
# positive    0.0
# dtype: float64

# %% [markdown]
# ## Save Data

# %%
# to float
for _sum in lda_summer_global:
    _sum[2] = [(tup[0], float(tup[1])) for tup in _sum[2]]
    
for _sum in lda_summer_kpop:
    _sum[2] = [(tup[0], float(tup[1])) for tup in _sum[2]]
    
for count in lda_counter_global:
    count[2] = [(tup[0], float(tup[1])) for tup in count[2]]

for count in lda_counter_kpop:
    count[2] = [(tup[0], float(tup[1])) for tup in count[2]]

# %%
json_data = {
    "tfidf_counter_global": tfidf_counter_global,
    "tfidf_summer_global": tfidf_summer_global,
    "tfidf_counter_kpop": tfidf_counter_kpop,
    "tfidf_summer_kpop": tfidf_summer_kpop,
    "lda_counter_global": lda_counter_global,
    "lda_summer_global": lda_summer_global,
    "lda_counter_kpop": lda_counter_kpop,
    "lda_summer_kpop": lda_summer_kpop,
    "lda_html_global": lda_html_global,
    "lda_html_kpop": lda_html_kpop,
    "normalized_mean_emotion_target": normalized_mean_emotion_target.astype(float).tolist(),
    "normalized_mean_sentiment_target": normalized_mean_sentiment_target.astype(float).tolist(),
    "emotion_percentage_global": emotion_percentage_global.astype(float).tolist(),
    "sentiment_percentage_global": sentiment_percentage_global.astype(float).tolist(),
    "emotion_percentage_kpop": emotion_percentage_kpop.astype(float).tolist(),
    "sentiment_percentage_kpop": sentiment_percentage_kpop.astype(float).tolist(),
}

# %%
import json
with open("data_"+ target_group +".json", "w") as f:
    json.dump(json_data, f)
